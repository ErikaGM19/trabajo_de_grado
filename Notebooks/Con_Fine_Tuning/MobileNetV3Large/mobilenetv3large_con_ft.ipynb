# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = 'mobilenetv3large_con_ft'

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# DATA AUGMENTATION — IGUAL EN TODOS LOS MODELOS
train_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO MOBILENETV3LARGE

# %%
# CARGAR MOBILENETV3LARGE CON PESOS DE IMAGENET
base_model = MobileNetV3Large(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPAS FINALES PERSONALIZADAS
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "mobilenetv3large_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3large (Functiona  (None, 7, 7, 960)        2996352
#  l)
#
#  global_average_pooling2d (G  (None, 960)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               123008
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,120,650
# Trainable params: 124,298
# Non-trainable params: 2,996,352
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.9709 - accuracy: 0.6898
# Epoch 1: val_loss improved from inf to 0.31909, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 174s 902ms/step - loss: 0.9709 - accuracy: 0.6898 - val_loss: 0.3191 - val_accuracy: 0.9197 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4265 - accuracy: 0.8737
# Epoch 2: val_loss improved from 0.31909 to 0.24021, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 184s 965ms/step - loss: 0.4265 - accuracy: 0.8737 - val_loss: 0.2402 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.9022
# Epoch 3: val_loss improved from 0.24021 to 0.19470, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 160s 837ms/step - loss: 0.3317 - accuracy: 0.9022 - val_loss: 0.1947 - val_accuracy: 0.9411 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2872 - accuracy: 0.9160
# Epoch 4: val_loss improved from 0.19470 to 0.17595, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 167s 876ms/step - loss: 0.2872 - accuracy: 0.9160 - val_loss: 0.1760 - val_accuracy: 0.9503 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.9278
# Epoch 5: val_loss did not improve from 0.17595
# 191/191 [==============================] - 160s 837ms/step - loss: 0.2544 - accuracy: 0.9278 - val_loss: 0.1760 - val_accuracy: 0.9518 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2278 - accuracy: 0.9315
# Epoch 6: val_loss did not improve from 0.17595
# 191/191 [==============================] - 162s 846ms/step - loss: 0.2278 - accuracy: 0.9315 - val_loss: 0.2017 - val_accuracy: 0.9434 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2204 - accuracy: 0.9369
# Epoch 7: val_loss improved from 0.17595 to 0.15221, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 158s 826ms/step - loss: 0.2204 - accuracy: 0.9369 - val_loss: 0.1522 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2161 - accuracy: 0.9391
# Epoch 8: val_loss did not improve from 0.15221
# 191/191 [==============================] - 158s 825ms/step - loss: 0.2161 - accuracy: 0.9391 - val_loss: 0.1645 - val_accuracy: 0.9549 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1946 - accuracy: 0.9473
# Epoch 9: val_loss did not improve from 0.15221
# 191/191 [==============================] - 157s 821ms/step - loss: 0.1946 - accuracy: 0.9473 - val_loss: 0.1533 - val_accuracy: 0.9564 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2092 - accuracy: 0.9448
# Epoch 10: val_loss improved from 0.15221 to 0.14148, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 158s 826ms/step - loss: 0.2092 - accuracy: 0.9448 - val_loss: 0.1415 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1899 - accuracy: 0.9496
# Epoch 11: val_loss improved from 0.14148 to 0.13202, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 157s 824ms/step - loss: 0.1899 - accuracy: 0.9496 - val_loss: 0.1320 - val_accuracy: 0.9702 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1755 - accuracy: 0.9525
# Epoch 12: val_loss did not improve from 0.13202
# 191/191 [==============================] - 158s 826ms/step - loss: 0.1755 - accuracy: 0.9525 - val_loss: 0.1752 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1781 - accuracy: 0.9522
# Epoch 13: val_loss did not improve from 0.13202
# 191/191 [==============================] - 158s 825ms/step - loss: 0.1781 - accuracy: 0.9522 - val_loss: 0.1368 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1721 - accuracy: 0.9527
# Epoch 14: val_loss did not improve from 0.13202
# 191/191 [==============================] - 157s 820ms/step - loss: 0.1721 - accuracy: 0.9527 - val_loss: 0.1327 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9630
# Epoch 15: val_loss improved from 0.13202 to 0.12611, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 158s 827ms/step - loss: 0.1567 - accuracy: 0.9630 - val_loss: 0.1261 - val_accuracy: 0.9732 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 0.9573
# Epoch 16: val_loss did not improve from 0.12611
# 191/191 [==============================] - 157s 820ms/step - loss: 0.1683 - accuracy: 0.9573 - val_loss: 0.1460 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.9546
# Epoch 17: val_loss improved from 0.12611 to 0.12493, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 158s 827ms/step - loss: 0.1660 - accuracy: 0.9546 - val_loss: 0.1249 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.9553
# Epoch 18: val_loss did not improve from 0.12493
# 191/191 [==============================] - 157s 823ms/step - loss: 0.1704 - accuracy: 0.9553 - val_loss: 0.1313 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9587
# Epoch 19: val_loss improved from 0.12493 to 0.12260, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 157s 822ms/step - loss: 0.1598 - accuracy: 0.9587 - val_loss: 0.1226 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9622
# Epoch 20: val_loss improved from 0.12260 to 0.12031, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 158s 826ms/step - loss: 0.1495 - accuracy: 0.9622 - val_loss: 0.1203 - val_accuracy: 0.9732 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9632
# Epoch 21: val_loss did not improve from 0.12031
# 191/191 [==============================] - 159s 830ms/step - loss: 0.1550 - accuracy: 0.9632 - val_loss: 0.1391 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1610 - accuracy: 0.9625
# Epoch 22: val_loss did not improve from 0.12031
# 191/191 [==============================] - 157s 824ms/step - loss: 0.1610 - accuracy: 0.9625 - val_loss: 0.1302 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1588 - accuracy: 0.9592
# Epoch 23: val_loss did not improve from 0.12031
# 191/191 [==============================] - 160s 838ms/step - loss: 0.1588 - accuracy: 0.9592 - val_loss: 0.1305 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.9618
# Epoch 24: val_loss did not improve from 0.12031
# 191/191 [==============================] - 158s 826ms/step - loss: 0.1568 - accuracy: 0.9618 - val_loss: 0.1225 - val_accuracy: 0.9740 - lr: 0.0010
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9638
# Epoch 25: val_loss did not improve from 0.12031
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 158s 829ms/step - loss: 0.1550 - accuracy: 0.9638 - val_loss: 0.1253 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9725
# Epoch 26: val_loss did not improve from 0.12031
# 191/191 [==============================] - 158s 827ms/step - loss: 0.1265 - accuracy: 0.9725 - val_loss: 0.1331 - val_accuracy: 0.9687 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1280 - accuracy: 0.9720
# Epoch 27: val_loss improved from 0.12031 to 0.11702, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 156s 816ms/step - loss: 0.1280 - accuracy: 0.9720 - val_loss: 0.1170 - val_accuracy: 0.9717 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9740
# Epoch 28: val_loss did not improve from 0.11702
# 191/191 [==============================] - 158s 830ms/step - loss: 0.1221 - accuracy: 0.9740 - val_loss: 0.1353 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9720
# Epoch 29: val_loss did not improve from 0.11702
# 191/191 [==============================] - 159s 832ms/step - loss: 0.1285 - accuracy: 0.9720 - val_loss: 0.1216 - val_accuracy: 0.9725 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9712
# Epoch 30: val_loss did not improve from 0.11702
# 191/191 [==============================] - 157s 822ms/step - loss: 0.1236 - accuracy: 0.9712 - val_loss: 0.1451 - val_accuracy: 0.9633 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1238 - accuracy: 0.9738
# Epoch 31: val_loss did not improve from 0.11702
# 191/191 [==============================] - 158s 825ms/step - loss: 0.1238 - accuracy: 0.9738 - val_loss: 0.1207 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9769
# Epoch 32: val_loss improved from 0.11702 to 0.11129, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 157s 820ms/step - loss: 0.1114 - accuracy: 0.9769 - val_loss: 0.1113 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1138 - accuracy: 0.9749
# Epoch 33: val_loss did not improve from 0.11129
# 191/191 [==============================] - 158s 826ms/step - loss: 0.1138 - accuracy: 0.9749 - val_loss: 0.1217 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9723
# Epoch 34: val_loss did not improve from 0.11129
# 191/191 [==============================] - 158s 828ms/step - loss: 0.1233 - accuracy: 0.9723 - val_loss: 0.1217 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9761
# Epoch 35: val_loss did not improve from 0.11129
# 191/191 [==============================] - 157s 823ms/step - loss: 0.1145 - accuracy: 0.9761 - val_loss: 0.1317 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9785
# Epoch 36: val_loss did not improve from 0.11129
# 191/191 [==============================] - 157s 822ms/step - loss: 0.1044 - accuracy: 0.9785 - val_loss: 0.1302 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9763
# Epoch 37: val_loss did not improve from 0.11129
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 157s 822ms/step - loss: 0.1101 - accuracy: 0.9763 - val_loss: 0.1121 - val_accuracy: 0.9725 - lr: 5.0000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1109 - accuracy: 0.9777
# Epoch 38: val_loss did not improve from 0.11129
# 191/191 [==============================] - 157s 820ms/step - loss: 0.1109 - accuracy: 0.9777 - val_loss: 0.1118 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9787
# Epoch 39: val_loss did not improve from 0.11129
# 191/191 [==============================] - 158s 825ms/step - loss: 0.1040 - accuracy: 0.9787 - val_loss: 0.1210 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9777
# Epoch 40: val_loss did not improve from 0.11129
# 191/191 [==============================] - 158s 827ms/step - loss: 0.1043 - accuracy: 0.9777 - val_loss: 0.1185 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9782
# Epoch 41: val_loss improved from 0.11129 to 0.10966, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 157s 823ms/step - loss: 0.1042 - accuracy: 0.9782 - val_loss: 0.1097 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9787
# Epoch 42: val_loss did not improve from 0.10966
# 191/191 [==============================] - 159s 831ms/step - loss: 0.1034 - accuracy: 0.9787 - val_loss: 0.1121 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0944 - accuracy: 0.9817
# Epoch 43: val_loss improved from 0.10966 to 0.10892, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 162s 848ms/step - loss: 0.0944 - accuracy: 0.9817 - val_loss: 0.1089 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9800
# Epoch 44: val_loss improved from 0.10892 to 0.10849, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 188s 986ms/step - loss: 0.0998 - accuracy: 0.9800 - val_loss: 0.1085 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9838
# Epoch 45: val_loss improved from 0.10849 to 0.10624, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 188s 983ms/step - loss: 0.0890 - accuracy: 0.9838 - val_loss: 0.1062 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0950 - accuracy: 0.9817
# Epoch 46: val_loss did not improve from 0.10624
# 191/191 [==============================] - 185s 967ms/step - loss: 0.0950 - accuracy: 0.9817 - val_loss: 0.1098 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9799
# Epoch 47: val_loss did not improve from 0.10624
# 191/191 [==============================] - 188s 984ms/step - loss: 0.0968 - accuracy: 0.9799 - val_loss: 0.1134 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9825
# Epoch 48: val_loss did not improve from 0.10624
# 191/191 [==============================] - 179s 935ms/step - loss: 0.0916 - accuracy: 0.9825 - val_loss: 0.1065 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9808
# Epoch 49: val_loss did not improve from 0.10624
# 191/191 [==============================] - 171s 893ms/step - loss: 0.0991 - accuracy: 0.9808 - val_loss: 0.1084 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9785
# Epoch 50: val_loss did not improve from 0.10624
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 169s 886ms/step - loss: 0.0985 - accuracy: 0.9785 - val_loss: 0.1171 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0904 - accuracy: 0.9813
# Epoch 51: val_loss improved from 0.10624 to 0.10577, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 153s 798ms/step - loss: 0.0904 - accuracy: 0.9813 - val_loss: 0.1058 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9853
# Epoch 52: val_loss did not improve from 0.10577
# 191/191 [==============================] - 148s 774ms/step - loss: 0.0884 - accuracy: 0.9853 - val_loss: 0.1070 - val_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0864 - accuracy: 0.9828
# Epoch 53: val_loss did not improve from 0.10577
# 191/191 [==============================] - 149s 778ms/step - loss: 0.0864 - accuracy: 0.9828 - val_loss: 0.1084 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9818
# Epoch 54: val_loss did not improve from 0.10577
# 191/191 [==============================] - 148s 774ms/step - loss: 0.0910 - accuracy: 0.9818 - val_loss: 0.1072 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0888 - accuracy: 0.9828
# Epoch 55: val_loss did not improve from 0.10577
# 191/191 [==============================] - 153s 802ms/step - loss: 0.0888 - accuracy: 0.9828 - val_loss: 0.1060 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 56/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9812
# Epoch 56: val_loss improved from 0.10577 to 0.10111, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 151s 791ms/step - loss: 0.0937 - accuracy: 0.9812 - val_loss: 0.1011 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 57/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9833
# Epoch 57: val_loss did not improve from 0.10111
# 191/191 [==============================] - 155s 813ms/step - loss: 0.0853 - accuracy: 0.9833 - val_loss: 0.1053 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 58/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9838
# Epoch 58: val_loss did not improve from 0.10111
# 191/191 [==============================] - 157s 824ms/step - loss: 0.0863 - accuracy: 0.9838 - val_loss: 0.1074 - val_accuracy: 0.9725 - lr: 1.2500e-04
# Epoch 59/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0854 - accuracy: 0.9854
# Epoch 59: val_loss improved from 0.10111 to 0.09930, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 157s 823ms/step - loss: 0.0854 - accuracy: 0.9854 - val_loss: 0.0993 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 60/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9844
# Epoch 60: val_loss improved from 0.09930 to 0.09845, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 156s 818ms/step - loss: 0.0805 - accuracy: 0.9844 - val_loss: 0.0984 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 61/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9869
# Epoch 61: val_loss improved from 0.09845 to 0.09708, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 156s 814ms/step - loss: 0.0819 - accuracy: 0.9869 - val_loss: 0.0971 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 62/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0854 - accuracy: 0.9828
# Epoch 62: val_loss did not improve from 0.09708
# 191/191 [==============================] - 157s 823ms/step - loss: 0.0854 - accuracy: 0.9828 - val_loss: 0.1011 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 63/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9853
# Epoch 63: val_loss improved from 0.09708 to 0.09644, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 156s 816ms/step - loss: 0.0844 - accuracy: 0.9853 - val_loss: 0.0964 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 64/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9846
# Epoch 64: val_loss did not improve from 0.09644
# 191/191 [==============================] - 155s 813ms/step - loss: 0.0834 - accuracy: 0.9846 - val_loss: 0.1011 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 65/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9840
# Epoch 65: val_loss did not improve from 0.09644
# 191/191 [==============================] - 157s 821ms/step - loss: 0.0845 - accuracy: 0.9840 - val_loss: 0.1027 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 66/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9848
# Epoch 66: val_loss improved from 0.09644 to 0.09619, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 155s 812ms/step - loss: 0.0870 - accuracy: 0.9848 - val_loss: 0.0962 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 67/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9862
# Epoch 67: val_loss did not improve from 0.09619
# 191/191 [==============================] - 161s 841ms/step - loss: 0.0794 - accuracy: 0.9862 - val_loss: 0.1107 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 68/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9858
# Epoch 68: val_loss did not improve from 0.09619
# 191/191 [==============================] - 161s 842ms/step - loss: 0.0792 - accuracy: 0.9858 - val_loss: 0.0964 - val_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 69/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9858
# Epoch 69: val_loss did not improve from 0.09619
# 191/191 [==============================] - 157s 822ms/step - loss: 0.0794 - accuracy: 0.9858 - val_loss: 0.1001 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 70/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9830
# Epoch 70: val_loss did not improve from 0.09619
# 191/191 [==============================] - 158s 829ms/step - loss: 0.0855 - accuracy: 0.9830 - val_loss: 0.1022 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 71/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.9864
# Epoch 71: val_loss did not improve from 0.09619
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 160s 836ms/step - loss: 0.0799 - accuracy: 0.9864 - val_loss: 0.0994 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 72/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9856
# Epoch 72: val_loss did not improve from 0.09619
# 191/191 [==============================] - 160s 839ms/step - loss: 0.0758 - accuracy: 0.9856 - val_loss: 0.0996 - val_accuracy: 0.9778 - lr: 6.2500e-05
# Epoch 73/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9867
# Epoch 73: val_loss did not improve from 0.09619
# 191/191 [==============================] - 158s 825ms/step - loss: 0.0760 - accuracy: 0.9867 - val_loss: 0.1003 - val_accuracy: 0.9748 - lr: 6.2500e-05
# Epoch 74/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9859
# Epoch 74: val_loss did not improve from 0.09619
# 191/191 [==============================] - 152s 794ms/step - loss: 0.0819 - accuracy: 0.9859 - val_loss: 0.0967 - val_accuracy: 0.9755 - lr: 6.2500e-05
# Epoch 75/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0789 - accuracy: 0.9848
# Epoch 75: val_loss did not improve from 0.09619
# 191/191 [==============================] - 152s 795ms/step - loss: 0.0789 - accuracy: 0.9848 - val_loss: 0.1012 - val_accuracy: 0.9740 - lr: 6.2500e-05
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9801

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10, igual en todos los modelos
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    min_lr=1e-7,
    verbose=1
)

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 263
# Capas congeladas         : 233
# Capas descongeladas      : 30
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9854
# Epoch 1: val_loss improved from inf to 0.09998, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 153s 802ms/step - loss: 0.0793 - accuracy: 0.9854 - val_loss: 0.1000 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0802 - accuracy: 0.9831
# Epoch 2: val_loss improved from 0.09998 to 0.09925, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 152s 795ms/step - loss: 0.0802 - accuracy: 0.9831 - val_loss: 0.0992 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0810 - accuracy: 0.9858
# Epoch 3: val_loss did not improve from 0.09925
# 191/191 [==============================] - 151s 791ms/step - loss: 0.0810 - accuracy: 0.9858 - val_loss: 0.0997 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 0.9866
# Epoch 4: val_loss improved from 0.09925 to 0.09858, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 153s 799ms/step - loss: 0.0766 - accuracy: 0.9866 - val_loss: 0.0986 - val_accuracy: 0.9717 - lr: 1.0000e-05
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.9869
# Epoch 5: val_loss did not improve from 0.09858
# 191/191 [==============================] - 158s 830ms/step - loss: 0.0765 - accuracy: 0.9869 - val_loss: 0.0988 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9887
# Epoch 6: val_loss improved from 0.09858 to 0.09845, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 155s 810ms/step - loss: 0.0733 - accuracy: 0.9887 - val_loss: 0.0985 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.9849
# Epoch 7: val_loss improved from 0.09845 to 0.09780, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 155s 812ms/step - loss: 0.0814 - accuracy: 0.9849 - val_loss: 0.0978 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9866
# Epoch 8: val_loss improved from 0.09780 to 0.09728, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 156s 818ms/step - loss: 0.0806 - accuracy: 0.9866 - val_loss: 0.0973 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9876
# Epoch 9: val_loss did not improve from 0.09728
# 191/191 [==============================] - 155s 810ms/step - loss: 0.0755 - accuracy: 0.9876 - val_loss: 0.0976 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9864
# Epoch 10: val_loss did not improve from 0.09728
# 191/191 [==============================] - 157s 824ms/step - loss: 0.0785 - accuracy: 0.9864 - val_loss: 0.0986 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9874
# Epoch 11: val_loss did not improve from 0.09728
# 191/191 [==============================] - 161s 843ms/step - loss: 0.0770 - accuracy: 0.9874 - val_loss: 0.0991 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9862
# Epoch 12: val_loss did not improve from 0.09728
# 191/191 [==============================] - 158s 825ms/step - loss: 0.0781 - accuracy: 0.9862 - val_loss: 0.0985 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0751 - accuracy: 0.9887
# Epoch 13: val_loss did not improve from 0.09728
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 157s 823ms/step - loss: 0.0751 - accuracy: 0.9887 - val_loss: 0.0987 - val_accuracy: 0.9755 - lr: 1.0000e-05
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9889
# Epoch 14: val_loss did not improve from 0.09728
# 191/191 [==============================] - 156s 814ms/step - loss: 0.0699 - accuracy: 0.9889 - val_loss: 0.0982 - val_accuracy: 0.9755 - lr: 5.0000e-06
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9846
# Epoch 15: val_loss did not improve from 0.09728
# 191/191 [==============================] - 160s 836ms/step - loss: 0.0790 - accuracy: 0.9846 - val_loss: 0.0983 - val_accuracy: 0.9755 - lr: 5.0000e-06
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9848
# Epoch 16: val_loss did not improve from 0.09728
# 191/191 [==============================] - 158s 827ms/step - loss: 0.0798 - accuracy: 0.9848 - val_loss: 0.0980 - val_accuracy: 0.9771 - lr: 5.0000e-06
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9892
# Epoch 17: val_loss did not improve from 0.09728
# 191/191 [==============================] - 157s 822ms/step - loss: 0.0711 - accuracy: 0.9892 - val_loss: 0.0983 - val_accuracy: 0.9755 - lr: 5.0000e-06
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9856Restoring model weights from the end of the best epoch: 8.
#
# Epoch 18: val_loss did not improve from 0.09728
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 191/191 [==============================] - 157s 821ms/step - loss: 0.0805 - accuracy: 0.9856 - val_loss: 0.0977 - val_accuracy: 0.9755 - lr: 5.0000e-06
# Epoch 18: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9771

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9801
# Fase 2 — mejor val_accuracy: 0.9771

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 21s 521ms/step - loss: 0.0953 - accuracy: 0.9847
#
# Test Accuracy : 0.9847
# Test Loss     : 0.0953
# 41/41 [==============================] - 21s 501ms/step
# F1 Score      : 0.9847
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     1.0000    0.9933    0.9967       150
#    mancha_anillo     1.0000    1.0000    1.0000       105
#     mancha_parda     0.9800    0.9800    0.9800       150
#          mosaico     1.0000    0.9667    0.9831       150
#      muermo_rojo     0.9613    0.9933    0.9770       150
#             roya     0.9792    0.9400    0.9592       150
#            sanas     0.9494    1.0000    0.9740       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     1.0000    0.9933    0.9967       150
#
#         accuracy                         0.9847      1308
#        macro avg     0.9870    0.9867    0.9867      1308
#     weighted avg     0.9851    0.9847    0.9847      1308
#
#
# Resultados guardados en mobilenetv3large_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]
class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 5 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]
print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]
    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()
    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9, color='red'
        )
        axes[j].axis('off')
    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')
    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14, fontweight='bold', y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#   roya → muermo_rojo: 6 imágenes
#
# Total de imágenes a mostrar: 6

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: mobilenetv3large_con_ft_weights.h5
