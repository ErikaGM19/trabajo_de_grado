# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
NUM_CLASSES   = 10
NOMBRE_MODELO = 'mobilenetv3large_con_ft'

# Fase 1: Congelación de capas
PATIENCE_ES_F1  = 10
PATIENCE_LR_F1  = 5

# Fase 2: Descongelación de capas
PATIENCE_ES_F2  = 15
PATIENCE_LR_F2  = 8

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# DATA AUGMENTATION — IGUAL EN TODOS LOS MODELOS
train_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO MOBILENETV3LARGE

# %%
# CARGAR MOBILENETV3LARGE CON PESOS DE IMAGENET
base_model = MobileNetV3Large(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPAS FINALES PERSONALIZADAS
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "mobilenetv3large_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3large (Functiona  (None, 7, 7, 960)        2996352
#  l)
#
#  global_average_pooling2d (G  (None, 960)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               123008
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 3,120,650
# Trainable params: 124,298
# Non-trainable params: 2,996,352
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F1,
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F1,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.9141 - accuracy: 0.6960
# Epoch 1: val_loss improved from inf to 0.31384, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 230s 1s/step - loss: 0.9141 - accuracy: 0.6960 - val_loss: 0.3138 - val_accuracy: 0.9243 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4270 - accuracy: 0.8701
# Epoch 2: val_loss improved from 0.31384 to 0.23131, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 225s 1s/step - loss: 0.4270 - accuracy: 0.8701 - val_loss: 0.2313 - val_accuracy: 0.9365 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3275 - accuracy: 0.9030
# Epoch 3: val_loss improved from 0.23131 to 0.20136, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 219s 1s/step - loss: 0.3275 - accuracy: 0.9030 - val_loss: 0.2014 - val_accuracy: 0.9465 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.9155
# Epoch 4: val_loss improved from 0.20136 to 0.19591, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 217s 1s/step - loss: 0.2896 - accuracy: 0.9155 - val_loss: 0.1959 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.9265
# Epoch 5: val_loss improved from 0.19591 to 0.17577, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 225s 1s/step - loss: 0.2588 - accuracy: 0.9265 - val_loss: 0.1758 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2191 - accuracy: 0.9376
# Epoch 6: val_loss improved from 0.17577 to 0.17114, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 218s 1s/step - loss: 0.2191 - accuracy: 0.9376 - val_loss: 0.1711 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2207 - accuracy: 0.9361
# Epoch 7: val_loss improved from 0.17114 to 0.15892, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 218s 1s/step - loss: 0.2207 - accuracy: 0.9361 - val_loss: 0.1589 - val_accuracy: 0.9595 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2193 - accuracy: 0.9379
# Epoch 8: val_loss did not improve from 0.15892
# 191/191 [==============================] - 216s 1s/step - loss: 0.2193 - accuracy: 0.9379 - val_loss: 0.1745 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2049 - accuracy: 0.9443
# Epoch 9: val_loss improved from 0.15892 to 0.14647, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 219s 1s/step - loss: 0.2049 - accuracy: 0.9443 - val_loss: 0.1465 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9496
# Epoch 10: val_loss did not improve from 0.14647
# 191/191 [==============================] - 218s 1s/step - loss: 0.1857 - accuracy: 0.9496 - val_loss: 0.1602 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1882 - accuracy: 0.9492
# Epoch 11: val_loss improved from 0.14647 to 0.14136, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 215s 1s/step - loss: 0.1882 - accuracy: 0.9492 - val_loss: 0.1414 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1637 - accuracy: 0.9564
# Epoch 12: val_loss improved from 0.14136 to 0.13234, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 216s 1s/step - loss: 0.1637 - accuracy: 0.9564 - val_loss: 0.1323 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1735 - accuracy: 0.9550
# Epoch 13: val_loss did not improve from 0.13234
# 191/191 [==============================] - 219s 1s/step - loss: 0.1735 - accuracy: 0.9550 - val_loss: 0.1434 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1759 - accuracy: 0.9507
# Epoch 14: val_loss improved from 0.13234 to 0.12484, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 216s 1s/step - loss: 0.1759 - accuracy: 0.9507 - val_loss: 0.1248 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1756 - accuracy: 0.9522
# Epoch 15: val_loss did not improve from 0.12484
# 191/191 [==============================] - 221s 1s/step - loss: 0.1756 - accuracy: 0.9522 - val_loss: 0.1326 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1750 - accuracy: 0.9545
# Epoch 16: val_loss did not improve from 0.12484
# 191/191 [==============================] - 218s 1s/step - loss: 0.1750 - accuracy: 0.9545 - val_loss: 0.1626 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.9522
# Epoch 17: val_loss did not improve from 0.12484
# 191/191 [==============================] - 219s 1s/step - loss: 0.1784 - accuracy: 0.9522 - val_loss: 0.1375 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1677 - accuracy: 0.9600
# Epoch 18: val_loss did not improve from 0.12484
# 191/191 [==============================] - 218s 1s/step - loss: 0.1677 - accuracy: 0.9600 - val_loss: 0.1516 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1644 - accuracy: 0.9587
# Epoch 19: val_loss did not improve from 0.12484
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 203s 1s/step - loss: 0.1644 - accuracy: 0.9587 - val_loss: 0.1450 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9651
# Epoch 20: val_loss did not improve from 0.12484
# 191/191 [==============================] - 204s 1s/step - loss: 0.1434 - accuracy: 0.9651 - val_loss: 0.1355 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1345 - accuracy: 0.9687
# Epoch 21: val_loss did not improve from 0.12484
# 191/191 [==============================] - 200s 1s/step - loss: 0.1345 - accuracy: 0.9687 - val_loss: 0.1402 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9740
# Epoch 22: val_loss did not improve from 0.12484
# 191/191 [==============================] - 202s 1s/step - loss: 0.1265 - accuracy: 0.9740 - val_loss: 0.1290 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9669
# Epoch 23: val_loss improved from 0.12484 to 0.12311, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 207s 1s/step - loss: 0.1340 - accuracy: 0.9669 - val_loss: 0.1231 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1241 - accuracy: 0.9705
# Epoch 24: val_loss did not improve from 0.12311
# 191/191 [==============================] - 219s 1s/step - loss: 0.1241 - accuracy: 0.9705 - val_loss: 0.1260 - val_accuracy: 0.9687 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1235 - accuracy: 0.9725
# Epoch 25: val_loss did not improve from 0.12311
# 191/191 [==============================] - 207s 1s/step - loss: 0.1235 - accuracy: 0.9725 - val_loss: 0.1231 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9686
# Epoch 26: val_loss did not improve from 0.12311
# 191/191 [==============================] - 206s 1s/step - loss: 0.1279 - accuracy: 0.9686 - val_loss: 0.1278 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1249 - accuracy: 0.9695
# Epoch 27: val_loss improved from 0.12311 to 0.11445, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 203s 1s/step - loss: 0.1249 - accuracy: 0.9695 - val_loss: 0.1145 - val_accuracy: 0.9740 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9717
# Epoch 28: val_loss improved from 0.11445 to 0.11425, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 201s 1s/step - loss: 0.1240 - accuracy: 0.9717 - val_loss: 0.1142 - val_accuracy: 0.9717 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9718
# Epoch 29: val_loss did not improve from 0.11425
# 191/191 [==============================] - 204s 1s/step - loss: 0.1228 - accuracy: 0.9718 - val_loss: 0.1303 - val_accuracy: 0.9687 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1283 - accuracy: 0.9692
# Epoch 30: val_loss did not improve from 0.11425
# 191/191 [==============================] - 207s 1s/step - loss: 0.1283 - accuracy: 0.9692 - val_loss: 0.1367 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1179 - accuracy: 0.9731
# Epoch 31: val_loss did not improve from 0.11425
# 191/191 [==============================] - 211s 1s/step - loss: 0.1179 - accuracy: 0.9731 - val_loss: 0.1263 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9718
# Epoch 32: val_loss did not improve from 0.11425
# 191/191 [==============================] - 206s 1s/step - loss: 0.1207 - accuracy: 0.9718 - val_loss: 0.1356 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1186 - accuracy: 0.9707
# Epoch 33: val_loss did not improve from 0.11425
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 214s 1s/step - loss: 0.1186 - accuracy: 0.9707 - val_loss: 0.1474 - val_accuracy: 0.9625 - lr: 5.0000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9753
# Epoch 34: val_loss did not improve from 0.11425
# 191/191 [==============================] - 208s 1s/step - loss: 0.1122 - accuracy: 0.9753 - val_loss: 0.1217 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1074 - accuracy: 0.9769
# Epoch 35: val_loss improved from 0.11425 to 0.11408, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 209s 1s/step - loss: 0.1074 - accuracy: 0.9769 - val_loss: 0.1141 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9764
# Epoch 36: val_loss did not improve from 0.11408
# 191/191 [==============================] - 208s 1s/step - loss: 0.1042 - accuracy: 0.9764 - val_loss: 0.1170 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 0.9772
# Epoch 37: val_loss did not improve from 0.11408
# 191/191 [==============================] - 208s 1s/step - loss: 0.1078 - accuracy: 0.9772 - val_loss: 0.1202 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0977 - accuracy: 0.9799
# Epoch 38: val_loss did not improve from 0.11408
# 191/191 [==============================] - 207s 1s/step - loss: 0.0977 - accuracy: 0.9799 - val_loss: 0.1159 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9766
# Epoch 39: val_loss improved from 0.11408 to 0.11364, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 209s 1s/step - loss: 0.1041 - accuracy: 0.9766 - val_loss: 0.1136 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9790
# Epoch 40: val_loss did not improve from 0.11364
# 191/191 [==============================] - 211s 1s/step - loss: 0.0957 - accuracy: 0.9790 - val_loss: 0.1188 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9779
# Epoch 41: val_loss improved from 0.11364 to 0.11281, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 207s 1s/step - loss: 0.1012 - accuracy: 0.9779 - val_loss: 0.1128 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9792
# Epoch 42: val_loss did not improve from 0.11281
# 191/191 [==============================] - 211s 1s/step - loss: 0.1024 - accuracy: 0.9792 - val_loss: 0.1160 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9808
# Epoch 43: val_loss did not improve from 0.11281
# 191/191 [==============================] - 205s 1s/step - loss: 0.0937 - accuracy: 0.9808 - val_loss: 0.1246 - val_accuracy: 0.9694 - lr: 2.5000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1058 - accuracy: 0.9774
# Epoch 44: val_loss did not improve from 0.11281
# 191/191 [==============================] - 205s 1s/step - loss: 0.1058 - accuracy: 0.9774 - val_loss: 0.1146 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9812
# Epoch 45: val_loss improved from 0.11281 to 0.10812, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 202s 1s/step - loss: 0.0933 - accuracy: 0.9812 - val_loss: 0.1081 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9794
# Epoch 46: val_loss did not improve from 0.10812
# 191/191 [==============================] - 211s 1s/step - loss: 0.1000 - accuracy: 0.9794 - val_loss: 0.1090 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9792
# Epoch 47: val_loss did not improve from 0.10812
# 191/191 [==============================] - 196s 1s/step - loss: 0.0985 - accuracy: 0.9792 - val_loss: 0.1137 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9825
# Epoch 48: val_loss improved from 0.10812 to 0.10646, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 193s 1s/step - loss: 0.0967 - accuracy: 0.9825 - val_loss: 0.1065 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1004 - accuracy: 0.9790
# Epoch 49: val_loss did not improve from 0.10646
# 191/191 [==============================] - 191s 1s/step - loss: 0.1004 - accuracy: 0.9790 - val_loss: 0.1149 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9815
# Epoch 50: val_loss improved from 0.10646 to 0.10564, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 192s 1s/step - loss: 0.0969 - accuracy: 0.9815 - val_loss: 0.1056 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0979 - accuracy: 0.9800
# Epoch 51: val_loss improved from 0.10564 to 0.10384, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 191s 1s/step - loss: 0.0979 - accuracy: 0.9800 - val_loss: 0.1038 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9803
# Epoch 52: val_loss improved from 0.10384 to 0.10262, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 192s 1s/step - loss: 0.0953 - accuracy: 0.9803 - val_loss: 0.1026 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9807
# Epoch 53: val_loss did not improve from 0.10262
# 191/191 [==============================] - 192s 1s/step - loss: 0.0957 - accuracy: 0.9807 - val_loss: 0.1035 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0895 - accuracy: 0.9805
# Epoch 54: val_loss did not improve from 0.10262
# 191/191 [==============================] - 192s 1s/step - loss: 0.0895 - accuracy: 0.9805 - val_loss: 0.1089 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9787
# Epoch 55: val_loss did not improve from 0.10262
# 191/191 [==============================] - 193s 1s/step - loss: 0.0953 - accuracy: 0.9787 - val_loss: 0.1098 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 56/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9792
# Epoch 56: val_loss did not improve from 0.10262
# 191/191 [==============================] - 192s 1s/step - loss: 0.0956 - accuracy: 0.9792 - val_loss: 0.1122 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 57/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9807
# Epoch 57: val_loss did not improve from 0.10262
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 197s 1s/step - loss: 0.0898 - accuracy: 0.9807 - val_loss: 0.1030 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 58/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9831
# Epoch 58: val_loss did not improve from 0.10262
# 191/191 [==============================] - 194s 1s/step - loss: 0.0878 - accuracy: 0.9831 - val_loss: 0.1074 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 59/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9772
# Epoch 59: val_loss improved from 0.10262 to 0.10175, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 191s 1s/step - loss: 0.0997 - accuracy: 0.9772 - val_loss: 0.1017 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 60/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9846
# Epoch 60: val_loss did not improve from 0.10175
# 191/191 [==============================] - 190s 997ms/step - loss: 0.0804 - accuracy: 0.9846 - val_loss: 0.1033 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 61/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 0.9800
# Epoch 61: val_loss did not improve from 0.10175
# 191/191 [==============================] - 191s 998ms/step - loss: 0.0893 - accuracy: 0.9800 - val_loss: 0.1062 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 62/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9851
# Epoch 62: val_loss did not improve from 0.10175
# 191/191 [==============================] - 191s 1s/step - loss: 0.0798 - accuracy: 0.9851 - val_loss: 0.1058 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 63/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9830
# Epoch 63: val_loss did not improve from 0.10175
# 191/191 [==============================] - 193s 1s/step - loss: 0.0844 - accuracy: 0.9830 - val_loss: 0.1025 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 64/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9841
# Epoch 64: val_loss improved from 0.10175 to 0.09893, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 209s 1s/step - loss: 0.0825 - accuracy: 0.9841 - val_loss: 0.0989 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 65/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0838 - accuracy: 0.9820
# Epoch 65: val_loss did not improve from 0.09893
# 191/191 [==============================] - 199s 1s/step - loss: 0.0838 - accuracy: 0.9820 - val_loss: 0.1060 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 66/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9831
# Epoch 66: val_loss did not improve from 0.09893
# 191/191 [==============================] - 194s 1s/step - loss: 0.0815 - accuracy: 0.9831 - val_loss: 0.1061 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 67/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9828
# Epoch 67: val_loss did not improve from 0.09893
# 191/191 [==============================] - 191s 999ms/step - loss: 0.0824 - accuracy: 0.9828 - val_loss: 0.1031 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 68/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9825
# Epoch 68: val_loss did not improve from 0.09893
# 191/191 [==============================] - 193s 1s/step - loss: 0.0851 - accuracy: 0.9825 - val_loss: 0.1023 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 69/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0842 - accuracy: 0.9841
# Epoch 69: val_loss improved from 0.09893 to 0.09642, saving model to mobilenetv3large_con_ft_fase1_weights.h5
# 191/191 [==============================] - 190s 995ms/step - loss: 0.0842 - accuracy: 0.9841 - val_loss: 0.0964 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 70/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0842 - accuracy: 0.9833
# Epoch 70: val_loss did not improve from 0.09642
# 191/191 [==============================] - 189s 988ms/step - loss: 0.0842 - accuracy: 0.9833 - val_loss: 0.1004 - val_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 71/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9833
# Epoch 71: val_loss did not improve from 0.09642
# 191/191 [==============================] - 189s 989ms/step - loss: 0.0848 - accuracy: 0.9833 - val_loss: 0.1007 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 72/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9833
# Epoch 72: val_loss did not improve from 0.09642
# 191/191 [==============================] - 189s 988ms/step - loss: 0.0815 - accuracy: 0.9833 - val_loss: 0.1034 - val_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 73/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.9840
# Epoch 73: val_loss did not improve from 0.09642
# 191/191 [==============================] - 189s 991ms/step - loss: 0.0799 - accuracy: 0.9840 - val_loss: 0.1022 - val_accuracy: 0.9709 - lr: 1.2500e-04
# Epoch 74/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9854
# Epoch 74: val_loss did not improve from 0.09642
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 188s 984ms/step - loss: 0.0776 - accuracy: 0.9854 - val_loss: 0.1051 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 75/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 0.9840
# Epoch 75: val_loss did not improve from 0.09642
# 191/191 [==============================] - 188s 986ms/step - loss: 0.0807 - accuracy: 0.9840 - val_loss: 0.1053 - val_accuracy: 0.9732 - lr: 6.2500e-05
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9786

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F2,          # = 15, igual en todos los modelos
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F2,
    min_lr=1e-6,
    verbose=1
)

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 263
# Capas congeladas         : 233
# Capas descongeladas      : 30
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9861
# Epoch 1: val_loss improved from inf to 0.10325, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 189s 992ms/step - loss: 0.0817 - accuracy: 0.9861 - val_loss: 0.1033 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9841
# Epoch 2: val_loss improved from 0.10325 to 0.10227, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 189s 990ms/step - loss: 0.0859 - accuracy: 0.9841 - val_loss: 0.1023 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9867
# Epoch 3: val_loss improved from 0.10227 to 0.10181, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 190s 998ms/step - loss: 0.0760 - accuracy: 0.9867 - val_loss: 0.1018 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9862
# Epoch 4: val_loss improved from 0.10181 to 0.10162, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 189s 991ms/step - loss: 0.0798 - accuracy: 0.9862 - val_loss: 0.1016 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9843
# Epoch 5: val_loss did not improve from 0.10162
# 191/191 [==============================] - 190s 995ms/step - loss: 0.0792 - accuracy: 0.9843 - val_loss: 0.1022 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0751 - accuracy: 0.9861
# Epoch 6: val_loss improved from 0.10162 to 0.10150, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 188s 986ms/step - loss: 0.0751 - accuracy: 0.9861 - val_loss: 0.1015 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0766 - accuracy: 0.9848
# Epoch 7: val_loss did not improve from 0.10150
# 191/191 [==============================] - 190s 996ms/step - loss: 0.0766 - accuracy: 0.9848 - val_loss: 0.1021 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9856
# Epoch 8: val_loss did not improve from 0.10150
# 191/191 [==============================] - 188s 985ms/step - loss: 0.0795 - accuracy: 0.9856 - val_loss: 0.1018 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9871
# Epoch 9: val_loss did not improve from 0.10150
# 191/191 [==============================] - 190s 995ms/step - loss: 0.0753 - accuracy: 0.9871 - val_loss: 0.1023 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9861
# Epoch 10: val_loss did not improve from 0.10150
# 191/191 [==============================] - 188s 983ms/step - loss: 0.0782 - accuracy: 0.9861 - val_loss: 0.1019 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0780 - accuracy: 0.9840
# Epoch 11: val_loss did not improve from 0.10150
# 191/191 [==============================] - 189s 991ms/step - loss: 0.0780 - accuracy: 0.9840 - val_loss: 0.1020 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9843
# Epoch 12: val_loss improved from 0.10150 to 0.10140, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 188s 984ms/step - loss: 0.0775 - accuracy: 0.9843 - val_loss: 0.1014 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9853
# Epoch 13: val_loss did not improve from 0.10140
# 191/191 [==============================] - 190s 997ms/step - loss: 0.0767 - accuracy: 0.9853 - val_loss: 0.1020 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9851
# Epoch 14: val_loss did not improve from 0.10140
# 191/191 [==============================] - 189s 989ms/step - loss: 0.0777 - accuracy: 0.9851 - val_loss: 0.1016 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9843
# Epoch 15: val_loss did not improve from 0.10140
# 191/191 [==============================] - 190s 996ms/step - loss: 0.0777 - accuracy: 0.9843 - val_loss: 0.1017 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.9831
# Epoch 16: val_loss did not improve from 0.10140
# 191/191 [==============================] - 188s 983ms/step - loss: 0.0788 - accuracy: 0.9831 - val_loss: 0.1026 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9871
# Epoch 17: val_loss improved from 0.10140 to 0.10111, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 190s 995ms/step - loss: 0.0761 - accuracy: 0.9871 - val_loss: 0.1011 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9862
# Epoch 18: val_loss improved from 0.10111 to 0.10066, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 190s 994ms/step - loss: 0.0745 - accuracy: 0.9862 - val_loss: 0.1007 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9831
# Epoch 19: val_loss improved from 0.10066 to 0.10061, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 190s 995ms/step - loss: 0.0775 - accuracy: 0.9831 - val_loss: 0.1006 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9836
# Epoch 20: val_loss did not improve from 0.10061
# 191/191 [==============================] - 189s 990ms/step - loss: 0.0779 - accuracy: 0.9836 - val_loss: 0.1007 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9858
# Epoch 21: val_loss improved from 0.10061 to 0.10051, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 189s 990ms/step - loss: 0.0736 - accuracy: 0.9858 - val_loss: 0.1005 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9869
# Epoch 22: val_loss improved from 0.10051 to 0.10010, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 190s 998ms/step - loss: 0.0743 - accuracy: 0.9869 - val_loss: 0.1001 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9841
# Epoch 23: val_loss did not improve from 0.10010
# 191/191 [==============================] - 189s 992ms/step - loss: 0.0792 - accuracy: 0.9841 - val_loss: 0.1003 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9864
# Epoch 24: val_loss did not improve from 0.10010
# 191/191 [==============================] - 192s 1s/step - loss: 0.0747 - accuracy: 0.9864 - val_loss: 0.1001 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9864
# Epoch 25: val_loss did not improve from 0.10010
# 191/191 [==============================] - 188s 986ms/step - loss: 0.0725 - accuracy: 0.9864 - val_loss: 0.1006 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9858
# Epoch 26: val_loss did not improve from 0.10010
# 191/191 [==============================] - 190s 993ms/step - loss: 0.0725 - accuracy: 0.9858 - val_loss: 0.1002 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9858
# Epoch 27: val_loss did not improve from 0.10010
# 191/191 [==============================] - 188s 986ms/step - loss: 0.0756 - accuracy: 0.9858 - val_loss: 0.1011 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9866
# Epoch 28: val_loss did not improve from 0.10010
# 191/191 [==============================] - 190s 993ms/step - loss: 0.0777 - accuracy: 0.9866 - val_loss: 0.1006 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.9859
# Epoch 29: val_loss did not improve from 0.10010
# 191/191 [==============================] - 188s 984ms/step - loss: 0.0765 - accuracy: 0.9859 - val_loss: 0.1002 - val_accuracy: 0.9717 - lr: 1.0000e-05
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9858
# Epoch 30: val_loss did not improve from 0.10010
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 189s 987ms/step - loss: 0.0744 - accuracy: 0.9858 - val_loss: 0.1008 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0750 - accuracy: 0.9854
# Epoch 31: val_loss did not improve from 0.10010
# 191/191 [==============================] - 190s 996ms/step - loss: 0.0750 - accuracy: 0.9854 - val_loss: 0.1006 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9854
# Epoch 32: val_loss did not improve from 0.10010
# 191/191 [==============================] - 189s 988ms/step - loss: 0.0790 - accuracy: 0.9854 - val_loss: 0.1010 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0774 - accuracy: 0.9858
# Epoch 33: val_loss did not improve from 0.10010
# 191/191 [==============================] - 190s 993ms/step - loss: 0.0774 - accuracy: 0.9858 - val_loss: 0.1008 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9848
# Epoch 34: val_loss did not improve from 0.10010
# 191/191 [==============================] - 189s 989ms/step - loss: 0.0804 - accuracy: 0.9848 - val_loss: 0.1003 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9872
# Epoch 35: val_loss did not improve from 0.10010
# 191/191 [==============================] - 190s 994ms/step - loss: 0.0775 - accuracy: 0.9872 - val_loss: 0.1005 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9861
# Epoch 36: val_loss did not improve from 0.10010
# 191/191 [==============================] - 188s 985ms/step - loss: 0.0735 - accuracy: 0.9861 - val_loss: 0.1001 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9880
# Epoch 37: val_loss improved from 0.10010 to 0.09985, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 190s 995ms/step - loss: 0.0732 - accuracy: 0.9880 - val_loss: 0.0999 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9853
# Epoch 38: val_loss improved from 0.09985 to 0.09952, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 190s 996ms/step - loss: 0.0749 - accuracy: 0.9853 - val_loss: 0.0995 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9874
# Epoch 39: val_loss did not improve from 0.09952
# 191/191 [==============================] - 190s 994ms/step - loss: 0.0745 - accuracy: 0.9874 - val_loss: 0.0995 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9833
# Epoch 40: val_loss did not improve from 0.09952
# 191/191 [==============================] - 190s 992ms/step - loss: 0.0779 - accuracy: 0.9833 - val_loss: 0.0996 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.9867
# Epoch 41: val_loss did not improve from 0.09952
# 191/191 [==============================] - 189s 988ms/step - loss: 0.0763 - accuracy: 0.9867 - val_loss: 0.0999 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.9862
# Epoch 42: val_loss did not improve from 0.09952
# 191/191 [==============================] - 189s 992ms/step - loss: 0.0763 - accuracy: 0.9862 - val_loss: 0.0999 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9872
# Epoch 43: val_loss did not improve from 0.09952
# 191/191 [==============================] - 190s 993ms/step - loss: 0.0715 - accuracy: 0.9872 - val_loss: 0.0999 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9854
# Epoch 44: val_loss did not improve from 0.09952
# 191/191 [==============================] - 190s 992ms/step - loss: 0.0768 - accuracy: 0.9854 - val_loss: 0.0996 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9866
# Epoch 45: val_loss improved from 0.09952 to 0.09913, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 188s 987ms/step - loss: 0.0775 - accuracy: 0.9866 - val_loss: 0.0991 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9880
# Epoch 46: val_loss did not improve from 0.09913
# 191/191 [==============================] - 190s 994ms/step - loss: 0.0727 - accuracy: 0.9880 - val_loss: 0.0995 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9848
# Epoch 47: val_loss did not improve from 0.09913
# 191/191 [==============================] - 188s 987ms/step - loss: 0.0758 - accuracy: 0.9848 - val_loss: 0.0997 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9838
# Epoch 48: val_loss did not improve from 0.09913
# 191/191 [==============================] - 189s 992ms/step - loss: 0.0795 - accuracy: 0.9838 - val_loss: 0.0996 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9874
# Epoch 49: val_loss did not improve from 0.09913
# 191/191 [==============================] - 188s 983ms/step - loss: 0.0732 - accuracy: 0.9874 - val_loss: 0.0993 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9866
# Epoch 50: val_loss did not improve from 0.09913
# 191/191 [==============================] - 189s 989ms/step - loss: 0.0753 - accuracy: 0.9866 - val_loss: 0.0992 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9854
# Epoch 51: val_loss improved from 0.09913 to 0.09892, saving model to mobilenetv3large_con_ft_weights.h5
# 191/191 [==============================] - 189s 991ms/step - loss: 0.0754 - accuracy: 0.9854 - val_loss: 0.0989 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0772 - accuracy: 0.9862
# Epoch 52: val_loss did not improve from 0.09892
# 191/191 [==============================] - 190s 994ms/step - loss: 0.0772 - accuracy: 0.9862 - val_loss: 0.0994 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9862
# Epoch 53: val_loss did not improve from 0.09892
# 191/191 [==============================] - 189s 992ms/step - loss: 0.0741 - accuracy: 0.9862 - val_loss: 0.0991 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9880
# Epoch 54: val_loss did not improve from 0.09892
# 191/191 [==============================] - 190s 993ms/step - loss: 0.0727 - accuracy: 0.9880 - val_loss: 0.0992 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9861
# Epoch 55: val_loss did not improve from 0.09892
# 191/191 [==============================] - 190s 995ms/step - loss: 0.0732 - accuracy: 0.9861 - val_loss: 0.0997 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 56/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0727 - accuracy: 0.9864
# Epoch 56: val_loss did not improve from 0.09892
# 191/191 [==============================] - 189s 990ms/step - loss: 0.0727 - accuracy: 0.9864 - val_loss: 0.1001 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 57/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9846
# Epoch 57: val_loss did not improve from 0.09892
# 191/191 [==============================] - 190s 995ms/step - loss: 0.0793 - accuracy: 0.9846 - val_loss: 0.1001 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 58/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9861
# Epoch 58: val_loss did not improve from 0.09892
# 191/191 [==============================] - 190s 997ms/step - loss: 0.0764 - accuracy: 0.9861 - val_loss: 0.1002 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 59/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9849
# Epoch 59: val_loss did not improve from 0.09892
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 191/191 [==============================] - 190s 996ms/step - loss: 0.0757 - accuracy: 0.9849 - val_loss: 0.1005 - val_accuracy: 0.9740 - lr: 5.0000e-06
# Epoch 60/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9828
# Epoch 60: val_loss did not improve from 0.09892
# 191/191 [==============================] - 188s 987ms/step - loss: 0.0833 - accuracy: 0.9828 - val_loss: 0.1007 - val_accuracy: 0.9740 - lr: 2.5000e-06
# Epoch 61/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9853
# Epoch 61: val_loss did not improve from 0.09892
# 191/191 [==============================] - 190s 997ms/step - loss: 0.0752 - accuracy: 0.9853 - val_loss: 0.1003 - val_accuracy: 0.9740 - lr: 2.5000e-06
# Epoch 62/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9877
# Epoch 62: val_loss did not improve from 0.09892
# 191/191 [==============================] - 189s 989ms/step - loss: 0.0732 - accuracy: 0.9877 - val_loss: 0.1002 - val_accuracy: 0.9732 - lr: 2.5000e-06
# Epoch 63/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0759 - accuracy: 0.9848
# Epoch 63: val_loss did not improve from 0.09892
# 191/191 [==============================] - 190s 993ms/step - loss: 0.0759 - accuracy: 0.9848 - val_loss: 0.1000 - val_accuracy: 0.9732 - lr: 2.5000e-06
# Epoch 64/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9841
# Epoch 64: val_loss did not improve from 0.09892
# 191/191 [==============================] - 189s 987ms/step - loss: 0.0782 - accuracy: 0.9841 - val_loss: 0.1002 - val_accuracy: 0.9740 - lr: 2.5000e-06
# Epoch 65/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9874
# Epoch 65: val_loss did not improve from 0.09892
# 191/191 [==============================] - 190s 996ms/step - loss: 0.0738 - accuracy: 0.9874 - val_loss: 0.1001 - val_accuracy: 0.9740 - lr: 2.5000e-06
# Epoch 66/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9858Restoring model weights from the end of the best epoch: 51.
#
# Epoch 66: val_loss did not improve from 0.09892
# 191/191 [==============================] - 188s 987ms/step - loss: 0.0781 - accuracy: 0.9858 - val_loss: 0.1001 - val_accuracy: 0.9740 - lr: 2.5000e-06
# Epoch 66: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9740

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9786
# Fase 2 — mejor val_accuracy: 0.9740

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 23s 561ms/step - loss: 0.0962 - accuracy: 0.9824
#
# Test Accuracy : 0.9824
# Test Loss     : 0.0962
# 41/41 [==============================] - 25s 567ms/step
# F1 Score      : 0.9825
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     1.0000    0.9933    0.9967       150
#    mancha_anillo     1.0000    1.0000    1.0000       105
#     mancha_parda     0.9735    0.9800    0.9767       150
#          mosaico     1.0000    0.9533    0.9761       150
#      muermo_rojo     0.9545    0.9800    0.9671       150
#             roya     0.9861    0.9467    0.9660       150
#            sanas     0.9375    1.0000    0.9677       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     1.0000    0.9933    0.9967       150
#
#         accuracy                         0.9824      1308
#        macro avg     0.9852    0.9847    0.9847      1308
#     weighted avg     0.9830    0.9824    0.9825      1308
#
#
# Resultados guardados en mobilenetv3large_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]
class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 1 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]
print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]
    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()
    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9, color='red'
        )
        axes[j].axis('off')
    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')
    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14, fontweight='bold', y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 1 o más confusiones:
#   mosaico → sanas: 7 imágenes
#   roya → muermo_rojo: 5 imágenes
#   mancha_parda → sanas: 2 imágenes
#   muermo_rojo → roya: 2 imágenes
#   roya → mancha_parda: 2 imágenes
#   hoja_amarilla → muermo_rojo: 1 imágenes
#   mancha_parda → muermo_rojo: 1 imágenes
#   muermo_rojo → mancha_parda: 1 imágenes
#   roya → sanas: 1 imágenes
#   tizon_bacteriano → mancha_parda: 1 imágenes
#
# Total de imágenes a mostrar: 23

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: mobilenetv3large_con_ft_weights.h5
