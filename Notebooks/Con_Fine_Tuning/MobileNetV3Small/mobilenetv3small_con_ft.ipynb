# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
NUM_CLASSES   = 10
NOMBRE_MODELO = 'mobilenetv3small_con_ft'

# Fase 1: Congelación de capas
PATIENCE_ES_F1  = 10
PATIENCE_LR_F1  = 5

# Fase 2: Descongelación de capas
PATIENCE_ES_F2  = 15
PATIENCE_LR_F2  = 8

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# DATA AUGMENTATION — IGUAL EN TODOS LOS MODELOS
train_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v3.preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO MOBILENETV3SMALL

# %%
# CARGAR MOBILENETV3SMALL CON PESOS DE IMAGENET
base_model = MobileNetV3Small(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPAS FINALES PERSONALIZADAS
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 [==============================] - 1s 0us/step

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "mobilenetv3small_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3small (Functiona  (None, 7, 7, 576)        939120
#  l)
#
#  global_average_pooling2d (G  (None, 576)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               73856
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,014,266
# Trainable params: 75,146
# Non-trainable params: 939,120
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F1,
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F1,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 1.1015 - accuracy: 0.6420
# Epoch 1: val_loss improved from inf to 0.42022, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 118s 609ms/step - loss: 1.1015 - accuracy: 0.6420 - val_loss: 0.4202 - val_accuracy: 0.8983 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.5187 - accuracy: 0.8446
# Epoch 2: val_loss improved from 0.42022 to 0.29965, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 113s 591ms/step - loss: 0.5187 - accuracy: 0.8446 - val_loss: 0.2997 - val_accuracy: 0.9266 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4136 - accuracy: 0.8770
# Epoch 3: val_loss improved from 0.29965 to 0.25197, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 112s 585ms/step - loss: 0.4136 - accuracy: 0.8770 - val_loss: 0.2520 - val_accuracy: 0.9312 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3677 - accuracy: 0.8926
# Epoch 4: val_loss improved from 0.25197 to 0.22283, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 113s 594ms/step - loss: 0.3677 - accuracy: 0.8926 - val_loss: 0.2228 - val_accuracy: 0.9495 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3319 - accuracy: 0.9011
# Epoch 5: val_loss improved from 0.22283 to 0.21760, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 111s 581ms/step - loss: 0.3319 - accuracy: 0.9011 - val_loss: 0.2176 - val_accuracy: 0.9472 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3097 - accuracy: 0.9124
# Epoch 6: val_loss improved from 0.21760 to 0.20121, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 112s 587ms/step - loss: 0.3097 - accuracy: 0.9124 - val_loss: 0.2012 - val_accuracy: 0.9457 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2807 - accuracy: 0.9240
# Epoch 7: val_loss did not improve from 0.20121
# 191/191 [==============================] - 110s 576ms/step - loss: 0.2807 - accuracy: 0.9240 - val_loss: 0.2013 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2620 - accuracy: 0.9222
# Epoch 8: val_loss improved from 0.20121 to 0.17996, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 117s 613ms/step - loss: 0.2620 - accuracy: 0.9222 - val_loss: 0.1800 - val_accuracy: 0.9572 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2487 - accuracy: 0.9250
# Epoch 9: val_loss did not improve from 0.17996
# 191/191 [==============================] - 141s 739ms/step - loss: 0.2487 - accuracy: 0.9250 - val_loss: 0.1863 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2415 - accuracy: 0.9329
# Epoch 10: val_loss did not improve from 0.17996
# 191/191 [==============================] - 123s 644ms/step - loss: 0.2415 - accuracy: 0.9329 - val_loss: 0.1816 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2363 - accuracy: 0.9345
# Epoch 11: val_loss improved from 0.17996 to 0.17771, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 135s 708ms/step - loss: 0.2363 - accuracy: 0.9345 - val_loss: 0.1777 - val_accuracy: 0.9564 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2275 - accuracy: 0.9368
# Epoch 12: val_loss improved from 0.17771 to 0.17594, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 137s 717ms/step - loss: 0.2275 - accuracy: 0.9368 - val_loss: 0.1759 - val_accuracy: 0.9572 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2247 - accuracy: 0.9379
# Epoch 13: val_loss improved from 0.17594 to 0.16875, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 139s 728ms/step - loss: 0.2247 - accuracy: 0.9379 - val_loss: 0.1688 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2174 - accuracy: 0.9378
# Epoch 14: val_loss did not improve from 0.16875
# 191/191 [==============================] - 134s 704ms/step - loss: 0.2174 - accuracy: 0.9378 - val_loss: 0.1745 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.9402
# Epoch 15: val_loss improved from 0.16875 to 0.16209, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 127s 666ms/step - loss: 0.2180 - accuracy: 0.9402 - val_loss: 0.1621 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.9446
# Epoch 16: val_loss improved from 0.16209 to 0.15862, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 115s 605ms/step - loss: 0.2102 - accuracy: 0.9446 - val_loss: 0.1586 - val_accuracy: 0.9625 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.9453
# Epoch 17: val_loss did not improve from 0.15862
# 191/191 [==============================] - 115s 603ms/step - loss: 0.2088 - accuracy: 0.9453 - val_loss: 0.1714 - val_accuracy: 0.9625 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1919 - accuracy: 0.9461
# Epoch 18: val_loss did not improve from 0.15862
# 191/191 [==============================] - 123s 645ms/step - loss: 0.1919 - accuracy: 0.9461 - val_loss: 0.1654 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9433
# Epoch 19: val_loss did not improve from 0.15862
# 191/191 [==============================] - 115s 604ms/step - loss: 0.2079 - accuracy: 0.9433 - val_loss: 0.1691 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1999 - accuracy: 0.9438
# Epoch 20: val_loss did not improve from 0.15862
# 191/191 [==============================] - 113s 593ms/step - loss: 0.1999 - accuracy: 0.9438 - val_loss: 0.1674 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1970 - accuracy: 0.9481
# Epoch 21: val_loss improved from 0.15862 to 0.15725, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 112s 586ms/step - loss: 0.1970 - accuracy: 0.9481 - val_loss: 0.1572 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2015 - accuracy: 0.9450
# Epoch 22: val_loss did not improve from 0.15725
# 191/191 [==============================] - 113s 594ms/step - loss: 0.2015 - accuracy: 0.9450 - val_loss: 0.1574 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9450
# Epoch 23: val_loss did not improve from 0.15725
# 191/191 [==============================] - 112s 588ms/step - loss: 0.2005 - accuracy: 0.9450 - val_loss: 0.1619 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1969 - accuracy: 0.9468
# Epoch 24: val_loss did not improve from 0.15725
# 191/191 [==============================] - 113s 591ms/step - loss: 0.1969 - accuracy: 0.9468 - val_loss: 0.1591 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9486
# Epoch 25: val_loss did not improve from 0.15725
# 191/191 [==============================] - 113s 591ms/step - loss: 0.1967 - accuracy: 0.9486 - val_loss: 0.1611 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1896 - accuracy: 0.9509
# Epoch 26: val_loss did not improve from 0.15725
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 115s 601ms/step - loss: 0.1896 - accuracy: 0.9509 - val_loss: 0.1778 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1666 - accuracy: 0.9599
# Epoch 27: val_loss improved from 0.15725 to 0.15345, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 107s 558ms/step - loss: 0.1666 - accuracy: 0.9599 - val_loss: 0.1535 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1628 - accuracy: 0.9599
# Epoch 28: val_loss did not improve from 0.15345
# 191/191 [==============================] - 110s 575ms/step - loss: 0.1628 - accuracy: 0.9599 - val_loss: 0.1566 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.9628
# Epoch 29: val_loss improved from 0.15345 to 0.14442, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 113s 593ms/step - loss: 0.1591 - accuracy: 0.9628 - val_loss: 0.1444 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9597
# Epoch 30: val_loss improved from 0.14442 to 0.14066, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 108s 565ms/step - loss: 0.1559 - accuracy: 0.9597 - val_loss: 0.1407 - val_accuracy: 0.9725 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1618 - accuracy: 0.9612
# Epoch 31: val_loss did not improve from 0.14066
# 191/191 [==============================] - 109s 571ms/step - loss: 0.1618 - accuracy: 0.9612 - val_loss: 0.1550 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9605
# Epoch 32: val_loss did not improve from 0.14066
# 191/191 [==============================] - 112s 587ms/step - loss: 0.1600 - accuracy: 0.9605 - val_loss: 0.1477 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1521 - accuracy: 0.9635
# Epoch 33: val_loss did not improve from 0.14066
# 191/191 [==============================] - 111s 582ms/step - loss: 0.1521 - accuracy: 0.9635 - val_loss: 0.1480 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1574 - accuracy: 0.9615
# Epoch 34: val_loss did not improve from 0.14066
# 191/191 [==============================] - 112s 589ms/step - loss: 0.1574 - accuracy: 0.9615 - val_loss: 0.1475 - val_accuracy: 0.9725 - lr: 5.0000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9617
# Epoch 35: val_loss did not improve from 0.14066
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 111s 582ms/step - loss: 0.1524 - accuracy: 0.9617 - val_loss: 0.1517 - val_accuracy: 0.9687 - lr: 5.0000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1498 - accuracy: 0.9630
# Epoch 36: val_loss did not improve from 0.14066
# 191/191 [==============================] - 112s 588ms/step - loss: 0.1498 - accuracy: 0.9630 - val_loss: 0.1488 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9677
# Epoch 37: val_loss did not improve from 0.14066
# 191/191 [==============================] - 130s 680ms/step - loss: 0.1425 - accuracy: 0.9677 - val_loss: 0.1436 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.9690
# Epoch 38: val_loss did not improve from 0.14066
# 191/191 [==============================] - 139s 727ms/step - loss: 0.1370 - accuracy: 0.9690 - val_loss: 0.1423 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9658
# Epoch 39: val_loss did not improve from 0.14066
# 191/191 [==============================] - 139s 728ms/step - loss: 0.1421 - accuracy: 0.9658 - val_loss: 0.1407 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9656
# Epoch 40: val_loss improved from 0.14066 to 0.14014, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 138s 723ms/step - loss: 0.1356 - accuracy: 0.9656 - val_loss: 0.1401 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9650
# Epoch 41: val_loss did not improve from 0.14014
# 191/191 [==============================] - 140s 733ms/step - loss: 0.1357 - accuracy: 0.9650 - val_loss: 0.1444 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1435 - accuracy: 0.9641
# Epoch 42: val_loss did not improve from 0.14014
# 191/191 [==============================] - 140s 732ms/step - loss: 0.1435 - accuracy: 0.9641 - val_loss: 0.1404 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9677
# Epoch 43: val_loss did not improve from 0.14014
# 191/191 [==============================] - 141s 738ms/step - loss: 0.1400 - accuracy: 0.9677 - val_loss: 0.1450 - val_accuracy: 0.9694 - lr: 2.5000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9677
# Epoch 44: val_loss improved from 0.14014 to 0.13744, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 124s 650ms/step - loss: 0.1364 - accuracy: 0.9677 - val_loss: 0.1374 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1404 - accuracy: 0.9653
# Epoch 45: val_loss did not improve from 0.13744
# 191/191 [==============================] - 113s 589ms/step - loss: 0.1404 - accuracy: 0.9653 - val_loss: 0.1394 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9738
# Epoch 46: val_loss improved from 0.13744 to 0.13641, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 114s 597ms/step - loss: 0.1253 - accuracy: 0.9738 - val_loss: 0.1364 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1398 - accuracy: 0.9676
# Epoch 47: val_loss improved from 0.13641 to 0.13320, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 112s 588ms/step - loss: 0.1398 - accuracy: 0.9676 - val_loss: 0.1332 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1328 - accuracy: 0.9697
# Epoch 48: val_loss did not improve from 0.13320
# 191/191 [==============================] - 113s 592ms/step - loss: 0.1328 - accuracy: 0.9697 - val_loss: 0.1372 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9672
# Epoch 49: val_loss did not improve from 0.13320
# 191/191 [==============================] - 113s 592ms/step - loss: 0.1362 - accuracy: 0.9672 - val_loss: 0.1350 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1280 - accuracy: 0.9718
# Epoch 50: val_loss did not improve from 0.13320
# 191/191 [==============================] - 112s 585ms/step - loss: 0.1280 - accuracy: 0.9718 - val_loss: 0.1375 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9687
# Epoch 51: val_loss did not improve from 0.13320
# 191/191 [==============================] - 112s 588ms/step - loss: 0.1309 - accuracy: 0.9687 - val_loss: 0.1386 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9710
# Epoch 52: val_loss did not improve from 0.13320
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 129s 674ms/step - loss: 0.1271 - accuracy: 0.9710 - val_loss: 0.1395 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.9728
# Epoch 53: val_loss did not improve from 0.13320
# 191/191 [==============================] - 139s 729ms/step - loss: 0.1237 - accuracy: 0.9728 - val_loss: 0.1343 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9736
# Epoch 54: val_loss improved from 0.13320 to 0.13188, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 126s 659ms/step - loss: 0.1271 - accuracy: 0.9736 - val_loss: 0.1319 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.9730
# Epoch 55: val_loss did not improve from 0.13188
# 191/191 [==============================] - 126s 662ms/step - loss: 0.1248 - accuracy: 0.9730 - val_loss: 0.1321 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 56/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9710
# Epoch 56: val_loss did not improve from 0.13188
# 191/191 [==============================] - 131s 687ms/step - loss: 0.1243 - accuracy: 0.9710 - val_loss: 0.1331 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 57/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9736
# Epoch 57: val_loss did not improve from 0.13188
# 191/191 [==============================] - 128s 669ms/step - loss: 0.1198 - accuracy: 0.9736 - val_loss: 0.1338 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 58/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9733
# Epoch 58: val_loss did not improve from 0.13188
# 191/191 [==============================] - 132s 692ms/step - loss: 0.1268 - accuracy: 0.9733 - val_loss: 0.1334 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 59/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9689
# Epoch 59: val_loss improved from 0.13188 to 0.13088, saving model to mobilenetv3small_con_ft_fase1_weights.h5
# 191/191 [==============================] - 133s 694ms/step - loss: 0.1300 - accuracy: 0.9689 - val_loss: 0.1309 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 60/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1297 - accuracy: 0.9705
# Epoch 60: val_loss did not improve from 0.13088
# 191/191 [==============================] - 134s 701ms/step - loss: 0.1297 - accuracy: 0.9705 - val_loss: 0.1333 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 61/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1251 - accuracy: 0.9715
# Epoch 61: val_loss did not improve from 0.13088
# 191/191 [==============================] - 127s 666ms/step - loss: 0.1251 - accuracy: 0.9715 - val_loss: 0.1345 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 62/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1203 - accuracy: 0.9723
# Epoch 62: val_loss did not improve from 0.13088
# 191/191 [==============================] - 135s 708ms/step - loss: 0.1203 - accuracy: 0.9723 - val_loss: 0.1344 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 63/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9731
# Epoch 63: val_loss did not improve from 0.13088
# 191/191 [==============================] - 133s 698ms/step - loss: 0.1228 - accuracy: 0.9731 - val_loss: 0.1343 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 64/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9697
# Epoch 64: val_loss did not improve from 0.13088
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 133s 697ms/step - loss: 0.1298 - accuracy: 0.9697 - val_loss: 0.1345 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 65/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9733
# Epoch 65: val_loss did not improve from 0.13088
# 191/191 [==============================] - 151s 794ms/step - loss: 0.1171 - accuracy: 0.9733 - val_loss: 0.1323 - val_accuracy: 0.9740 - lr: 6.2500e-05
# Epoch 66/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1127 - accuracy: 0.9774
# Epoch 66: val_loss did not improve from 0.13088
# 191/191 [==============================] - 138s 725ms/step - loss: 0.1127 - accuracy: 0.9774 - val_loss: 0.1332 - val_accuracy: 0.9740 - lr: 6.2500e-05
# Epoch 67/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9728
# Epoch 67: val_loss did not improve from 0.13088
# 191/191 [==============================] - 140s 736ms/step - loss: 0.1187 - accuracy: 0.9728 - val_loss: 0.1313 - val_accuracy: 0.9755 - lr: 6.2500e-05
# Epoch 68/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9776
# Epoch 68: val_loss did not improve from 0.13088
# 191/191 [==============================] - 136s 712ms/step - loss: 0.1114 - accuracy: 0.9776 - val_loss: 0.1334 - val_accuracy: 0.9763 - lr: 6.2500e-05
# Epoch 69/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9746Restoring model weights from the end of the best epoch: 59.
#
# Epoch 69: val_loss did not improve from 0.13088
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 191/191 [==============================] - 131s 683ms/step - loss: 0.1174 - accuracy: 0.9746 - val_loss: 0.1335 - val_accuracy: 0.9755 - lr: 6.2500e-05
# Epoch 69: early stopping
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9763

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F2,          # = 15, igual en todos los modelos
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F2,
    min_lr=1e-6,
    verbose=1
)

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 229
# Capas congeladas         : 199
# Capas descongeladas      : 30
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9738
# Epoch 1: val_loss improved from inf to 0.13102, saving model to mobilenetv3small_con_ft_weights.h5
# 191/191 [==============================] - 114s 595ms/step - loss: 0.1182 - accuracy: 0.9738 - val_loss: 0.1310 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1274 - accuracy: 0.9705
# Epoch 2: val_loss did not improve from 0.13102
# 191/191 [==============================] - 112s 586ms/step - loss: 0.1274 - accuracy: 0.9705 - val_loss: 0.1318 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1183 - accuracy: 0.9743
# Epoch 3: val_loss did not improve from 0.13102
# 191/191 [==============================] - 112s 585ms/step - loss: 0.1183 - accuracy: 0.9743 - val_loss: 0.1318 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9731
# Epoch 4: val_loss did not improve from 0.13102
# 191/191 [==============================] - 112s 584ms/step - loss: 0.1246 - accuracy: 0.9731 - val_loss: 0.1323 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9745
# Epoch 5: val_loss did not improve from 0.13102
# 191/191 [==============================] - 112s 585ms/step - loss: 0.1145 - accuracy: 0.9745 - val_loss: 0.1320 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.9785
# Epoch 6: val_loss did not improve from 0.13102
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 113s 591ms/step - loss: 0.1084 - accuracy: 0.9785 - val_loss: 0.1323 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9740
# Epoch 7: val_loss did not improve from 0.13102
# 191/191 [==============================] - 113s 589ms/step - loss: 0.1174 - accuracy: 0.9740 - val_loss: 0.1323 - val_accuracy: 0.9771 - lr: 5.0000e-06
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9758
# Epoch 8: val_loss did not improve from 0.13102
# 191/191 [==============================] - 114s 596ms/step - loss: 0.1192 - accuracy: 0.9758 - val_loss: 0.1324 - val_accuracy: 0.9771 - lr: 5.0000e-06
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9736
# Epoch 9: val_loss did not improve from 0.13102
# 191/191 [==============================] - 111s 581ms/step - loss: 0.1169 - accuracy: 0.9736 - val_loss: 0.1321 - val_accuracy: 0.9771 - lr: 5.0000e-06
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1158 - accuracy: 0.9754
# Epoch 10: val_loss did not improve from 0.13102
# 191/191 [==============================] - 111s 580ms/step - loss: 0.1158 - accuracy: 0.9754 - val_loss: 0.1321 - val_accuracy: 0.9771 - lr: 5.0000e-06
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1130 - accuracy: 0.9756Restoring model weights from the end of the best epoch: 1.
#
# Epoch 11: val_loss did not improve from 0.13102
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 191/191 [==============================] - 112s 584ms/step - loss: 0.1130 - accuracy: 0.9756 - val_loss: 0.1320 - val_accuracy: 0.9763 - lr: 5.0000e-06
# Epoch 11: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9771

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9763
# Fase 2 — mejor val_accuracy: 0.9771

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 13s 323ms/step - loss: 0.1024 - accuracy: 0.9794
#
# Test Accuracy : 0.9794
# Test Loss     : 0.1024
# 41/41 [==============================] - 14s 312ms/step
# F1 Score      : 0.9794
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9867    0.9867    0.9867       150
#    mancha_anillo     1.0000    0.9905    0.9952       105
#     mancha_parda     0.9866    0.9800    0.9833       150
#          mosaico     0.9864    0.9667    0.9764       150
#      muermo_rojo     0.9470    0.9533    0.9502       150
#             roya     0.9669    0.9733    0.9701       150
#            sanas     0.9673    0.9867    0.9769       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     0.9800    0.9800    0.9800       150
#
#         accuracy                         0.9794      1308
#        macro avg     0.9821    0.9817    0.9819      1308
#     weighted avg     0.9795    0.9794    0.9794      1308
#
#
# Resultados guardados en mobilenetv3small_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]
class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 1 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]
print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]
    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()
    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9, color='red'
        )
        axes[j].axis('off')
    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')
    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14, fontweight='bold', y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#
# Total de imágenes a mostrar: 0

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: mobilenetv3small_con_ft_weights.h5
