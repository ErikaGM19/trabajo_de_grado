# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = 'efficientnetB0_con_ft'

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# DATA AUGMENTATION — IGUAL EN TODOS LOS MODELOS
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFICIENTNETB0

# %%
# CARGAR EFFICIENTNETB0 CON PESOS DE IMAGENET
base_model = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPAS FINALES PERSONALIZADAS
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 1s 0us/step

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "efficientnetB0_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 4,214,829
# Trainable params: 165,258
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.9184 - accuracy: 0.7059
# Epoch 1: val_loss improved from inf to 0.32559, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 569s 3s/step - loss: 0.9184 - accuracy: 0.7059 - val_loss: 0.3256 - val_accuracy: 0.9251 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4418 - accuracy: 0.8683
# Epoch 2: val_loss improved from 0.32559 to 0.23080, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 431s 2s/step - loss: 0.4418 - accuracy: 0.8683 - val_loss: 0.2308 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3500 - accuracy: 0.8999
# Epoch 3: val_loss improved from 0.23080 to 0.21172, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 416s 2s/step - loss: 0.3500 - accuracy: 0.8999 - val_loss: 0.2117 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3059 - accuracy: 0.9165
# Epoch 4: val_loss improved from 0.21172 to 0.18303, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 419s 2s/step - loss: 0.3059 - accuracy: 0.9165 - val_loss: 0.1830 - val_accuracy: 0.9503 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2890 - accuracy: 0.9202
# Epoch 5: val_loss improved from 0.18303 to 0.17992, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 416s 2s/step - loss: 0.2890 - accuracy: 0.9202 - val_loss: 0.1799 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2571 - accuracy: 0.9263
# Epoch 6: val_loss improved from 0.17992 to 0.16907, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 423s 2s/step - loss: 0.2571 - accuracy: 0.9263 - val_loss: 0.1691 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 0.9302
# Epoch 7: val_loss improved from 0.16907 to 0.14339, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 417s 2s/step - loss: 0.2485 - accuracy: 0.9302 - val_loss: 0.1434 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2334 - accuracy: 0.9360
# Epoch 8: val_loss did not improve from 0.14339
# 191/191 [==============================] - 479s 3s/step - loss: 0.2334 - accuracy: 0.9360 - val_loss: 0.1593 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2324 - accuracy: 0.9415
# Epoch 9: val_loss improved from 0.14339 to 0.13836, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 436s 2s/step - loss: 0.2324 - accuracy: 0.9415 - val_loss: 0.1384 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9386
# Epoch 10: val_loss did not improve from 0.13836
# 191/191 [==============================] - 417s 2s/step - loss: 0.2276 - accuracy: 0.9386 - val_loss: 0.1490 - val_accuracy: 0.9625 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2210 - accuracy: 0.9430
# Epoch 11: val_loss did not improve from 0.13836
# 191/191 [==============================] - 413s 2s/step - loss: 0.2210 - accuracy: 0.9430 - val_loss: 0.1521 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2066 - accuracy: 0.9484
# Epoch 12: val_loss did not improve from 0.13836
# 191/191 [==============================] - 417s 2s/step - loss: 0.2066 - accuracy: 0.9484 - val_loss: 0.1566 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2120 - accuracy: 0.9461
# Epoch 13: val_loss did not improve from 0.13836
# 191/191 [==============================] - 417s 2s/step - loss: 0.2120 - accuracy: 0.9461 - val_loss: 0.1537 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2155 - accuracy: 0.9458
# Epoch 14: val_loss did not improve from 0.13836
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 420s 2s/step - loss: 0.2155 - accuracy: 0.9458 - val_loss: 0.1407 - val_accuracy: 0.9702 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9561
# Epoch 15: val_loss did not improve from 0.13836
# 191/191 [==============================] - 451s 2s/step - loss: 0.1841 - accuracy: 0.9561 - val_loss: 0.1465 - val_accuracy: 0.9656 - lr: 5.0000e-04
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1888 - accuracy: 0.9537
# Epoch 16: val_loss did not improve from 0.13836
# 191/191 [==============================] - 414s 2s/step - loss: 0.1888 - accuracy: 0.9537 - val_loss: 0.1507 - val_accuracy: 0.9625 - lr: 5.0000e-04
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1829 - accuracy: 0.9537
# Epoch 17: val_loss improved from 0.13836 to 0.13144, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 419s 2s/step - loss: 0.1829 - accuracy: 0.9537 - val_loss: 0.1314 - val_accuracy: 0.9725 - lr: 5.0000e-04
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1782 - accuracy: 0.9595
# Epoch 18: val_loss did not improve from 0.13144
# 191/191 [==============================] - 415s 2s/step - loss: 0.1782 - accuracy: 0.9595 - val_loss: 0.1336 - val_accuracy: 0.9755 - lr: 5.0000e-04
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1697 - accuracy: 0.9599
# Epoch 19: val_loss improved from 0.13144 to 0.12509, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 415s 2s/step - loss: 0.1697 - accuracy: 0.9599 - val_loss: 0.1251 - val_accuracy: 0.9755 - lr: 5.0000e-04
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1620 - accuracy: 0.9636
# Epoch 20: val_loss did not improve from 0.12509
# 191/191 [==============================] - 418s 2s/step - loss: 0.1620 - accuracy: 0.9636 - val_loss: 0.1372 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9646
# Epoch 21: val_loss did not improve from 0.12509
# 191/191 [==============================] - 417s 2s/step - loss: 0.1625 - accuracy: 0.9646 - val_loss: 0.1320 - val_accuracy: 0.9717 - lr: 5.0000e-04
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.9628
# Epoch 22: val_loss did not improve from 0.12509
# 191/191 [==============================] - 416s 2s/step - loss: 0.1645 - accuracy: 0.9628 - val_loss: 0.1316 - val_accuracy: 0.9717 - lr: 5.0000e-04
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9602
# Epoch 23: val_loss did not improve from 0.12509
# 191/191 [==============================] - 422s 2s/step - loss: 0.1742 - accuracy: 0.9602 - val_loss: 0.1353 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9687
# Epoch 24: val_loss did not improve from 0.12509
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 415s 2s/step - loss: 0.1503 - accuracy: 0.9687 - val_loss: 0.1296 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1529 - accuracy: 0.9672
# Epoch 25: val_loss did not improve from 0.12509
# 191/191 [==============================] - 418s 2s/step - loss: 0.1529 - accuracy: 0.9672 - val_loss: 0.1300 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9682
# Epoch 26: val_loss improved from 0.12509 to 0.12274, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 417s 2s/step - loss: 0.1450 - accuracy: 0.9682 - val_loss: 0.1227 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1463 - accuracy: 0.9692
# Epoch 27: val_loss did not improve from 0.12274
# 191/191 [==============================] - 416s 2s/step - loss: 0.1463 - accuracy: 0.9692 - val_loss: 0.1246 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1369 - accuracy: 0.9708
# Epoch 28: val_loss improved from 0.12274 to 0.11926, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 417s 2s/step - loss: 0.1369 - accuracy: 0.9708 - val_loss: 0.1193 - val_accuracy: 0.9786 - lr: 2.5000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1514 - accuracy: 0.9682
# Epoch 29: val_loss did not improve from 0.11926
# 191/191 [==============================] - 420s 2s/step - loss: 0.1514 - accuracy: 0.9682 - val_loss: 0.1233 - val_accuracy: 0.9786 - lr: 2.5000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1398 - accuracy: 0.9694
# Epoch 30: val_loss did not improve from 0.11926
# 191/191 [==============================] - 420s 2s/step - loss: 0.1398 - accuracy: 0.9694 - val_loss: 0.1267 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9692
# Epoch 31: val_loss improved from 0.11926 to 0.11734, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 418s 2s/step - loss: 0.1422 - accuracy: 0.9692 - val_loss: 0.1173 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1413 - accuracy: 0.9713
# Epoch 32: val_loss did not improve from 0.11734
# 191/191 [==============================] - 423s 2s/step - loss: 0.1413 - accuracy: 0.9713 - val_loss: 0.1251 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9702
# Epoch 33: val_loss improved from 0.11734 to 0.11623, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 421s 2s/step - loss: 0.1373 - accuracy: 0.9702 - val_loss: 0.1162 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9715
# Epoch 34: val_loss did not improve from 0.11623
# 191/191 [==============================] - 417s 2s/step - loss: 0.1374 - accuracy: 0.9715 - val_loss: 0.1215 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9722
# Epoch 35: val_loss improved from 0.11623 to 0.11074, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 420s 2s/step - loss: 0.1406 - accuracy: 0.9722 - val_loss: 0.1107 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9712
# Epoch 36: val_loss did not improve from 0.11074
# 191/191 [==============================] - 421s 2s/step - loss: 0.1295 - accuracy: 0.9712 - val_loss: 0.1239 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9686
# Epoch 37: val_loss did not improve from 0.11074
# 191/191 [==============================] - 422s 2s/step - loss: 0.1343 - accuracy: 0.9686 - val_loss: 0.1213 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9722
# Epoch 38: val_loss did not improve from 0.11074
# 191/191 [==============================] - 422s 2s/step - loss: 0.1363 - accuracy: 0.9722 - val_loss: 0.1132 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9758
# Epoch 39: val_loss did not improve from 0.11074
# 191/191 [==============================] - 421s 2s/step - loss: 0.1268 - accuracy: 0.9758 - val_loss: 0.1152 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 0.9731
# Epoch 40: val_loss did not improve from 0.11074
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 425s 2s/step - loss: 0.1312 - accuracy: 0.9731 - val_loss: 0.1135 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9748
# Epoch 41: val_loss did not improve from 0.11074
# 191/191 [==============================] - 423s 2s/step - loss: 0.1253 - accuracy: 0.9748 - val_loss: 0.1148 - val_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9745
# Epoch 42: val_loss did not improve from 0.11074
# 191/191 [==============================] - 424s 2s/step - loss: 0.1269 - accuracy: 0.9745 - val_loss: 0.1145 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.9769
# Epoch 43: val_loss did not improve from 0.11074
# 191/191 [==============================] - 424s 2s/step - loss: 0.1237 - accuracy: 0.9769 - val_loss: 0.1134 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9748
# Epoch 44: val_loss improved from 0.11074 to 0.10994, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 424s 2s/step - loss: 0.1233 - accuracy: 0.9748 - val_loss: 0.1099 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1250 - accuracy: 0.9728
# Epoch 45: val_loss did not improve from 0.10994
# 191/191 [==============================] - 424s 2s/step - loss: 0.1250 - accuracy: 0.9728 - val_loss: 0.1125 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9728
# Epoch 46: val_loss did not improve from 0.10994
# 191/191 [==============================] - 427s 2s/step - loss: 0.1332 - accuracy: 0.9728 - val_loss: 0.1141 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1288 - accuracy: 0.9743
# Epoch 47: val_loss did not improve from 0.10994
# 191/191 [==============================] - 482s 3s/step - loss: 0.1288 - accuracy: 0.9743 - val_loss: 0.1167 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9746
# Epoch 48: val_loss did not improve from 0.10994
# 191/191 [==============================] - 434s 2s/step - loss: 0.1233 - accuracy: 0.9746 - val_loss: 0.1159 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1267 - accuracy: 0.9743
# Epoch 49: val_loss did not improve from 0.10994
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 425s 2s/step - loss: 0.1267 - accuracy: 0.9743 - val_loss: 0.1214 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9735
# Epoch 50: val_loss did not improve from 0.10994
# 191/191 [==============================] - 423s 2s/step - loss: 0.1270 - accuracy: 0.9735 - val_loss: 0.1126 - val_accuracy: 0.9755 - lr: 6.2500e-05
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1235 - accuracy: 0.9743
# Epoch 51: val_loss improved from 0.10994 to 0.10946, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 424s 2s/step - loss: 0.1235 - accuracy: 0.9743 - val_loss: 0.1095 - val_accuracy: 0.9786 - lr: 6.2500e-05
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9774
# Epoch 52: val_loss did not improve from 0.10946
# 191/191 [==============================] - 424s 2s/step - loss: 0.1193 - accuracy: 0.9774 - val_loss: 0.1109 - val_accuracy: 0.9794 - lr: 6.2500e-05
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9761
# Epoch 53: val_loss did not improve from 0.10946
# 191/191 [==============================] - 425s 2s/step - loss: 0.1219 - accuracy: 0.9761 - val_loss: 0.1112 - val_accuracy: 0.9771 - lr: 6.2500e-05
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9771
# Epoch 54: val_loss did not improve from 0.10946
# 191/191 [==============================] - 436s 2s/step - loss: 0.1172 - accuracy: 0.9771 - val_loss: 0.1135 - val_accuracy: 0.9740 - lr: 6.2500e-05
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9772
# Epoch 55: val_loss did not improve from 0.10946
# 191/191 [==============================] - 440s 2s/step - loss: 0.1156 - accuracy: 0.9772 - val_loss: 0.1138 - val_accuracy: 0.9763 - lr: 6.2500e-05
# Epoch 56/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9769
# Epoch 56: val_loss did not improve from 0.10946
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 191/191 [==============================] - 430s 2s/step - loss: 0.1156 - accuracy: 0.9769 - val_loss: 0.1112 - val_accuracy: 0.9778 - lr: 6.2500e-05
# Epoch 57/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9790
# Epoch 57: val_loss did not improve from 0.10946
# 191/191 [==============================] - 430s 2s/step - loss: 0.1126 - accuracy: 0.9790 - val_loss: 0.1097 - val_accuracy: 0.9794 - lr: 3.1250e-05
# Epoch 58/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1120 - accuracy: 0.9769
# Epoch 58: val_loss improved from 0.10946 to 0.10866, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 449s 2s/step - loss: 0.1120 - accuracy: 0.9769 - val_loss: 0.1087 - val_accuracy: 0.9786 - lr: 3.1250e-05
# Epoch 59/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9785
# Epoch 59: val_loss did not improve from 0.10866
# 191/191 [==============================] - 437s 2s/step - loss: 0.1112 - accuracy: 0.9785 - val_loss: 0.1087 - val_accuracy: 0.9794 - lr: 3.1250e-05
# Epoch 60/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9774
# Epoch 60: val_loss did not improve from 0.10866
# 191/191 [==============================] - 431s 2s/step - loss: 0.1147 - accuracy: 0.9774 - val_loss: 0.1106 - val_accuracy: 0.9763 - lr: 3.1250e-05
# Epoch 61/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1115 - accuracy: 0.9800
# Epoch 61: val_loss did not improve from 0.10866
# 191/191 [==============================] - 428s 2s/step - loss: 0.1115 - accuracy: 0.9800 - val_loss: 0.1110 - val_accuracy: 0.9748 - lr: 3.1250e-05
# Epoch 62/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9785
# Epoch 62: val_loss did not improve from 0.10866
# 191/191 [==============================] - 434s 2s/step - loss: 0.1122 - accuracy: 0.9785 - val_loss: 0.1100 - val_accuracy: 0.9786 - lr: 3.1250e-05
# Epoch 63/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9767
# Epoch 63: val_loss did not improve from 0.10866
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 191/191 [==============================] - 433s 2s/step - loss: 0.1159 - accuracy: 0.9767 - val_loss: 0.1093 - val_accuracy: 0.9809 - lr: 3.1250e-05
# Epoch 64/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1117 - accuracy: 0.9777
# Epoch 64: val_loss did not improve from 0.10866
# 191/191 [==============================] - 431s 2s/step - loss: 0.1117 - accuracy: 0.9777 - val_loss: 0.1088 - val_accuracy: 0.9817 - lr: 1.5625e-05
# Epoch 65/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1133 - accuracy: 0.9763
# Epoch 65: val_loss did not improve from 0.10866
# 191/191 [==============================] - 432s 2s/step - loss: 0.1133 - accuracy: 0.9763 - val_loss: 0.1096 - val_accuracy: 0.9801 - lr: 1.5625e-05
# Epoch 66/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9805
# Epoch 66: val_loss improved from 0.10866 to 0.10791, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 430s 2s/step - loss: 0.1150 - accuracy: 0.9805 - val_loss: 0.1079 - val_accuracy: 0.9817 - lr: 1.5625e-05
# Epoch 67/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9731
# Epoch 67: val_loss did not improve from 0.10791
# 191/191 [==============================] - 428s 2s/step - loss: 0.1155 - accuracy: 0.9731 - val_loss: 0.1085 - val_accuracy: 0.9801 - lr: 1.5625e-05
# Epoch 68/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9776
# Epoch 68: val_loss did not improve from 0.10791
# 191/191 [==============================] - 430s 2s/step - loss: 0.1163 - accuracy: 0.9776 - val_loss: 0.1092 - val_accuracy: 0.9794 - lr: 1.5625e-05
# Epoch 69/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9823
# Epoch 69: val_loss did not improve from 0.10791
# 191/191 [==============================] - 431s 2s/step - loss: 0.1082 - accuracy: 0.9823 - val_loss: 0.1094 - val_accuracy: 0.9786 - lr: 1.5625e-05
# Epoch 70/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9766
# Epoch 70: val_loss did not improve from 0.10791
# 191/191 [==============================] - 429s 2s/step - loss: 0.1157 - accuracy: 0.9766 - val_loss: 0.1091 - val_accuracy: 0.9817 - lr: 1.5625e-05
# Epoch 71/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9789
# Epoch 71: val_loss did not improve from 0.10791
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 191/191 [==============================] - 432s 2s/step - loss: 0.1126 - accuracy: 0.9789 - val_loss: 0.1086 - val_accuracy: 0.9794 - lr: 1.5625e-05
# Epoch 72/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1108 - accuracy: 0.9774
# Epoch 72: val_loss did not improve from 0.10791
# 191/191 [==============================] - 433s 2s/step - loss: 0.1108 - accuracy: 0.9774 - val_loss: 0.1081 - val_accuracy: 0.9794 - lr: 7.8125e-06
# Epoch 73/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9810
# Epoch 73: val_loss did not improve from 0.10791
# 191/191 [==============================] - 430s 2s/step - loss: 0.1101 - accuracy: 0.9810 - val_loss: 0.1081 - val_accuracy: 0.9809 - lr: 7.8125e-06
# Epoch 74/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1087 - accuracy: 0.9800
# Epoch 74: val_loss did not improve from 0.10791
# 191/191 [==============================] - 435s 2s/step - loss: 0.1087 - accuracy: 0.9800 - val_loss: 0.1083 - val_accuracy: 0.9801 - lr: 7.8125e-06
# Epoch 75/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1130 - accuracy: 0.9797
# Epoch 75: val_loss did not improve from 0.10791
# 191/191 [==============================] - 433s 2s/step - loss: 0.1130 - accuracy: 0.9797 - val_loss: 0.1084 - val_accuracy: 0.9817 - lr: 7.8125e-06
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9817

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10, igual en todos los modelos
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    min_lr=1e-7,
    verbose=1
)

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 238
# Capas congeladas         : 208
# Capas descongeladas      : 30
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9764
# Epoch 1: val_loss improved from inf to 0.10802, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 434s 2s/step - loss: 0.1197 - accuracy: 0.9764 - val_loss: 0.1080 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1109 - accuracy: 0.9785
# Epoch 2: val_loss did not improve from 0.10802
# 191/191 [==============================] - 431s 2s/step - loss: 0.1109 - accuracy: 0.9785 - val_loss: 0.1084 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9810
# Epoch 3: val_loss did not improve from 0.10802
# 191/191 [==============================] - 432s 2s/step - loss: 0.1064 - accuracy: 0.9810 - val_loss: 0.1085 - val_accuracy: 0.9809 - lr: 1.0000e-05
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9766
# Epoch 4: val_loss did not improve from 0.10802
# 191/191 [==============================] - 433s 2s/step - loss: 0.1149 - accuracy: 0.9766 - val_loss: 0.1081 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9803
# Epoch 5: val_loss improved from 0.10802 to 0.10798, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 435s 2s/step - loss: 0.1110 - accuracy: 0.9803 - val_loss: 0.1080 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9785
# Epoch 6: val_loss improved from 0.10798 to 0.10796, saving model to efficientnetB0_con_ft_weights.h5
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 455s 2s/step - loss: 0.1145 - accuracy: 0.9785 - val_loss: 0.1080 - val_accuracy: 0.9824 - lr: 1.0000e-05
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9813
# Epoch 7: val_loss improved from 0.10796 to 0.10756, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 493s 3s/step - loss: 0.1079 - accuracy: 0.9813 - val_loss: 0.1076 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9767
# Epoch 8: val_loss improved from 0.10756 to 0.10724, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 436s 2s/step - loss: 0.1132 - accuracy: 0.9767 - val_loss: 0.1072 - val_accuracy: 0.9817 - lr: 5.0000e-06
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9790
# Epoch 9: val_loss improved from 0.10724 to 0.10712, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 432s 2s/step - loss: 0.1159 - accuracy: 0.9790 - val_loss: 0.1071 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1108 - accuracy: 0.9799
# Epoch 10: val_loss did not improve from 0.10712
# 191/191 [==============================] - 436s 2s/step - loss: 0.1108 - accuracy: 0.9799 - val_loss: 0.1077 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9759
# Epoch 11: val_loss did not improve from 0.10712
# 191/191 [==============================] - 434s 2s/step - loss: 0.1137 - accuracy: 0.9759 - val_loss: 0.1076 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1184 - accuracy: 0.9761
# Epoch 12: val_loss did not improve from 0.10712
# 191/191 [==============================] - 433s 2s/step - loss: 0.1184 - accuracy: 0.9761 - val_loss: 0.1076 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1104 - accuracy: 0.9789
# Epoch 13: val_loss did not improve from 0.10712
# 191/191 [==============================] - 450s 2s/step - loss: 0.1104 - accuracy: 0.9789 - val_loss: 0.1078 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9792
# Epoch 14: val_loss did not improve from 0.10712
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 191/191 [==============================] - 465s 2s/step - loss: 0.1125 - accuracy: 0.9792 - val_loss: 0.1076 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9769
# Epoch 15: val_loss did not improve from 0.10712
# 191/191 [==============================] - 458s 2s/step - loss: 0.1124 - accuracy: 0.9769 - val_loss: 0.1075 - val_accuracy: 0.9824 - lr: 2.5000e-06
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1161 - accuracy: 0.9774
# Epoch 16: val_loss did not improve from 0.10712
# 191/191 [==============================] - 434s 2s/step - loss: 0.1161 - accuracy: 0.9774 - val_loss: 0.1072 - val_accuracy: 0.9824 - lr: 2.5000e-06
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9753
# Epoch 17: val_loss improved from 0.10712 to 0.10686, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 437s 2s/step - loss: 0.1157 - accuracy: 0.9753 - val_loss: 0.1069 - val_accuracy: 0.9824 - lr: 2.5000e-06
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1109 - accuracy: 0.9797
# Epoch 18: val_loss did not improve from 0.10686
# 191/191 [==============================] - 434s 2s/step - loss: 0.1109 - accuracy: 0.9797 - val_loss: 0.1070 - val_accuracy: 0.9824 - lr: 2.5000e-06
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9789
# Epoch 19: val_loss did not improve from 0.10686
# 191/191 [==============================] - 434s 2s/step - loss: 0.1126 - accuracy: 0.9789 - val_loss: 0.1071 - val_accuracy: 0.9824 - lr: 2.5000e-06
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9800
# Epoch 20: val_loss did not improve from 0.10686
# 191/191 [==============================] - 432s 2s/step - loss: 0.1093 - accuracy: 0.9800 - val_loss: 0.1071 - val_accuracy: 0.9824 - lr: 2.5000e-06
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9808
# Epoch 21: val_loss did not improve from 0.10686
# 191/191 [==============================] - 442s 2s/step - loss: 0.1145 - accuracy: 0.9808 - val_loss: 0.1070 - val_accuracy: 0.9824 - lr: 2.5000e-06
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1092 - accuracy: 0.9766
# Epoch 22: val_loss did not improve from 0.10686
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 191/191 [==============================] - 440s 2s/step - loss: 0.1092 - accuracy: 0.9766 - val_loss: 0.1069 - val_accuracy: 0.9824 - lr: 2.5000e-06
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9802
# Epoch 23: val_loss did not improve from 0.10686
# 191/191 [==============================] - 444s 2s/step - loss: 0.1064 - accuracy: 0.9802 - val_loss: 0.1070 - val_accuracy: 0.9824 - lr: 1.2500e-06
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1121 - accuracy: 0.9784
# Epoch 24: val_loss did not improve from 0.10686
# 191/191 [==============================] - 435s 2s/step - loss: 0.1121 - accuracy: 0.9784 - val_loss: 0.1070 - val_accuracy: 0.9824 - lr: 1.2500e-06
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9767
# Epoch 25: val_loss did not improve from 0.10686
# 191/191 [==============================] - 437s 2s/step - loss: 0.1146 - accuracy: 0.9767 - val_loss: 0.1069 - val_accuracy: 0.9824 - lr: 1.2500e-06
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1109 - accuracy: 0.9794
# Epoch 26: val_loss improved from 0.10686 to 0.10683, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 434s 2s/step - loss: 0.1109 - accuracy: 0.9794 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 1.2500e-06
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9779
# Epoch 27: val_loss improved from 0.10683 to 0.10678, saving model to efficientnetB0_con_ft_weights.h5
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# 191/191 [==============================] - 439s 2s/step - loss: 0.1157 - accuracy: 0.9779 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 1.2500e-06
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9815
# Epoch 28: val_loss improved from 0.10678 to 0.10674, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 435s 2s/step - loss: 0.1095 - accuracy: 0.9815 - val_loss: 0.1067 - val_accuracy: 0.9824 - lr: 6.2500e-07
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9776
# Epoch 29: val_loss improved from 0.10674 to 0.10674, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 440s 2s/step - loss: 0.1102 - accuracy: 0.9776 - val_loss: 0.1067 - val_accuracy: 0.9824 - lr: 6.2500e-07
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9774
# Epoch 30: val_loss did not improve from 0.10674
# 191/191 [==============================] - 436s 2s/step - loss: 0.1100 - accuracy: 0.9774 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 6.2500e-07
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9790
# Epoch 31: val_loss did not improve from 0.10674
# 191/191 [==============================] - 443s 2s/step - loss: 0.1093 - accuracy: 0.9790 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 6.2500e-07
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1175 - accuracy: 0.9774
# Epoch 32: val_loss did not improve from 0.10674
# 191/191 [==============================] - 436s 2s/step - loss: 0.1175 - accuracy: 0.9774 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 6.2500e-07
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1097 - accuracy: 0.9800
# Epoch 33: val_loss did not improve from 0.10674
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# 191/191 [==============================] - 438s 2s/step - loss: 0.1097 - accuracy: 0.9800 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 6.2500e-07
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9785
# Epoch 34: val_loss did not improve from 0.10674
# 191/191 [==============================] - 469s 2s/step - loss: 0.1122 - accuracy: 0.9785 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 3.1250e-07
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1139 - accuracy: 0.9784
# Epoch 35: val_loss did not improve from 0.10674
# 191/191 [==============================] - 497s 3s/step - loss: 0.1139 - accuracy: 0.9784 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 3.1250e-07
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9772
# Epoch 36: val_loss did not improve from 0.10674
# 191/191 [==============================] - 437s 2s/step - loss: 0.1110 - accuracy: 0.9772 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 3.1250e-07
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.9733
# Epoch 37: val_loss did not improve from 0.10674
# 191/191 [==============================] - 444s 2s/step - loss: 0.1201 - accuracy: 0.9733 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 3.1250e-07
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9764
# Epoch 38: val_loss did not improve from 0.10674
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
# 191/191 [==============================] - 442s 2s/step - loss: 0.1147 - accuracy: 0.9764 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 3.1250e-07
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1105 - accuracy: 0.9807Restoring model weights from the end of the best epoch: 29.
#
# Epoch 39: val_loss did not improve from 0.10674
# 191/191 [==============================] - 448s 2s/step - loss: 0.1105 - accuracy: 0.9807 - val_loss: 0.1068 - val_accuracy: 0.9824 - lr: 1.5625e-07
# Epoch 39: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9824

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9817
# Fase 2 — mejor val_accuracy: 0.9824

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 76s 2s/step - loss: 0.1036 - accuracy: 0.9740
#
# Test Accuracy : 0.9740
# Test Loss     : 0.1036
# 41/41 [==============================] - 71s 2s/step
# F1 Score      : 0.9740
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9800    0.9800    0.9800       150
#    mancha_anillo     1.0000    1.0000    1.0000       105
#     mancha_parda     0.9735    0.9800    0.9767       150
#          mosaico     0.9858    0.9267    0.9553       150
#      muermo_rojo     0.9536    0.9600    0.9568       150
#             roya     0.9726    0.9467    0.9595       150
#            sanas     0.9193    0.9867    0.9518       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     0.9933    0.9933    0.9933       150
#
#         accuracy                         0.9740      1308
#        macro avg     0.9778    0.9773    0.9773      1308
#     weighted avg     0.9746    0.9740    0.9740      1308
#
#
# Resultados guardados en efficientnetB0_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]
class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 5 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]
print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]
    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()
    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9, color='red'
        )
        axes[j].axis('off')
    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')
    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14, fontweight='bold', y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#   mosaico → sanas: 10 imágenes
#
# Total de imágenes a mostrar: 10

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB0_con_ft_weights.h5
