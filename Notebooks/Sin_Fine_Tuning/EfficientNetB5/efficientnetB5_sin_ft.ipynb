# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB5
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE      = 456
BATCH_SIZE    = 8
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = "efficientnetB5_sin_ft"

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFIENTNETB5

# %%
# CARGAR EFFICIENTNET-B5 CON PESOS DE IMAGENET

base_model = EfficientNetB5(
    weights='imagenet',                 
    include_top=False,                  
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Congelamos la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb5_notop.h5
# 115263384/115263384 [==============================] - 18s 0us/step

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb5 (Functional)  (None, 15, 15, 2048)     28513527
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 28,777,089
# Trainable params: 263,562
# Non-trainable params: 28,513,527
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{NOMBRE_MODELO}_weights.h5",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 764/764 [==============================] - ETA: 0s - loss: 0.6906 - accuracy: 0.7720
# Epoch 1: val_loss improved from inf to 0.31546, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 6728s 9s/step - loss: 0.6906 - accuracy: 0.7720 - val_loss: 0.3155 - val_accuracy: 0.8998 - lr: 0.0010
# Epoch 2/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3659 - accuracy: 0.8847
# Epoch 2: val_loss did not improve from 0.31546
# 764/764 [==============================] - 6318s 8s/step - loss: 0.3659 - accuracy: 0.8847 - val_loss: 0.3953 - val_accuracy: 0.8593 - lr: 0.0010
# Epoch 3/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3074 - accuracy: 0.8998
# Epoch 3: val_loss improved from 0.31546 to 0.19814, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 6820s 9s/step - loss: 0.3074 - accuracy: 0.8998 - val_loss: 0.1981 - val_accuracy: 0.9335 - lr: 0.0010
# Epoch 4/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.9112
# Epoch 4: val_loss did not improve from 0.19814
# 764/764 [==============================] - 6655s 9s/step - loss: 0.2637 - accuracy: 0.9112 - val_loss: 0.2103 - val_accuracy: 0.9281 - lr: 0.0010
# Epoch 5/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.9199
# Epoch 5: val_loss improved from 0.19814 to 0.19160, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 6686s 9s/step - loss: 0.2384 - accuracy: 0.9199 - val_loss: 0.1916 - val_accuracy: 0.9365 - lr: 0.0010
# Epoch 6/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2243 - accuracy: 0.9235
# Epoch 6: val_loss improved from 0.19160 to 0.15339, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 41147s 54s/step - loss: 0.2243 - accuracy: 0.9235 - val_loss: 0.1534 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 7/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2093 - accuracy: 0.9317
# Epoch 7: val_loss improved from 0.15339 to 0.13580, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 6797s 9s/step - loss: 0.2093 - accuracy: 0.9317 - val_loss: 0.1358 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 8/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1905 - accuracy: 0.9365
# Epoch 8: val_loss did not improve from 0.13580
# 764/764 [==============================] - 6625s 9s/step - loss: 0.1905 - accuracy: 0.9365 - val_loss: 0.1800 - val_accuracy: 0.9365 - lr: 0.0010
# Epoch 9/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1886 - accuracy: 0.9387
# Epoch 9: val_loss did not improve from 0.13580
# 764/764 [==============================] - 6673s 9s/step - loss: 0.1886 - accuracy: 0.9387 - val_loss: 0.1495 - val_accuracy: 0.9472 - lr: 0.0010
# Epoch 10/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9343
# Epoch 10: val_loss did not improve from 0.13580
# 764/764 [==============================] - 6780s 9s/step - loss: 0.1971 - accuracy: 0.9343 - val_loss: 0.1859 - val_accuracy: 0.9320 - lr: 0.0010
# Epoch 11/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1642 - accuracy: 0.9432
# Epoch 11: val_loss did not improve from 0.13580
# 764/764 [==============================] - 6751s 9s/step - loss: 0.1642 - accuracy: 0.9432 - val_loss: 0.2033 - val_accuracy: 0.9335 - lr: 0.0010
# Epoch 12/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1637 - accuracy: 0.9453
# Epoch 12: val_loss did not improve from 0.13580
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 764/764 [==============================] - 6763s 9s/step - loss: 0.1637 - accuracy: 0.9453 - val_loss: 0.1597 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 13/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9507
# Epoch 13: val_loss improved from 0.13580 to 0.12056, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 6773s 9s/step - loss: 0.1483 - accuracy: 0.9507 - val_loss: 0.1206 - val_accuracy: 0.9618 - lr: 5.0000e-04
# Epoch 14/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9550
# Epoch 14: val_loss improved from 0.12056 to 0.11878, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 6804s 9s/step - loss: 0.1380 - accuracy: 0.9550 - val_loss: 0.1188 - val_accuracy: 0.9587 - lr: 5.0000e-04
# Epoch 15/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.9599
# Epoch 15: val_loss improved from 0.11878 to 0.11816, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 6763s 9s/step - loss: 0.1202 - accuracy: 0.9599 - val_loss: 0.1182 - val_accuracy: 0.9587 - lr: 5.0000e-04
# Epoch 16/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9659
# Epoch 16: val_loss did not improve from 0.11816
# 764/764 [==============================] - 6770s 9s/step - loss: 0.1110 - accuracy: 0.9659 - val_loss: 0.1193 - val_accuracy: 0.9572 - lr: 5.0000e-04
# Epoch 17/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1184 - accuracy: 0.9617
# Epoch 17: val_loss improved from 0.11816 to 0.10447, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 6839s 9s/step - loss: 0.1184 - accuracy: 0.9617 - val_loss: 0.1045 - val_accuracy: 0.9641 - lr: 5.0000e-04
# Epoch 18/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1063 - accuracy: 0.9640
# Epoch 18: val_loss did not improve from 0.10447
# 764/764 [==============================] - 6819s 9s/step - loss: 0.1063 - accuracy: 0.9640 - val_loss: 0.1046 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 19/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9635
# Epoch 19: val_loss did not improve from 0.10447
# 764/764 [==============================] - 6790s 9s/step - loss: 0.1070 - accuracy: 0.9635 - val_loss: 0.1072 - val_accuracy: 0.9618 - lr: 5.0000e-04
# Epoch 20/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9666
# Epoch 20: val_loss did not improve from 0.10447
# 764/764 [==============================] - 6851s 9s/step - loss: 0.1046 - accuracy: 0.9666 - val_loss: 0.1640 - val_accuracy: 0.9480 - lr: 5.0000e-04
# Epoch 21/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1075 - accuracy: 0.9638
# Epoch 21: val_loss did not improve from 0.10447
# 764/764 [==============================] - 6822s 9s/step - loss: 0.1075 - accuracy: 0.9638 - val_loss: 0.1205 - val_accuracy: 0.9618 - lr: 5.0000e-04
# Epoch 22/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1118 - accuracy: 0.9623
# Epoch 22: val_loss did not improve from 0.10447
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 764/764 [==============================] - 6915s 9s/step - loss: 0.1118 - accuracy: 0.9623 - val_loss: 0.1190 - val_accuracy: 0.9633 - lr: 5.0000e-04
# Epoch 23/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9723
# Epoch 23: val_loss did not improve from 0.10447
# 764/764 [==============================] - 6848s 9s/step - loss: 0.0831 - accuracy: 0.9723 - val_loss: 0.1238 - val_accuracy: 0.9587 - lr: 2.5000e-04
# Epoch 24/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9741
# Epoch 24: val_loss did not improve from 0.10447
# 764/764 [==============================] - 10237s 13s/step - loss: 0.0757 - accuracy: 0.9741 - val_loss: 0.1165 - val_accuracy: 0.9610 - lr: 2.5000e-04
# Epoch 25/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 0.9738
# Epoch 25: val_loss improved from 0.10447 to 0.09386, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 6530s 9s/step - loss: 0.0769 - accuracy: 0.9738 - val_loss: 0.0939 - val_accuracy: 0.9671 - lr: 2.5000e-04
# Epoch 26/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9746
# Epoch 26: val_loss did not improve from 0.09386
# 764/764 [==============================] - 35211s 46s/step - loss: 0.0786 - accuracy: 0.9746 - val_loss: 0.1094 - val_accuracy: 0.9610 - lr: 2.5000e-04
# Epoch 27/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9767
# Epoch 27: val_loss did not improve from 0.09386
# 764/764 [==============================] - 6422s 8s/step - loss: 0.0728 - accuracy: 0.9767 - val_loss: 0.0943 - val_accuracy: 0.9664 - lr: 2.5000e-04
# Epoch 28/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9741
# Epoch 28: val_loss improved from 0.09386 to 0.08330, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 6416s 8s/step - loss: 0.0746 - accuracy: 0.9741 - val_loss: 0.0833 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 29/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9769
# Epoch 29: val_loss did not improve from 0.08330
# 764/764 [==============================] - 6408s 8s/step - loss: 0.0719 - accuracy: 0.9769 - val_loss: 0.0920 - val_accuracy: 0.9694 - lr: 2.5000e-04
# Epoch 30/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9758
# Epoch 30: val_loss did not improve from 0.08330
# 764/764 [==============================] - 6405s 8s/step - loss: 0.0744 - accuracy: 0.9758 - val_loss: 0.1019 - val_accuracy: 0.9648 - lr: 2.5000e-04
# Epoch 31/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0685 - accuracy: 0.9782
# Epoch 31: val_loss did not improve from 0.08330
# 764/764 [==============================] - 6465s 8s/step - loss: 0.0685 - accuracy: 0.9782 - val_loss: 0.0845 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 32/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9764
# Epoch 32: val_loss did not improve from 0.08330
# 764/764 [==============================] - 6571s 9s/step - loss: 0.0784 - accuracy: 0.9764 - val_loss: 0.0857 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 33/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9746
# Epoch 33: val_loss did not improve from 0.08330
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 764/764 [==============================] - 6541s 9s/step - loss: 0.0719 - accuracy: 0.9746 - val_loss: 0.0931 - val_accuracy: 0.9671 - lr: 2.5000e-04
# Epoch 34/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9797
# Epoch 34: val_loss did not improve from 0.08330
# 764/764 [==============================] - 6515s 9s/step - loss: 0.0639 - accuracy: 0.9797 - val_loss: 0.0911 - val_accuracy: 0.9664 - lr: 1.2500e-04
# Epoch 35/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0685 - accuracy: 0.9790
# Epoch 35: val_loss improved from 0.08330 to 0.08030, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 36816s 48s/step - loss: 0.0685 - accuracy: 0.9790 - val_loss: 0.0803 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 36/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9785
# Epoch 36: val_loss did not improve from 0.08030
# 764/764 [==============================] - 6643s 9s/step - loss: 0.0597 - accuracy: 0.9785 - val_loss: 0.0899 - val_accuracy: 0.9702 - lr: 1.2500e-04
# Epoch 37/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9821
# Epoch 37: val_loss improved from 0.08030 to 0.07245, saving model to efficientnetB5_sin_ft_weights.h5
# 764/764 [==============================] - 6517s 9s/step - loss: 0.0546 - accuracy: 0.9821 - val_loss: 0.0724 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 38/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9769
# Epoch 38: val_loss did not improve from 0.07245
# 764/764 [==============================] - 6542s 9s/step - loss: 0.0659 - accuracy: 0.9769 - val_loss: 0.0827 - val_accuracy: 0.9702 - lr: 1.2500e-04
# Epoch 39/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9781
# Epoch 39: val_loss did not improve from 0.07245
# 764/764 [==============================] - 6518s 9s/step - loss: 0.0641 - accuracy: 0.9781 - val_loss: 0.0881 - val_accuracy: 0.9702 - lr: 1.2500e-04
# Epoch 40/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9821
# Epoch 40: val_loss did not improve from 0.07245
# 764/764 [==============================] - 7136s 9s/step - loss: 0.0609 - accuracy: 0.9821 - val_loss: 0.0851 - val_accuracy: 0.9709 - lr: 1.2500e-04
# Epoch 41/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9813
# Epoch 41: val_loss did not improve from 0.07245
# 764/764 [==============================] - 6795s 9s/step - loss: 0.0553 - accuracy: 0.9813 - val_loss: 0.0853 - val_accuracy: 0.9694 - lr: 1.2500e-04
# Epoch 42/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9813
# Epoch 42: val_loss did not improve from 0.07245
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 764/764 [==============================] - 6679s 9s/step - loss: 0.0542 - accuracy: 0.9813 - val_loss: 0.0845 - val_accuracy: 0.9702 - lr: 1.2500e-04
# Epoch 43/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9815
# Epoch 43: val_loss did not improve from 0.07245
# 764/764 [==============================] - 6428s 8s/step - loss: 0.0555 - accuracy: 0.9815 - val_loss: 0.0862 - val_accuracy: 0.9702 - lr: 6.2500e-05
# Epoch 44/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0552 - accuracy: 0.9823
# Epoch 44: val_loss did not improve from 0.07245
# 764/764 [==============================] - 6447s 8s/step - loss: 0.0552 - accuracy: 0.9823 - val_loss: 0.0813 - val_accuracy: 0.9709 - lr: 6.2500e-05
# Epoch 45/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9815
# Epoch 45: val_loss did not improve from 0.07245
# 764/764 [==============================] - 6468s 8s/step - loss: 0.0553 - accuracy: 0.9815 - val_loss: 0.0809 - val_accuracy: 0.9702 - lr: 6.2500e-05
# Epoch 46/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9846
# Epoch 46: val_loss did not improve from 0.07245
# 764/764 [==============================] - 6390s 8s/step - loss: 0.0474 - accuracy: 0.9846 - val_loss: 0.0838 - val_accuracy: 0.9709 - lr: 6.2500e-05
# Epoch 47/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9821Restoring model weights from the end of the best epoch: 37.
#
# Epoch 47: val_loss did not improve from 0.07245
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 764/764 [==============================] - 6305s 8s/step - loss: 0.0531 - accuracy: 0.9821 - val_loss: 0.0814 - val_accuracy: 0.9717 - lr: 6.2500e-05
# Epoch 47: early stopping

# %% [markdown]
# ### 7. EVALUACIÓN DEL MODELO EFFICIENTNETB5

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

# Gráfica de Loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 164/164 [==============================] - 1085s 7s/step - loss: 0.0596 - accuracy: 0.9832
#
# Test Accuracy : 0.9832
# Test Loss     : 0.0596
# 164/164 [==============================] - 1096s 7s/step
# F1 Score      : 0.9832
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9613    0.9933    0.9770       150
#    mancha_anillo     0.9905    0.9905    0.9905       105
#     mancha_parda     0.9932    0.9800    0.9866       150
#          mosaico     0.9800    0.9800    0.9800       150
#      muermo_rojo     0.9864    0.9667    0.9764       150
#             roya     0.9732    0.9667    0.9699       150
#            sanas     0.9735    0.9800    0.9767       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     0.9933    0.9933    0.9933       150
#
#         accuracy                         0.9832      1308
#        macro avg     0.9851    0.9850    0.9851      1308
#     weighted avg     0.9833    0.9832    0.9832      1308
#
#
# Resultados guardados en efficientnetB5_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Pares con 5 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#
# Total de imágenes a mostrar: 0

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB5_sin_ft_weights.h5
