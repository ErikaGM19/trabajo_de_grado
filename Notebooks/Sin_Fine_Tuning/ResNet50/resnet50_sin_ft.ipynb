# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = 'resnet50_sin_ft'

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO RESNET50

# %%
# CARGAR RESNET50 CON PESOS DE IMAGENET
base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False    # Congelamos toda la red base 

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 11s 0us/step

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 23,851,274
# Trainable params: 263,562
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.9197 - accuracy: 0.7006
# Epoch 1: val_loss improved from inf to 0.30036, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1152s 6s/step - loss: 0.9197 - accuracy: 0.7006 - val_loss: 0.3004 - val_accuracy: 0.8968 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4412 - accuracy: 0.8592
# Epoch 2: val_loss improved from 0.30036 to 0.20218, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1198s 6s/step - loss: 0.4412 - accuracy: 0.8592 - val_loss: 0.2022 - val_accuracy: 0.9388 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3516 - accuracy: 0.8916
# Epoch 3: val_loss improved from 0.20218 to 0.18006, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1210s 6s/step - loss: 0.3516 - accuracy: 0.8916 - val_loss: 0.1801 - val_accuracy: 0.9411 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.9034
# Epoch 4: val_loss improved from 0.18006 to 0.16724, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1202s 6s/step - loss: 0.3000 - accuracy: 0.9034 - val_loss: 0.1672 - val_accuracy: 0.9427 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2769 - accuracy: 0.9076
# Epoch 5: val_loss improved from 0.16724 to 0.13681, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1216s 6s/step - loss: 0.2769 - accuracy: 0.9076 - val_loss: 0.1368 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2368 - accuracy: 0.9243
# Epoch 6: val_loss improved from 0.13681 to 0.12673, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1203s 6s/step - loss: 0.2368 - accuracy: 0.9243 - val_loss: 0.1267 - val_accuracy: 0.9564 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2560 - accuracy: 0.9135
# Epoch 7: val_loss improved from 0.12673 to 0.11316, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1212s 6s/step - loss: 0.2560 - accuracy: 0.9135 - val_loss: 0.1132 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2282 - accuracy: 0.9279
# Epoch 8: val_loss improved from 0.11316 to 0.10513, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1217s 6s/step - loss: 0.2282 - accuracy: 0.9279 - val_loss: 0.1051 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2114 - accuracy: 0.9314
# Epoch 9: val_loss did not improve from 0.10513
# 191/191 [==============================] - 1210s 6s/step - loss: 0.2114 - accuracy: 0.9314 - val_loss: 0.1135 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9338
# Epoch 10: val_loss improved from 0.10513 to 0.10356, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1248s 7s/step - loss: 0.1998 - accuracy: 0.9338 - val_loss: 0.1036 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1839 - accuracy: 0.9355
# Epoch 11: val_loss did not improve from 0.10356
# 191/191 [==============================] - 1220s 6s/step - loss: 0.1839 - accuracy: 0.9355 - val_loss: 0.1166 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1834 - accuracy: 0.9384
# Epoch 12: val_loss improved from 0.10356 to 0.10074, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1250s 7s/step - loss: 0.1834 - accuracy: 0.9384 - val_loss: 0.1007 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2008 - accuracy: 0.9363
# Epoch 13: val_loss improved from 0.10074 to 0.09743, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1215s 6s/step - loss: 0.2008 - accuracy: 0.9363 - val_loss: 0.0974 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1526 - accuracy: 0.9504
# Epoch 14: val_loss did not improve from 0.09743
# 191/191 [==============================] - 1214s 6s/step - loss: 0.1526 - accuracy: 0.9504 - val_loss: 0.1091 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1727 - accuracy: 0.9417
# Epoch 15: val_loss did not improve from 0.09743
# 191/191 [==============================] - 1210s 6s/step - loss: 0.1727 - accuracy: 0.9417 - val_loss: 0.1221 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9410
# Epoch 16: val_loss did not improve from 0.09743
# 191/191 [==============================] - 1221s 6s/step - loss: 0.1842 - accuracy: 0.9410 - val_loss: 0.1159 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1637 - accuracy: 0.9448
# Epoch 17: val_loss did not improve from 0.09743
# 191/191 [==============================] - 1218s 6s/step - loss: 0.1637 - accuracy: 0.9448 - val_loss: 0.1268 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.9481
# Epoch 18: val_loss improved from 0.09743 to 0.08456, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1221s 6s/step - loss: 0.1660 - accuracy: 0.9481 - val_loss: 0.0846 - val_accuracy: 0.9740 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9484
# Epoch 19: val_loss did not improve from 0.08456
# 191/191 [==============================] - 1222s 6s/step - loss: 0.1603 - accuracy: 0.9484 - val_loss: 0.1257 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9482
# Epoch 20: val_loss did not improve from 0.08456
# 191/191 [==============================] - 1284s 7s/step - loss: 0.1609 - accuracy: 0.9482 - val_loss: 0.1085 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9505
# Epoch 21: val_loss did not improve from 0.08456
# 191/191 [==============================] - 1241s 6s/step - loss: 0.1561 - accuracy: 0.9505 - val_loss: 0.1040 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9502
# Epoch 22: val_loss did not improve from 0.08456
# 191/191 [==============================] - 1228s 6s/step - loss: 0.1535 - accuracy: 0.9502 - val_loss: 0.0979 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9523
# Epoch 23: val_loss did not improve from 0.08456
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 1232s 6s/step - loss: 0.1414 - accuracy: 0.9523 - val_loss: 0.1044 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9609
# Epoch 24: val_loss did not improve from 0.08456
# 191/191 [==============================] - 1223s 6s/step - loss: 0.1147 - accuracy: 0.9609 - val_loss: 0.0973 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1097 - accuracy: 0.9653
# Epoch 25: val_loss improved from 0.08456 to 0.08041, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1235s 6s/step - loss: 0.1097 - accuracy: 0.9653 - val_loss: 0.0804 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9677
# Epoch 26: val_loss did not improve from 0.08041
# 191/191 [==============================] - 1231s 6s/step - loss: 0.1041 - accuracy: 0.9677 - val_loss: 0.0941 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0995 - accuracy: 0.9653
# Epoch 27: val_loss did not improve from 0.08041
# 191/191 [==============================] - 1228s 6s/step - loss: 0.0995 - accuracy: 0.9653 - val_loss: 0.0853 - val_accuracy: 0.9732 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9712
# Epoch 28: val_loss did not improve from 0.08041
# 191/191 [==============================] - 1317s 7s/step - loss: 0.0947 - accuracy: 0.9712 - val_loss: 0.0851 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0878 - accuracy: 0.9676
# Epoch 29: val_loss did not improve from 0.08041
# 191/191 [==============================] - 1257s 7s/step - loss: 0.0878 - accuracy: 0.9676 - val_loss: 0.0861 - val_accuracy: 0.9740 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.9674
# Epoch 30: val_loss did not improve from 0.08041
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 5992s 32s/step - loss: 0.0990 - accuracy: 0.9674 - val_loss: 0.0855 - val_accuracy: 0.9725 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9702
# Epoch 31: val_loss did not improve from 0.08041
# 191/191 [==============================] - 1075s 6s/step - loss: 0.0817 - accuracy: 0.9702 - val_loss: 0.0916 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9733
# Epoch 32: val_loss improved from 0.08041 to 0.07936, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1022s 5s/step - loss: 0.0787 - accuracy: 0.9733 - val_loss: 0.0794 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.9736
# Epoch 33: val_loss improved from 0.07936 to 0.07881, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1013s 5s/step - loss: 0.0814 - accuracy: 0.9736 - val_loss: 0.0788 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9751
# Epoch 34: val_loss did not improve from 0.07881
# 191/191 [==============================] - 1001s 5s/step - loss: 0.0784 - accuracy: 0.9751 - val_loss: 0.0862 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9725
# Epoch 35: val_loss did not improve from 0.07881
# 191/191 [==============================] - 1105s 6s/step - loss: 0.0824 - accuracy: 0.9725 - val_loss: 0.0862 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9764
# Epoch 36: val_loss did not improve from 0.07881
# 191/191 [==============================] - 1167s 6s/step - loss: 0.0777 - accuracy: 0.9764 - val_loss: 0.0872 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9781
# Epoch 37: val_loss did not improve from 0.07881
# 191/191 [==============================] - 1155s 6s/step - loss: 0.0656 - accuracy: 0.9781 - val_loss: 0.0819 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9779
# Epoch 38: val_loss improved from 0.07881 to 0.07446, saving model to resnet50_sin_ft_weights.h5
# 191/191 [==============================] - 1140s 6s/step - loss: 0.0699 - accuracy: 0.9779 - val_loss: 0.0745 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9749
# Epoch 39: val_loss did not improve from 0.07446
# 191/191 [==============================] - 1143s 6s/step - loss: 0.0735 - accuracy: 0.9749 - val_loss: 0.0804 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9790
# Epoch 40: val_loss did not improve from 0.07446
# 191/191 [==============================] - 1149s 6s/step - loss: 0.0639 - accuracy: 0.9790 - val_loss: 0.0831 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9761
# Epoch 41: val_loss did not improve from 0.07446
# 191/191 [==============================] - 1149s 6s/step - loss: 0.0740 - accuracy: 0.9761 - val_loss: 0.0788 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9776
# Epoch 42: val_loss did not improve from 0.07446
# 191/191 [==============================] - 1144s 6s/step - loss: 0.0668 - accuracy: 0.9776 - val_loss: 0.0774 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0689 - accuracy: 0.9771
# Epoch 43: val_loss did not improve from 0.07446
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 1147s 6s/step - loss: 0.0689 - accuracy: 0.9771 - val_loss: 0.0898 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9758
# Epoch 44: val_loss did not improve from 0.07446
# 191/191 [==============================] - 1167s 6s/step - loss: 0.0695 - accuracy: 0.9758 - val_loss: 0.0774 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9794
# Epoch 45: val_loss did not improve from 0.07446
# 191/191 [==============================] - 1162s 6s/step - loss: 0.0656 - accuracy: 0.9794 - val_loss: 0.0800 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9794
# Epoch 46: val_loss did not improve from 0.07446
# 191/191 [==============================] - 1169s 6s/step - loss: 0.0640 - accuracy: 0.9794 - val_loss: 0.0811 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9790
# Epoch 47: val_loss did not improve from 0.07446
# 191/191 [==============================] - 1169s 6s/step - loss: 0.0651 - accuracy: 0.9790 - val_loss: 0.0776 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9779Restoring model weights from the end of the best epoch: 38.
#
# Epoch 48: val_loss did not improve from 0.07446
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 1165s 6s/step - loss: 0.0642 - accuracy: 0.9779 - val_loss: 0.0798 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 48: early stopping

# %% [markdown]
# ### 7. CURVAS DE ENTRENAMIENTO

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 200s 5s/step - loss: 0.0658 - accuracy: 0.9778
#
# Test Accuracy : 0.9778
# Test Loss     : 0.0658
# 41/41 [==============================] - 197s 5s/step
# F1 Score      : 0.9778
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9801    0.9867    0.9834       150
#    mancha_anillo     0.9813    1.0000    0.9906       105
#     mancha_parda     0.9669    0.9733    0.9701       150
#          mosaico     0.9864    0.9667    0.9764       150
#      muermo_rojo     0.9474    0.9600    0.9536       150
#             roya     0.9859    0.9333    0.9589       150
#            sanas     0.9613    0.9933    0.9770       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     0.9933    0.9933    0.9933       150
#
#         accuracy                         0.9778      1308
#        macro avg     0.9803    0.9807    0.9803      1308
#     weighted avg     0.9780    0.9778    0.9778      1308
#
#
# Resultados guardados en resnet50_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL          = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 5 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#   roya → muermo_rojo: 5 imágenes
#
# Total de imágenes a mostrar: 5

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: resnet50_sin_ft_weights.h5
