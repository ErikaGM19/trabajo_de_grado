# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE      = 380
BATCH_SIZE    = 16
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = "efficientnetB4_sin_ft"

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFIENTNETB4

# %%
# CARGAR EFFICIENTNET-B4 CON PESOS DE IMAGENET

base_model = EfficientNetB4(
    weights='imagenet',                 
    include_top=False,                  
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Congelamos la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb4 (Functional)  (None, 12, 12, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               229504
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 17,904,617
# Trainable params: 230,794
# Non-trainable params: 17,673,823
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{NOMBRE_MODELO}_weights.h5",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 382/382 [==============================] - ETA: 0s - loss: 0.8629 - accuracy: 0.7083
# Epoch 1: val_loss improved from inf to 0.41485, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1130s 3s/step - loss: 0.8629 - accuracy: 0.7083 - val_loss: 0.4148 - val_accuracy: 0.8670 - lr: 0.0010
# Epoch 2/75
# 382/382 [==============================] - ETA: 0s - loss: 0.4373 - accuracy: 0.8541
# Epoch 2: val_loss improved from 0.41485 to 0.26852, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1089s 3s/step - loss: 0.4373 - accuracy: 0.8541 - val_loss: 0.2685 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 3/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3531 - accuracy: 0.8829
# Epoch 3: val_loss improved from 0.26852 to 0.23310, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1087s 3s/step - loss: 0.3531 - accuracy: 0.8829 - val_loss: 0.2331 - val_accuracy: 0.9343 - lr: 0.0010
# Epoch 4/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.8952
# Epoch 4: val_loss improved from 0.23310 to 0.22847, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1085s 3s/step - loss: 0.3069 - accuracy: 0.8952 - val_loss: 0.2285 - val_accuracy: 0.9159 - lr: 0.0010
# Epoch 5/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2859 - accuracy: 0.9052
# Epoch 5: val_loss improved from 0.22847 to 0.15627, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1085s 3s/step - loss: 0.2859 - accuracy: 0.9052 - val_loss: 0.1563 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 6/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.9168
# Epoch 6: val_loss did not improve from 0.15627
# 382/382 [==============================] - 1080s 3s/step - loss: 0.2594 - accuracy: 0.9168 - val_loss: 0.1631 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 7/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.9179
# Epoch 7: val_loss did not improve from 0.15627
# 382/382 [==============================] - 1094s 3s/step - loss: 0.2395 - accuracy: 0.9179 - val_loss: 0.1584 - val_accuracy: 0.9442 - lr: 0.0010
# Epoch 8/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.9176
# Epoch 8: val_loss improved from 0.15627 to 0.14768, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1091s 3s/step - loss: 0.2384 - accuracy: 0.9176 - val_loss: 0.1477 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 9/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2197 - accuracy: 0.9299
# Epoch 9: val_loss improved from 0.14768 to 0.14044, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1089s 3s/step - loss: 0.2197 - accuracy: 0.9299 - val_loss: 0.1404 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 10/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2107 - accuracy: 0.9281
# Epoch 10: val_loss did not improve from 0.14044
# 382/382 [==============================] - 1089s 3s/step - loss: 0.2107 - accuracy: 0.9281 - val_loss: 0.1535 - val_accuracy: 0.9396 - lr: 0.0010
# Epoch 11/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2075 - accuracy: 0.9286
# Epoch 11: val_loss improved from 0.14044 to 0.11365, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1084s 3s/step - loss: 0.2075 - accuracy: 0.9286 - val_loss: 0.1137 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 12/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9365
# Epoch 12: val_loss did not improve from 0.11365
# 382/382 [==============================] - 1095s 3s/step - loss: 0.1915 - accuracy: 0.9365 - val_loss: 0.1154 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 13/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.9394
# Epoch 13: val_loss did not improve from 0.11365
# 382/382 [==============================] - 1096s 3s/step - loss: 0.1772 - accuracy: 0.9394 - val_loss: 0.1240 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 14/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1919 - accuracy: 0.9384
# Epoch 14: val_loss did not improve from 0.11365
# 382/382 [==============================] - 1052s 3s/step - loss: 0.1919 - accuracy: 0.9384 - val_loss: 0.1163 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 15/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1886 - accuracy: 0.9356
# Epoch 15: val_loss improved from 0.11365 to 0.11287, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 989s 3s/step - loss: 0.1886 - accuracy: 0.9356 - val_loss: 0.1129 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 16/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9387
# Epoch 16: val_loss did not improve from 0.11287
# 382/382 [==============================] - 990s 3s/step - loss: 0.1841 - accuracy: 0.9387 - val_loss: 0.1164 - val_accuracy: 0.9625 - lr: 0.0010
# Epoch 17/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1624 - accuracy: 0.9471
# Epoch 17: val_loss improved from 0.11287 to 0.10880, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 990s 3s/step - loss: 0.1624 - accuracy: 0.9471 - val_loss: 0.1088 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 18/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1744 - accuracy: 0.9419
# Epoch 18: val_loss improved from 0.10880 to 0.10850, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1015s 3s/step - loss: 0.1744 - accuracy: 0.9419 - val_loss: 0.1085 - val_accuracy: 0.9625 - lr: 0.0010
# Epoch 19/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.9446
# Epoch 19: val_loss did not improve from 0.10850
# 382/382 [==============================] - 1038s 3s/step - loss: 0.1591 - accuracy: 0.9446 - val_loss: 0.1194 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 20/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9451
# Epoch 20: val_loss improved from 0.10850 to 0.09489, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1036s 3s/step - loss: 0.1609 - accuracy: 0.9451 - val_loss: 0.0949 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 21/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 0.9482
# Epoch 21: val_loss did not improve from 0.09489
# 382/382 [==============================] - 1036s 3s/step - loss: 0.1553 - accuracy: 0.9482 - val_loss: 0.1126 - val_accuracy: 0.9564 - lr: 0.0010
# Epoch 22/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1690 - accuracy: 0.9443
# Epoch 22: val_loss did not improve from 0.09489
# 382/382 [==============================] - 1226s 3s/step - loss: 0.1690 - accuracy: 0.9443 - val_loss: 0.1100 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 23/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 0.9453
# Epoch 23: val_loss improved from 0.09489 to 0.09341, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1173s 3s/step - loss: 0.1570 - accuracy: 0.9453 - val_loss: 0.0934 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 24/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1547 - accuracy: 0.9476
# Epoch 24: val_loss did not improve from 0.09341
# 382/382 [==============================] - 1103s 3s/step - loss: 0.1547 - accuracy: 0.9476 - val_loss: 0.0940 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 25/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9522
# Epoch 25: val_loss did not improve from 0.09341
# 382/382 [==============================] - 1083s 3s/step - loss: 0.1400 - accuracy: 0.9522 - val_loss: 0.1302 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 26/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1473 - accuracy: 0.9505
# Epoch 26: val_loss did not improve from 0.09341
# 382/382 [==============================] - 1080s 3s/step - loss: 0.1473 - accuracy: 0.9505 - val_loss: 0.1115 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 27/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9505
# Epoch 27: val_loss did not improve from 0.09341
# 382/382 [==============================] - 1079s 3s/step - loss: 0.1485 - accuracy: 0.9505 - val_loss: 0.1257 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 28/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9505
# Epoch 28: val_loss did not improve from 0.09341
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 382/382 [==============================] - 1085s 3s/step - loss: 0.1443 - accuracy: 0.9505 - val_loss: 0.1024 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 29/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1139 - accuracy: 0.9620
# Epoch 29: val_loss did not improve from 0.09341
# 382/382 [==============================] - 1083s 3s/step - loss: 0.1139 - accuracy: 0.9620 - val_loss: 0.0948 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 30/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9659
# Epoch 30: val_loss improved from 0.09341 to 0.09338, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1084s 3s/step - loss: 0.0975 - accuracy: 0.9659 - val_loss: 0.0934 - val_accuracy: 0.9656 - lr: 5.0000e-04
# Epoch 31/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9633
# Epoch 31: val_loss improved from 0.09338 to 0.08351, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1085s 3s/step - loss: 0.1049 - accuracy: 0.9633 - val_loss: 0.0835 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 32/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9674
# Epoch 32: val_loss improved from 0.08351 to 0.07640, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1086s 3s/step - loss: 0.0968 - accuracy: 0.9674 - val_loss: 0.0764 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 33/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9668
# Epoch 33: val_loss did not improve from 0.07640
# 382/382 [==============================] - 1086s 3s/step - loss: 0.0982 - accuracy: 0.9668 - val_loss: 0.0958 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 34/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9690
# Epoch 34: val_loss did not improve from 0.07640
# 382/382 [==============================] - 1088s 3s/step - loss: 0.0917 - accuracy: 0.9690 - val_loss: 0.0872 - val_accuracy: 0.9687 - lr: 5.0000e-04
# Epoch 35/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1004 - accuracy: 0.9684
# Epoch 35: val_loss did not improve from 0.07640
# 382/382 [==============================] - 1082s 3s/step - loss: 0.1004 - accuracy: 0.9684 - val_loss: 0.0855 - val_accuracy: 0.9687 - lr: 5.0000e-04
# Epoch 36/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9681
# Epoch 36: val_loss did not improve from 0.07640
# 382/382 [==============================] - 1080s 3s/step - loss: 0.0912 - accuracy: 0.9681 - val_loss: 0.0780 - val_accuracy: 0.9732 - lr: 5.0000e-04
# Epoch 37/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9664
# Epoch 37: val_loss did not improve from 0.07640
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 382/382 [==============================] - 1085s 3s/step - loss: 0.0927 - accuracy: 0.9664 - val_loss: 0.0945 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 38/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0908 - accuracy: 0.9692
# Epoch 38: val_loss did not improve from 0.07640
# 382/382 [==============================] - 1084s 3s/step - loss: 0.0908 - accuracy: 0.9692 - val_loss: 0.0791 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 39/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9704
# Epoch 39: val_loss improved from 0.07640 to 0.07326, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1081s 3s/step - loss: 0.0855 - accuracy: 0.9704 - val_loss: 0.0733 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 40/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9713
# Epoch 40: val_loss improved from 0.07326 to 0.06856, saving model to efficientnetB4_sin_ft_weights.h5
# 382/382 [==============================] - 1085s 3s/step - loss: 0.0795 - accuracy: 0.9713 - val_loss: 0.0686 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 41/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9769
# Epoch 41: val_loss did not improve from 0.06856
# 382/382 [==============================] - 1087s 3s/step - loss: 0.0782 - accuracy: 0.9769 - val_loss: 0.0834 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 42/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9708
# Epoch 42: val_loss did not improve from 0.06856
# 382/382 [==============================] - 1082s 3s/step - loss: 0.0782 - accuracy: 0.9708 - val_loss: 0.0831 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 43/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9733
# Epoch 43: val_loss did not improve from 0.06856
# 382/382 [==============================] - 1088s 3s/step - loss: 0.0760 - accuracy: 0.9733 - val_loss: 0.0756 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 44/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9756
# Epoch 44: val_loss did not improve from 0.06856
# 382/382 [==============================] - 1082s 3s/step - loss: 0.0718 - accuracy: 0.9756 - val_loss: 0.0755 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 45/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9735
# Epoch 45: val_loss did not improve from 0.06856
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 382/382 [==============================] - 1082s 3s/step - loss: 0.0761 - accuracy: 0.9735 - val_loss: 0.0895 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 46/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9754
# Epoch 46: val_loss did not improve from 0.06856
# 382/382 [==============================] - 1086s 3s/step - loss: 0.0734 - accuracy: 0.9754 - val_loss: 0.0777 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 47/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9802
# Epoch 47: val_loss did not improve from 0.06856
# 382/382 [==============================] - 1092s 3s/step - loss: 0.0637 - accuracy: 0.9802 - val_loss: 0.0706 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 48/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9767
# Epoch 48: val_loss did not improve from 0.06856
# 382/382 [==============================] - 1083s 3s/step - loss: 0.0729 - accuracy: 0.9767 - val_loss: 0.0726 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 49/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9803
# Epoch 49: val_loss did not improve from 0.06856
# 382/382 [==============================] - 1084s 3s/step - loss: 0.0607 - accuracy: 0.9803 - val_loss: 0.0743 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 50/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9777Restoring model weights from the end of the best epoch: 40.
#
# Epoch 50: val_loss did not improve from 0.06856
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 382/382 [==============================] - 1084s 3s/step - loss: 0.0678 - accuracy: 0.9777 - val_loss: 0.0806 - val_accuracy: 0.9717 - lr: 1.2500e-04
# Epoch 50: early stopping

# %% [markdown]
# ### 7. EVALUACIÓN DEL MODELO EFFICIENTNETB4

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

# Gráfica de Loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 82/82 [==============================] - 178s 2s/step - loss: 0.0534 - accuracy: 0.9855
#
# Test Accuracy : 0.9855
# Test Loss     : 0.0534
# 82/82 [==============================] - 181s 2s/step
# F1 Score      : 0.9855
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9740    1.0000    0.9868       150
#    mancha_anillo     0.9906    1.0000    0.9953       105
#     mancha_parda     0.9799    0.9733    0.9766       150
#          mosaico     0.9933    0.9933    0.9933       150
#      muermo_rojo     0.9733    0.9733    0.9733       150
#             roya     0.9735    0.9800    0.9767       150
#            sanas     0.9932    0.9733    0.9832       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     0.9932    0.9800    0.9866       150
#
#         accuracy                         0.9855      1308
#        macro avg     0.9871    0.9873    0.9872      1308
#     weighted avg     0.9855    0.9855    0.9855      1308
#
#
# Resultados guardados en efficientnetB4_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Pares con 5 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#
# Total de imágenes a mostrar: 0

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB4_sin_ft_weights.h5
