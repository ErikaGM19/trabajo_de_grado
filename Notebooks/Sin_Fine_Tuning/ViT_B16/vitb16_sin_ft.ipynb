# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from vit_keras import vit
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# C:\Users\USUARIO\AppData\Roaming\Python\Python310\site-packages\vit_keras\utils.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = 'vitb16_sin_ft'

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# Función de preprocesamiento específica de ViT (escala 0-1)
def preprocess_vit(image):
    image = image / 255.0
    return image

# # Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_vit,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_vit
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO ViT-B16

# %%
# CARGAR ViT-B16 CON PESOS DE IMAGENET
vit_model = vit.vit_b16(
    image_size=IMG_SIZE,
    activation='softmax',
    pretrained=True,
    include_top=False,
    pretrained_top=False
)

vit_model.trainable = False     # Congelamos toda la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    vit_model,
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# C:\Users\USUARIO\AppData\Roaming\Python\Python310\site-packages\vit_keras\utils.py:81: UserWarning: Resizing position embeddings from 24, 24 to 14, 14
#   warnings.warn(

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit-b16 (Functional)        (None, 768)               85798656
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense (Dense)               (None, 256)               196864
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 85,998,090
# Trainable params: 199,434
# Non-trainable params: 85,798,656
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# CALLBACKS

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.9348 - accuracy: 0.6856
# Epoch 1: val_loss improved from inf to 0.39220, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1948s 10s/step - loss: 0.9348 - accuracy: 0.6856 - val_loss: 0.3922 - val_accuracy: 0.8746 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4552 - accuracy: 0.8454
# Epoch 2: val_loss improved from 0.39220 to 0.25896, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1916s 10s/step - loss: 0.4552 - accuracy: 0.8454 - val_loss: 0.2590 - val_accuracy: 0.9197 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3744 - accuracy: 0.8744
# Epoch 3: val_loss improved from 0.25896 to 0.23038, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1914s 10s/step - loss: 0.3744 - accuracy: 0.8744 - val_loss: 0.2304 - val_accuracy: 0.9197 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3185 - accuracy: 0.8911
# Epoch 4: val_loss improved from 0.23038 to 0.20982, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1917s 10s/step - loss: 0.3185 - accuracy: 0.8911 - val_loss: 0.2098 - val_accuracy: 0.9404 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2935 - accuracy: 0.9055
# Epoch 5: val_loss improved from 0.20982 to 0.18872, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1920s 10s/step - loss: 0.2935 - accuracy: 0.9055 - val_loss: 0.1887 - val_accuracy: 0.9373 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2798 - accuracy: 0.9058
# Epoch 6: val_loss did not improve from 0.18872
# 191/191 [==============================] - 1912s 10s/step - loss: 0.2798 - accuracy: 0.9058 - val_loss: 0.1918 - val_accuracy: 0.9411 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2584 - accuracy: 0.9094
# Epoch 7: val_loss did not improve from 0.18872
# 191/191 [==============================] - 1914s 10s/step - loss: 0.2584 - accuracy: 0.9094 - val_loss: 0.1975 - val_accuracy: 0.9358 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.9158
# Epoch 8: val_loss improved from 0.18872 to 0.17672, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1915s 10s/step - loss: 0.2494 - accuracy: 0.9158 - val_loss: 0.1767 - val_accuracy: 0.9365 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2315 - accuracy: 0.9217
# Epoch 9: val_loss improved from 0.17672 to 0.16705, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1908s 10s/step - loss: 0.2315 - accuracy: 0.9217 - val_loss: 0.1671 - val_accuracy: 0.9434 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2111 - accuracy: 0.9286
# Epoch 10: val_loss did not improve from 0.16705
# 191/191 [==============================] - 1913s 10s/step - loss: 0.2111 - accuracy: 0.9286 - val_loss: 0.1779 - val_accuracy: 0.9404 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2270 - accuracy: 0.9237
# Epoch 11: val_loss improved from 0.16705 to 0.15502, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1911s 10s/step - loss: 0.2270 - accuracy: 0.9237 - val_loss: 0.1550 - val_accuracy: 0.9434 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.9243
# Epoch 12: val_loss improved from 0.15502 to 0.14999, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1906s 10s/step - loss: 0.2180 - accuracy: 0.9243 - val_loss: 0.1500 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2103 - accuracy: 0.9279
# Epoch 13: val_loss improved from 0.14999 to 0.14862, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1908s 10s/step - loss: 0.2103 - accuracy: 0.9279 - val_loss: 0.1486 - val_accuracy: 0.9495 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2072 - accuracy: 0.9302
# Epoch 14: val_loss did not improve from 0.14862
# 191/191 [==============================] - 1912s 10s/step - loss: 0.2072 - accuracy: 0.9302 - val_loss: 0.1618 - val_accuracy: 0.9404 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 0.9338
# Epoch 15: val_loss did not improve from 0.14862
# 191/191 [==============================] - 1910s 10s/step - loss: 0.1972 - accuracy: 0.9338 - val_loss: 0.1568 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.9368
# Epoch 16: val_loss did not improve from 0.14862
# 191/191 [==============================] - 1913s 10s/step - loss: 0.1900 - accuracy: 0.9368 - val_loss: 0.1678 - val_accuracy: 0.9457 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2034 - accuracy: 0.9302
# Epoch 17: val_loss did not improve from 0.14862
# 191/191 [==============================] - 1918s 10s/step - loss: 0.2034 - accuracy: 0.9302 - val_loss: 0.1710 - val_accuracy: 0.9442 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2008 - accuracy: 0.9322
# Epoch 18: val_loss improved from 0.14862 to 0.14482, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1907s 10s/step - loss: 0.2008 - accuracy: 0.9322 - val_loss: 0.1448 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9369
# Epoch 19: val_loss improved from 0.14482 to 0.12980, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1925s 10s/step - loss: 0.1853 - accuracy: 0.9369 - val_loss: 0.1298 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1847 - accuracy: 0.9401
# Epoch 20: val_loss did not improve from 0.12980
# 191/191 [==============================] - 1937s 10s/step - loss: 0.1847 - accuracy: 0.9401 - val_loss: 0.1324 - val_accuracy: 0.9564 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1687 - accuracy: 0.9456
# Epoch 21: val_loss did not improve from 0.12980
# 191/191 [==============================] - 1986s 10s/step - loss: 0.1687 - accuracy: 0.9456 - val_loss: 0.1420 - val_accuracy: 0.9564 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9392
# Epoch 22: val_loss did not improve from 0.12980
# 191/191 [==============================] - 1856s 10s/step - loss: 0.1783 - accuracy: 0.9392 - val_loss: 0.1438 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9394
# Epoch 23: val_loss did not improve from 0.12980
# 191/191 [==============================] - 1786s 9s/step - loss: 0.1821 - accuracy: 0.9394 - val_loss: 0.1678 - val_accuracy: 0.9472 - lr: 0.0010
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.9427
# Epoch 24: val_loss did not improve from 0.12980
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 1796s 9s/step - loss: 0.1671 - accuracy: 0.9427 - val_loss: 0.1493 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1514 - accuracy: 0.9476
# Epoch 25: val_loss improved from 0.12980 to 0.10222, saving model to vitb16_sin_ft_weights.h5
# 191/191 [==============================] - 1790s 9s/step - loss: 0.1514 - accuracy: 0.9476 - val_loss: 0.1022 - val_accuracy: 0.9656 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1506 - accuracy: 0.9471
# Epoch 26: val_loss did not improve from 0.10222
# 191/191 [==============================] - 1845s 10s/step - loss: 0.1506 - accuracy: 0.9471 - val_loss: 0.1055 - val_accuracy: 0.9602 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9528
# Epoch 27: val_loss did not improve from 0.10222
# 191/191 [==============================] - 1902s 10s/step - loss: 0.1397 - accuracy: 0.9528 - val_loss: 0.1470 - val_accuracy: 0.9541 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9532
# Epoch 28: val_loss did not improve from 0.10222
# 191/191 [==============================] - 1902s 10s/step - loss: 0.1400 - accuracy: 0.9532 - val_loss: 0.1161 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9559
# Epoch 29: val_loss did not improve from 0.10222
# 191/191 [==============================] - 1902s 10s/step - loss: 0.1356 - accuracy: 0.9559 - val_loss: 0.1194 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9509
# Epoch 30: val_loss did not improve from 0.10222
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 1900s 10s/step - loss: 0.1453 - accuracy: 0.9509 - val_loss: 0.1128 - val_accuracy: 0.9618 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1280 - accuracy: 0.9571
# Epoch 31: val_loss did not improve from 0.10222
# 191/191 [==============================] - 1903s 10s/step - loss: 0.1280 - accuracy: 0.9571 - val_loss: 0.1108 - val_accuracy: 0.9648 - lr: 2.5000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.9589
# Epoch 32: val_loss did not improve from 0.10222
# 191/191 [==============================] - 1903s 10s/step - loss: 0.1199 - accuracy: 0.9589 - val_loss: 0.1143 - val_accuracy: 0.9664 - lr: 2.5000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.9587
# Epoch 33: val_loss did not improve from 0.10222
# 191/191 [==============================] - 1903s 10s/step - loss: 0.1209 - accuracy: 0.9587 - val_loss: 0.1102 - val_accuracy: 0.9656 - lr: 2.5000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9615
# Epoch 34: val_loss did not improve from 0.10222
# 191/191 [==============================] - 1903s 10s/step - loss: 0.1171 - accuracy: 0.9615 - val_loss: 0.1124 - val_accuracy: 0.9648 - lr: 2.5000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9653Restoring model weights from the end of the best epoch: 25.
#
# Epoch 35: val_loss did not improve from 0.10222
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 1953s 10s/step - loss: 0.1054 - accuracy: 0.9653 - val_loss: 0.1090 - val_accuracy: 0.9648 - lr: 2.5000e-04
# Epoch 35: early stopping

# %% [markdown]
# ### 7. CURVAS DE ENTRENAMIENTO

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 286s 7s/step - loss: 0.0770 - accuracy: 0.9763
#
# Test Accuracy : 0.9763
# Test Loss     : 0.0770
# 41/41 [==============================] - 283s 7s/step
# F1 Score      : 0.9762
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9868    1.0000    0.9934       150
#    mancha_anillo     1.0000    0.9619    0.9806       105
#     mancha_parda     0.9740    1.0000    0.9868       150
#          mosaico     0.9728    0.9533    0.9630       150
#      muermo_rojo     0.9792    0.9400    0.9592       150
#             roya     0.9527    0.9400    0.9463       150
#            sanas     0.9427    0.9867    0.9642       150
#            secas     0.9873    1.0000    0.9936        78
# tizon_bacteriano     0.9934    1.0000    0.9967       150
#
#         accuracy                         0.9763      1308
#        macro avg     0.9789    0.9782    0.9784      1308
#     weighted avg     0.9765    0.9763    0.9762      1308
#
#
# Resultados guardados en vitb16_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 5 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#   mosaico → sanas: 6 imágenes
#
# Total de imágenes a mostrar: 6

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: vitb16_sin_ft_weights.h5
