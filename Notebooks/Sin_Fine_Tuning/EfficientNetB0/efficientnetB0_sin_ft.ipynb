# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = "efficientnetB0_sin_ft"

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %%
# Balanceo de Imagenes

from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Calcular pesos automáticamente
clases = np.unique(train_generator.classes)
pesos = compute_class_weight(
    class_weight='balanced',
    classes=clases,
    y=train_generator.classes
)
class_weights = dict(enumerate(pesos))
print("Pesos por clase:", class_weights)
# Out:
# Pesos por clase: {0: 1.7445714285714287, 1: 0.8722857142857143, 2: 1.2410569105691056, 3: 0.8722857142857143, 4: 0.8722857142857143, 5: 0.8722857142857143, 6: 0.8722857142857143, 7: 0.8722857142857143, 8: 1.6774725274725275, 9: 0.8722857142857143}

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFIENTNETB0

# %%
# CARGAR EFFICIENTNET-B0 CON PESOS DE IMAGENET

base_model = EfficientNetB0(
    weights='imagenet',                 
    include_top=False,                  
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Congelamos la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 4,214,829
# Trainable params: 165,258
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{NOMBRE_MODELO}_weights.h5",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr], 
    class_weight=class_weights
)
# Out:
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.7980 - accuracy: 0.7137
# Epoch 1: val_loss improved from inf to 0.29760, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 233s 1s/step - loss: 0.7980 - accuracy: 0.7137 - val_loss: 0.2976 - val_accuracy: 0.9243 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.8723
# Epoch 2: val_loss improved from 0.29760 to 0.19030, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 222s 1s/step - loss: 0.3673 - accuracy: 0.8723 - val_loss: 0.1903 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2934 - accuracy: 0.9008
# Epoch 3: val_loss improved from 0.19030 to 0.17432, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 229s 1s/step - loss: 0.2934 - accuracy: 0.9008 - val_loss: 0.1743 - val_accuracy: 0.9488 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2473 - accuracy: 0.9119
# Epoch 4: val_loss improved from 0.17432 to 0.16553, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 232s 1s/step - loss: 0.2473 - accuracy: 0.9119 - val_loss: 0.1655 - val_accuracy: 0.9488 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2250 - accuracy: 0.9209
# Epoch 5: val_loss improved from 0.16553 to 0.15911, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 233s 1s/step - loss: 0.2250 - accuracy: 0.9209 - val_loss: 0.1591 - val_accuracy: 0.9465 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2033 - accuracy: 0.9304
# Epoch 6: val_loss improved from 0.15911 to 0.13649, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 232s 1s/step - loss: 0.2033 - accuracy: 0.9304 - val_loss: 0.1365 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1891 - accuracy: 0.9366
# Epoch 7: val_loss improved from 0.13649 to 0.12594, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 233s 1s/step - loss: 0.1891 - accuracy: 0.9366 - val_loss: 0.1259 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1787 - accuracy: 0.9335
# Epoch 8: val_loss improved from 0.12594 to 0.09914, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 232s 1s/step - loss: 0.1787 - accuracy: 0.9335 - val_loss: 0.0991 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9373
# Epoch 9: val_loss did not improve from 0.09914
# 191/191 [==============================] - 232s 1s/step - loss: 0.1676 - accuracy: 0.9373 - val_loss: 0.1048 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9409
# Epoch 10: val_loss did not improve from 0.09914
# 191/191 [==============================] - 233s 1s/step - loss: 0.1720 - accuracy: 0.9409 - val_loss: 0.1004 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.9430
# Epoch 11: val_loss improved from 0.09914 to 0.09490, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 232s 1s/step - loss: 0.1568 - accuracy: 0.9430 - val_loss: 0.0949 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9469
# Epoch 12: val_loss did not improve from 0.09490
# 191/191 [==============================] - 231s 1s/step - loss: 0.1499 - accuracy: 0.9469 - val_loss: 0.0999 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9500
# Epoch 13: val_loss improved from 0.09490 to 0.09421, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 233s 1s/step - loss: 0.1426 - accuracy: 0.9500 - val_loss: 0.0942 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9481
# Epoch 14: val_loss improved from 0.09421 to 0.08587, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 233s 1s/step - loss: 0.1356 - accuracy: 0.9481 - val_loss: 0.0859 - val_accuracy: 0.9732 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9509
# Epoch 15: val_loss did not improve from 0.08587
# 191/191 [==============================] - 232s 1s/step - loss: 0.1358 - accuracy: 0.9509 - val_loss: 0.0918 - val_accuracy: 0.9702 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9484
# Epoch 16: val_loss did not improve from 0.08587
# 191/191 [==============================] - 232s 1s/step - loss: 0.1364 - accuracy: 0.9484 - val_loss: 0.0972 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9522
# Epoch 17: val_loss did not improve from 0.08587
# 191/191 [==============================] - 234s 1s/step - loss: 0.1245 - accuracy: 0.9522 - val_loss: 0.0890 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1325 - accuracy: 0.9510
# Epoch 18: val_loss did not improve from 0.08587
# 191/191 [==============================] - 232s 1s/step - loss: 0.1325 - accuracy: 0.9510 - val_loss: 0.0974 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9528
# Epoch 19: val_loss improved from 0.08587 to 0.08402, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 233s 1s/step - loss: 0.1170 - accuracy: 0.9528 - val_loss: 0.0840 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9566
# Epoch 20: val_loss did not improve from 0.08402
# 191/191 [==============================] - 232s 1s/step - loss: 0.1207 - accuracy: 0.9566 - val_loss: 0.0911 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9579
# Epoch 21: val_loss improved from 0.08402 to 0.07777, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 232s 1s/step - loss: 0.1169 - accuracy: 0.9579 - val_loss: 0.0778 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9574
# Epoch 22: val_loss did not improve from 0.07777
# 191/191 [==============================] - 233s 1s/step - loss: 0.1155 - accuracy: 0.9574 - val_loss: 0.0929 - val_accuracy: 0.9740 - lr: 0.0010
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.9559
# Epoch 23: val_loss improved from 0.07777 to 0.07310, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 233s 1s/step - loss: 0.1098 - accuracy: 0.9559 - val_loss: 0.0731 - val_accuracy: 0.9748 - lr: 0.0010
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1158 - accuracy: 0.9563
# Epoch 24: val_loss did not improve from 0.07310
# 191/191 [==============================] - 232s 1s/step - loss: 0.1158 - accuracy: 0.9563 - val_loss: 0.0897 - val_accuracy: 0.9702 - lr: 0.0010
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9630
# Epoch 25: val_loss did not improve from 0.07310
# 191/191 [==============================] - 231s 1s/step - loss: 0.1093 - accuracy: 0.9630 - val_loss: 0.0820 - val_accuracy: 0.9732 - lr: 0.0010
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9605
# Epoch 26: val_loss did not improve from 0.07310
# 191/191 [==============================] - 232s 1s/step - loss: 0.1073 - accuracy: 0.9605 - val_loss: 0.0952 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9613
# Epoch 27: val_loss did not improve from 0.07310
# 191/191 [==============================] - 233s 1s/step - loss: 0.1033 - accuracy: 0.9613 - val_loss: 0.0805 - val_accuracy: 0.9755 - lr: 0.0010
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9592
# Epoch 28: val_loss did not improve from 0.07310
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 232s 1s/step - loss: 0.1026 - accuracy: 0.9592 - val_loss: 0.0869 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0984 - accuracy: 0.9622
# Epoch 29: val_loss improved from 0.07310 to 0.06572, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 233s 1s/step - loss: 0.0984 - accuracy: 0.9622 - val_loss: 0.0657 - val_accuracy: 0.9809 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 0.9676
# Epoch 30: val_loss did not improve from 0.06572
# 191/191 [==============================] - 232s 1s/step - loss: 0.0832 - accuracy: 0.9676 - val_loss: 0.0865 - val_accuracy: 0.9732 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9694
# Epoch 31: val_loss did not improve from 0.06572
# 191/191 [==============================] - 233s 1s/step - loss: 0.0846 - accuracy: 0.9694 - val_loss: 0.0692 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9668
# Epoch 32: val_loss did not improve from 0.06572
# 191/191 [==============================] - 233s 1s/step - loss: 0.0946 - accuracy: 0.9668 - val_loss: 0.0704 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9694
# Epoch 33: val_loss improved from 0.06572 to 0.06262, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 234s 1s/step - loss: 0.0792 - accuracy: 0.9694 - val_loss: 0.0626 - val_accuracy: 0.9771 - lr: 5.0000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9718
# Epoch 34: val_loss did not improve from 0.06262
# 191/191 [==============================] - 233s 1s/step - loss: 0.0743 - accuracy: 0.9718 - val_loss: 0.0687 - val_accuracy: 0.9817 - lr: 5.0000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0827 - accuracy: 0.9674
# Epoch 35: val_loss did not improve from 0.06262
# 191/191 [==============================] - 231s 1s/step - loss: 0.0827 - accuracy: 0.9674 - val_loss: 0.0663 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9712
# Epoch 36: val_loss did not improve from 0.06262
# 191/191 [==============================] - 233s 1s/step - loss: 0.0798 - accuracy: 0.9712 - val_loss: 0.0735 - val_accuracy: 0.9778 - lr: 5.0000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9715
# Epoch 37: val_loss did not improve from 0.06262
# 191/191 [==============================] - 232s 1s/step - loss: 0.0771 - accuracy: 0.9715 - val_loss: 0.0759 - val_accuracy: 0.9755 - lr: 5.0000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0709 - accuracy: 0.9726
# Epoch 38: val_loss did not improve from 0.06262
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 233s 1s/step - loss: 0.0709 - accuracy: 0.9726 - val_loss: 0.0732 - val_accuracy: 0.9809 - lr: 5.0000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0630 - accuracy: 0.9756
# Epoch 39: val_loss did not improve from 0.06262
# 191/191 [==============================] - 232s 1s/step - loss: 0.0630 - accuracy: 0.9756 - val_loss: 0.0694 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9745
# Epoch 40: val_loss did not improve from 0.06262
# 191/191 [==============================] - 233s 1s/step - loss: 0.0681 - accuracy: 0.9745 - val_loss: 0.0680 - val_accuracy: 0.9794 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9781
# Epoch 41: val_loss did not improve from 0.06262
# 191/191 [==============================] - 233s 1s/step - loss: 0.0628 - accuracy: 0.9781 - val_loss: 0.0759 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0647 - accuracy: 0.9746
# Epoch 42: val_loss did not improve from 0.06262
# 191/191 [==============================] - 232s 1s/step - loss: 0.0647 - accuracy: 0.9746 - val_loss: 0.0668 - val_accuracy: 0.9809 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0625 - accuracy: 0.9774Restoring model weights from the end of the best epoch: 33.
#
# Epoch 43: val_loss did not improve from 0.06262
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 233s 1s/step - loss: 0.0625 - accuracy: 0.9774 - val_loss: 0.0669 - val_accuracy: 0.9817 - lr: 2.5000e-04
# Epoch 43: early stopping

# %% [markdown]
# ### 7. EVALUACIÓN DEL MODELO EFFICIENTNETB0

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

# Gráfica de Loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys()
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys()
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 29s 696ms/step - loss: 0.0670 - accuracy: 0.9717
#
# Test Accuracy : 0.9717
# Test Loss     : 0.0670
# 41/41 [==============================] - 30s 677ms/step
# F1 Score      : 0.9717
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon       1.00      1.00      1.00        75
#    hoja_amarilla       0.99      0.98      0.98       150
#    mancha_anillo       0.99      1.00      1.00       105
#     mancha_parda       0.97      0.99      0.98       150
#          mosaico       0.98      0.93      0.95       150
#      muermo_rojo       0.97      0.93      0.95       150
#             roya       0.95      0.96      0.96       150
#            sanas       0.92      0.98      0.95       150
#            secas       1.00      1.00      1.00        78
# tizon_bacteriano       0.98      0.99      0.98       150
#
#         accuracy                           0.97      1308
#        macro avg       0.98      0.98      0.98      1308
#     weighted avg       0.97      0.97      0.97      1308
#
#
# Resultados guardados en efficientnetB0_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Pares con 5 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#   mosaico → sanas: 9 imágenes
#
# Total de imágenes a mostrar: 9

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB0_sin_ft_weights.h5
