# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE      = 240
BATCH_SIZE    = 32
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = "efficientnetB1_sin_ft"

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %%
# Balanceo de Imagenes

from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Calcular pesos automáticamente
clases = np.unique(train_generator.classes)
pesos = compute_class_weight(
    class_weight='balanced',
    classes=clases,
    y=train_generator.classes
)
class_weights = dict(enumerate(pesos))
print("Pesos por clase:", class_weights)
# Out:
# Pesos por clase: {0: 1.7445714285714287, 1: 0.8722857142857143, 2: 1.2410569105691056, 3: 0.8722857142857143, 4: 0.8722857142857143, 5: 0.8722857142857143, 6: 0.8722857142857143, 7: 0.8722857142857143, 8: 1.6774725274725275, 9: 0.8722857142857143}

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFIENTNETB1

# %%
# CARGAR EFFICIENTNET-B1 CON PESOS DE IMAGENET

base_model = EfficientNetB1(
    weights='imagenet',                 
    include_top=False,                  
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Congelamos la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb1 (Functional)  (None, 8, 8, 1280)       6575239
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 6,740,497
# Trainable params: 165,258
# Non-trainable params: 6,575,239
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{NOMBRE_MODELO}_weights.h5",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.8919 - accuracy: 0.6841
# Epoch 1: val_loss improved from inf to 0.39017, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 336s 2s/step - loss: 0.8919 - accuracy: 0.6841 - val_loss: 0.3902 - val_accuracy: 0.8838 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4251 - accuracy: 0.8510
# Epoch 2: val_loss improved from 0.39017 to 0.28641, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 314s 2s/step - loss: 0.4251 - accuracy: 0.8510 - val_loss: 0.2864 - val_accuracy: 0.9098 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3383 - accuracy: 0.8786
# Epoch 3: val_loss improved from 0.28641 to 0.24264, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 313s 2s/step - loss: 0.3383 - accuracy: 0.8786 - val_loss: 0.2426 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.8967
# Epoch 4: val_loss improved from 0.24264 to 0.21042, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 315s 2s/step - loss: 0.2924 - accuracy: 0.8967 - val_loss: 0.2104 - val_accuracy: 0.9304 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2685 - accuracy: 0.9052
# Epoch 5: val_loss improved from 0.21042 to 0.19700, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 315s 2s/step - loss: 0.2685 - accuracy: 0.9052 - val_loss: 0.1970 - val_accuracy: 0.9289 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2508 - accuracy: 0.9088
# Epoch 6: val_loss improved from 0.19700 to 0.17554, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 314s 2s/step - loss: 0.2508 - accuracy: 0.9088 - val_loss: 0.1755 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2294 - accuracy: 0.9163
# Epoch 7: val_loss did not improve from 0.17554
# 191/191 [==============================] - 313s 2s/step - loss: 0.2294 - accuracy: 0.9163 - val_loss: 0.1975 - val_accuracy: 0.9320 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2074 - accuracy: 0.9237
# Epoch 8: val_loss did not improve from 0.17554
# 191/191 [==============================] - 314s 2s/step - loss: 0.2074 - accuracy: 0.9237 - val_loss: 0.1790 - val_accuracy: 0.9404 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1949 - accuracy: 0.9268
# Epoch 9: val_loss improved from 0.17554 to 0.17139, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 315s 2s/step - loss: 0.1949 - accuracy: 0.9268 - val_loss: 0.1714 - val_accuracy: 0.9472 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.9273
# Epoch 10: val_loss improved from 0.17139 to 0.15976, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 314s 2s/step - loss: 0.1982 - accuracy: 0.9273 - val_loss: 0.1598 - val_accuracy: 0.9503 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9333
# Epoch 11: val_loss did not improve from 0.15976
# 191/191 [==============================] - 313s 2s/step - loss: 0.1843 - accuracy: 0.9333 - val_loss: 0.1702 - val_accuracy: 0.9404 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1879 - accuracy: 0.9327
# Epoch 12: val_loss improved from 0.15976 to 0.14691, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 316s 2s/step - loss: 0.1879 - accuracy: 0.9327 - val_loss: 0.1469 - val_accuracy: 0.9472 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1851 - accuracy: 0.9304
# Epoch 13: val_loss improved from 0.14691 to 0.13907, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 315s 2s/step - loss: 0.1851 - accuracy: 0.9304 - val_loss: 0.1391 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1727 - accuracy: 0.9361
# Epoch 14: val_loss did not improve from 0.13907
# 191/191 [==============================] - 314s 2s/step - loss: 0.1727 - accuracy: 0.9361 - val_loss: 0.1791 - val_accuracy: 0.9343 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.9387
# Epoch 15: val_loss improved from 0.13907 to 0.13353, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 314s 2s/step - loss: 0.1660 - accuracy: 0.9387 - val_loss: 0.1335 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9391
# Epoch 16: val_loss did not improve from 0.13353
# 191/191 [==============================] - 314s 2s/step - loss: 0.1625 - accuracy: 0.9391 - val_loss: 0.1632 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1583 - accuracy: 0.9406
# Epoch 17: val_loss did not improve from 0.13353
# 191/191 [==============================] - 315s 2s/step - loss: 0.1583 - accuracy: 0.9406 - val_loss: 0.1533 - val_accuracy: 0.9495 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.9401
# Epoch 18: val_loss did not improve from 0.13353
# 191/191 [==============================] - 316s 2s/step - loss: 0.1592 - accuracy: 0.9401 - val_loss: 0.1366 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9420
# Epoch 19: val_loss improved from 0.13353 to 0.12254, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 313s 2s/step - loss: 0.1535 - accuracy: 0.9420 - val_loss: 0.1225 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1573 - accuracy: 0.9389
# Epoch 20: val_loss did not improve from 0.12254
# 191/191 [==============================] - 314s 2s/step - loss: 0.1573 - accuracy: 0.9389 - val_loss: 0.1290 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.9504
# Epoch 21: val_loss did not improve from 0.12254
# 191/191 [==============================] - 315s 2s/step - loss: 0.1383 - accuracy: 0.9504 - val_loss: 0.1309 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9494
# Epoch 22: val_loss did not improve from 0.12254
# 191/191 [==============================] - 313s 2s/step - loss: 0.1421 - accuracy: 0.9494 - val_loss: 0.1440 - val_accuracy: 0.9518 - lr: 0.0010
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9464
# Epoch 23: val_loss did not improve from 0.12254
# 191/191 [==============================] - 313s 2s/step - loss: 0.1431 - accuracy: 0.9464 - val_loss: 0.1268 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9410
# Epoch 24: val_loss did not improve from 0.12254
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 314s 2s/step - loss: 0.1500 - accuracy: 0.9410 - val_loss: 0.1328 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9551
# Epoch 25: val_loss did not improve from 0.12254
# 191/191 [==============================] - 314s 2s/step - loss: 0.1170 - accuracy: 0.9551 - val_loss: 0.1236 - val_accuracy: 0.9572 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 0.9548
# Epoch 26: val_loss did not improve from 0.12254
# 191/191 [==============================] - 313s 2s/step - loss: 0.1259 - accuracy: 0.9548 - val_loss: 0.1267 - val_accuracy: 0.9625 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9579
# Epoch 27: val_loss did not improve from 0.12254
# 191/191 [==============================] - 314s 2s/step - loss: 0.1046 - accuracy: 0.9579 - val_loss: 0.1254 - val_accuracy: 0.9602 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9589
# Epoch 28: val_loss improved from 0.12254 to 0.11802, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 315s 2s/step - loss: 0.1053 - accuracy: 0.9589 - val_loss: 0.1180 - val_accuracy: 0.9602 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9610
# Epoch 29: val_loss did not improve from 0.11802
# 191/191 [==============================] - 313s 2s/step - loss: 0.1103 - accuracy: 0.9610 - val_loss: 0.1248 - val_accuracy: 0.9580 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9582
# Epoch 30: val_loss did not improve from 0.11802
# 191/191 [==============================] - 312s 2s/step - loss: 0.1107 - accuracy: 0.9582 - val_loss: 0.1198 - val_accuracy: 0.9602 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9615
# Epoch 31: val_loss improved from 0.11802 to 0.11545, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 314s 2s/step - loss: 0.1064 - accuracy: 0.9615 - val_loss: 0.1155 - val_accuracy: 0.9602 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9558
# Epoch 32: val_loss improved from 0.11545 to 0.11166, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 316s 2s/step - loss: 0.1132 - accuracy: 0.9558 - val_loss: 0.1117 - val_accuracy: 0.9625 - lr: 5.0000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9602
# Epoch 33: val_loss improved from 0.11166 to 0.10945, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 313s 2s/step - loss: 0.1033 - accuracy: 0.9602 - val_loss: 0.1095 - val_accuracy: 0.9641 - lr: 5.0000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9569
# Epoch 34: val_loss improved from 0.10945 to 0.10789, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 317s 2s/step - loss: 0.1134 - accuracy: 0.9569 - val_loss: 0.1079 - val_accuracy: 0.9717 - lr: 5.0000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9612
# Epoch 35: val_loss improved from 0.10789 to 0.09934, saving model to efficientnetB1_sin_ft_weights.h5
# 191/191 [==============================] - 315s 2s/step - loss: 0.1032 - accuracy: 0.9612 - val_loss: 0.0993 - val_accuracy: 0.9755 - lr: 5.0000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9654
# Epoch 36: val_loss did not improve from 0.09934
# 191/191 [==============================] - 315s 2s/step - loss: 0.0923 - accuracy: 0.9654 - val_loss: 0.1128 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9625
# Epoch 37: val_loss did not improve from 0.09934
# 191/191 [==============================] - 315s 2s/step - loss: 0.1019 - accuracy: 0.9625 - val_loss: 0.1070 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9607
# Epoch 38: val_loss did not improve from 0.09934
# 191/191 [==============================] - 315s 2s/step - loss: 0.1032 - accuracy: 0.9607 - val_loss: 0.1061 - val_accuracy: 0.9717 - lr: 5.0000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9659
# Epoch 39: val_loss did not improve from 0.09934
# 191/191 [==============================] - 314s 2s/step - loss: 0.0953 - accuracy: 0.9659 - val_loss: 0.1240 - val_accuracy: 0.9580 - lr: 5.0000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 0.9599
# Epoch 40: val_loss did not improve from 0.09934
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 316s 2s/step - loss: 0.1006 - accuracy: 0.9599 - val_loss: 0.1119 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9710
# Epoch 41: val_loss did not improve from 0.09934
# 191/191 [==============================] - 314s 2s/step - loss: 0.0848 - accuracy: 0.9710 - val_loss: 0.1116 - val_accuracy: 0.9633 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0873 - accuracy: 0.9664
# Epoch 42: val_loss did not improve from 0.09934
# 191/191 [==============================] - 314s 2s/step - loss: 0.0873 - accuracy: 0.9664 - val_loss: 0.1077 - val_accuracy: 0.9671 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0832 - accuracy: 0.9689
# Epoch 43: val_loss did not improve from 0.09934
# 191/191 [==============================] - 314s 2s/step - loss: 0.0832 - accuracy: 0.9689 - val_loss: 0.1066 - val_accuracy: 0.9687 - lr: 2.5000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0850 - accuracy: 0.9695
# Epoch 44: val_loss did not improve from 0.09934
# 191/191 [==============================] - 315s 2s/step - loss: 0.0850 - accuracy: 0.9695 - val_loss: 0.1114 - val_accuracy: 0.9656 - lr: 2.5000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9686Restoring model weights from the end of the best epoch: 35.
#
# Epoch 45: val_loss did not improve from 0.09934
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 314s 2s/step - loss: 0.0819 - accuracy: 0.9686 - val_loss: 0.1066 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 45: early stopping

# %% [markdown]
# ### 7. EVALUACIÓN DEL MODELO EFFICIENTNETB1

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

# Gráfica de Loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys()
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys()
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 42s 1s/step - loss: 0.0882 - accuracy: 0.9679
#
# Test Accuracy : 0.9679
# Test Loss     : 0.0882
# 41/41 [==============================] - 47s 1s/step
# F1 Score      : 0.9679
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon       1.00      1.00      1.00        75
#    hoja_amarilla       0.97      0.98      0.98       150
#    mancha_anillo       1.00      1.00      1.00       105
#     mancha_parda       0.98      0.98      0.98       150
#          mosaico       0.95      0.94      0.95       150
#      muermo_rojo       0.94      0.96      0.95       150
#             roya       0.95      0.94      0.95       150
#            sanas       0.93      0.93      0.93       150
#            secas       1.00      1.00      1.00        78
# tizon_bacteriano       0.99      0.99      0.99       150
#
#         accuracy                           0.97      1308
#        macro avg       0.97      0.97      0.97      1308
#     weighted avg       0.97      0.97      0.97      1308
#
#
# Resultados guardados en efficientnetB1_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Pares con 5 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#   mosaico → sanas: 8 imágenes
#   roya → muermo_rojo: 6 imágenes
#   sanas → mosaico: 5 imágenes
#
# Total de imágenes a mostrar: 19

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB1_sin_ft_weights.h5
