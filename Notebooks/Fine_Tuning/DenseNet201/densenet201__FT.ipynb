# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
NUM_CLASSES   = 10
NOMBRE_MODELO = 'densenet201_FT'

# Fase 1: Congelación de capas
PATIENCE_ES_F1  = 10
PATIENCE_LR_F1  = 5

# Fase 2: Descongelación de capas
PATIENCE_ES_F2  = 15
PATIENCE_LR_F2  = 8

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# DATA AUGMENTATION — IGUAL EN TODOS LOS MODELOS
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO DENSENET201

# %%
# CARGAR DENSENET201 CON PESOS DE IMAGENET
base_model = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPAS FINALES PERSONALIZADAS
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "densenet201_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               245888
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 18,569,162
# Trainable params: 247,178
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F1,
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F1,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 1.0614 - accuracy: 0.6443
# Epoch 1: val_loss improved from inf to 0.35322, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 494s 2s/step - loss: 1.0614 - accuracy: 0.6443 - val_loss: 0.3532 - val_accuracy: 0.8998 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4727 - accuracy: 0.8524
# Epoch 2: val_loss improved from 0.35322 to 0.22403, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 467s 2s/step - loss: 0.4727 - accuracy: 0.8524 - val_loss: 0.2240 - val_accuracy: 0.9350 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3727 - accuracy: 0.8859
# Epoch 3: val_loss improved from 0.22403 to 0.19142, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 977s 5s/step - loss: 0.3727 - accuracy: 0.8859 - val_loss: 0.1914 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3127 - accuracy: 0.9078
# Epoch 4: val_loss improved from 0.19142 to 0.16140, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 445s 2s/step - loss: 0.3127 - accuracy: 0.9078 - val_loss: 0.1614 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.9158
# Epoch 5: val_loss improved from 0.16140 to 0.15901, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 437s 2s/step - loss: 0.2896 - accuracy: 0.9158 - val_loss: 0.1590 - val_accuracy: 0.9572 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2545 - accuracy: 0.9242
# Epoch 6: val_loss improved from 0.15901 to 0.14609, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 458s 2s/step - loss: 0.2545 - accuracy: 0.9242 - val_loss: 0.1461 - val_accuracy: 0.9549 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2602 - accuracy: 0.9198
# Epoch 7: val_loss improved from 0.14609 to 0.14373, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 444s 2s/step - loss: 0.2602 - accuracy: 0.9198 - val_loss: 0.1437 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2171 - accuracy: 0.9353
# Epoch 8: val_loss did not improve from 0.14373
# 191/191 [==============================] - 432s 2s/step - loss: 0.2171 - accuracy: 0.9353 - val_loss: 0.1486 - val_accuracy: 0.9572 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2288 - accuracy: 0.9273
# Epoch 9: val_loss improved from 0.14373 to 0.12859, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 444s 2s/step - loss: 0.2288 - accuracy: 0.9273 - val_loss: 0.1286 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2134 - accuracy: 0.9389
# Epoch 10: val_loss improved from 0.12859 to 0.12639, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 442s 2s/step - loss: 0.2134 - accuracy: 0.9389 - val_loss: 0.1264 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2033 - accuracy: 0.9448
# Epoch 11: val_loss improved from 0.12639 to 0.11925, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 444s 2s/step - loss: 0.2033 - accuracy: 0.9448 - val_loss: 0.1193 - val_accuracy: 0.9702 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9420
# Epoch 12: val_loss did not improve from 0.11925
# 191/191 [==============================] - 441s 2s/step - loss: 0.1952 - accuracy: 0.9420 - val_loss: 0.1253 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2076 - accuracy: 0.9401
# Epoch 13: val_loss did not improve from 0.11925
# 191/191 [==============================] - 442s 2s/step - loss: 0.2076 - accuracy: 0.9401 - val_loss: 0.1250 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2051 - accuracy: 0.9420
# Epoch 14: val_loss improved from 0.11925 to 0.11297, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 443s 2s/step - loss: 0.2051 - accuracy: 0.9420 - val_loss: 0.1130 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9392
# Epoch 15: val_loss did not improve from 0.11297
# 191/191 [==============================] - 443s 2s/step - loss: 0.2079 - accuracy: 0.9392 - val_loss: 0.1155 - val_accuracy: 0.9740 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1858 - accuracy: 0.9446
# Epoch 16: val_loss did not improve from 0.11297
# 191/191 [==============================] - 442s 2s/step - loss: 0.1858 - accuracy: 0.9446 - val_loss: 0.1273 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1976 - accuracy: 0.9445
# Epoch 17: val_loss did not improve from 0.11297
# 191/191 [==============================] - 442s 2s/step - loss: 0.1976 - accuracy: 0.9445 - val_loss: 0.1268 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1869 - accuracy: 0.9474
# Epoch 18: val_loss did not improve from 0.11297
# 191/191 [==============================] - 442s 2s/step - loss: 0.1869 - accuracy: 0.9474 - val_loss: 0.1276 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9476
# Epoch 19: val_loss did not improve from 0.11297
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 444s 2s/step - loss: 0.1820 - accuracy: 0.9476 - val_loss: 0.1166 - val_accuracy: 0.9748 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1547 - accuracy: 0.9571
# Epoch 20: val_loss did not improve from 0.11297
# 191/191 [==============================] - 442s 2s/step - loss: 0.1547 - accuracy: 0.9571 - val_loss: 0.1150 - val_accuracy: 0.9755 - lr: 5.0000e-04
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9605
# Epoch 21: val_loss improved from 0.11297 to 0.11214, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 443s 2s/step - loss: 0.1446 - accuracy: 0.9605 - val_loss: 0.1121 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9615
# Epoch 22: val_loss did not improve from 0.11214
# 191/191 [==============================] - 444s 2s/step - loss: 0.1441 - accuracy: 0.9615 - val_loss: 0.1171 - val_accuracy: 0.9771 - lr: 5.0000e-04
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9625
# Epoch 23: val_loss did not improve from 0.11214
# 191/191 [==============================] - 444s 2s/step - loss: 0.1429 - accuracy: 0.9625 - val_loss: 0.1127 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1476 - accuracy: 0.9587
# Epoch 24: val_loss improved from 0.11214 to 0.10225, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 444s 2s/step - loss: 0.1476 - accuracy: 0.9587 - val_loss: 0.1022 - val_accuracy: 0.9794 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9620
# Epoch 25: val_loss did not improve from 0.10225
# 191/191 [==============================] - 440s 2s/step - loss: 0.1389 - accuracy: 0.9620 - val_loss: 0.1064 - val_accuracy: 0.9778 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9656
# Epoch 26: val_loss did not improve from 0.10225
# 191/191 [==============================] - 440s 2s/step - loss: 0.1327 - accuracy: 0.9656 - val_loss: 0.1130 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.9630
# Epoch 27: val_loss did not improve from 0.10225
# 191/191 [==============================] - 442s 2s/step - loss: 0.1412 - accuracy: 0.9630 - val_loss: 0.1031 - val_accuracy: 0.9778 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1311 - accuracy: 0.9668
# Epoch 28: val_loss did not improve from 0.10225
# 191/191 [==============================] - 442s 2s/step - loss: 0.1311 - accuracy: 0.9668 - val_loss: 0.1123 - val_accuracy: 0.9755 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9632
# Epoch 29: val_loss did not improve from 0.10225
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 461s 2s/step - loss: 0.1397 - accuracy: 0.9632 - val_loss: 0.1049 - val_accuracy: 0.9801 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9687
# Epoch 30: val_loss did not improve from 0.10225
# 191/191 [==============================] - 457s 2s/step - loss: 0.1260 - accuracy: 0.9687 - val_loss: 0.1043 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9692
# Epoch 31: val_loss improved from 0.10225 to 0.10038, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 456s 2s/step - loss: 0.1219 - accuracy: 0.9692 - val_loss: 0.1004 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9708
# Epoch 32: val_loss did not improve from 0.10038
# 191/191 [==============================] - 457s 2s/step - loss: 0.1150 - accuracy: 0.9708 - val_loss: 0.1117 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9712
# Epoch 33: val_loss did not improve from 0.10038
# 191/191 [==============================] - 456s 2s/step - loss: 0.1165 - accuracy: 0.9712 - val_loss: 0.1053 - val_accuracy: 0.9786 - lr: 2.5000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9713
# Epoch 34: val_loss did not improve from 0.10038
# 191/191 [==============================] - 456s 2s/step - loss: 0.1226 - accuracy: 0.9713 - val_loss: 0.1019 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9687
# Epoch 35: val_loss improved from 0.10038 to 0.09942, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 456s 2s/step - loss: 0.1188 - accuracy: 0.9687 - val_loss: 0.0994 - val_accuracy: 0.9786 - lr: 2.5000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1191 - accuracy: 0.9689
# Epoch 36: val_loss did not improve from 0.09942
# 191/191 [==============================] - 455s 2s/step - loss: 0.1191 - accuracy: 0.9689 - val_loss: 0.1000 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1209 - accuracy: 0.9690
# Epoch 37: val_loss did not improve from 0.09942
# 191/191 [==============================] - 455s 2s/step - loss: 0.1209 - accuracy: 0.9690 - val_loss: 0.1007 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9687
# Epoch 38: val_loss did not improve from 0.09942
# 191/191 [==============================] - 456s 2s/step - loss: 0.1193 - accuracy: 0.9687 - val_loss: 0.1034 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1069 - accuracy: 0.9764
# Epoch 39: val_loss did not improve from 0.09942
# 191/191 [==============================] - 455s 2s/step - loss: 0.1069 - accuracy: 0.9764 - val_loss: 0.1019 - val_accuracy: 0.9786 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1179 - accuracy: 0.9705
# Epoch 40: val_loss improved from 0.09942 to 0.09826, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 456s 2s/step - loss: 0.1179 - accuracy: 0.9705 - val_loss: 0.0983 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1249 - accuracy: 0.9699
# Epoch 41: val_loss improved from 0.09826 to 0.09824, saving model to densenet201_con_ft_fase1_weights.h5
# 191/191 [==============================] - 457s 2s/step - loss: 0.1249 - accuracy: 0.9699 - val_loss: 0.0982 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1104 - accuracy: 0.9735
# Epoch 42: val_loss did not improve from 0.09824
# 191/191 [==============================] - 455s 2s/step - loss: 0.1104 - accuracy: 0.9735 - val_loss: 0.1060 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9718
# Epoch 43: val_loss did not improve from 0.09824
# 191/191 [==============================] - 455s 2s/step - loss: 0.1146 - accuracy: 0.9718 - val_loss: 0.1046 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 0.9695
# Epoch 44: val_loss did not improve from 0.09824
# 191/191 [==============================] - 455s 2s/step - loss: 0.1129 - accuracy: 0.9695 - val_loss: 0.1009 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9700
# Epoch 45: val_loss did not improve from 0.09824
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 455s 2s/step - loss: 0.1172 - accuracy: 0.9700 - val_loss: 0.1004 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9731
# Epoch 46: val_loss did not improve from 0.09824
# 191/191 [==============================] - 453s 2s/step - loss: 0.1102 - accuracy: 0.9731 - val_loss: 0.1011 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9728
# Epoch 47: val_loss did not improve from 0.09824
# 191/191 [==============================] - 456s 2s/step - loss: 0.1101 - accuracy: 0.9728 - val_loss: 0.1003 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9746
# Epoch 48: val_loss did not improve from 0.09824
# 191/191 [==============================] - 455s 2s/step - loss: 0.1073 - accuracy: 0.9746 - val_loss: 0.1027 - val_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9738
# Epoch 49: val_loss did not improve from 0.09824
# 191/191 [==============================] - 456s 2s/step - loss: 0.1059 - accuracy: 0.9738 - val_loss: 0.0994 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9741
# Epoch 50: val_loss did not improve from 0.09824
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 453s 2s/step - loss: 0.1031 - accuracy: 0.9741 - val_loss: 0.0989 - val_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9751Restoring model weights from the end of the best epoch: 41.
#
# Epoch 51: val_loss did not improve from 0.09824
# 191/191 [==============================] - 455s 2s/step - loss: 0.1065 - accuracy: 0.9751 - val_loss: 0.1024 - val_accuracy: 0.9786 - lr: 6.2500e-05
# Epoch 51: early stopping
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9801

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F2,          # = 15, igual en todos los modelos
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F2,
    min_lr=1e-6,
    verbose=1
)

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 707
# Capas congeladas         : 677
# Capas descongeladas      : 30
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9695
# Epoch 1: val_loss improved from inf to 0.09614, saving model to densenet201_con_ft_weights.h5
# 191/191 [==============================] - 457s 2s/step - loss: 0.1157 - accuracy: 0.9695 - val_loss: 0.0961 - val_accuracy: 0.9786 - lr: 1.0000e-05
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1092 - accuracy: 0.9722
# Epoch 2: val_loss improved from 0.09614 to 0.09602, saving model to densenet201_con_ft_weights.h5
# 191/191 [==============================] - 456s 2s/step - loss: 0.1092 - accuracy: 0.9722 - val_loss: 0.0960 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9748
# Epoch 3: val_loss improved from 0.09602 to 0.09594, saving model to densenet201_con_ft_weights.h5
# 191/191 [==============================] - 460s 2s/step - loss: 0.1088 - accuracy: 0.9748 - val_loss: 0.0959 - val_accuracy: 0.9794 - lr: 1.0000e-05
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9746
# Epoch 4: val_loss did not improve from 0.09594
# 191/191 [==============================] - 456s 2s/step - loss: 0.1018 - accuracy: 0.9746 - val_loss: 0.0960 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9758
# Epoch 5: val_loss did not improve from 0.09594
# 191/191 [==============================] - 456s 2s/step - loss: 0.1016 - accuracy: 0.9758 - val_loss: 0.0962 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9708
# Epoch 6: val_loss improved from 0.09594 to 0.09563, saving model to densenet201_con_ft_weights.h5
# 191/191 [==============================] - 457s 2s/step - loss: 0.1088 - accuracy: 0.9708 - val_loss: 0.0956 - val_accuracy: 0.9809 - lr: 1.0000e-05
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9753
# Epoch 7: val_loss did not improve from 0.09563
# 191/191 [==============================] - 456s 2s/step - loss: 0.1026 - accuracy: 0.9753 - val_loss: 0.0961 - val_accuracy: 0.9794 - lr: 1.0000e-05
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1048 - accuracy: 0.9748
# Epoch 8: val_loss did not improve from 0.09563
# 191/191 [==============================] - 454s 2s/step - loss: 0.1048 - accuracy: 0.9748 - val_loss: 0.0968 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9777
# Epoch 9: val_loss did not improve from 0.09563
# 191/191 [==============================] - 455s 2s/step - loss: 0.0994 - accuracy: 0.9777 - val_loss: 0.0971 - val_accuracy: 0.9809 - lr: 1.0000e-05
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9726
# Epoch 10: val_loss did not improve from 0.09563
# 191/191 [==============================] - 456s 2s/step - loss: 0.1005 - accuracy: 0.9726 - val_loss: 0.0971 - val_accuracy: 0.9809 - lr: 1.0000e-05
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9735
# Epoch 11: val_loss did not improve from 0.09563
# 191/191 [==============================] - 455s 2s/step - loss: 0.1054 - accuracy: 0.9735 - val_loss: 0.0972 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9751
# Epoch 12: val_loss did not improve from 0.09563
# 191/191 [==============================] - 455s 2s/step - loss: 0.1053 - accuracy: 0.9751 - val_loss: 0.0972 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9769
# Epoch 13: val_loss did not improve from 0.09563
# 191/191 [==============================] - 454s 2s/step - loss: 0.0957 - accuracy: 0.9769 - val_loss: 0.0978 - val_accuracy: 0.9809 - lr: 1.0000e-05
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9745
# Epoch 14: val_loss did not improve from 0.09563
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 455s 2s/step - loss: 0.1045 - accuracy: 0.9745 - val_loss: 0.0976 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9741
# Epoch 15: val_loss did not improve from 0.09563
# 191/191 [==============================] - 456s 2s/step - loss: 0.1100 - accuracy: 0.9741 - val_loss: 0.0970 - val_accuracy: 0.9801 - lr: 5.0000e-06
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 0.9749
# Epoch 16: val_loss did not improve from 0.09563
# 191/191 [==============================] - 455s 2s/step - loss: 0.1029 - accuracy: 0.9749 - val_loss: 0.0975 - val_accuracy: 0.9801 - lr: 5.0000e-06
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9756
# Epoch 17: val_loss did not improve from 0.09563
# 191/191 [==============================] - 457s 2s/step - loss: 0.1017 - accuracy: 0.9756 - val_loss: 0.0976 - val_accuracy: 0.9801 - lr: 5.0000e-06
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9769
# Epoch 18: val_loss did not improve from 0.09563
# 191/191 [==============================] - 455s 2s/step - loss: 0.1037 - accuracy: 0.9769 - val_loss: 0.0976 - val_accuracy: 0.9801 - lr: 5.0000e-06
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9751
# Epoch 19: val_loss did not improve from 0.09563
# 191/191 [==============================] - 454s 2s/step - loss: 0.1040 - accuracy: 0.9751 - val_loss: 0.0979 - val_accuracy: 0.9801 - lr: 5.0000e-06
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9766
# Epoch 20: val_loss did not improve from 0.09563
# 191/191 [==============================] - 455s 2s/step - loss: 0.0994 - accuracy: 0.9766 - val_loss: 0.0981 - val_accuracy: 0.9786 - lr: 5.0000e-06
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9728Restoring model weights from the end of the best epoch: 6.
#
# Epoch 21: val_loss did not improve from 0.09563
# 191/191 [==============================] - 455s 2s/step - loss: 0.1114 - accuracy: 0.9728 - val_loss: 0.0979 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 21: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9809

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9801
# Fase 2 — mejor val_accuracy: 0.9809

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 78s 2s/step - loss: 0.0688 - accuracy: 0.9855
#
# Test Accuracy : 0.9855
# Test Loss     : 0.0688
# 41/41 [==============================] - 82s 2s/step
# F1 Score      : 0.9854
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9803    0.9933    0.9868       150
#    mancha_anillo     1.0000    0.9905    0.9952       105
#     mancha_parda     0.9866    0.9800    0.9833       150
#          mosaico     0.9931    0.9600    0.9763       150
#      muermo_rojo     0.9931    0.9600    0.9763       150
#             roya     0.9610    0.9867    0.9737       150
#            sanas     0.9740    1.0000    0.9868       150
#            secas     0.9873    1.0000    0.9936        78
# tizon_bacteriano     0.9934    1.0000    0.9967       150
#
#         accuracy                         0.9855      1308
#        macro avg     0.9869    0.9870    0.9869      1308
#     weighted avg     0.9857    0.9855    0.9854      1308
#
#
# Resultados guardados en densenet201_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]
class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 1 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]
print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]
    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()
    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9, color='red'
        )
        axes[j].axis('off')
    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')
    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14, fontweight='bold', y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 1 o más confusiones:
#   mosaico → sanas: 4 imágenes
#   muermo_rojo → roya: 3 imágenes
#   mancha_parda → hoja_amarilla: 2 imágenes
#   muermo_rojo → mancha_parda: 2 imágenes
#   hoja_amarilla → roya: 1 imágenes
#   mancha_anillo → roya: 1 imágenes
#   mancha_parda → mosaico: 1 imágenes
#   mosaico → roya: 1 imágenes
#   mosaico → secas: 1 imágenes
#   muermo_rojo → hoja_amarilla: 1 imágenes
#   roya → muermo_rojo: 1 imágenes
#   roya → tizon_bacteriano: 1 imágenes
#
# Total de imágenes a mostrar: 19

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: densenet201_con_ft_weights.h5
