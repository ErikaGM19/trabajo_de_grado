# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.applications.resnet_v2 import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
NUM_CLASSES   = 10
NOMBRE_MODELO = 'resnet50v2_FT'

# Fase 1: Congelación de capas
PATIENCE_ES_F1  = 10
PATIENCE_LR_F1  = 5

# Fase 2: Descongelación de capas
PATIENCE_ES_F2  = 15
PATIENCE_LR_F2  = 8

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# DATA AUGMENTATION — IGUAL EN TODOS LOS MODELOS
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO RESNET50V2

# %%
# CARGAR RESNET50V2 CON PESOS DE IMAGENET
base_model = ResNet50V2(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPAS FINALES PERSONALIZADAS
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "resnet50v2_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 23,828,362
# Trainable params: 263,562
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F1,
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F1,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 1.0827 - accuracy: 0.6363
# Epoch 1: val_loss improved from inf to 0.47167, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 327s 2s/step - loss: 1.0827 - accuracy: 0.6363 - val_loss: 0.4717 - val_accuracy: 0.8570 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.6366 - accuracy: 0.7914
# Epoch 2: val_loss improved from 0.47167 to 0.35226, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 316s 2s/step - loss: 0.6366 - accuracy: 0.7914 - val_loss: 0.3523 - val_accuracy: 0.8991 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.5217 - accuracy: 0.8325
# Epoch 3: val_loss did not improve from 0.35226
# 191/191 [==============================] - 337s 2s/step - loss: 0.5217 - accuracy: 0.8325 - val_loss: 0.3774 - val_accuracy: 0.8716 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4821 - accuracy: 0.8485
# Epoch 4: val_loss improved from 0.35226 to 0.30360, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 306s 2s/step - loss: 0.4821 - accuracy: 0.8485 - val_loss: 0.3036 - val_accuracy: 0.9090 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4319 - accuracy: 0.8664
# Epoch 5: val_loss improved from 0.30360 to 0.27176, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 306s 2s/step - loss: 0.4319 - accuracy: 0.8664 - val_loss: 0.2718 - val_accuracy: 0.9205 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4181 - accuracy: 0.8703
# Epoch 6: val_loss did not improve from 0.27176
# 191/191 [==============================] - 305s 2s/step - loss: 0.4181 - accuracy: 0.8703 - val_loss: 0.2782 - val_accuracy: 0.9174 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4036 - accuracy: 0.8736
# Epoch 7: val_loss improved from 0.27176 to 0.25175, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 302s 2s/step - loss: 0.4036 - accuracy: 0.8736 - val_loss: 0.2518 - val_accuracy: 0.9358 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3954 - accuracy: 0.8795
# Epoch 8: val_loss improved from 0.25175 to 0.24899, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 306s 2s/step - loss: 0.3954 - accuracy: 0.8795 - val_loss: 0.2490 - val_accuracy: 0.9289 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.8844
# Epoch 9: val_loss improved from 0.24899 to 0.24203, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 329s 2s/step - loss: 0.3684 - accuracy: 0.8844 - val_loss: 0.2420 - val_accuracy: 0.9343 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3512 - accuracy: 0.8926
# Epoch 10: val_loss did not improve from 0.24203
# 191/191 [==============================] - 317s 2s/step - loss: 0.3512 - accuracy: 0.8926 - val_loss: 0.2510 - val_accuracy: 0.9281 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3549 - accuracy: 0.8896
# Epoch 11: val_loss improved from 0.24203 to 0.23538, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 319s 2s/step - loss: 0.3549 - accuracy: 0.8896 - val_loss: 0.2354 - val_accuracy: 0.9343 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3681 - accuracy: 0.8878
# Epoch 12: val_loss did not improve from 0.23538
# 191/191 [==============================] - 827s 4s/step - loss: 0.3681 - accuracy: 0.8878 - val_loss: 0.2444 - val_accuracy: 0.9358 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3478 - accuracy: 0.8965
# Epoch 13: val_loss did not improve from 0.23538
# 191/191 [==============================] - 270s 1s/step - loss: 0.3478 - accuracy: 0.8965 - val_loss: 0.2646 - val_accuracy: 0.9205 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3519 - accuracy: 0.8917
# Epoch 14: val_loss improved from 0.23538 to 0.23203, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.3519 - accuracy: 0.8917 - val_loss: 0.2320 - val_accuracy: 0.9335 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3236 - accuracy: 0.9029
# Epoch 15: val_loss improved from 0.23203 to 0.22069, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.3236 - accuracy: 0.9029 - val_loss: 0.2207 - val_accuracy: 0.9404 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3165 - accuracy: 0.9070
# Epoch 16: val_loss improved from 0.22069 to 0.21760, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 297s 2s/step - loss: 0.3165 - accuracy: 0.9070 - val_loss: 0.2176 - val_accuracy: 0.9343 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3308 - accuracy: 0.9039
# Epoch 17: val_loss did not improve from 0.21760
# 191/191 [==============================] - 297s 2s/step - loss: 0.3308 - accuracy: 0.9039 - val_loss: 0.2454 - val_accuracy: 0.9411 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3208 - accuracy: 0.9081
# Epoch 18: val_loss did not improve from 0.21760
# 191/191 [==============================] - 294s 2s/step - loss: 0.3208 - accuracy: 0.9081 - val_loss: 0.2292 - val_accuracy: 0.9404 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3237 - accuracy: 0.9098
# Epoch 19: val_loss did not improve from 0.21760
# 191/191 [==============================] - 297s 2s/step - loss: 0.3237 - accuracy: 0.9098 - val_loss: 0.2293 - val_accuracy: 0.9365 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3163 - accuracy: 0.9119
# Epoch 20: val_loss did not improve from 0.21760
# 191/191 [==============================] - 292s 2s/step - loss: 0.3163 - accuracy: 0.9119 - val_loss: 0.2276 - val_accuracy: 0.9488 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3332 - accuracy: 0.9050
# Epoch 21: val_loss did not improve from 0.21760
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 298s 2s/step - loss: 0.3332 - accuracy: 0.9050 - val_loss: 0.2295 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.9188
# Epoch 22: val_loss improved from 0.21760 to 0.21650, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.2937 - accuracy: 0.9188 - val_loss: 0.2165 - val_accuracy: 0.9457 - lr: 5.0000e-04
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.9222
# Epoch 23: val_loss did not improve from 0.21650
# 191/191 [==============================] - 297s 2s/step - loss: 0.2762 - accuracy: 0.9222 - val_loss: 0.2179 - val_accuracy: 0.9457 - lr: 5.0000e-04
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2790 - accuracy: 0.9245
# Epoch 24: val_loss improved from 0.21650 to 0.20378, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.2790 - accuracy: 0.9245 - val_loss: 0.2038 - val_accuracy: 0.9465 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.9296
# Epoch 25: val_loss did not improve from 0.20378
# 191/191 [==============================] - 296s 2s/step - loss: 0.2648 - accuracy: 0.9296 - val_loss: 0.2097 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.9255
# Epoch 26: val_loss did not improve from 0.20378
# 191/191 [==============================] - 297s 2s/step - loss: 0.2708 - accuracy: 0.9255 - val_loss: 0.2062 - val_accuracy: 0.9526 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2568 - accuracy: 0.9309
# Epoch 27: val_loss improved from 0.20378 to 0.19525, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 295s 2s/step - loss: 0.2568 - accuracy: 0.9309 - val_loss: 0.1952 - val_accuracy: 0.9534 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2549 - accuracy: 0.9279
# Epoch 28: val_loss did not improve from 0.19525
# 191/191 [==============================] - 297s 2s/step - loss: 0.2549 - accuracy: 0.9279 - val_loss: 0.1968 - val_accuracy: 0.9549 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2570 - accuracy: 0.9307
# Epoch 29: val_loss did not improve from 0.19525
# 191/191 [==============================] - 297s 2s/step - loss: 0.2570 - accuracy: 0.9307 - val_loss: 0.2037 - val_accuracy: 0.9526 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.9291
# Epoch 30: val_loss improved from 0.19525 to 0.19117, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 295s 2s/step - loss: 0.2637 - accuracy: 0.9291 - val_loss: 0.1912 - val_accuracy: 0.9503 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2477 - accuracy: 0.9366
# Epoch 31: val_loss did not improve from 0.19117
# 191/191 [==============================] - 298s 2s/step - loss: 0.2477 - accuracy: 0.9366 - val_loss: 0.1917 - val_accuracy: 0.9541 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.9271
# Epoch 32: val_loss improved from 0.19117 to 0.18867, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.2565 - accuracy: 0.9271 - val_loss: 0.1887 - val_accuracy: 0.9557 - lr: 5.0000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2510 - accuracy: 0.9335
# Epoch 33: val_loss improved from 0.18867 to 0.17894, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.2510 - accuracy: 0.9335 - val_loss: 0.1789 - val_accuracy: 0.9595 - lr: 5.0000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2504 - accuracy: 0.9315
# Epoch 34: val_loss did not improve from 0.17894
# 191/191 [==============================] - 296s 2s/step - loss: 0.2504 - accuracy: 0.9315 - val_loss: 0.1918 - val_accuracy: 0.9534 - lr: 5.0000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2452 - accuracy: 0.9366
# Epoch 35: val_loss did not improve from 0.17894
# 191/191 [==============================] - 295s 2s/step - loss: 0.2452 - accuracy: 0.9366 - val_loss: 0.2064 - val_accuracy: 0.9488 - lr: 5.0000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9402
# Epoch 36: val_loss did not improve from 0.17894
# 191/191 [==============================] - 296s 2s/step - loss: 0.2344 - accuracy: 0.9402 - val_loss: 0.2146 - val_accuracy: 0.9472 - lr: 5.0000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2471 - accuracy: 0.9333
# Epoch 37: val_loss did not improve from 0.17894
# 191/191 [==============================] - 297s 2s/step - loss: 0.2471 - accuracy: 0.9333 - val_loss: 0.1860 - val_accuracy: 0.9564 - lr: 5.0000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.9337
# Epoch 38: val_loss did not improve from 0.17894
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 297s 2s/step - loss: 0.2478 - accuracy: 0.9337 - val_loss: 0.1806 - val_accuracy: 0.9564 - lr: 5.0000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9442
# Epoch 39: val_loss did not improve from 0.17894
# 191/191 [==============================] - 296s 2s/step - loss: 0.2241 - accuracy: 0.9442 - val_loss: 0.1810 - val_accuracy: 0.9564 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2210 - accuracy: 0.9430
# Epoch 40: val_loss did not improve from 0.17894
# 191/191 [==============================] - 297s 2s/step - loss: 0.2210 - accuracy: 0.9430 - val_loss: 0.1835 - val_accuracy: 0.9587 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2126 - accuracy: 0.9433
# Epoch 41: val_loss improved from 0.17894 to 0.16807, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 292s 2s/step - loss: 0.2126 - accuracy: 0.9433 - val_loss: 0.1681 - val_accuracy: 0.9625 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2125 - accuracy: 0.9438
# Epoch 42: val_loss did not improve from 0.16807
# 191/191 [==============================] - 296s 2s/step - loss: 0.2125 - accuracy: 0.9438 - val_loss: 0.1731 - val_accuracy: 0.9595 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.9443
# Epoch 43: val_loss did not improve from 0.16807
# 191/191 [==============================] - 294s 2s/step - loss: 0.2144 - accuracy: 0.9443 - val_loss: 0.1782 - val_accuracy: 0.9580 - lr: 2.5000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2076 - accuracy: 0.9461
# Epoch 44: val_loss did not improve from 0.16807
# 191/191 [==============================] - 298s 2s/step - loss: 0.2076 - accuracy: 0.9461 - val_loss: 0.1706 - val_accuracy: 0.9625 - lr: 2.5000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9443
# Epoch 45: val_loss did not improve from 0.16807
# 191/191 [==============================] - 298s 2s/step - loss: 0.2219 - accuracy: 0.9443 - val_loss: 0.1694 - val_accuracy: 0.9595 - lr: 2.5000e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2229 - accuracy: 0.9420
# Epoch 46: val_loss did not improve from 0.16807
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 293s 2s/step - loss: 0.2229 - accuracy: 0.9420 - val_loss: 0.1711 - val_accuracy: 0.9618 - lr: 2.5000e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2092 - accuracy: 0.9466
# Epoch 47: val_loss improved from 0.16807 to 0.16751, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 295s 2s/step - loss: 0.2092 - accuracy: 0.9466 - val_loss: 0.1675 - val_accuracy: 0.9602 - lr: 1.2500e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1938 - accuracy: 0.9504
# Epoch 48: val_loss improved from 0.16751 to 0.16251, saving model to resnet50v2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 297s 2s/step - loss: 0.1938 - accuracy: 0.9504 - val_loss: 0.1625 - val_accuracy: 0.9618 - lr: 1.2500e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.9473
# Epoch 49: val_loss did not improve from 0.16251
# 191/191 [==============================] - 296s 2s/step - loss: 0.2016 - accuracy: 0.9473 - val_loss: 0.1658 - val_accuracy: 0.9633 - lr: 1.2500e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9451
# Epoch 50: val_loss did not improve from 0.16251
# 191/191 [==============================] - 296s 2s/step - loss: 0.2098 - accuracy: 0.9451 - val_loss: 0.1663 - val_accuracy: 0.9610 - lr: 1.2500e-04
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2009 - accuracy: 0.9519
# Epoch 51: val_loss did not improve from 0.16251
# 191/191 [==============================] - 295s 2s/step - loss: 0.2009 - accuracy: 0.9519 - val_loss: 0.1677 - val_accuracy: 0.9610 - lr: 1.2500e-04
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.9496
# Epoch 52: val_loss did not improve from 0.16251
# 191/191 [==============================] - 297s 2s/step - loss: 0.1973 - accuracy: 0.9496 - val_loss: 0.1694 - val_accuracy: 0.9595 - lr: 1.2500e-04
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1959 - accuracy: 0.9520
# Epoch 53: val_loss did not improve from 0.16251
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 295s 2s/step - loss: 0.1959 - accuracy: 0.9520 - val_loss: 0.1717 - val_accuracy: 0.9595 - lr: 1.2500e-04
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9453
# Epoch 54: val_loss did not improve from 0.16251
# 191/191 [==============================] - 295s 2s/step - loss: 0.1996 - accuracy: 0.9453 - val_loss: 0.1653 - val_accuracy: 0.9610 - lr: 6.2500e-05
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9528
# Epoch 55: val_loss did not improve from 0.16251
# 191/191 [==============================] - 296s 2s/step - loss: 0.1971 - accuracy: 0.9528 - val_loss: 0.1678 - val_accuracy: 0.9610 - lr: 6.2500e-05
# Epoch 56/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.9566
# Epoch 56: val_loss did not improve from 0.16251
# 191/191 [==============================] - 295s 2s/step - loss: 0.1894 - accuracy: 0.9566 - val_loss: 0.1670 - val_accuracy: 0.9610 - lr: 6.2500e-05
# Epoch 57/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.9502
# Epoch 57: val_loss did not improve from 0.16251
# 191/191 [==============================] - 295s 2s/step - loss: 0.1940 - accuracy: 0.9502 - val_loss: 0.1644 - val_accuracy: 0.9625 - lr: 6.2500e-05
# Epoch 58/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.9515Restoring model weights from the end of the best epoch: 48.
#
# Epoch 58: val_loss did not improve from 0.16251
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 191/191 [==============================] - 296s 2s/step - loss: 0.1902 - accuracy: 0.9515 - val_loss: 0.1661 - val_accuracy: 0.9610 - lr: 6.2500e-05
# Epoch 58: early stopping
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9633

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F2,          # = 15, igual en todos los modelos
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F2,
    min_lr=1e-6,
    verbose=1
)

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 190
# Capas congeladas         : 160
# Capas descongeladas      : 30
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1944 - accuracy: 0.9512
# Epoch 1: val_loss improved from inf to 0.16312, saving model to resnet50v2_con_ft_weights.h5
# 191/191 [==============================] - 298s 2s/step - loss: 0.1944 - accuracy: 0.9512 - val_loss: 0.1631 - val_accuracy: 0.9625 - lr: 1.0000e-05
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9520
# Epoch 2: val_loss did not improve from 0.16312
# 191/191 [==============================] - 297s 2s/step - loss: 0.1984 - accuracy: 0.9520 - val_loss: 0.1638 - val_accuracy: 0.9618 - lr: 1.0000e-05
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9500
# Epoch 3: val_loss did not improve from 0.16312
# 191/191 [==============================] - 296s 2s/step - loss: 0.1930 - accuracy: 0.9500 - val_loss: 0.1636 - val_accuracy: 0.9625 - lr: 1.0000e-05
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9527
# Epoch 4: val_loss improved from 0.16312 to 0.16271, saving model to resnet50v2_con_ft_weights.h5
# 191/191 [==============================] - 291s 2s/step - loss: 0.1897 - accuracy: 0.9527 - val_loss: 0.1627 - val_accuracy: 0.9633 - lr: 1.0000e-05
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2024 - accuracy: 0.9469
# Epoch 5: val_loss did not improve from 0.16271
# 191/191 [==============================] - 296s 2s/step - loss: 0.2024 - accuracy: 0.9469 - val_loss: 0.1630 - val_accuracy: 0.9633 - lr: 1.0000e-05
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2030 - accuracy: 0.9484
# Epoch 6: val_loss did not improve from 0.16271
# 191/191 [==============================] - 293s 2s/step - loss: 0.2030 - accuracy: 0.9484 - val_loss: 0.1632 - val_accuracy: 0.9648 - lr: 1.0000e-05
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2015 - accuracy: 0.9497
# Epoch 7: val_loss did not improve from 0.16271
# 191/191 [==============================] - 295s 2s/step - loss: 0.2015 - accuracy: 0.9497 - val_loss: 0.1636 - val_accuracy: 0.9641 - lr: 1.0000e-05
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1932 - accuracy: 0.9499
# Epoch 8: val_loss did not improve from 0.16271
# 191/191 [==============================] - 297s 2s/step - loss: 0.1932 - accuracy: 0.9499 - val_loss: 0.1640 - val_accuracy: 0.9633 - lr: 1.0000e-05
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1911 - accuracy: 0.9546
# Epoch 9: val_loss did not improve from 0.16271
# 191/191 [==============================] - 294s 2s/step - loss: 0.1911 - accuracy: 0.9546 - val_loss: 0.1644 - val_accuracy: 0.9641 - lr: 1.0000e-05
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9507
# Epoch 10: val_loss did not improve from 0.16271
# 191/191 [==============================] - 296s 2s/step - loss: 0.1926 - accuracy: 0.9507 - val_loss: 0.1642 - val_accuracy: 0.9641 - lr: 1.0000e-05
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2015 - accuracy: 0.9499
# Epoch 11: val_loss did not improve from 0.16271
# 191/191 [==============================] - 296s 2s/step - loss: 0.2015 - accuracy: 0.9499 - val_loss: 0.1633 - val_accuracy: 0.9641 - lr: 1.0000e-05
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1956 - accuracy: 0.9537
# Epoch 12: val_loss did not improve from 0.16271
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 293s 2s/step - loss: 0.1956 - accuracy: 0.9537 - val_loss: 0.1636 - val_accuracy: 0.9641 - lr: 1.0000e-05
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.9500
# Epoch 13: val_loss did not improve from 0.16271
# 191/191 [==============================] - 297s 2s/step - loss: 0.1973 - accuracy: 0.9500 - val_loss: 0.1634 - val_accuracy: 0.9641 - lr: 5.0000e-06
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9505
# Epoch 14: val_loss did not improve from 0.16271
# 191/191 [==============================] - 295s 2s/step - loss: 0.1931 - accuracy: 0.9505 - val_loss: 0.1636 - val_accuracy: 0.9641 - lr: 5.0000e-06
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9523
# Epoch 15: val_loss did not improve from 0.16271
# 191/191 [==============================] - 294s 2s/step - loss: 0.1883 - accuracy: 0.9523 - val_loss: 0.1633 - val_accuracy: 0.9641 - lr: 5.0000e-06
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1965 - accuracy: 0.9505
# Epoch 16: val_loss did not improve from 0.16271
# 191/191 [==============================] - 296s 2s/step - loss: 0.1965 - accuracy: 0.9505 - val_loss: 0.1635 - val_accuracy: 0.9641 - lr: 5.0000e-06
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2064 - accuracy: 0.9489
# Epoch 17: val_loss did not improve from 0.16271
# 191/191 [==============================] - 296s 2s/step - loss: 0.2064 - accuracy: 0.9489 - val_loss: 0.1636 - val_accuracy: 0.9641 - lr: 5.0000e-06
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9491
# Epoch 18: val_loss did not improve from 0.16271
# 191/191 [==============================] - 295s 2s/step - loss: 0.1988 - accuracy: 0.9491 - val_loss: 0.1635 - val_accuracy: 0.9641 - lr: 5.0000e-06
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2037 - accuracy: 0.9481Restoring model weights from the end of the best epoch: 4.
#
# Epoch 19: val_loss did not improve from 0.16271
# 191/191 [==============================] - 295s 2s/step - loss: 0.2037 - accuracy: 0.9481 - val_loss: 0.1636 - val_accuracy: 0.9633 - lr: 5.0000e-06
# Epoch 19: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9648

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9633
# Fase 2 — mejor val_accuracy: 0.9648

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 45s 1s/step - loss: 0.1440 - accuracy: 0.9732
#
# Test Accuracy : 0.9732
# Test Loss     : 0.1440
# 41/41 [==============================] - 45s 1s/step
# F1 Score      : 0.9733
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9796    0.9600    0.9697       150
#    mancha_anillo     0.9906    1.0000    0.9953       105
#     mancha_parda     0.9800    0.9800    0.9800       150
#          mosaico     0.9799    0.9733    0.9766       150
#      muermo_rojo     0.9286    0.9533    0.9408       150
#             roya     0.9600    0.9600    0.9600       150
#            sanas     0.9539    0.9667    0.9603       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     0.9932    0.9733    0.9832       150
#
#         accuracy                         0.9732      1308
#        macro avg     0.9766    0.9767    0.9766      1308
#     weighted avg     0.9735    0.9732    0.9733      1308
#
#
# Resultados guardados en resnet50v2_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]
class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 1 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]
print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]
    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()
    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9, color='red'
        )
        axes[j].axis('off')
    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')
    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14, fontweight='bold', y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 1 o más confusiones:
#   hoja_amarilla → muermo_rojo: 3 imágenes
#   roya → muermo_rojo: 3 imágenes
#   hoja_amarilla → sanas: 2 imágenes
#   mancha_parda → hoja_amarilla: 2 imágenes
#   mosaico → sanas: 2 imágenes
#   muermo_rojo → mancha_parda: 2 imágenes
#   muermo_rojo → roya: 2 imágenes
#   roya → sanas: 2 imágenes
#   sanas → roya: 2 imágenes
#   sanas → mosaico: 2 imágenes
#   tizon_bacteriano → muermo_rojo: 2 imágenes
#   tizon_bacteriano → roya: 2 imágenes
#   hoja_amarilla → mancha_parda: 1 imágenes
#   mancha_parda → muermo_rojo: 1 imágenes
#   mosaico → muermo_rojo: 1 imágenes
#   mosaico → tizon_bacteriano: 1 imágenes
#   muermo_rojo → mosaico: 1 imágenes
#   muermo_rojo → hoja_amarilla: 1 imágenes
#   muermo_rojo → sanas: 1 imágenes
#   roya → mancha_anillo: 1 imágenes
#   sanas → muermo_rojo: 1 imágenes
#
# Total de imágenes a mostrar: 35

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: resnet50v2_con_ft_weights.h5
