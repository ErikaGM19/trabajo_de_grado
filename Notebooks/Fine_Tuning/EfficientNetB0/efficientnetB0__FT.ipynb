# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
NUM_CLASSES   = 10
NOMBRE_MODELO = 'efficientnetB0_FT'

# Fase 1: Congelación de capas
PATIENCE_ES_F1  = 10
PATIENCE_LR_F1  = 5

# Fase 2: Descongelación de capas
PATIENCE_ES_F2  = 15
PATIENCE_LR_F2  = 8

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# DATA AUGMENTATION — IGUAL EN TODOS LOS MODELOS
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFICIENTNETB0

# %%
# CARGAR EFFICIENTNETB0 CON PESOS DE IMAGENET
base_model = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPAS FINALES PERSONALIZADAS
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "efficientnetB0_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 4,214,829
# Trainable params: 165,258
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F1,
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F1,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.8601 - accuracy: 0.7294
# Epoch 1: val_loss improved from inf to 0.32809, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 228s 1s/step - loss: 0.8601 - accuracy: 0.7294 - val_loss: 0.3281 - val_accuracy: 0.9235 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4311 - accuracy: 0.8736
# Epoch 2: val_loss improved from 0.32809 to 0.22131, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 234s 1s/step - loss: 0.4311 - accuracy: 0.8736 - val_loss: 0.2213 - val_accuracy: 0.9488 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3568 - accuracy: 0.8958
# Epoch 3: val_loss improved from 0.22131 to 0.20026, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 228s 1s/step - loss: 0.3568 - accuracy: 0.8958 - val_loss: 0.2003 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3120 - accuracy: 0.9107
# Epoch 4: val_loss improved from 0.20026 to 0.19084, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 214s 1s/step - loss: 0.3120 - accuracy: 0.9107 - val_loss: 0.1908 - val_accuracy: 0.9564 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2672 - accuracy: 0.9227
# Epoch 5: val_loss improved from 0.19084 to 0.16107, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 217s 1s/step - loss: 0.2672 - accuracy: 0.9227 - val_loss: 0.1611 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 0.9265
# Epoch 6: val_loss did not improve from 0.16107
# 191/191 [==============================] - 218s 1s/step - loss: 0.2655 - accuracy: 0.9265 - val_loss: 0.1654 - val_accuracy: 0.9549 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2427 - accuracy: 0.9345
# Epoch 7: val_loss did not improve from 0.16107
# 191/191 [==============================] - 216s 1s/step - loss: 0.2427 - accuracy: 0.9345 - val_loss: 0.1658 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2359 - accuracy: 0.9402
# Epoch 8: val_loss improved from 0.16107 to 0.15190, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 219s 1s/step - loss: 0.2359 - accuracy: 0.9402 - val_loss: 0.1519 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2350 - accuracy: 0.9365
# Epoch 9: val_loss did not improve from 0.15190
# 191/191 [==============================] - 211s 1s/step - loss: 0.2350 - accuracy: 0.9365 - val_loss: 0.1550 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2290 - accuracy: 0.9391
# Epoch 10: val_loss did not improve from 0.15190
# 191/191 [==============================] - 206s 1s/step - loss: 0.2290 - accuracy: 0.9391 - val_loss: 0.1661 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9451
# Epoch 11: val_loss improved from 0.15190 to 0.15109, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 207s 1s/step - loss: 0.2187 - accuracy: 0.9451 - val_loss: 0.1511 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2159 - accuracy: 0.9448
# Epoch 12: val_loss did not improve from 0.15109
# 191/191 [==============================] - 205s 1s/step - loss: 0.2159 - accuracy: 0.9448 - val_loss: 0.1611 - val_accuracy: 0.9549 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2096 - accuracy: 0.9473
# Epoch 13: val_loss improved from 0.15109 to 0.13707, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 205s 1s/step - loss: 0.2096 - accuracy: 0.9473 - val_loss: 0.1371 - val_accuracy: 0.9732 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9486
# Epoch 14: val_loss did not improve from 0.13707
# 191/191 [==============================] - 204s 1s/step - loss: 0.2012 - accuracy: 0.9486 - val_loss: 0.1405 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2096 - accuracy: 0.9476
# Epoch 15: val_loss did not improve from 0.13707
# 191/191 [==============================] - 202s 1s/step - loss: 0.2096 - accuracy: 0.9476 - val_loss: 0.1378 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2017 - accuracy: 0.9514
# Epoch 16: val_loss improved from 0.13707 to 0.13451, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 206s 1s/step - loss: 0.2017 - accuracy: 0.9514 - val_loss: 0.1345 - val_accuracy: 0.9732 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2069 - accuracy: 0.9515
# Epoch 17: val_loss did not improve from 0.13451
# 191/191 [==============================] - 212s 1s/step - loss: 0.2069 - accuracy: 0.9515 - val_loss: 0.1428 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2076 - accuracy: 0.9460
# Epoch 18: val_loss did not improve from 0.13451
# 191/191 [==============================] - 203s 1s/step - loss: 0.2076 - accuracy: 0.9460 - val_loss: 0.1535 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2116 - accuracy: 0.9471
# Epoch 19: val_loss did not improve from 0.13451
# 191/191 [==============================] - 203s 1s/step - loss: 0.2116 - accuracy: 0.9471 - val_loss: 0.1489 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1955 - accuracy: 0.9548
# Epoch 20: val_loss did not improve from 0.13451
# 191/191 [==============================] - 202s 1s/step - loss: 0.1955 - accuracy: 0.9548 - val_loss: 0.1374 - val_accuracy: 0.9740 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2007 - accuracy: 0.9504
# Epoch 21: val_loss did not improve from 0.13451
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 202s 1s/step - loss: 0.2007 - accuracy: 0.9504 - val_loss: 0.1472 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1782 - accuracy: 0.9579
# Epoch 22: val_loss did not improve from 0.13451
# 191/191 [==============================] - 203s 1s/step - loss: 0.1782 - accuracy: 0.9579 - val_loss: 0.1354 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1751 - accuracy: 0.9591
# Epoch 23: val_loss did not improve from 0.13451
# 191/191 [==============================] - 202s 1s/step - loss: 0.1751 - accuracy: 0.9591 - val_loss: 0.1400 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9668
# Epoch 24: val_loss did not improve from 0.13451
# 191/191 [==============================] - 203s 1s/step - loss: 0.1603 - accuracy: 0.9668 - val_loss: 0.1443 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.9676
# Epoch 25: val_loss did not improve from 0.13451
# 191/191 [==============================] - 203s 1s/step - loss: 0.1597 - accuracy: 0.9676 - val_loss: 0.1409 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1552 - accuracy: 0.9699
# Epoch 26: val_loss improved from 0.13451 to 0.13177, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 202s 1s/step - loss: 0.1552 - accuracy: 0.9699 - val_loss: 0.1318 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1628 - accuracy: 0.9641
# Epoch 27: val_loss improved from 0.13177 to 0.12823, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 202s 1s/step - loss: 0.1628 - accuracy: 0.9641 - val_loss: 0.1282 - val_accuracy: 0.9778 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 0.9671
# Epoch 28: val_loss did not improve from 0.12823
# 191/191 [==============================] - 202s 1s/step - loss: 0.1539 - accuracy: 0.9671 - val_loss: 0.1307 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1549 - accuracy: 0.9663
# Epoch 29: val_loss did not improve from 0.12823
# 191/191 [==============================] - 203s 1s/step - loss: 0.1549 - accuracy: 0.9663 - val_loss: 0.1314 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 0.9694
# Epoch 30: val_loss did not improve from 0.12823
# 191/191 [==============================] - 202s 1s/step - loss: 0.1539 - accuracy: 0.9694 - val_loss: 0.1297 - val_accuracy: 0.9740 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1578 - accuracy: 0.9661
# Epoch 31: val_loss did not improve from 0.12823
# 191/191 [==============================] - 203s 1s/step - loss: 0.1578 - accuracy: 0.9661 - val_loss: 0.1378 - val_accuracy: 0.9732 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 0.9645
# Epoch 32: val_loss did not improve from 0.12823
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 202s 1s/step - loss: 0.1570 - accuracy: 0.9645 - val_loss: 0.1297 - val_accuracy: 0.9755 - lr: 5.0000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1447 - accuracy: 0.9700
# Epoch 33: val_loss improved from 0.12823 to 0.12264, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 202s 1s/step - loss: 0.1447 - accuracy: 0.9700 - val_loss: 0.1226 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1471 - accuracy: 0.9690
# Epoch 34: val_loss did not improve from 0.12264
# 191/191 [==============================] - 210s 1s/step - loss: 0.1471 - accuracy: 0.9690 - val_loss: 0.1260 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9699
# Epoch 35: val_loss improved from 0.12264 to 0.12077, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 204s 1s/step - loss: 0.1411 - accuracy: 0.9699 - val_loss: 0.1208 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1440 - accuracy: 0.9697
# Epoch 36: val_loss did not improve from 0.12077
# 191/191 [==============================] - 202s 1s/step - loss: 0.1440 - accuracy: 0.9697 - val_loss: 0.1292 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9725
# Epoch 37: val_loss improved from 0.12077 to 0.12018, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 204s 1s/step - loss: 0.1374 - accuracy: 0.9725 - val_loss: 0.1202 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1339 - accuracy: 0.9736
# Epoch 38: val_loss did not improve from 0.12018
# 191/191 [==============================] - 203s 1s/step - loss: 0.1339 - accuracy: 0.9736 - val_loss: 0.1253 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9722
# Epoch 39: val_loss did not improve from 0.12018
# 191/191 [==============================] - 203s 1s/step - loss: 0.1377 - accuracy: 0.9722 - val_loss: 0.1222 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.9702
# Epoch 40: val_loss improved from 0.12018 to 0.11718, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 202s 1s/step - loss: 0.1379 - accuracy: 0.9702 - val_loss: 0.1172 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9722
# Epoch 41: val_loss did not improve from 0.11718
# 191/191 [==============================] - 204s 1s/step - loss: 0.1360 - accuracy: 0.9722 - val_loss: 0.1176 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9722
# Epoch 42: val_loss did not improve from 0.11718
# 191/191 [==============================] - 202s 1s/step - loss: 0.1375 - accuracy: 0.9722 - val_loss: 0.1189 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9767
# Epoch 43: val_loss did not improve from 0.11718
# 191/191 [==============================] - 203s 1s/step - loss: 0.1269 - accuracy: 0.9767 - val_loss: 0.1206 - val_accuracy: 0.9786 - lr: 2.5000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9767
# Epoch 44: val_loss did not improve from 0.11718
# 191/191 [==============================] - 202s 1s/step - loss: 0.1265 - accuracy: 0.9767 - val_loss: 0.1203 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 0.9733
# Epoch 45: val_loss did not improve from 0.11718
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 202s 1s/step - loss: 0.1323 - accuracy: 0.9733 - val_loss: 0.1185 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1277 - accuracy: 0.9735
# Epoch 46: val_loss did not improve from 0.11718
# 191/191 [==============================] - 203s 1s/step - loss: 0.1277 - accuracy: 0.9735 - val_loss: 0.1217 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9759
# Epoch 47: val_loss did not improve from 0.11718
# 191/191 [==============================] - 202s 1s/step - loss: 0.1253 - accuracy: 0.9759 - val_loss: 0.1178 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1203 - accuracy: 0.9769
# Epoch 48: val_loss improved from 0.11718 to 0.11567, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 203s 1s/step - loss: 0.1203 - accuracy: 0.9769 - val_loss: 0.1157 - val_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1218 - accuracy: 0.9781
# Epoch 49: val_loss did not improve from 0.11567
# 191/191 [==============================] - 214s 1s/step - loss: 0.1218 - accuracy: 0.9781 - val_loss: 0.1180 - val_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9728
# Epoch 50: val_loss did not improve from 0.11567
# 191/191 [==============================] - 214s 1s/step - loss: 0.1305 - accuracy: 0.9728 - val_loss: 0.1186 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9764
# Epoch 51: val_loss improved from 0.11567 to 0.11481, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 217s 1s/step - loss: 0.1226 - accuracy: 0.9764 - val_loss: 0.1148 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1211 - accuracy: 0.9758
# Epoch 52: val_loss improved from 0.11481 to 0.11315, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 215s 1s/step - loss: 0.1211 - accuracy: 0.9758 - val_loss: 0.1131 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9790
# Epoch 53: val_loss did not improve from 0.11315
# 191/191 [==============================] - 220s 1s/step - loss: 0.1169 - accuracy: 0.9790 - val_loss: 0.1141 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9797
# Epoch 54: val_loss improved from 0.11315 to 0.11280, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 220s 1s/step - loss: 0.1153 - accuracy: 0.9797 - val_loss: 0.1128 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.9784
# Epoch 55: val_loss did not improve from 0.11280
# 191/191 [==============================] - 212s 1s/step - loss: 0.1201 - accuracy: 0.9784 - val_loss: 0.1175 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 56/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 0.9782
# Epoch 56: val_loss did not improve from 0.11280
# 191/191 [==============================] - 210s 1s/step - loss: 0.1168 - accuracy: 0.9782 - val_loss: 0.1158 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 57/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9781
# Epoch 57: val_loss did not improve from 0.11280
# 191/191 [==============================] - 208s 1s/step - loss: 0.1226 - accuracy: 0.9781 - val_loss: 0.1168 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 58/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9743
# Epoch 58: val_loss improved from 0.11280 to 0.11269, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 211s 1s/step - loss: 0.1231 - accuracy: 0.9743 - val_loss: 0.1127 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 59/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.9751
# Epoch 59: val_loss improved from 0.11269 to 0.11118, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 209s 1s/step - loss: 0.1215 - accuracy: 0.9751 - val_loss: 0.1112 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 60/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9753
# Epoch 60: val_loss improved from 0.11118 to 0.11008, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 212s 1s/step - loss: 0.1205 - accuracy: 0.9753 - val_loss: 0.1101 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 61/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9771
# Epoch 61: val_loss did not improve from 0.11008
# 191/191 [==============================] - 204s 1s/step - loss: 0.1171 - accuracy: 0.9771 - val_loss: 0.1116 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 62/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9777
# Epoch 62: val_loss did not improve from 0.11008
# 191/191 [==============================] - 231s 1s/step - loss: 0.1162 - accuracy: 0.9777 - val_loss: 0.1115 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 63/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1166 - accuracy: 0.9774
# Epoch 63: val_loss did not improve from 0.11008
# 191/191 [==============================] - 218s 1s/step - loss: 0.1166 - accuracy: 0.9774 - val_loss: 0.1116 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 64/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9758
# Epoch 64: val_loss did not improve from 0.11008
# 191/191 [==============================] - 217s 1s/step - loss: 0.1193 - accuracy: 0.9758 - val_loss: 0.1104 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 65/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1047 - accuracy: 0.9823
# Epoch 65: val_loss improved from 0.11008 to 0.10718, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 215s 1s/step - loss: 0.1047 - accuracy: 0.9823 - val_loss: 0.1072 - val_accuracy: 0.9824 - lr: 1.2500e-04
# Epoch 66/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9779
# Epoch 66: val_loss did not improve from 0.10718
# 191/191 [==============================] - 223s 1s/step - loss: 0.1142 - accuracy: 0.9779 - val_loss: 0.1111 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 67/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1109 - accuracy: 0.9808
# Epoch 67: val_loss did not improve from 0.10718
# 191/191 [==============================] - 216s 1s/step - loss: 0.1109 - accuracy: 0.9808 - val_loss: 0.1092 - val_accuracy: 0.9824 - lr: 1.2500e-04
# Epoch 68/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1184 - accuracy: 0.9764
# Epoch 68: val_loss did not improve from 0.10718
# 191/191 [==============================] - 215s 1s/step - loss: 0.1184 - accuracy: 0.9764 - val_loss: 0.1132 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 69/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9777
# Epoch 69: val_loss did not improve from 0.10718
# 191/191 [==============================] - 215s 1s/step - loss: 0.1170 - accuracy: 0.9777 - val_loss: 0.1105 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 70/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1187 - accuracy: 0.9774
# Epoch 70: val_loss did not improve from 0.10718
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 223s 1s/step - loss: 0.1187 - accuracy: 0.9774 - val_loss: 0.1084 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 71/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9790
# Epoch 71: val_loss improved from 0.10718 to 0.10698, saving model to efficientnetB0_con_ft_fase1_weights.h5
# 191/191 [==============================] - 220s 1s/step - loss: 0.1100 - accuracy: 0.9790 - val_loss: 0.1070 - val_accuracy: 0.9817 - lr: 6.2500e-05
# Epoch 72/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9763
# Epoch 72: val_loss did not improve from 0.10698
# 191/191 [==============================] - 217s 1s/step - loss: 0.1163 - accuracy: 0.9763 - val_loss: 0.1099 - val_accuracy: 0.9809 - lr: 6.2500e-05
# Epoch 73/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1108 - accuracy: 0.9795
# Epoch 73: val_loss did not improve from 0.10698
# 191/191 [==============================] - 222s 1s/step - loss: 0.1108 - accuracy: 0.9795 - val_loss: 0.1114 - val_accuracy: 0.9794 - lr: 6.2500e-05
# Epoch 74/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1123 - accuracy: 0.9772
# Epoch 74: val_loss did not improve from 0.10698
# 191/191 [==============================] - 223s 1s/step - loss: 0.1123 - accuracy: 0.9772 - val_loss: 0.1116 - val_accuracy: 0.9786 - lr: 6.2500e-05
# Epoch 75/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1183 - accuracy: 0.9781
# Epoch 75: val_loss did not improve from 0.10698
# 191/191 [==============================] - 223s 1s/step - loss: 0.1183 - accuracy: 0.9781 - val_loss: 0.1088 - val_accuracy: 0.9817 - lr: 6.2500e-05
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9824

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F2,          
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F2,
    min_lr=1e-6,
    verbose=1
)

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 238
# Capas congeladas         : 208
# Capas descongeladas      : 30
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9759
# Epoch 1: val_loss improved from inf to 0.10956, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 224s 1s/step - loss: 0.1141 - accuracy: 0.9759 - val_loss: 0.1096 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1176 - accuracy: 0.9759
# Epoch 2: val_loss did not improve from 0.10956
# 191/191 [==============================] - 224s 1s/step - loss: 0.1176 - accuracy: 0.9759 - val_loss: 0.1101 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1106 - accuracy: 0.9808
# Epoch 3: val_loss did not improve from 0.10956
# 191/191 [==============================] - 223s 1s/step - loss: 0.1106 - accuracy: 0.9808 - val_loss: 0.1098 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9805
# Epoch 4: val_loss improved from 0.10956 to 0.10956, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 224s 1s/step - loss: 0.1072 - accuracy: 0.9805 - val_loss: 0.1096 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9767
# Epoch 5: val_loss improved from 0.10956 to 0.10950, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 222s 1s/step - loss: 0.1157 - accuracy: 0.9767 - val_loss: 0.1095 - val_accuracy: 0.9809 - lr: 1.0000e-05
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.9810
# Epoch 6: val_loss did not improve from 0.10950
# 191/191 [==============================] - 225s 1s/step - loss: 0.1090 - accuracy: 0.9810 - val_loss: 0.1097 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9800
# Epoch 7: val_loss did not improve from 0.10950
# 191/191 [==============================] - 224s 1s/step - loss: 0.1119 - accuracy: 0.9800 - val_loss: 0.1100 - val_accuracy: 0.9794 - lr: 1.0000e-05
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1120 - accuracy: 0.9794
# Epoch 8: val_loss did not improve from 0.10950
# 191/191 [==============================] - 224s 1s/step - loss: 0.1120 - accuracy: 0.9794 - val_loss: 0.1102 - val_accuracy: 0.9794 - lr: 1.0000e-05
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1075 - accuracy: 0.9794
# Epoch 9: val_loss did not improve from 0.10950
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 225s 1s/step - loss: 0.1075 - accuracy: 0.9794 - val_loss: 0.1098 - val_accuracy: 0.9794 - lr: 1.0000e-05
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9813
# Epoch 10: val_loss did not improve from 0.10950
# 191/191 [==============================] - 223s 1s/step - loss: 0.1035 - accuracy: 0.9813 - val_loss: 0.1100 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1113 - accuracy: 0.9774
# Epoch 11: val_loss did not improve from 0.10950
# 191/191 [==============================] - 224s 1s/step - loss: 0.1113 - accuracy: 0.9774 - val_loss: 0.1097 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9815
# Epoch 12: val_loss did not improve from 0.10950
# 191/191 [==============================] - 217s 1s/step - loss: 0.1060 - accuracy: 0.9815 - val_loss: 0.1102 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9817
# Epoch 13: val_loss did not improve from 0.10950
# 191/191 [==============================] - 214s 1s/step - loss: 0.1033 - accuracy: 0.9817 - val_loss: 0.1098 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9802
# Epoch 14: val_loss did not improve from 0.10950
# 191/191 [==============================] - 212s 1s/step - loss: 0.1094 - accuracy: 0.9802 - val_loss: 0.1096 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9807
# Epoch 15: val_loss improved from 0.10950 to 0.10935, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 217s 1s/step - loss: 0.1095 - accuracy: 0.9807 - val_loss: 0.1094 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9830
# Epoch 16: val_loss improved from 0.10935 to 0.10931, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 224s 1s/step - loss: 0.1037 - accuracy: 0.9830 - val_loss: 0.1093 - val_accuracy: 0.9786 - lr: 5.0000e-06
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9815
# Epoch 17: val_loss did not improve from 0.10931
# 191/191 [==============================] - 222s 1s/step - loss: 0.1055 - accuracy: 0.9815 - val_loss: 0.1094 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9789
# Epoch 18: val_loss improved from 0.10931 to 0.10922, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 225s 1s/step - loss: 0.1107 - accuracy: 0.9789 - val_loss: 0.1092 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9805
# Epoch 19: val_loss improved from 0.10922 to 0.10892, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 221s 1s/step - loss: 0.1037 - accuracy: 0.9805 - val_loss: 0.1089 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1103 - accuracy: 0.9802
# Epoch 20: val_loss did not improve from 0.10892
# 191/191 [==============================] - 224s 1s/step - loss: 0.1103 - accuracy: 0.9802 - val_loss: 0.1091 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9795
# Epoch 21: val_loss did not improve from 0.10892
# 191/191 [==============================] - 224s 1s/step - loss: 0.1085 - accuracy: 0.9795 - val_loss: 0.1092 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9799
# Epoch 22: val_loss improved from 0.10892 to 0.10880, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 221s 1s/step - loss: 0.1065 - accuracy: 0.9799 - val_loss: 0.1088 - val_accuracy: 0.9801 - lr: 5.0000e-06
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9799
# Epoch 23: val_loss improved from 0.10880 to 0.10842, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 225s 1s/step - loss: 0.1042 - accuracy: 0.9799 - val_loss: 0.1084 - val_accuracy: 0.9809 - lr: 5.0000e-06
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.9808
# Epoch 24: val_loss did not improve from 0.10842
# 191/191 [==============================] - 224s 1s/step - loss: 0.1090 - accuracy: 0.9808 - val_loss: 0.1086 - val_accuracy: 0.9801 - lr: 5.0000e-06
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9818
# Epoch 25: val_loss did not improve from 0.10842
# 191/191 [==============================] - 222s 1s/step - loss: 0.1050 - accuracy: 0.9818 - val_loss: 0.1086 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9805
# Epoch 26: val_loss improved from 0.10842 to 0.10831, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 224s 1s/step - loss: 0.1052 - accuracy: 0.9805 - val_loss: 0.1083 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9794
# Epoch 27: val_loss did not improve from 0.10831
# 191/191 [==============================] - 220s 1s/step - loss: 0.1076 - accuracy: 0.9794 - val_loss: 0.1083 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1063 - accuracy: 0.9800
# Epoch 28: val_loss did not improve from 0.10831
# 191/191 [==============================] - 223s 1s/step - loss: 0.1063 - accuracy: 0.9800 - val_loss: 0.1084 - val_accuracy: 0.9801 - lr: 5.0000e-06
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9792
# Epoch 29: val_loss did not improve from 0.10831
# 191/191 [==============================] - 224s 1s/step - loss: 0.1082 - accuracy: 0.9792 - val_loss: 0.1087 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1051 - accuracy: 0.9813
# Epoch 30: val_loss did not improve from 0.10831
# 191/191 [==============================] - 212s 1s/step - loss: 0.1051 - accuracy: 0.9813 - val_loss: 0.1085 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9803
# Epoch 31: val_loss did not improve from 0.10831
# 191/191 [==============================] - 213s 1s/step - loss: 0.1081 - accuracy: 0.9803 - val_loss: 0.1085 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1063 - accuracy: 0.9795
# Epoch 32: val_loss did not improve from 0.10831
# 191/191 [==============================] - 213s 1s/step - loss: 0.1063 - accuracy: 0.9795 - val_loss: 0.1088 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1123 - accuracy: 0.9789
# Epoch 33: val_loss did not improve from 0.10831
# 191/191 [==============================] - 212s 1s/step - loss: 0.1123 - accuracy: 0.9789 - val_loss: 0.1084 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9835
# Epoch 34: val_loss improved from 0.10831 to 0.10816, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 211s 1s/step - loss: 0.1012 - accuracy: 0.9835 - val_loss: 0.1082 - val_accuracy: 0.9801 - lr: 5.0000e-06
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9795
# Epoch 35: val_loss did not improve from 0.10816
# 191/191 [==============================] - 213s 1s/step - loss: 0.1027 - accuracy: 0.9795 - val_loss: 0.1084 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9789
# Epoch 36: val_loss did not improve from 0.10816
# 191/191 [==============================] - 212s 1s/step - loss: 0.1086 - accuracy: 0.9789 - val_loss: 0.1086 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9815
# Epoch 37: val_loss did not improve from 0.10816
# 191/191 [==============================] - 210s 1s/step - loss: 0.1093 - accuracy: 0.9815 - val_loss: 0.1088 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0992 - accuracy: 0.9830
# Epoch 38: val_loss did not improve from 0.10816
# 191/191 [==============================] - 211s 1s/step - loss: 0.0992 - accuracy: 0.9830 - val_loss: 0.1088 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9808
# Epoch 39: val_loss did not improve from 0.10816
# 191/191 [==============================] - 211s 1s/step - loss: 0.1046 - accuracy: 0.9808 - val_loss: 0.1089 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1106 - accuracy: 0.9797
# Epoch 40: val_loss did not improve from 0.10816
# 191/191 [==============================] - 209s 1s/step - loss: 0.1106 - accuracy: 0.9797 - val_loss: 0.1088 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9820
# Epoch 41: val_loss did not improve from 0.10816
# 191/191 [==============================] - 212s 1s/step - loss: 0.1032 - accuracy: 0.9820 - val_loss: 0.1088 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1047 - accuracy: 0.9828
# Epoch 42: val_loss did not improve from 0.10816
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 191/191 [==============================] - 212s 1s/step - loss: 0.1047 - accuracy: 0.9828 - val_loss: 0.1086 - val_accuracy: 0.9794 - lr: 5.0000e-06
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1068 - accuracy: 0.9808
# Epoch 43: val_loss did not improve from 0.10816
# 191/191 [==============================] - 209s 1s/step - loss: 0.1068 - accuracy: 0.9808 - val_loss: 0.1085 - val_accuracy: 0.9794 - lr: 2.5000e-06
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9792
# Epoch 44: val_loss did not improve from 0.10816
# 191/191 [==============================] - 210s 1s/step - loss: 0.1089 - accuracy: 0.9792 - val_loss: 0.1082 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9826
# Epoch 45: val_loss improved from 0.10816 to 0.10814, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 210s 1s/step - loss: 0.1055 - accuracy: 0.9826 - val_loss: 0.1081 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9795
# Epoch 46: val_loss improved from 0.10814 to 0.10799, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 210s 1s/step - loss: 0.1089 - accuracy: 0.9795 - val_loss: 0.1080 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9800
# Epoch 47: val_loss did not improve from 0.10799
# 191/191 [==============================] - 213s 1s/step - loss: 0.1071 - accuracy: 0.9800 - val_loss: 0.1080 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9812
# Epoch 48: val_loss did not improve from 0.10799
# 191/191 [==============================] - 209s 1s/step - loss: 0.1094 - accuracy: 0.9812 - val_loss: 0.1081 - val_accuracy: 0.9794 - lr: 2.5000e-06
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9803
# Epoch 49: val_loss improved from 0.10799 to 0.10796, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 210s 1s/step - loss: 0.1065 - accuracy: 0.9803 - val_loss: 0.1080 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1105 - accuracy: 0.9771
# Epoch 50: val_loss did not improve from 0.10796
# 191/191 [==============================] - 212s 1s/step - loss: 0.1105 - accuracy: 0.9771 - val_loss: 0.1080 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0973 - accuracy: 0.9867
# Epoch 51: val_loss improved from 0.10796 to 0.10776, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 214s 1s/step - loss: 0.0973 - accuracy: 0.9867 - val_loss: 0.1078 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9826
# Epoch 52: val_loss did not improve from 0.10776
# 191/191 [==============================] - 210s 1s/step - loss: 0.1024 - accuracy: 0.9826 - val_loss: 0.1078 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.9810
# Epoch 53: val_loss did not improve from 0.10776
# 191/191 [==============================] - 213s 1s/step - loss: 0.1099 - accuracy: 0.9810 - val_loss: 0.1078 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.9815
# Epoch 54: val_loss did not improve from 0.10776
# 191/191 [==============================] - 211s 1s/step - loss: 0.1028 - accuracy: 0.9815 - val_loss: 0.1080 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1080 - accuracy: 0.9812
# Epoch 55: val_loss did not improve from 0.10776
# 191/191 [==============================] - 212s 1s/step - loss: 0.1080 - accuracy: 0.9812 - val_loss: 0.1081 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 56/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1041 - accuracy: 0.9807
# Epoch 56: val_loss did not improve from 0.10776
# 191/191 [==============================] - 209s 1s/step - loss: 0.1041 - accuracy: 0.9807 - val_loss: 0.1080 - val_accuracy: 0.9809 - lr: 2.5000e-06
# Epoch 57/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.9790
# Epoch 57: val_loss did not improve from 0.10776
# 191/191 [==============================] - 213s 1s/step - loss: 0.1090 - accuracy: 0.9790 - val_loss: 0.1078 - val_accuracy: 0.9809 - lr: 2.5000e-06
# Epoch 58/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1069 - accuracy: 0.9784
# Epoch 58: val_loss improved from 0.10776 to 0.10768, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 210s 1s/step - loss: 0.1069 - accuracy: 0.9784 - val_loss: 0.1077 - val_accuracy: 0.9817 - lr: 2.5000e-06
# Epoch 59/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9825
# Epoch 59: val_loss improved from 0.10768 to 0.10762, saving model to efficientnetB0_con_ft_weights.h5
# 191/191 [==============================] - 212s 1s/step - loss: 0.1073 - accuracy: 0.9825 - val_loss: 0.1076 - val_accuracy: 0.9817 - lr: 2.5000e-06
# Epoch 60/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9812
# Epoch 60: val_loss did not improve from 0.10762
# 191/191 [==============================] - 211s 1s/step - loss: 0.1044 - accuracy: 0.9812 - val_loss: 0.1079 - val_accuracy: 0.9809 - lr: 2.5000e-06
# Epoch 61/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9787
# Epoch 61: val_loss did not improve from 0.10762
# 191/191 [==============================] - 208s 1s/step - loss: 0.1071 - accuracy: 0.9787 - val_loss: 0.1079 - val_accuracy: 0.9809 - lr: 2.5000e-06
# Epoch 62/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9784
# Epoch 62: val_loss did not improve from 0.10762
# 191/191 [==============================] - 209s 1s/step - loss: 0.1072 - accuracy: 0.9784 - val_loss: 0.1078 - val_accuracy: 0.9809 - lr: 2.5000e-06
# Epoch 63/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9797
# Epoch 63: val_loss did not improve from 0.10762
# 191/191 [==============================] - 208s 1s/step - loss: 0.1052 - accuracy: 0.9797 - val_loss: 0.1079 - val_accuracy: 0.9817 - lr: 2.5000e-06
# Epoch 64/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1052 - accuracy: 0.9810
# Epoch 64: val_loss did not improve from 0.10762
# 191/191 [==============================] - 212s 1s/step - loss: 0.1052 - accuracy: 0.9810 - val_loss: 0.1077 - val_accuracy: 0.9824 - lr: 2.5000e-06
# Epoch 65/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1048 - accuracy: 0.9826
# Epoch 65: val_loss did not improve from 0.10762
# 191/191 [==============================] - 211s 1s/step - loss: 0.1048 - accuracy: 0.9826 - val_loss: 0.1078 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 66/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9817
# Epoch 66: val_loss did not improve from 0.10762
# 191/191 [==============================] - 212s 1s/step - loss: 0.1107 - accuracy: 0.9817 - val_loss: 0.1078 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 67/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9812
# Epoch 67: val_loss did not improve from 0.10762
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 191/191 [==============================] - 210s 1s/step - loss: 0.1062 - accuracy: 0.9812 - val_loss: 0.1080 - val_accuracy: 0.9801 - lr: 2.5000e-06
# Epoch 68/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1058 - accuracy: 0.9800
# Epoch 68: val_loss did not improve from 0.10762
# 191/191 [==============================] - 209s 1s/step - loss: 0.1058 - accuracy: 0.9800 - val_loss: 0.1081 - val_accuracy: 0.9801 - lr: 1.2500e-06
# Epoch 69/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9826
# Epoch 69: val_loss did not improve from 0.10762
# 191/191 [==============================] - 210s 1s/step - loss: 0.1026 - accuracy: 0.9826 - val_loss: 0.1080 - val_accuracy: 0.9801 - lr: 1.2500e-06
# Epoch 70/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9820
# Epoch 70: val_loss did not improve from 0.10762
# 191/191 [==============================] - 209s 1s/step - loss: 0.0988 - accuracy: 0.9820 - val_loss: 0.1079 - val_accuracy: 0.9809 - lr: 1.2500e-06
# Epoch 71/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9844
# Epoch 71: val_loss did not improve from 0.10762
# 191/191 [==============================] - 211s 1s/step - loss: 0.1019 - accuracy: 0.9844 - val_loss: 0.1079 - val_accuracy: 0.9809 - lr: 1.2500e-06
# Epoch 72/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9790
# Epoch 72: val_loss did not improve from 0.10762
# 191/191 [==============================] - 209s 1s/step - loss: 0.1089 - accuracy: 0.9790 - val_loss: 0.1079 - val_accuracy: 0.9801 - lr: 1.2500e-06
# Epoch 73/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9802
# Epoch 73: val_loss did not improve from 0.10762
# 191/191 [==============================] - 212s 1s/step - loss: 0.1054 - accuracy: 0.9802 - val_loss: 0.1079 - val_accuracy: 0.9809 - lr: 1.2500e-06
# Epoch 74/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9802Restoring model weights from the end of the best epoch: 59.
#
# Epoch 74: val_loss did not improve from 0.10762
# 191/191 [==============================] - 209s 1s/step - loss: 0.1060 - accuracy: 0.9802 - val_loss: 0.1078 - val_accuracy: 0.9809 - lr: 1.2500e-06
# Epoch 74: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9824

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9824
# Fase 2 — mejor val_accuracy: 0.9824

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 25s 611ms/step - loss: 0.1013 - accuracy: 0.9809
#
# Test Accuracy : 0.9809
# Test Loss     : 0.1013
# 41/41 [==============================] - 26s 578ms/step
# F1 Score      : 0.9809
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9801    0.9867    0.9834       150
#    mancha_anillo     1.0000    1.0000    1.0000       105
#     mancha_parda     0.9933    0.9867    0.9900       150
#          mosaico     0.9929    0.9333    0.9622       150
#      muermo_rojo     0.9799    0.9733    0.9766       150
#             roya     0.9797    0.9667    0.9732       150
#            sanas     0.9255    0.9933    0.9582       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     0.9868    0.9933    0.9900       150
#
#         accuracy                         0.9809      1308
#        macro avg     0.9838    0.9833    0.9834      1308
#     weighted avg     0.9814    0.9809    0.9809      1308
#
#
# Resultados guardados en efficientnetB0_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]
class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 1 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]
print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]
    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()
    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9, color='red'
        )
        axes[j].axis('off')
    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')
    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14, fontweight='bold', y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 1 o más confusiones:
#   mosaico → sanas: 10 imágenes
#   muermo_rojo → tizon_bacteriano: 2 imágenes
#   roya → hoja_amarilla: 2 imágenes
#   roya → muermo_rojo: 2 imágenes
#   hoja_amarilla → roya: 1 imágenes
#   hoja_amarilla → mosaico: 1 imágenes
#   mancha_parda → hoja_amarilla: 1 imágenes
#   mancha_parda → sanas: 1 imágenes
#   muermo_rojo → roya: 1 imágenes
#   muermo_rojo → sanas: 1 imágenes
#   roya → mancha_parda: 1 imágenes
#   sanas → roya: 1 imágenes
#   tizon_bacteriano → muermo_rojo: 1 imágenes
#
# Total de imágenes a mostrar: 25

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB0_con_ft_weights.h5
