# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 380
BATCH_SIZE    = 16
EPOCHS        = 75
NUM_CLASSES   = 10
NOMBRE_MODELO = 'efficientnetB4_FT'

# Fase 1: Congelación de capas
PATIENCE_ES_F1  = 10
PATIENCE_LR_F1  = 5

# Fase 2: Descongelación de capas
PATIENCE_ES_F2  = 15
PATIENCE_LR_F2  = 8

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# DATA AUGMENTATION — IGUAL EN TODOS LOS MODELOS
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFICIENTNETB4

# %%
# CARGAR EFFICIENTNETB4 CON PESOS DE IMAGENET
base_model = EfficientNetB4(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPAS FINALES PERSONALIZADAS
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "efficientnetB4_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb4 (Functional)  (None, 12, 12, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               229504
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 17,904,617
# Trainable params: 230,794
# Non-trainable params: 17,673,823
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F1,
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F1,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Epoch 1/75
# 382/382 [==============================] - ETA: 0s - loss: 0.8599 - accuracy: 0.7177
# Epoch 1: val_loss improved from inf to 0.39317, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1147s 3s/step - loss: 0.8599 - accuracy: 0.7177 - val_loss: 0.3932 - val_accuracy: 0.8891 - lr: 0.0010
# Epoch 2/75
# 382/382 [==============================] - ETA: 0s - loss: 0.4632 - accuracy: 0.8616
# Epoch 2: val_loss improved from 0.39317 to 0.34309, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1167s 3s/step - loss: 0.4632 - accuracy: 0.8616 - val_loss: 0.3431 - val_accuracy: 0.8937 - lr: 0.0010
# Epoch 3/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3865 - accuracy: 0.8827
# Epoch 3: val_loss improved from 0.34309 to 0.26296, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1099s 3s/step - loss: 0.3865 - accuracy: 0.8827 - val_loss: 0.2630 - val_accuracy: 0.9335 - lr: 0.0010
# Epoch 4/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3593 - accuracy: 0.8957
# Epoch 4: val_loss improved from 0.26296 to 0.23698, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1103s 3s/step - loss: 0.3593 - accuracy: 0.8957 - val_loss: 0.2370 - val_accuracy: 0.9411 - lr: 0.0010
# Epoch 5/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.9078
# Epoch 5: val_loss did not improve from 0.23698
# 382/382 [==============================] - 1099s 3s/step - loss: 0.3221 - accuracy: 0.9078 - val_loss: 0.2392 - val_accuracy: 0.9320 - lr: 0.0010
# Epoch 6/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3228 - accuracy: 0.9119
# Epoch 6: val_loss improved from 0.23698 to 0.23103, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1100s 3s/step - loss: 0.3228 - accuracy: 0.9119 - val_loss: 0.2310 - val_accuracy: 0.9358 - lr: 0.0010
# Epoch 7/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3082 - accuracy: 0.9129
# Epoch 7: val_loss improved from 0.23103 to 0.22551, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1107s 3s/step - loss: 0.3082 - accuracy: 0.9129 - val_loss: 0.2255 - val_accuracy: 0.9427 - lr: 0.0010
# Epoch 8/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2897 - accuracy: 0.9220
# Epoch 8: val_loss did not improve from 0.22551
# 382/382 [==============================] - 1112s 3s/step - loss: 0.2897 - accuracy: 0.9220 - val_loss: 0.2739 - val_accuracy: 0.9266 - lr: 0.0010
# Epoch 9/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2856 - accuracy: 0.9265
# Epoch 9: val_loss improved from 0.22551 to 0.22479, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1110s 3s/step - loss: 0.2856 - accuracy: 0.9265 - val_loss: 0.2248 - val_accuracy: 0.9495 - lr: 0.0010
# Epoch 10/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2841 - accuracy: 0.9274
# Epoch 10: val_loss did not improve from 0.22479
# 382/382 [==============================] - 1100s 3s/step - loss: 0.2841 - accuracy: 0.9274 - val_loss: 0.2359 - val_accuracy: 0.9457 - lr: 0.0010
# Epoch 11/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.9278
# Epoch 11: val_loss improved from 0.22479 to 0.20191, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1101s 3s/step - loss: 0.2823 - accuracy: 0.9278 - val_loss: 0.2019 - val_accuracy: 0.9572 - lr: 0.0010
# Epoch 12/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2689 - accuracy: 0.9351
# Epoch 12: val_loss did not improve from 0.20191
# 382/382 [==============================] - 1100s 3s/step - loss: 0.2689 - accuracy: 0.9351 - val_loss: 0.2230 - val_accuracy: 0.9503 - lr: 0.0010
# Epoch 13/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2753 - accuracy: 0.9311
# Epoch 13: val_loss improved from 0.20191 to 0.19567, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1101s 3s/step - loss: 0.2753 - accuracy: 0.9311 - val_loss: 0.1957 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 14/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.9306
# Epoch 14: val_loss did not improve from 0.19567
# 382/382 [==============================] - 1099s 3s/step - loss: 0.2812 - accuracy: 0.9306 - val_loss: 0.2641 - val_accuracy: 0.9365 - lr: 0.0010
# Epoch 15/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2884 - accuracy: 0.9312
# Epoch 15: val_loss did not improve from 0.19567
# 382/382 [==============================] - 1099s 3s/step - loss: 0.2884 - accuracy: 0.9312 - val_loss: 0.2090 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 16/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2748 - accuracy: 0.9355
# Epoch 16: val_loss did not improve from 0.19567
# 382/382 [==============================] - 1099s 3s/step - loss: 0.2748 - accuracy: 0.9355 - val_loss: 0.2186 - val_accuracy: 0.9472 - lr: 0.0010
# Epoch 17/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.9319
# Epoch 17: val_loss did not improve from 0.19567
# 382/382 [==============================] - 1103s 3s/step - loss: 0.2792 - accuracy: 0.9319 - val_loss: 0.2407 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 18/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2728 - accuracy: 0.9402
# Epoch 18: val_loss did not improve from 0.19567
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 382/382 [==============================] - 1100s 3s/step - loss: 0.2728 - accuracy: 0.9402 - val_loss: 0.2331 - val_accuracy: 0.9427 - lr: 0.0010
# Epoch 19/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.9497
# Epoch 19: val_loss did not improve from 0.19567
# 382/382 [==============================] - 1099s 3s/step - loss: 0.2385 - accuracy: 0.9497 - val_loss: 0.2161 - val_accuracy: 0.9580 - lr: 5.0000e-04
# Epoch 20/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2235 - accuracy: 0.9569
# Epoch 20: val_loss did not improve from 0.19567
# 382/382 [==============================] - 1099s 3s/step - loss: 0.2235 - accuracy: 0.9569 - val_loss: 0.2080 - val_accuracy: 0.9541 - lr: 5.0000e-04
# Epoch 21/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2154 - accuracy: 0.9545
# Epoch 21: val_loss did not improve from 0.19567
# 382/382 [==============================] - 1101s 3s/step - loss: 0.2154 - accuracy: 0.9545 - val_loss: 0.1981 - val_accuracy: 0.9595 - lr: 5.0000e-04
# Epoch 22/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2168 - accuracy: 0.9533
# Epoch 22: val_loss improved from 0.19567 to 0.19076, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1104s 3s/step - loss: 0.2168 - accuracy: 0.9533 - val_loss: 0.1908 - val_accuracy: 0.9610 - lr: 5.0000e-04
# Epoch 23/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9589
# Epoch 23: val_loss improved from 0.19076 to 0.17245, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1108s 3s/step - loss: 0.2082 - accuracy: 0.9589 - val_loss: 0.1725 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 24/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2072 - accuracy: 0.9577
# Epoch 24: val_loss did not improve from 0.17245
# 382/382 [==============================] - 1098s 3s/step - loss: 0.2072 - accuracy: 0.9577 - val_loss: 0.1825 - val_accuracy: 0.9618 - lr: 5.0000e-04
# Epoch 25/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2037 - accuracy: 0.9568
# Epoch 25: val_loss did not improve from 0.17245
# 382/382 [==============================] - 1099s 3s/step - loss: 0.2037 - accuracy: 0.9568 - val_loss: 0.1726 - val_accuracy: 0.9687 - lr: 5.0000e-04
# Epoch 26/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2063 - accuracy: 0.9584
# Epoch 26: val_loss did not improve from 0.17245
# 382/382 [==============================] - 1100s 3s/step - loss: 0.2063 - accuracy: 0.9584 - val_loss: 0.1741 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 27/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1969 - accuracy: 0.9579
# Epoch 27: val_loss improved from 0.17245 to 0.16736, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1100s 3s/step - loss: 0.1969 - accuracy: 0.9579 - val_loss: 0.1674 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 28/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1946 - accuracy: 0.9613
# Epoch 28: val_loss did not improve from 0.16736
# 382/382 [==============================] - 1101s 3s/step - loss: 0.1946 - accuracy: 0.9613 - val_loss: 0.1696 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 29/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9635
# Epoch 29: val_loss did not improve from 0.16736
# 382/382 [==============================] - 1100s 3s/step - loss: 0.1935 - accuracy: 0.9635 - val_loss: 0.1931 - val_accuracy: 0.9610 - lr: 5.0000e-04
# Epoch 30/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1922 - accuracy: 0.9597
# Epoch 30: val_loss did not improve from 0.16736
# 382/382 [==============================] - 1102s 3s/step - loss: 0.1922 - accuracy: 0.9597 - val_loss: 0.1690 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 31/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1955 - accuracy: 0.9618
# Epoch 31: val_loss did not improve from 0.16736
# 382/382 [==============================] - 1107s 3s/step - loss: 0.1955 - accuracy: 0.9618 - val_loss: 0.1732 - val_accuracy: 0.9641 - lr: 5.0000e-04
# Epoch 32/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1905 - accuracy: 0.9625
# Epoch 32: val_loss did not improve from 0.16736
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 382/382 [==============================] - 1108s 3s/step - loss: 0.1905 - accuracy: 0.9625 - val_loss: 0.1714 - val_accuracy: 0.9641 - lr: 5.0000e-04
# Epoch 33/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1751 - accuracy: 0.9671
# Epoch 33: val_loss did not improve from 0.16736
# 382/382 [==============================] - 1107s 3s/step - loss: 0.1751 - accuracy: 0.9671 - val_loss: 0.1878 - val_accuracy: 0.9633 - lr: 2.5000e-04
# Epoch 34/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9700
# Epoch 34: val_loss improved from 0.16736 to 0.16028, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1109s 3s/step - loss: 0.1668 - accuracy: 0.9700 - val_loss: 0.1603 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 35/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1644 - accuracy: 0.9694
# Epoch 35: val_loss did not improve from 0.16028
# 382/382 [==============================] - 1107s 3s/step - loss: 0.1644 - accuracy: 0.9694 - val_loss: 0.1791 - val_accuracy: 0.9664 - lr: 2.5000e-04
# Epoch 36/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1725 - accuracy: 0.9661
# Epoch 36: val_loss did not improve from 0.16028
# 382/382 [==============================] - 1103s 3s/step - loss: 0.1725 - accuracy: 0.9661 - val_loss: 0.1606 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 37/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1651 - accuracy: 0.9700
# Epoch 37: val_loss improved from 0.16028 to 0.15535, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1105s 3s/step - loss: 0.1651 - accuracy: 0.9700 - val_loss: 0.1553 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 38/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1616 - accuracy: 0.9713
# Epoch 38: val_loss did not improve from 0.15535
# 382/382 [==============================] - 1114s 3s/step - loss: 0.1616 - accuracy: 0.9713 - val_loss: 0.1620 - val_accuracy: 0.9633 - lr: 2.5000e-04
# Epoch 39/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.9679
# Epoch 39: val_loss did not improve from 0.15535
# 382/382 [==============================] - 1109s 3s/step - loss: 0.1681 - accuracy: 0.9679 - val_loss: 0.1652 - val_accuracy: 0.9648 - lr: 2.5000e-04
# Epoch 40/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9725
# Epoch 40: val_loss did not improve from 0.15535
# 382/382 [==============================] - 1105s 3s/step - loss: 0.1569 - accuracy: 0.9725 - val_loss: 0.1595 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 41/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.9700
# Epoch 41: val_loss improved from 0.15535 to 0.15138, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1106s 3s/step - loss: 0.1661 - accuracy: 0.9700 - val_loss: 0.1514 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 42/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.9704
# Epoch 42: val_loss did not improve from 0.15138
# 382/382 [==============================] - 1111s 3s/step - loss: 0.1645 - accuracy: 0.9704 - val_loss: 0.1711 - val_accuracy: 0.9648 - lr: 2.5000e-04
# Epoch 43/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1589 - accuracy: 0.9712
# Epoch 43: val_loss did not improve from 0.15138
# 382/382 [==============================] - 1112s 3s/step - loss: 0.1589 - accuracy: 0.9712 - val_loss: 0.1641 - val_accuracy: 0.9648 - lr: 2.5000e-04
# Epoch 44/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1708 - accuracy: 0.9687
# Epoch 44: val_loss did not improve from 0.15138
# 382/382 [==============================] - 1109s 3s/step - loss: 0.1708 - accuracy: 0.9687 - val_loss: 0.1546 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 45/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.9731
# Epoch 45: val_loss improved from 0.15138 to 0.15041, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1113s 3s/step - loss: 0.1491 - accuracy: 0.9731 - val_loss: 0.1504 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 46/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9695
# Epoch 46: val_loss did not improve from 0.15041
# 382/382 [==============================] - 1110s 3s/step - loss: 0.1569 - accuracy: 0.9695 - val_loss: 0.1542 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 47/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1494 - accuracy: 0.9715
# Epoch 47: val_loss did not improve from 0.15041
# 382/382 [==============================] - 1110s 3s/step - loss: 0.1494 - accuracy: 0.9715 - val_loss: 0.1553 - val_accuracy: 0.9694 - lr: 2.5000e-04
# Epoch 48/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9726
# Epoch 48: val_loss improved from 0.15041 to 0.14755, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1108s 3s/step - loss: 0.1559 - accuracy: 0.9726 - val_loss: 0.1476 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 49/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9697
# Epoch 49: val_loss did not improve from 0.14755
# 382/382 [==============================] - 1110s 3s/step - loss: 0.1550 - accuracy: 0.9697 - val_loss: 0.1486 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 50/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1458 - accuracy: 0.9758
# Epoch 50: val_loss improved from 0.14755 to 0.14009, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1104s 3s/step - loss: 0.1458 - accuracy: 0.9758 - val_loss: 0.1401 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 51/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9738
# Epoch 51: val_loss improved from 0.14009 to 0.13558, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1126s 3s/step - loss: 0.1470 - accuracy: 0.9738 - val_loss: 0.1356 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 52/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9763
# Epoch 52: val_loss did not improve from 0.13558
# 382/382 [==============================] - 1098s 3s/step - loss: 0.1407 - accuracy: 0.9763 - val_loss: 0.1429 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 53/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1436 - accuracy: 0.9736
# Epoch 53: val_loss did not improve from 0.13558
# 382/382 [==============================] - 1103s 3s/step - loss: 0.1436 - accuracy: 0.9736 - val_loss: 0.1435 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 54/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1519 - accuracy: 0.9730
# Epoch 54: val_loss did not improve from 0.13558
# 382/382 [==============================] - 1030s 3s/step - loss: 0.1519 - accuracy: 0.9730 - val_loss: 0.1431 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 55/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9740
# Epoch 55: val_loss improved from 0.13558 to 0.12834, saving model to efficientnetB4_con_ft_fase1_weights.h5
# 382/382 [==============================] - 1048s 3s/step - loss: 0.1445 - accuracy: 0.9740 - val_loss: 0.1283 - val_accuracy: 0.9786 - lr: 2.5000e-04
# Epoch 56/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9754
# Epoch 56: val_loss did not improve from 0.12834
# 382/382 [==============================] - 1091s 3s/step - loss: 0.1401 - accuracy: 0.9754 - val_loss: 0.1395 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 57/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9731
# Epoch 57: val_loss did not improve from 0.12834
# 382/382 [==============================] - 1105s 3s/step - loss: 0.1486 - accuracy: 0.9731 - val_loss: 0.1423 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 58/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9740
# Epoch 58: val_loss did not improve from 0.12834
# 382/382 [==============================] - 1099s 3s/step - loss: 0.1505 - accuracy: 0.9740 - val_loss: 0.1427 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 59/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9733
# Epoch 59: val_loss did not improve from 0.12834
# 382/382 [==============================] - 1099s 3s/step - loss: 0.1443 - accuracy: 0.9733 - val_loss: 0.1347 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 60/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9754
# Epoch 60: val_loss did not improve from 0.12834
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 382/382 [==============================] - 1100s 3s/step - loss: 0.1393 - accuracy: 0.9754 - val_loss: 0.1481 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 61/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9769
# Epoch 61: val_loss did not improve from 0.12834
# 382/382 [==============================] - 1100s 3s/step - loss: 0.1320 - accuracy: 0.9769 - val_loss: 0.1362 - val_accuracy: 0.9717 - lr: 1.2500e-04
# Epoch 62/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9794
# Epoch 62: val_loss did not improve from 0.12834
# 382/382 [==============================] - 1101s 3s/step - loss: 0.1281 - accuracy: 0.9794 - val_loss: 0.1425 - val_accuracy: 0.9717 - lr: 1.2500e-04
# Epoch 63/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9813
# Epoch 63: val_loss did not improve from 0.12834
# 382/382 [==============================] - 1098s 3s/step - loss: 0.1233 - accuracy: 0.9813 - val_loss: 0.1388 - val_accuracy: 0.9725 - lr: 1.2500e-04
# Epoch 64/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1308 - accuracy: 0.9779
# Epoch 64: val_loss did not improve from 0.12834
# 382/382 [==============================] - 1099s 3s/step - loss: 0.1308 - accuracy: 0.9779 - val_loss: 0.1370 - val_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 65/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1328 - accuracy: 0.9784Restoring model weights from the end of the best epoch: 55.
#
# Epoch 65: val_loss did not improve from 0.12834
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 382/382 [==============================] - 1099s 3s/step - loss: 0.1328 - accuracy: 0.9784 - val_loss: 0.1384 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 65: early stopping
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9786

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F2,          # = 10, igual en todos los modelos
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F2,
    min_lr=1e-6,
    verbose=1
)

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 475
# Capas congeladas         : 445
# Capas descongeladas      : 30
# Epoch 1/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1436 - accuracy: 0.9746
# Epoch 1: val_loss improved from inf to 0.12951, saving model to efficientnetB4_con_ft_weights.h5
# 382/382 [==============================] - 1105s 3s/step - loss: 0.1436 - accuracy: 0.9746 - val_loss: 0.1295 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 2/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9767
# Epoch 2: val_loss improved from 0.12951 to 0.12881, saving model to efficientnetB4_con_ft_weights.h5
# 382/382 [==============================] - 1104s 3s/step - loss: 0.1373 - accuracy: 0.9767 - val_loss: 0.1288 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 3/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9761
# Epoch 3: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1103s 3s/step - loss: 0.1347 - accuracy: 0.9761 - val_loss: 0.1293 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 4/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9774
# Epoch 4: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1104s 3s/step - loss: 0.1342 - accuracy: 0.9774 - val_loss: 0.1301 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 5/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9794
# Epoch 5: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1100s 3s/step - loss: 0.1290 - accuracy: 0.9794 - val_loss: 0.1294 - val_accuracy: 0.9786 - lr: 1.0000e-05
# Epoch 6/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1353 - accuracy: 0.9769
# Epoch 6: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1107s 3s/step - loss: 0.1353 - accuracy: 0.9769 - val_loss: 0.1295 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 7/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9825
# Epoch 7: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1105s 3s/step - loss: 0.1224 - accuracy: 0.9825 - val_loss: 0.1298 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 8/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1259 - accuracy: 0.9807
# Epoch 8: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1102s 3s/step - loss: 0.1259 - accuracy: 0.9807 - val_loss: 0.1290 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 9/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9774
# Epoch 9: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1100s 3s/step - loss: 0.1356 - accuracy: 0.9774 - val_loss: 0.1299 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 10/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9790
# Epoch 10: val_loss did not improve from 0.12881
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 382/382 [==============================] - 1102s 3s/step - loss: 0.1347 - accuracy: 0.9790 - val_loss: 0.1311 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 11/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9769
# Epoch 11: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1101s 3s/step - loss: 0.1310 - accuracy: 0.9769 - val_loss: 0.1318 - val_accuracy: 0.9763 - lr: 5.0000e-06
# Epoch 12/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9808
# Epoch 12: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1102s 3s/step - loss: 0.1275 - accuracy: 0.9808 - val_loss: 0.1306 - val_accuracy: 0.9771 - lr: 5.0000e-06
# Epoch 13/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9805
# Epoch 13: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1101s 3s/step - loss: 0.1265 - accuracy: 0.9805 - val_loss: 0.1309 - val_accuracy: 0.9771 - lr: 5.0000e-06
# Epoch 14/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1322 - accuracy: 0.9785
# Epoch 14: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1102s 3s/step - loss: 0.1322 - accuracy: 0.9785 - val_loss: 0.1310 - val_accuracy: 0.9771 - lr: 5.0000e-06
# Epoch 15/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9764
# Epoch 15: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1101s 3s/step - loss: 0.1279 - accuracy: 0.9764 - val_loss: 0.1306 - val_accuracy: 0.9778 - lr: 5.0000e-06
# Epoch 16/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1321 - accuracy: 0.9774
# Epoch 16: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1104s 3s/step - loss: 0.1321 - accuracy: 0.9774 - val_loss: 0.1307 - val_accuracy: 0.9771 - lr: 5.0000e-06
# Epoch 17/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.9771Restoring model weights from the end of the best epoch: 2.
#
# Epoch 17: val_loss did not improve from 0.12881
# 382/382 [==============================] - 1104s 3s/step - loss: 0.1314 - accuracy: 0.9771 - val_loss: 0.1302 - val_accuracy: 0.9786 - lr: 5.0000e-06
# Epoch 17: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9786

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9786
# Fase 2 — mejor val_accuracy: 0.9786

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 82/82 [==============================] - 181s 2s/step - loss: 0.1154 - accuracy: 0.9839
#
# Test Accuracy : 0.9839
# Test Loss     : 0.1154
# 82/82 [==============================] - 185s 2s/step
# F1 Score      : 0.9839
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9803    0.9933    0.9868       150
#    mancha_anillo     0.9906    1.0000    0.9953       105
#     mancha_parda     0.9605    0.9733    0.9669       150
#          mosaico     0.9868    0.9933    0.9900       150
#      muermo_rojo     0.9732    0.9667    0.9699       150
#             roya     0.9863    0.9600    0.9730       150
#            sanas     0.9866    0.9800    0.9833       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     0.9933    0.9933    0.9933       150
#
#         accuracy                         0.9839      1308
#        macro avg     0.9857    0.9860    0.9858      1308
#     weighted avg     0.9840    0.9839    0.9839      1308
#
#
# Resultados guardados en efficientnetB4_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]
class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 1 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]
print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]
    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()
    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9, color='red'
        )
        axes[j].axis('off')
    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')
    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14, fontweight='bold', y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 1 o más confusiones:
#   muermo_rojo → mancha_parda: 3 imágenes
#   mancha_parda → hoja_amarilla: 2 imágenes
#   roya → muermo_rojo: 2 imágenes
#   roya → mancha_parda: 2 imágenes
#   sanas → mosaico: 2 imágenes
#   hoja_amarilla → roya: 1 imágenes
#   mancha_parda → roya: 1 imágenes
#   mancha_parda → muermo_rojo: 1 imágenes
#   mosaico → sanas: 1 imágenes
#   muermo_rojo → hoja_amarilla: 1 imágenes
#   muermo_rojo → tizon_bacteriano: 1 imágenes
#   roya → sanas: 1 imágenes
#   roya → mancha_anillo: 1 imágenes
#   sanas → mancha_parda: 1 imágenes
#   tizon_bacteriano → muermo_rojo: 1 imágenes
#
# Total de imágenes a mostrar: 21

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB4_con_ft_weights.h5
