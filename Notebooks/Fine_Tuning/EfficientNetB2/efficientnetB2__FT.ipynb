# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB2
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 260
BATCH_SIZE    = 32
EPOCHS        = 75
NUM_CLASSES   = 10
NOMBRE_MODELO = 'efficientnetB2_FT'

# Fase 1: Congelación de capas
PATIENCE_ES_F1  = 10
PATIENCE_LR_F1  = 5

# Fase 2: Descongelación de capas
PATIENCE_ES_F2  = 15
PATIENCE_LR_F2  = 8

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# DATA AUGMENTATION — IGUAL EN TODOS LOS MODELOS
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFICIENTNETB2

# %%
# CARGAR EFFICIENTNETB2 CON PESOS DE IMAGENET
base_model = EfficientNetB2(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPAS FINALES PERSONALIZADAS
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "efficientnetB2_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb2 (Functional)  (None, 9, 9, 1408)       7768569
#
#  global_average_pooling2d (G  (None, 1408)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               180352
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 7,950,211
# Trainable params: 181,642
# Non-trainable params: 7,768,569
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F1,
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F1,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.9173 - accuracy: 0.7065
# Epoch 1: val_loss improved from inf to 0.41644, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 363s 2s/step - loss: 0.9173 - accuracy: 0.7065 - val_loss: 0.4164 - val_accuracy: 0.8930 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4826 - accuracy: 0.8582
# Epoch 2: val_loss improved from 0.41644 to 0.29491, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 359s 2s/step - loss: 0.4826 - accuracy: 0.8582 - val_loss: 0.2949 - val_accuracy: 0.9251 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3880 - accuracy: 0.8899
# Epoch 3: val_loss improved from 0.29491 to 0.25881, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 364s 2s/step - loss: 0.3880 - accuracy: 0.8899 - val_loss: 0.2588 - val_accuracy: 0.9388 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3384 - accuracy: 0.9004
# Epoch 4: val_loss improved from 0.25881 to 0.23810, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 367s 2s/step - loss: 0.3384 - accuracy: 0.9004 - val_loss: 0.2381 - val_accuracy: 0.9358 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3147 - accuracy: 0.9073
# Epoch 5: val_loss improved from 0.23810 to 0.22042, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 365s 2s/step - loss: 0.3147 - accuracy: 0.9073 - val_loss: 0.2204 - val_accuracy: 0.9411 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3077 - accuracy: 0.9140
# Epoch 6: val_loss improved from 0.22042 to 0.21004, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 359s 2s/step - loss: 0.3077 - accuracy: 0.9140 - val_loss: 0.2100 - val_accuracy: 0.9442 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2790 - accuracy: 0.9201
# Epoch 7: val_loss improved from 0.21004 to 0.19857, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 360s 2s/step - loss: 0.2790 - accuracy: 0.9201 - val_loss: 0.1986 - val_accuracy: 0.9503 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.9281
# Epoch 8: val_loss improved from 0.19857 to 0.18851, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 360s 2s/step - loss: 0.2708 - accuracy: 0.9281 - val_loss: 0.1885 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2860 - accuracy: 0.9175
# Epoch 9: val_loss did not improve from 0.18851
# 191/191 [==============================] - 359s 2s/step - loss: 0.2860 - accuracy: 0.9175 - val_loss: 0.1930 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2567 - accuracy: 0.9315
# Epoch 10: val_loss did not improve from 0.18851
# 191/191 [==============================] - 359s 2s/step - loss: 0.2567 - accuracy: 0.9315 - val_loss: 0.1987 - val_accuracy: 0.9488 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2599 - accuracy: 0.9274
# Epoch 11: val_loss did not improve from 0.18851
# 191/191 [==============================] - 362s 2s/step - loss: 0.2599 - accuracy: 0.9274 - val_loss: 0.1941 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2507 - accuracy: 0.9312
# Epoch 12: val_loss did not improve from 0.18851
# 191/191 [==============================] - 359s 2s/step - loss: 0.2507 - accuracy: 0.9312 - val_loss: 0.2046 - val_accuracy: 0.9434 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2419 - accuracy: 0.9369
# Epoch 13: val_loss improved from 0.18851 to 0.17431, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 358s 2s/step - loss: 0.2419 - accuracy: 0.9369 - val_loss: 0.1743 - val_accuracy: 0.9625 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2373 - accuracy: 0.9384
# Epoch 14: val_loss did not improve from 0.17431
# 191/191 [==============================] - 359s 2s/step - loss: 0.2373 - accuracy: 0.9384 - val_loss: 0.1934 - val_accuracy: 0.9518 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2453 - accuracy: 0.9360
# Epoch 15: val_loss did not improve from 0.17431
# 191/191 [==============================] - 359s 2s/step - loss: 0.2453 - accuracy: 0.9360 - val_loss: 0.1829 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2311 - accuracy: 0.9419
# Epoch 16: val_loss did not improve from 0.17431
# 191/191 [==============================] - 358s 2s/step - loss: 0.2311 - accuracy: 0.9419 - val_loss: 0.1747 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2406 - accuracy: 0.9387
# Epoch 17: val_loss did not improve from 0.17431
# 191/191 [==============================] - 359s 2s/step - loss: 0.2406 - accuracy: 0.9387 - val_loss: 0.1784 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2348 - accuracy: 0.9381
# Epoch 18: val_loss did not improve from 0.17431
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 359s 2s/step - loss: 0.2348 - accuracy: 0.9381 - val_loss: 0.1866 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2008 - accuracy: 0.9512
# Epoch 19: val_loss did not improve from 0.17431
# 191/191 [==============================] - 359s 2s/step - loss: 0.2008 - accuracy: 0.9512 - val_loss: 0.1826 - val_accuracy: 0.9580 - lr: 5.0000e-04
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9497
# Epoch 20: val_loss improved from 0.17431 to 0.16512, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 359s 2s/step - loss: 0.2082 - accuracy: 0.9497 - val_loss: 0.1651 - val_accuracy: 0.9641 - lr: 5.0000e-04
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2045 - accuracy: 0.9489
# Epoch 21: val_loss improved from 0.16512 to 0.15968, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 360s 2s/step - loss: 0.2045 - accuracy: 0.9489 - val_loss: 0.1597 - val_accuracy: 0.9602 - lr: 5.0000e-04
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1948 - accuracy: 0.9520
# Epoch 22: val_loss improved from 0.15968 to 0.15715, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 359s 2s/step - loss: 0.1948 - accuracy: 0.9520 - val_loss: 0.1572 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2032 - accuracy: 0.9530
# Epoch 23: val_loss did not improve from 0.15715
# 191/191 [==============================] - 359s 2s/step - loss: 0.2032 - accuracy: 0.9530 - val_loss: 0.1586 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9576
# Epoch 24: val_loss improved from 0.15715 to 0.15681, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 360s 2s/step - loss: 0.1930 - accuracy: 0.9576 - val_loss: 0.1568 - val_accuracy: 0.9725 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1831 - accuracy: 0.9550
# Epoch 25: val_loss did not improve from 0.15681
# 191/191 [==============================] - 359s 2s/step - loss: 0.1831 - accuracy: 0.9550 - val_loss: 0.1694 - val_accuracy: 0.9587 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1867 - accuracy: 0.9587
# Epoch 26: val_loss improved from 0.15681 to 0.15464, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 358s 2s/step - loss: 0.1867 - accuracy: 0.9587 - val_loss: 0.1546 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1790 - accuracy: 0.9600
# Epoch 27: val_loss did not improve from 0.15464
# 191/191 [==============================] - 359s 2s/step - loss: 0.1790 - accuracy: 0.9600 - val_loss: 0.1574 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1776 - accuracy: 0.9586
# Epoch 28: val_loss did not improve from 0.15464
# 191/191 [==============================] - 359s 2s/step - loss: 0.1776 - accuracy: 0.9586 - val_loss: 0.1626 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1788 - accuracy: 0.9586
# Epoch 29: val_loss did not improve from 0.15464
# 191/191 [==============================] - 359s 2s/step - loss: 0.1788 - accuracy: 0.9586 - val_loss: 0.1631 - val_accuracy: 0.9633 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9579
# Epoch 30: val_loss did not improve from 0.15464
# 191/191 [==============================] - 358s 2s/step - loss: 0.1878 - accuracy: 0.9579 - val_loss: 0.1551 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9548
# Epoch 31: val_loss did not improve from 0.15464
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 360s 2s/step - loss: 0.1889 - accuracy: 0.9548 - val_loss: 0.1619 - val_accuracy: 0.9610 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1801 - accuracy: 0.9610
# Epoch 32: val_loss did not improve from 0.15464
# 191/191 [==============================] - 359s 2s/step - loss: 0.1801 - accuracy: 0.9610 - val_loss: 0.1583 - val_accuracy: 0.9648 - lr: 2.5000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1618 - accuracy: 0.9661
# Epoch 33: val_loss improved from 0.15464 to 0.15083, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 359s 2s/step - loss: 0.1618 - accuracy: 0.9661 - val_loss: 0.1508 - val_accuracy: 0.9694 - lr: 2.5000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9645
# Epoch 34: val_loss improved from 0.15083 to 0.14426, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 359s 2s/step - loss: 0.1686 - accuracy: 0.9645 - val_loss: 0.1443 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9681
# Epoch 35: val_loss did not improve from 0.14426
# 191/191 [==============================] - 359s 2s/step - loss: 0.1559 - accuracy: 0.9681 - val_loss: 0.1469 - val_accuracy: 0.9687 - lr: 2.5000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1566 - accuracy: 0.9650
# Epoch 36: val_loss did not improve from 0.14426
# 191/191 [==============================] - 359s 2s/step - loss: 0.1566 - accuracy: 0.9650 - val_loss: 0.1572 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9654
# Epoch 37: val_loss did not improve from 0.14426
# 191/191 [==============================] - 359s 2s/step - loss: 0.1625 - accuracy: 0.9654 - val_loss: 0.1449 - val_accuracy: 0.9687 - lr: 2.5000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9656
# Epoch 38: val_loss improved from 0.14426 to 0.14383, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 359s 2s/step - loss: 0.1596 - accuracy: 0.9656 - val_loss: 0.1438 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1554 - accuracy: 0.9661
# Epoch 39: val_loss did not improve from 0.14383
# 191/191 [==============================] - 358s 2s/step - loss: 0.1554 - accuracy: 0.9661 - val_loss: 0.1495 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9627
# Epoch 40: val_loss improved from 0.14383 to 0.13716, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 360s 2s/step - loss: 0.1655 - accuracy: 0.9627 - val_loss: 0.1372 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1582 - accuracy: 0.9664
# Epoch 41: val_loss did not improve from 0.13716
# 191/191 [==============================] - 359s 2s/step - loss: 0.1582 - accuracy: 0.9664 - val_loss: 0.1397 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 0.9679
# Epoch 42: val_loss improved from 0.13716 to 0.13578, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 360s 2s/step - loss: 0.1539 - accuracy: 0.9679 - val_loss: 0.1358 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9676
# Epoch 43: val_loss did not improve from 0.13578
# 191/191 [==============================] - 360s 2s/step - loss: 0.1615 - accuracy: 0.9676 - val_loss: 0.1383 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1610 - accuracy: 0.9653
# Epoch 44: val_loss did not improve from 0.13578
# 191/191 [==============================] - 360s 2s/step - loss: 0.1610 - accuracy: 0.9653 - val_loss: 0.1419 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9682
# Epoch 45: val_loss did not improve from 0.13578
# 191/191 [==============================] - 360s 2s/step - loss: 0.1505 - accuracy: 0.9682 - val_loss: 0.1388 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1527 - accuracy: 0.9663
# Epoch 46: val_loss did not improve from 0.13578
# 191/191 [==============================] - 360s 2s/step - loss: 0.1527 - accuracy: 0.9663 - val_loss: 0.1358 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9672
# Epoch 47: val_loss did not improve from 0.13578
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 359s 2s/step - loss: 0.1510 - accuracy: 0.9672 - val_loss: 0.1360 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9684
# Epoch 48: val_loss did not improve from 0.13578
# 191/191 [==============================] - 360s 2s/step - loss: 0.1470 - accuracy: 0.9684 - val_loss: 0.1388 - val_accuracy: 0.9709 - lr: 1.2500e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9704
# Epoch 49: val_loss did not improve from 0.13578
# 191/191 [==============================] - 359s 2s/step - loss: 0.1411 - accuracy: 0.9704 - val_loss: 0.1387 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9681
# Epoch 50: val_loss did not improve from 0.13578
# 191/191 [==============================] - 359s 2s/step - loss: 0.1446 - accuracy: 0.9681 - val_loss: 0.1398 - val_accuracy: 0.9717 - lr: 1.2500e-04
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.9708
# Epoch 51: val_loss did not improve from 0.13578
# 191/191 [==============================] - 360s 2s/step - loss: 0.1395 - accuracy: 0.9708 - val_loss: 0.1362 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9676
# Epoch 52: val_loss improved from 0.13578 to 0.13320, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 360s 2s/step - loss: 0.1484 - accuracy: 0.9676 - val_loss: 0.1332 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1535 - accuracy: 0.9653
# Epoch 53: val_loss improved from 0.13320 to 0.13304, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 360s 2s/step - loss: 0.1535 - accuracy: 0.9653 - val_loss: 0.1330 - val_accuracy: 0.9725 - lr: 1.2500e-04
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1353 - accuracy: 0.9725
# Epoch 54: val_loss did not improve from 0.13304
# 191/191 [==============================] - 358s 2s/step - loss: 0.1353 - accuracy: 0.9725 - val_loss: 0.1377 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9726
# Epoch 55: val_loss did not improve from 0.13304
# 191/191 [==============================] - 358s 2s/step - loss: 0.1378 - accuracy: 0.9726 - val_loss: 0.1347 - val_accuracy: 0.9725 - lr: 1.2500e-04
# Epoch 56/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9692
# Epoch 56: val_loss did not improve from 0.13304
# 191/191 [==============================] - 360s 2s/step - loss: 0.1344 - accuracy: 0.9692 - val_loss: 0.1367 - val_accuracy: 0.9709 - lr: 1.2500e-04
# Epoch 57/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1460 - accuracy: 0.9704
# Epoch 57: val_loss did not improve from 0.13304
# 191/191 [==============================] - 359s 2s/step - loss: 0.1460 - accuracy: 0.9704 - val_loss: 0.1332 - val_accuracy: 0.9717 - lr: 1.2500e-04
# Epoch 58/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9715
# Epoch 58: val_loss did not improve from 0.13304
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 360s 2s/step - loss: 0.1397 - accuracy: 0.9715 - val_loss: 0.1380 - val_accuracy: 0.9702 - lr: 1.2500e-04
# Epoch 59/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9717
# Epoch 59: val_loss did not improve from 0.13304
# 191/191 [==============================] - 359s 2s/step - loss: 0.1397 - accuracy: 0.9717 - val_loss: 0.1339 - val_accuracy: 0.9709 - lr: 6.2500e-05
# Epoch 60/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 0.9720
# Epoch 60: val_loss did not improve from 0.13304
# 191/191 [==============================] - 360s 2s/step - loss: 0.1390 - accuracy: 0.9720 - val_loss: 0.1346 - val_accuracy: 0.9702 - lr: 6.2500e-05
# Epoch 61/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9710
# Epoch 61: val_loss improved from 0.13304 to 0.13141, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 360s 2s/step - loss: 0.1363 - accuracy: 0.9710 - val_loss: 0.1314 - val_accuracy: 0.9725 - lr: 6.2500e-05
# Epoch 62/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1337 - accuracy: 0.9731
# Epoch 62: val_loss improved from 0.13141 to 0.13099, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 358s 2s/step - loss: 0.1337 - accuracy: 0.9731 - val_loss: 0.1310 - val_accuracy: 0.9732 - lr: 6.2500e-05
# Epoch 63/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9707
# Epoch 63: val_loss improved from 0.13099 to 0.13048, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 358s 2s/step - loss: 0.1406 - accuracy: 0.9707 - val_loss: 0.1305 - val_accuracy: 0.9740 - lr: 6.2500e-05
# Epoch 64/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9684
# Epoch 64: val_loss did not improve from 0.13048
# 191/191 [==============================] - 360s 2s/step - loss: 0.1416 - accuracy: 0.9684 - val_loss: 0.1305 - val_accuracy: 0.9732 - lr: 6.2500e-05
# Epoch 65/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9697
# Epoch 65: val_loss improved from 0.13048 to 0.12959, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 361s 2s/step - loss: 0.1385 - accuracy: 0.9697 - val_loss: 0.1296 - val_accuracy: 0.9740 - lr: 6.2500e-05
# Epoch 66/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9722
# Epoch 66: val_loss improved from 0.12959 to 0.12849, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 361s 2s/step - loss: 0.1408 - accuracy: 0.9722 - val_loss: 0.1285 - val_accuracy: 0.9755 - lr: 6.2500e-05
# Epoch 67/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9720
# Epoch 67: val_loss did not improve from 0.12849
# 191/191 [==============================] - 361s 2s/step - loss: 0.1386 - accuracy: 0.9720 - val_loss: 0.1296 - val_accuracy: 0.9763 - lr: 6.2500e-05
# Epoch 68/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1366 - accuracy: 0.9728
# Epoch 68: val_loss did not improve from 0.12849
# 191/191 [==============================] - 359s 2s/step - loss: 0.1366 - accuracy: 0.9728 - val_loss: 0.1298 - val_accuracy: 0.9732 - lr: 6.2500e-05
# Epoch 69/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1350 - accuracy: 0.9717
# Epoch 69: val_loss did not improve from 0.12849
# 191/191 [==============================] - 360s 2s/step - loss: 0.1350 - accuracy: 0.9717 - val_loss: 0.1287 - val_accuracy: 0.9732 - lr: 6.2500e-05
# Epoch 70/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9761
# Epoch 70: val_loss did not improve from 0.12849
# 191/191 [==============================] - 361s 2s/step - loss: 0.1255 - accuracy: 0.9761 - val_loss: 0.1294 - val_accuracy: 0.9740 - lr: 6.2500e-05
# Epoch 71/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1346 - accuracy: 0.9694
# Epoch 71: val_loss improved from 0.12849 to 0.12837, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 362s 2s/step - loss: 0.1346 - accuracy: 0.9694 - val_loss: 0.1284 - val_accuracy: 0.9732 - lr: 6.2500e-05
# Epoch 72/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9745
# Epoch 72: val_loss did not improve from 0.12837
# 191/191 [==============================] - 362s 2s/step - loss: 0.1340 - accuracy: 0.9745 - val_loss: 0.1307 - val_accuracy: 0.9717 - lr: 6.2500e-05
# Epoch 73/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9745
# Epoch 73: val_loss improved from 0.12837 to 0.12677, saving model to efficientnetB2_con_ft_fase1_weights.h5
# 191/191 [==============================] - 362s 2s/step - loss: 0.1317 - accuracy: 0.9745 - val_loss: 0.1268 - val_accuracy: 0.9748 - lr: 6.2500e-05
# Epoch 74/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9731
# Epoch 74: val_loss did not improve from 0.12677
# 191/191 [==============================] - 361s 2s/step - loss: 0.1360 - accuracy: 0.9731 - val_loss: 0.1284 - val_accuracy: 0.9748 - lr: 6.2500e-05
# Epoch 75/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 0.9753
# Epoch 75: val_loss did not improve from 0.12677
# 191/191 [==============================] - 362s 2s/step - loss: 0.1316 - accuracy: 0.9753 - val_loss: 0.1296 - val_accuracy: 0.9740 - lr: 6.2500e-05
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9763

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F2,          # = 15, igual en todos los modelos
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F2,        # = 8, igual en todos los modelos
    min_lr=1e-6,
    verbose=1
)

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 340
# Capas congeladas         : 310
# Capas descongeladas      : 30
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.9763
# Epoch 1: val_loss improved from inf to 0.12979, saving model to efficientnetB2_con_ft_weights.h5
# 191/191 [==============================] - 362s 2s/step - loss: 0.1248 - accuracy: 0.9763 - val_loss: 0.1298 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9746
# Epoch 2: val_loss improved from 0.12979 to 0.12911, saving model to efficientnetB2_con_ft_weights.h5
# 191/191 [==============================] - 361s 2s/step - loss: 0.1295 - accuracy: 0.9746 - val_loss: 0.1291 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1264 - accuracy: 0.9769
# Epoch 3: val_loss improved from 0.12911 to 0.12902, saving model to efficientnetB2_con_ft_weights.h5
# 191/191 [==============================] - 360s 2s/step - loss: 0.1264 - accuracy: 0.9769 - val_loss: 0.1290 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9728
# Epoch 4: val_loss did not improve from 0.12902
# 191/191 [==============================] - 360s 2s/step - loss: 0.1307 - accuracy: 0.9728 - val_loss: 0.1294 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9738
# Epoch 5: val_loss did not improve from 0.12902
# 191/191 [==============================] - 359s 2s/step - loss: 0.1313 - accuracy: 0.9738 - val_loss: 0.1301 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1292 - accuracy: 0.9735
# Epoch 6: val_loss did not improve from 0.12902
# 191/191 [==============================] - 361s 2s/step - loss: 0.1292 - accuracy: 0.9735 - val_loss: 0.1290 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9741
# Epoch 7: val_loss improved from 0.12902 to 0.12864, saving model to efficientnetB2_con_ft_weights.h5
# 191/191 [==============================] - 360s 2s/step - loss: 0.1341 - accuracy: 0.9741 - val_loss: 0.1286 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 0.9758
# Epoch 8: val_loss did not improve from 0.12864
# 191/191 [==============================] - 360s 2s/step - loss: 0.1323 - accuracy: 0.9758 - val_loss: 0.1288 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9764
# Epoch 9: val_loss improved from 0.12864 to 0.12819, saving model to efficientnetB2_con_ft_weights.h5
# 191/191 [==============================] - 359s 2s/step - loss: 0.1298 - accuracy: 0.9764 - val_loss: 0.1282 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1334 - accuracy: 0.9728
# Epoch 10: val_loss did not improve from 0.12819
# 191/191 [==============================] - 360s 2s/step - loss: 0.1334 - accuracy: 0.9728 - val_loss: 0.1285 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9728
# Epoch 11: val_loss did not improve from 0.12819
# 191/191 [==============================] - 361s 2s/step - loss: 0.1299 - accuracy: 0.9728 - val_loss: 0.1291 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1257 - accuracy: 0.9759
# Epoch 12: val_loss did not improve from 0.12819
# 191/191 [==============================] - 359s 2s/step - loss: 0.1257 - accuracy: 0.9759 - val_loss: 0.1286 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9745
# Epoch 13: val_loss improved from 0.12819 to 0.12804, saving model to efficientnetB2_con_ft_weights.h5
# 191/191 [==============================] - 359s 2s/step - loss: 0.1320 - accuracy: 0.9745 - val_loss: 0.1280 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.9759
# Epoch 14: val_loss did not improve from 0.12804
# 191/191 [==============================] - 358s 2s/step - loss: 0.1287 - accuracy: 0.9759 - val_loss: 0.1281 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1376 - accuracy: 0.9720
# Epoch 15: val_loss did not improve from 0.12804
# 191/191 [==============================] - 360s 2s/step - loss: 0.1376 - accuracy: 0.9720 - val_loss: 0.1286 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9754
# Epoch 16: val_loss did not improve from 0.12804
# 191/191 [==============================] - 361s 2s/step - loss: 0.1246 - accuracy: 0.9754 - val_loss: 0.1287 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 0.9761
# Epoch 17: val_loss did not improve from 0.12804
# 191/191 [==============================] - 361s 2s/step - loss: 0.1323 - accuracy: 0.9761 - val_loss: 0.1293 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9758
# Epoch 18: val_loss did not improve from 0.12804
# 191/191 [==============================] - 361s 2s/step - loss: 0.1243 - accuracy: 0.9758 - val_loss: 0.1290 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9708
# Epoch 19: val_loss did not improve from 0.12804
# 191/191 [==============================] - 360s 2s/step - loss: 0.1391 - accuracy: 0.9708 - val_loss: 0.1292 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9704
# Epoch 20: val_loss did not improve from 0.12804
# 191/191 [==============================] - 360s 2s/step - loss: 0.1320 - accuracy: 0.9704 - val_loss: 0.1300 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1280 - accuracy: 0.9772
# Epoch 21: val_loss did not improve from 0.12804
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 361s 2s/step - loss: 0.1280 - accuracy: 0.9772 - val_loss: 0.1295 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1289 - accuracy: 0.9740
# Epoch 22: val_loss did not improve from 0.12804
# 191/191 [==============================] - 360s 2s/step - loss: 0.1289 - accuracy: 0.9740 - val_loss: 0.1293 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9772
# Epoch 23: val_loss did not improve from 0.12804
# 191/191 [==============================] - 361s 2s/step - loss: 0.1234 - accuracy: 0.9772 - val_loss: 0.1293 - val_accuracy: 0.9717 - lr: 5.0000e-06
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.9763
# Epoch 24: val_loss did not improve from 0.12804
# 191/191 [==============================] - 376s 2s/step - loss: 0.1261 - accuracy: 0.9763 - val_loss: 0.1295 - val_accuracy: 0.9717 - lr: 5.0000e-06
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9753
# Epoch 25: val_loss did not improve from 0.12804
# 191/191 [==============================] - 413s 2s/step - loss: 0.1347 - accuracy: 0.9753 - val_loss: 0.1293 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9740
# Epoch 26: val_loss did not improve from 0.12804
# 191/191 [==============================] - 407s 2s/step - loss: 0.1329 - accuracy: 0.9740 - val_loss: 0.1291 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9754
# Epoch 27: val_loss did not improve from 0.12804
# 191/191 [==============================] - 403s 2s/step - loss: 0.1279 - accuracy: 0.9754 - val_loss: 0.1289 - val_accuracy: 0.9725 - lr: 5.0000e-06
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9717Restoring model weights from the end of the best epoch: 13.
#
# Epoch 28: val_loss did not improve from 0.12804
# 191/191 [==============================] - 406s 2s/step - loss: 0.1285 - accuracy: 0.9717 - val_loss: 0.1290 - val_accuracy: 0.9732 - lr: 5.0000e-06
# Epoch 28: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9748

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9763
# Fase 2 — mejor val_accuracy: 0.9748

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 53s 1s/step - loss: 0.1051 - accuracy: 0.9824
#
# Test Accuracy : 0.9824
# Test Loss     : 0.1051
# 41/41 [==============================] - 64s 1s/step
# F1 Score      : 0.9824
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9804    1.0000    0.9901       150
#    mancha_anillo     0.9906    1.0000    0.9953       105
#     mancha_parda     0.9735    0.9800    0.9767       150
#          mosaico     0.9868    1.0000    0.9934       150
#      muermo_rojo     0.9600    0.9600    0.9600       150
#             roya     0.9730    0.9600    0.9664       150
#            sanas     0.9865    0.9733    0.9799       150
#            secas     1.0000    0.9744    0.9870        78
# tizon_bacteriano     0.9933    0.9867    0.9900       150
#
#         accuracy                         0.9824      1308
#        macro avg     0.9844    0.9834    0.9839      1308
#     weighted avg     0.9824    0.9824    0.9824      1308
#
#
# Resultados guardados en efficientnetB2_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]
class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 1 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]
print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]
    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()
    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9, color='red'
        )
        axes[j].axis('off')
    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')
    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14, fontweight='bold', y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 1 o más confusiones:
#   roya → muermo_rojo: 5 imágenes
#   mancha_parda → hoja_amarilla: 2 imágenes
#   muermo_rojo → mancha_parda: 2 imágenes
#   sanas → roya: 2 imágenes
#   sanas → mosaico: 2 imágenes
#   mancha_parda → sanas: 1 imágenes
#   muermo_rojo → sanas: 1 imágenes
#   muermo_rojo → hoja_amarilla: 1 imágenes
#   muermo_rojo → roya: 1 imágenes
#   muermo_rojo → tizon_bacteriano: 1 imágenes
#   roya → mancha_anillo: 1 imágenes
#   secas → muermo_rojo: 1 imágenes
#   secas → mancha_parda: 1 imágenes
#   tizon_bacteriano → mancha_parda: 1 imágenes
#   tizon_bacteriano → roya: 1 imágenes
#
# Total de imágenes a mostrar: 23

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB2_con_ft_weights.h5
