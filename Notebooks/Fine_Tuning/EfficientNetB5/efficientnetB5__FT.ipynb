# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB5
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 456
BATCH_SIZE    = 8
EPOCHS        = 75
NUM_CLASSES   = 10
NOMBRE_MODELO = 'efficientnetB5_FT'

# Fase 1: Congelación de capas
PATIENCE_ES_F1  = 10
PATIENCE_LR_F1  = 5

# Fase 2: Descongelación de capas
PATIENCE_ES_F2  = 15
PATIENCE_LR_F2  = 8

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# DATA AUGMENTATION — IGUAL EN TODOS LOS MODELOS
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFICIENTNETB5

# %%
# CARGAR EFFICIENTNETB5 CON PESOS DE IMAGENET
base_model = EfficientNetB5(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPAS FINALES PERSONALIZADAS
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "efficientnetB5_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb5 (Functional)  (None, 15, 15, 2048)     28513527
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 28,777,089
# Trainable params: 263,562
# Non-trainable params: 28,513,527
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F1,
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F1,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Epoch 1/75
# 764/764 [==============================] - ETA: 0s - loss: 0.7232 - accuracy: 0.7697
# Epoch 1: val_loss improved from inf to 0.33095, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 3609s 5s/step - loss: 0.7232 - accuracy: 0.7697 - val_loss: 0.3310 - val_accuracy: 0.9083 - lr: 0.0010
# Epoch 2/75
# 764/764 [==============================] - ETA: 0s - loss: 0.4135 - accuracy: 0.8786
# Epoch 2: val_loss did not improve from 0.33095
# 764/764 [==============================] - 2074s 3s/step - loss: 0.4135 - accuracy: 0.8786 - val_loss: 0.3420 - val_accuracy: 0.8998 - lr: 0.0010
# Epoch 3/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3592 - accuracy: 0.8985
# Epoch 3: val_loss improved from 0.33095 to 0.24583, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2047s 3s/step - loss: 0.3592 - accuracy: 0.8985 - val_loss: 0.2458 - val_accuracy: 0.9495 - lr: 0.0010
# Epoch 4/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3332 - accuracy: 0.9081
# Epoch 4: val_loss did not improve from 0.24583
# 764/764 [==============================] - 2178s 3s/step - loss: 0.3332 - accuracy: 0.9081 - val_loss: 0.2627 - val_accuracy: 0.9289 - lr: 0.0010
# Epoch 5/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3145 - accuracy: 0.9181
# Epoch 5: val_loss did not improve from 0.24583
# 764/764 [==============================] - 2211s 3s/step - loss: 0.3145 - accuracy: 0.9181 - val_loss: 0.2917 - val_accuracy: 0.9266 - lr: 0.0010
# Epoch 6/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3065 - accuracy: 0.9216
# Epoch 6: val_loss did not improve from 0.24583
# 764/764 [==============================] - 2217s 3s/step - loss: 0.3065 - accuracy: 0.9216 - val_loss: 0.2888 - val_accuracy: 0.9320 - lr: 0.0010
# Epoch 7/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3024 - accuracy: 0.9309
# Epoch 7: val_loss did not improve from 0.24583
# 764/764 [==============================] - 2213s 3s/step - loss: 0.3024 - accuracy: 0.9309 - val_loss: 0.2745 - val_accuracy: 0.9358 - lr: 0.0010
# Epoch 8/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3112 - accuracy: 0.9279
# Epoch 8: val_loss improved from 0.24583 to 0.22291, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2217s 3s/step - loss: 0.3112 - accuracy: 0.9279 - val_loss: 0.2229 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 9/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3136 - accuracy: 0.9274
# Epoch 9: val_loss improved from 0.22291 to 0.22110, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2219s 3s/step - loss: 0.3136 - accuracy: 0.9274 - val_loss: 0.2211 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 10/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3105 - accuracy: 0.9240
# Epoch 10: val_loss did not improve from 0.22110
# 764/764 [==============================] - 2222s 3s/step - loss: 0.3105 - accuracy: 0.9240 - val_loss: 0.2599 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 11/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3087 - accuracy: 0.9299
# Epoch 11: val_loss did not improve from 0.22110
# 764/764 [==============================] - 2223s 3s/step - loss: 0.3087 - accuracy: 0.9299 - val_loss: 0.2804 - val_accuracy: 0.9350 - lr: 0.0010
# Epoch 12/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3050 - accuracy: 0.9315
# Epoch 12: val_loss did not improve from 0.22110
# 764/764 [==============================] - 2221s 3s/step - loss: 0.3050 - accuracy: 0.9315 - val_loss: 0.2685 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 13/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2969 - accuracy: 0.9394
# Epoch 13: val_loss did not improve from 0.22110
# 764/764 [==============================] - 2220s 3s/step - loss: 0.2969 - accuracy: 0.9394 - val_loss: 0.2475 - val_accuracy: 0.9572 - lr: 0.0010
# Epoch 14/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2971 - accuracy: 0.9427
# Epoch 14: val_loss did not improve from 0.22110
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 764/764 [==============================] - 2212s 3s/step - loss: 0.2971 - accuracy: 0.9427 - val_loss: 0.2869 - val_accuracy: 0.9411 - lr: 0.0010
# Epoch 15/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.9504
# Epoch 15: val_loss improved from 0.22110 to 0.21477, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2221s 3s/step - loss: 0.2540 - accuracy: 0.9504 - val_loss: 0.2148 - val_accuracy: 0.9633 - lr: 5.0000e-04
# Epoch 16/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.9545
# Epoch 16: val_loss did not improve from 0.21477
# 764/764 [==============================] - 2225s 3s/step - loss: 0.2392 - accuracy: 0.9545 - val_loss: 0.2526 - val_accuracy: 0.9511 - lr: 5.0000e-04
# Epoch 17/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2475 - accuracy: 0.9556
# Epoch 17: val_loss did not improve from 0.21477
# 764/764 [==============================] - 2227s 3s/step - loss: 0.2475 - accuracy: 0.9556 - val_loss: 0.2252 - val_accuracy: 0.9618 - lr: 5.0000e-04
# Epoch 18/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2252 - accuracy: 0.9604
# Epoch 18: val_loss did not improve from 0.21477
# 764/764 [==============================] - 2222s 3s/step - loss: 0.2252 - accuracy: 0.9604 - val_loss: 0.2193 - val_accuracy: 0.9541 - lr: 5.0000e-04
# Epoch 19/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2267 - accuracy: 0.9589
# Epoch 19: val_loss improved from 0.21477 to 0.20586, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2221s 3s/step - loss: 0.2267 - accuracy: 0.9589 - val_loss: 0.2059 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 20/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2153 - accuracy: 0.9609
# Epoch 20: val_loss improved from 0.20586 to 0.19448, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2239s 3s/step - loss: 0.2153 - accuracy: 0.9609 - val_loss: 0.1945 - val_accuracy: 0.9656 - lr: 5.0000e-04
# Epoch 21/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2149 - accuracy: 0.9584
# Epoch 21: val_loss did not improve from 0.19448
# 764/764 [==============================] - 2225s 3s/step - loss: 0.2149 - accuracy: 0.9584 - val_loss: 0.2393 - val_accuracy: 0.9442 - lr: 5.0000e-04
# Epoch 22/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2025 - accuracy: 0.9643
# Epoch 22: val_loss did not improve from 0.19448
# 764/764 [==============================] - 2224s 3s/step - loss: 0.2025 - accuracy: 0.9643 - val_loss: 0.2281 - val_accuracy: 0.9526 - lr: 5.0000e-04
# Epoch 23/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2051 - accuracy: 0.9646
# Epoch 23: val_loss did not improve from 0.19448
# 764/764 [==============================] - 2221s 3s/step - loss: 0.2051 - accuracy: 0.9646 - val_loss: 0.1951 - val_accuracy: 0.9641 - lr: 5.0000e-04
# Epoch 24/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9605
# Epoch 24: val_loss improved from 0.19448 to 0.17575, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2223s 3s/step - loss: 0.2109 - accuracy: 0.9605 - val_loss: 0.1757 - val_accuracy: 0.9687 - lr: 5.0000e-04
# Epoch 25/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2018 - accuracy: 0.9658
# Epoch 25: val_loss did not improve from 0.17575
# 764/764 [==============================] - 2228s 3s/step - loss: 0.2018 - accuracy: 0.9658 - val_loss: 0.1916 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 26/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2006 - accuracy: 0.9648
# Epoch 26: val_loss did not improve from 0.17575
# 764/764 [==============================] - 2225s 3s/step - loss: 0.2006 - accuracy: 0.9648 - val_loss: 0.1881 - val_accuracy: 0.9625 - lr: 5.0000e-04
# Epoch 27/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1949 - accuracy: 0.9636
# Epoch 27: val_loss improved from 0.17575 to 0.17261, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2221s 3s/step - loss: 0.1949 - accuracy: 0.9636 - val_loss: 0.1726 - val_accuracy: 0.9717 - lr: 5.0000e-04
# Epoch 28/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2023 - accuracy: 0.9632
# Epoch 28: val_loss did not improve from 0.17261
# 764/764 [==============================] - 2220s 3s/step - loss: 0.2023 - accuracy: 0.9632 - val_loss: 0.1783 - val_accuracy: 0.9656 - lr: 5.0000e-04
# Epoch 29/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2001 - accuracy: 0.9620
# Epoch 29: val_loss did not improve from 0.17261
# 764/764 [==============================] - 2215s 3s/step - loss: 0.2001 - accuracy: 0.9620 - val_loss: 0.1825 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 30/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9641
# Epoch 30: val_loss improved from 0.17261 to 0.17187, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2220s 3s/step - loss: 0.1980 - accuracy: 0.9641 - val_loss: 0.1719 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 31/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9641
# Epoch 31: val_loss did not improve from 0.17187
# 764/764 [==============================] - 2216s 3s/step - loss: 0.1953 - accuracy: 0.9641 - val_loss: 0.1746 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 32/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9622
# Epoch 32: val_loss improved from 0.17187 to 0.17092, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2212s 3s/step - loss: 0.1971 - accuracy: 0.9622 - val_loss: 0.1709 - val_accuracy: 0.9732 - lr: 5.0000e-04
# Epoch 33/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2033 - accuracy: 0.9579
# Epoch 33: val_loss did not improve from 0.17092
# 764/764 [==============================] - 2214s 3s/step - loss: 0.2033 - accuracy: 0.9579 - val_loss: 0.1744 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 34/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9659
# Epoch 34: val_loss did not improve from 0.17092
# 764/764 [==============================] - 2213s 3s/step - loss: 0.1892 - accuracy: 0.9659 - val_loss: 0.1871 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 35/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1949 - accuracy: 0.9664
# Epoch 35: val_loss did not improve from 0.17092
# 764/764 [==============================] - 2219s 3s/step - loss: 0.1949 - accuracy: 0.9664 - val_loss: 0.1766 - val_accuracy: 0.9725 - lr: 5.0000e-04
# Epoch 36/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9651
# Epoch 36: val_loss did not improve from 0.17092
# 764/764 [==============================] - 2220s 3s/step - loss: 0.1907 - accuracy: 0.9651 - val_loss: 0.1791 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 37/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 0.9668
# Epoch 37: val_loss did not improve from 0.17092
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 764/764 [==============================] - 2215s 3s/step - loss: 0.1871 - accuracy: 0.9668 - val_loss: 0.2058 - val_accuracy: 0.9602 - lr: 5.0000e-04
# Epoch 38/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.9713
# Epoch 38: val_loss did not improve from 0.17092
# 764/764 [==============================] - 2223s 3s/step - loss: 0.1718 - accuracy: 0.9713 - val_loss: 0.1773 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 39/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1574 - accuracy: 0.9751
# Epoch 39: val_loss did not improve from 0.17092
# 764/764 [==============================] - 2223s 3s/step - loss: 0.1574 - accuracy: 0.9751 - val_loss: 0.1789 - val_accuracy: 0.9656 - lr: 2.5000e-04
# Epoch 40/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1657 - accuracy: 0.9704
# Epoch 40: val_loss improved from 0.17092 to 0.16697, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2219s 3s/step - loss: 0.1657 - accuracy: 0.9704 - val_loss: 0.1670 - val_accuracy: 0.9687 - lr: 2.5000e-04
# Epoch 41/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.9764
# Epoch 41: val_loss did not improve from 0.16697
# 764/764 [==============================] - 2224s 3s/step - loss: 0.1496 - accuracy: 0.9764 - val_loss: 0.1682 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 42/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9749
# Epoch 42: val_loss improved from 0.16697 to 0.16589, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2221s 3s/step - loss: 0.1551 - accuracy: 0.9749 - val_loss: 0.1659 - val_accuracy: 0.9687 - lr: 2.5000e-04
# Epoch 43/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9722
# Epoch 43: val_loss improved from 0.16589 to 0.14961, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2227s 3s/step - loss: 0.1576 - accuracy: 0.9722 - val_loss: 0.1496 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 44/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9774
# Epoch 44: val_loss did not improve from 0.14961
# 764/764 [==============================] - 2223s 3s/step - loss: 0.1475 - accuracy: 0.9774 - val_loss: 0.1572 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 45/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9771
# Epoch 45: val_loss improved from 0.14961 to 0.14872, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2218s 3s/step - loss: 0.1490 - accuracy: 0.9771 - val_loss: 0.1487 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 46/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9748
# Epoch 46: val_loss did not improve from 0.14872
# 764/764 [==============================] - 2229s 3s/step - loss: 0.1538 - accuracy: 0.9748 - val_loss: 0.1711 - val_accuracy: 0.9648 - lr: 2.5000e-04
# Epoch 47/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1487 - accuracy: 0.9740
# Epoch 47: val_loss did not improve from 0.14872
# 764/764 [==============================] - 2236s 3s/step - loss: 0.1487 - accuracy: 0.9740 - val_loss: 0.1517 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 48/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9771
# Epoch 48: val_loss did not improve from 0.14872
# 764/764 [==============================] - 2233s 3s/step - loss: 0.1431 - accuracy: 0.9771 - val_loss: 0.1644 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 49/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.9748
# Epoch 49: val_loss improved from 0.14872 to 0.14563, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2248s 3s/step - loss: 0.1496 - accuracy: 0.9748 - val_loss: 0.1456 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 50/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9740
# Epoch 50: val_loss did not improve from 0.14563
# 764/764 [==============================] - 2236s 3s/step - loss: 0.1443 - accuracy: 0.9740 - val_loss: 0.1560 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 51/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1371 - accuracy: 0.9784
# Epoch 51: val_loss did not improve from 0.14563
# 764/764 [==============================] - 2287s 3s/step - loss: 0.1371 - accuracy: 0.9784 - val_loss: 0.1570 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 52/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.9767
# Epoch 52: val_loss did not improve from 0.14563
# 764/764 [==============================] - 2360s 3s/step - loss: 0.1395 - accuracy: 0.9767 - val_loss: 0.1557 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 53/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1452 - accuracy: 0.9743
# Epoch 53: val_loss improved from 0.14563 to 0.14089, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2261s 3s/step - loss: 0.1452 - accuracy: 0.9743 - val_loss: 0.1409 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 54/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1504 - accuracy: 0.9735
# Epoch 54: val_loss did not improve from 0.14089
# 764/764 [==============================] - 2275s 3s/step - loss: 0.1504 - accuracy: 0.9735 - val_loss: 0.1426 - val_accuracy: 0.9794 - lr: 2.5000e-04
# Epoch 55/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9779
# Epoch 55: val_loss did not improve from 0.14089
# 764/764 [==============================] - 2356s 3s/step - loss: 0.1357 - accuracy: 0.9779 - val_loss: 0.1411 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 56/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1384 - accuracy: 0.9771
# Epoch 56: val_loss did not improve from 0.14089
# 764/764 [==============================] - 2353s 3s/step - loss: 0.1384 - accuracy: 0.9771 - val_loss: 0.1653 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 57/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9756
# Epoch 57: val_loss improved from 0.14089 to 0.13829, saving model to efficientnetB5_con_ft_fase1_weights.h5
# 764/764 [==============================] - 2351s 3s/step - loss: 0.1421 - accuracy: 0.9756 - val_loss: 0.1383 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 58/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9784
# Epoch 58: val_loss did not improve from 0.13829
# 764/764 [==============================] - 2353s 3s/step - loss: 0.1349 - accuracy: 0.9784 - val_loss: 0.1462 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 59/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9774
# Epoch 59: val_loss did not improve from 0.13829
# 764/764 [==============================] - 2356s 3s/step - loss: 0.1329 - accuracy: 0.9774 - val_loss: 0.1488 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 60/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9730
# Epoch 60: val_loss did not improve from 0.13829
# 764/764 [==============================] - 2377s 3s/step - loss: 0.1445 - accuracy: 0.9730 - val_loss: 0.1438 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 61/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 0.9777
# Epoch 61: val_loss did not improve from 0.13829
# 764/764 [==============================] - 2349s 3s/step - loss: 0.1312 - accuracy: 0.9777 - val_loss: 0.1466 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 62/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1354 - accuracy: 0.9759
# Epoch 62: val_loss did not improve from 0.13829
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 764/764 [==============================] - 2357s 3s/step - loss: 0.1354 - accuracy: 0.9759 - val_loss: 0.1403 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 63/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9794
# Epoch 63: val_loss did not improve from 0.13829
# 764/764 [==============================] - 2352s 3s/step - loss: 0.1245 - accuracy: 0.9794 - val_loss: 0.1427 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 64/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1191 - accuracy: 0.9826
# Epoch 64: val_loss did not improve from 0.13829
# 764/764 [==============================] - 2353s 3s/step - loss: 0.1191 - accuracy: 0.9826 - val_loss: 0.1486 - val_accuracy: 0.9717 - lr: 1.2500e-04
# Epoch 65/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9828
# Epoch 65: val_loss did not improve from 0.13829
# 764/764 [==============================] - 2357s 3s/step - loss: 0.1152 - accuracy: 0.9828 - val_loss: 0.1417 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 66/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1229 - accuracy: 0.9795
# Epoch 66: val_loss did not improve from 0.13829
# 764/764 [==============================] - 2361s 3s/step - loss: 0.1229 - accuracy: 0.9795 - val_loss: 0.1414 - val_accuracy: 0.9717 - lr: 1.2500e-04
# Epoch 67/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9810Restoring model weights from the end of the best epoch: 57.
#
# Epoch 67: val_loss did not improve from 0.13829
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 764/764 [==============================] - 2358s 3s/step - loss: 0.1182 - accuracy: 0.9810 - val_loss: 0.1417 - val_accuracy: 0.9702 - lr: 1.2500e-04
# Epoch 67: early stopping
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9794

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F2,          # = 10, igual en todos los modelos
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F2,
    min_lr=1e-6,
    verbose=1
)

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 577
# Capas congeladas         : 547
# Capas descongeladas      : 30
# Epoch 1/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9800
# Epoch 1: val_loss improved from inf to 0.13992, saving model to efficientnetB5_con_ft_weights.h5
# 764/764 [==============================] - 2352s 3s/step - loss: 0.1295 - accuracy: 0.9800 - val_loss: 0.1399 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 2/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1240 - accuracy: 0.9821
# Epoch 2: val_loss did not improve from 0.13992
# 764/764 [==============================] - 2357s 3s/step - loss: 0.1240 - accuracy: 0.9821 - val_loss: 0.1403 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 3/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9808
# Epoch 3: val_loss did not improve from 0.13992
# 764/764 [==============================] - 2364s 3s/step - loss: 0.1239 - accuracy: 0.9808 - val_loss: 0.1405 - val_accuracy: 0.9755 - lr: 1.0000e-05
# Epoch 4/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1211 - accuracy: 0.9840
# Epoch 4: val_loss improved from 0.13992 to 0.13936, saving model to efficientnetB5_con_ft_weights.h5
# 764/764 [==============================] - 2373s 3s/step - loss: 0.1211 - accuracy: 0.9840 - val_loss: 0.1394 - val_accuracy: 0.9755 - lr: 1.0000e-05
# Epoch 5/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1232 - accuracy: 0.9815
# Epoch 5: val_loss improved from 0.13936 to 0.13821, saving model to efficientnetB5_con_ft_weights.h5
# 764/764 [==============================] - 2359s 3s/step - loss: 0.1232 - accuracy: 0.9815 - val_loss: 0.1382 - val_accuracy: 0.9755 - lr: 1.0000e-05
# Epoch 6/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1166 - accuracy: 0.9844
# Epoch 6: val_loss did not improve from 0.13821
# 764/764 [==============================] - 2361s 3s/step - loss: 0.1166 - accuracy: 0.9844 - val_loss: 0.1389 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 7/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.9848
# Epoch 7: val_loss improved from 0.13821 to 0.13785, saving model to efficientnetB5_con_ft_weights.h5
# 764/764 [==============================] - 2368s 3s/step - loss: 0.1199 - accuracy: 0.9848 - val_loss: 0.1378 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 8/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 0.9848
# Epoch 8: val_loss improved from 0.13785 to 0.13726, saving model to efficientnetB5_con_ft_weights.h5
# 764/764 [==============================] - 2331s 3s/step - loss: 0.1129 - accuracy: 0.9848 - val_loss: 0.1373 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 9/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9858
# Epoch 9: val_loss did not improve from 0.13726
# 764/764 [==============================] - 2236s 3s/step - loss: 0.1165 - accuracy: 0.9858 - val_loss: 0.1374 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 10/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9840
# Epoch 10: val_loss did not improve from 0.13726
# 764/764 [==============================] - 2287s 3s/step - loss: 0.1181 - accuracy: 0.9840 - val_loss: 0.1384 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 11/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9844
# Epoch 11: val_loss improved from 0.13726 to 0.13587, saving model to efficientnetB5_con_ft_weights.h5
# 764/764 [==============================] - 2317s 3s/step - loss: 0.1170 - accuracy: 0.9844 - val_loss: 0.1359 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 12/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9808
# Epoch 12: val_loss did not improve from 0.13587
# 764/764 [==============================] - 2228s 3s/step - loss: 0.1212 - accuracy: 0.9808 - val_loss: 0.1378 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 13/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1178 - accuracy: 0.9828
# Epoch 13: val_loss did not improve from 0.13587
# 764/764 [==============================] - 2196s 3s/step - loss: 0.1178 - accuracy: 0.9828 - val_loss: 0.1382 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 14/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1113 - accuracy: 0.9858
# Epoch 14: val_loss did not improve from 0.13587
# 764/764 [==============================] - 2191s 3s/step - loss: 0.1113 - accuracy: 0.9858 - val_loss: 0.1379 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 15/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 0.9848
# Epoch 15: val_loss did not improve from 0.13587
# 764/764 [==============================] - 2268s 3s/step - loss: 0.1168 - accuracy: 0.9848 - val_loss: 0.1363 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 16/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9831
# Epoch 16: val_loss improved from 0.13587 to 0.13561, saving model to efficientnetB5_con_ft_weights.h5
# 764/764 [==============================] - 2216s 3s/step - loss: 0.1210 - accuracy: 0.9831 - val_loss: 0.1356 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 17/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1126 - accuracy: 0.9849
# Epoch 17: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2319s 3s/step - loss: 0.1126 - accuracy: 0.9849 - val_loss: 0.1378 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 18/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9815
# Epoch 18: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2327s 3s/step - loss: 0.1200 - accuracy: 0.9815 - val_loss: 0.1377 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 19/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9856
# Epoch 19: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2225s 3s/step - loss: 0.1110 - accuracy: 0.9856 - val_loss: 0.1378 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 20/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9825
# Epoch 20: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2248s 3s/step - loss: 0.1185 - accuracy: 0.9825 - val_loss: 0.1367 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 21/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1151 - accuracy: 0.9838
# Epoch 21: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2101s 3s/step - loss: 0.1151 - accuracy: 0.9838 - val_loss: 0.1362 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 22/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9840
# Epoch 22: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2099s 3s/step - loss: 0.1170 - accuracy: 0.9840 - val_loss: 0.1379 - val_accuracy: 0.9748 - lr: 1.0000e-05
# Epoch 23/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1171 - accuracy: 0.9835
# Epoch 23: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2206s 3s/step - loss: 0.1171 - accuracy: 0.9835 - val_loss: 0.1380 - val_accuracy: 0.9732 - lr: 1.0000e-05
# Epoch 24/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 0.9846
# Epoch 24: val_loss did not improve from 0.13561
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 764/764 [==============================] - 2173s 3s/step - loss: 0.1168 - accuracy: 0.9846 - val_loss: 0.1390 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 25/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1130 - accuracy: 0.9844
# Epoch 25: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2173s 3s/step - loss: 0.1130 - accuracy: 0.9844 - val_loss: 0.1366 - val_accuracy: 0.9740 - lr: 5.0000e-06
# Epoch 26/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9874
# Epoch 26: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2107s 3s/step - loss: 0.1082 - accuracy: 0.9874 - val_loss: 0.1360 - val_accuracy: 0.9748 - lr: 5.0000e-06
# Epoch 27/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.9866
# Epoch 27: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2158s 3s/step - loss: 0.1084 - accuracy: 0.9866 - val_loss: 0.1363 - val_accuracy: 0.9748 - lr: 5.0000e-06
# Epoch 28/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9872
# Epoch 28: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2230s 3s/step - loss: 0.1112 - accuracy: 0.9872 - val_loss: 0.1364 - val_accuracy: 0.9748 - lr: 5.0000e-06
# Epoch 29/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9849
# Epoch 29: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2323s 3s/step - loss: 0.1134 - accuracy: 0.9849 - val_loss: 0.1361 - val_accuracy: 0.9755 - lr: 5.0000e-06
# Epoch 30/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9833
# Epoch 30: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2371s 3s/step - loss: 0.1146 - accuracy: 0.9833 - val_loss: 0.1373 - val_accuracy: 0.9740 - lr: 5.0000e-06
# Epoch 31/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.9844Restoring model weights from the end of the best epoch: 16.
#
# Epoch 31: val_loss did not improve from 0.13561
# 764/764 [==============================] - 2373s 3s/step - loss: 0.1140 - accuracy: 0.9844 - val_loss: 0.1361 - val_accuracy: 0.9748 - lr: 5.0000e-06
# Epoch 31: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9778

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9794
# Fase 2 — mejor val_accuracy: 0.9778

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 164/164 [==============================] - 402s 2s/step - loss: 0.1232 - accuracy: 0.9847
#
# Test Accuracy : 0.9847
# Test Loss     : 0.1232
# 164/164 [==============================] - 404s 2s/step
# F1 Score      : 0.9846
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9677    1.0000    0.9836       150
#    mancha_anillo     0.9905    0.9905    0.9905       105
#     mancha_parda     0.9865    0.9733    0.9799       150
#          mosaico     0.9868    0.9933    0.9900       150
#      muermo_rojo     0.9669    0.9733    0.9701       150
#             roya     0.9860    0.9400    0.9625       150
#            sanas     0.9868    1.0000    0.9934       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     0.9933    0.9933    0.9933       150
#
#         accuracy                         0.9847      1308
#        macro avg     0.9865    0.9864    0.9863      1308
#     weighted avg     0.9848    0.9847    0.9846      1308
#
#
# Resultados guardados en efficientnetB5_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]
class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 1 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]
print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]
    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()
    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9, color='red'
        )
        axes[j].axis('off')
    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')
    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14, fontweight='bold', y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 1 o más confusiones:
#   roya → muermo_rojo: 3 imágenes
#   mancha_parda → hoja_amarilla: 2 imágenes
#   muermo_rojo → mancha_parda: 2 imágenes
#   roya → hoja_amarilla: 2 imágenes
#   roya → mosaico: 2 imágenes
#   mancha_anillo → roya: 1 imágenes
#   mancha_parda → roya: 1 imágenes
#   mancha_parda → muermo_rojo: 1 imágenes
#   mosaico → sanas: 1 imágenes
#   muermo_rojo → hoja_amarilla: 1 imágenes
#   muermo_rojo → tizon_bacteriano: 1 imágenes
#   roya → sanas: 1 imágenes
#   roya → mancha_anillo: 1 imágenes
#   tizon_bacteriano → muermo_rojo: 1 imágenes
#
# Total de imágenes a mostrar: 20

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB5_con_ft_weights.h5
