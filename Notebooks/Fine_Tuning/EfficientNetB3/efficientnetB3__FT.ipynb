# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE      = 300
BATCH_SIZE    = 16
EPOCHS        = 75
NUM_CLASSES   = 10
NOMBRE_MODELO = "efficientnetB3_FT"

# Fase 1: Congelación de capas
PATIENCE_ES_F1  = 10
PATIENCE_LR_F1  = 5

# Fase 2: Descongelación de capas
PATIENCE_ES_F2  = 15
PATIENCE_LR_F2  = 8

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFIENTNETB3

# %%
# CARGAR EFFICIENTNET-B3 CON PESOS DE IMAGENET
base_model = EfficientNetB3(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "efficientnetB3_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb3 (Functional)  (None, 10, 10, 1536)     10783535
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               196736
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 10,981,561
# Trainable params: 198,026
# Non-trainable params: 10,783,535
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')
print(f'Capas entrenables: {sum(1 for l in model.layers if l.trainable)}')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F1,          # = 10, igual en todos los modelos
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F1,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Capas entrenables: 4
# Epoch 1/75
# 382/382 [==============================] - ETA: 0s - loss: 0.7444 - accuracy: 0.7589
# Epoch 1: val_loss improved from inf to 0.29141, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 592s 1s/step - loss: 0.7444 - accuracy: 0.7589 - val_loss: 0.2914 - val_accuracy: 0.9266 - lr: 0.0010
# Epoch 2/75
# 382/382 [==============================] - ETA: 0s - loss: 0.4021 - accuracy: 0.8849
# Epoch 2: val_loss improved from 0.29141 to 0.23363, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 554s 1s/step - loss: 0.4021 - accuracy: 0.8849 - val_loss: 0.2336 - val_accuracy: 0.9495 - lr: 0.0010
# Epoch 3/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3447 - accuracy: 0.9001
# Epoch 3: val_loss improved from 0.23363 to 0.19572, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 585s 2s/step - loss: 0.3447 - accuracy: 0.9001 - val_loss: 0.1957 - val_accuracy: 0.9472 - lr: 0.0010
# Epoch 4/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.9129
# Epoch 4: val_loss did not improve from 0.19572
# 382/382 [==============================] - 568s 1s/step - loss: 0.3003 - accuracy: 0.9129 - val_loss: 0.2349 - val_accuracy: 0.9335 - lr: 0.0010
# Epoch 5/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2973 - accuracy: 0.9158
# Epoch 5: val_loss improved from 0.19572 to 0.19555, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 563s 1s/step - loss: 0.2973 - accuracy: 0.9158 - val_loss: 0.1955 - val_accuracy: 0.9503 - lr: 0.0010
# Epoch 6/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2674 - accuracy: 0.9265
# Epoch 6: val_loss improved from 0.19555 to 0.18707, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 556s 1s/step - loss: 0.2674 - accuracy: 0.9265 - val_loss: 0.1871 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 7/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2587 - accuracy: 0.9294
# Epoch 7: val_loss did not improve from 0.18707
# 382/382 [==============================] - 555s 1s/step - loss: 0.2587 - accuracy: 0.9294 - val_loss: 0.1905 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 8/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2660 - accuracy: 0.9327
# Epoch 8: val_loss did not improve from 0.18707
# 382/382 [==============================] - 560s 1s/step - loss: 0.2660 - accuracy: 0.9327 - val_loss: 0.2039 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 9/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2568 - accuracy: 0.9347
# Epoch 9: val_loss did not improve from 0.18707
# 382/382 [==============================] - 560s 1s/step - loss: 0.2568 - accuracy: 0.9347 - val_loss: 0.1907 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 10/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2389 - accuracy: 0.9376
# Epoch 10: val_loss improved from 0.18707 to 0.17370, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 567s 1s/step - loss: 0.2389 - accuracy: 0.9376 - val_loss: 0.1737 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 11/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2567 - accuracy: 0.9366
# Epoch 11: val_loss did not improve from 0.17370
# 382/382 [==============================] - 556s 1s/step - loss: 0.2567 - accuracy: 0.9366 - val_loss: 0.2177 - val_accuracy: 0.9434 - lr: 0.0010
# Epoch 12/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2552 - accuracy: 0.9351
# Epoch 12: val_loss did not improve from 0.17370
# 382/382 [==============================] - 557s 1s/step - loss: 0.2552 - accuracy: 0.9351 - val_loss: 0.1891 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 13/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2446 - accuracy: 0.9432
# Epoch 13: val_loss did not improve from 0.17370
# 382/382 [==============================] - 558s 1s/step - loss: 0.2446 - accuracy: 0.9432 - val_loss: 0.1818 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 14/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2527 - accuracy: 0.9424
# Epoch 14: val_loss did not improve from 0.17370
# 382/382 [==============================] - 561s 1s/step - loss: 0.2527 - accuracy: 0.9424 - val_loss: 0.1859 - val_accuracy: 0.9564 - lr: 0.0010
# Epoch 15/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.9417
# Epoch 15: val_loss did not improve from 0.17370
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 382/382 [==============================] - 559s 1s/step - loss: 0.2478 - accuracy: 0.9417 - val_loss: 0.1798 - val_accuracy: 0.9595 - lr: 0.0010
# Epoch 16/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2070 - accuracy: 0.9564
# Epoch 16: val_loss improved from 0.17370 to 0.16709, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 559s 1s/step - loss: 0.2070 - accuracy: 0.9564 - val_loss: 0.1671 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 17/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1947 - accuracy: 0.9636
# Epoch 17: val_loss improved from 0.16709 to 0.15691, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 554s 1s/step - loss: 0.1947 - accuracy: 0.9636 - val_loss: 0.1569 - val_accuracy: 0.9687 - lr: 5.0000e-04
# Epoch 18/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9641
# Epoch 18: val_loss did not improve from 0.15691
# 382/382 [==============================] - 565s 1s/step - loss: 0.1857 - accuracy: 0.9641 - val_loss: 0.1691 - val_accuracy: 0.9656 - lr: 5.0000e-04
# Epoch 19/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.9594
# Epoch 19: val_loss improved from 0.15691 to 0.15670, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 557s 1s/step - loss: 0.1973 - accuracy: 0.9594 - val_loss: 0.1567 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 20/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1859 - accuracy: 0.9632
# Epoch 20: val_loss improved from 0.15670 to 0.15211, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 557s 1s/step - loss: 0.1859 - accuracy: 0.9632 - val_loss: 0.1521 - val_accuracy: 0.9732 - lr: 5.0000e-04
# Epoch 21/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9602
# Epoch 21: val_loss improved from 0.15211 to 0.15196, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 558s 1s/step - loss: 0.1935 - accuracy: 0.9602 - val_loss: 0.1520 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 22/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9613
# Epoch 22: val_loss improved from 0.15196 to 0.14867, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 558s 1s/step - loss: 0.1820 - accuracy: 0.9613 - val_loss: 0.1487 - val_accuracy: 0.9740 - lr: 5.0000e-04
# Epoch 23/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 0.9594
# Epoch 23: val_loss did not improve from 0.14867
# 382/382 [==============================] - 557s 1s/step - loss: 0.1871 - accuracy: 0.9594 - val_loss: 0.1510 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 24/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9635
# Epoch 24: val_loss did not improve from 0.14867
# 382/382 [==============================] - 558s 1s/step - loss: 0.1789 - accuracy: 0.9635 - val_loss: 0.1538 - val_accuracy: 0.9740 - lr: 5.0000e-04
# Epoch 25/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1859 - accuracy: 0.9602
# Epoch 25: val_loss did not improve from 0.14867
# 382/382 [==============================] - 556s 1s/step - loss: 0.1859 - accuracy: 0.9602 - val_loss: 0.1606 - val_accuracy: 0.9687 - lr: 5.0000e-04
# Epoch 26/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1800 - accuracy: 0.9622
# Epoch 26: val_loss did not improve from 0.14867
# 382/382 [==============================] - 556s 1s/step - loss: 0.1800 - accuracy: 0.9622 - val_loss: 0.1691 - val_accuracy: 0.9618 - lr: 5.0000e-04
# Epoch 27/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1771 - accuracy: 0.9630
# Epoch 27: val_loss did not improve from 0.14867
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 382/382 [==============================] - 558s 1s/step - loss: 0.1771 - accuracy: 0.9630 - val_loss: 0.1536 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 28/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1665 - accuracy: 0.9666
# Epoch 28: val_loss improved from 0.14867 to 0.14719, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 557s 1s/step - loss: 0.1665 - accuracy: 0.9666 - val_loss: 0.1472 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 29/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9717
# Epoch 29: val_loss improved from 0.14719 to 0.13896, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1623 - accuracy: 0.9717 - val_loss: 0.1390 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 30/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9707
# Epoch 30: val_loss did not improve from 0.13896
# 382/382 [==============================] - 561s 1s/step - loss: 0.1650 - accuracy: 0.9707 - val_loss: 0.1390 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 31/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9730
# Epoch 31: val_loss did not improve from 0.13896
# 382/382 [==============================] - 557s 1s/step - loss: 0.1544 - accuracy: 0.9730 - val_loss: 0.1413 - val_accuracy: 0.9755 - lr: 2.5000e-04
# Epoch 32/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.9710
# Epoch 32: val_loss improved from 0.13896 to 0.13360, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 558s 1s/step - loss: 0.1491 - accuracy: 0.9710 - val_loss: 0.1336 - val_accuracy: 0.9786 - lr: 2.5000e-04
# Epoch 33/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9699
# Epoch 33: val_loss did not improve from 0.13360
# 382/382 [==============================] - 556s 1s/step - loss: 0.1565 - accuracy: 0.9699 - val_loss: 0.1370 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 34/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9756
# Epoch 34: val_loss did not improve from 0.13360
# 382/382 [==============================] - 557s 1s/step - loss: 0.1425 - accuracy: 0.9756 - val_loss: 0.1348 - val_accuracy: 0.9786 - lr: 2.5000e-04
# Epoch 35/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9712
# Epoch 35: val_loss did not improve from 0.13360
# 382/382 [==============================] - 555s 1s/step - loss: 0.1545 - accuracy: 0.9712 - val_loss: 0.1389 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 36/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1455 - accuracy: 0.9745
# Epoch 36: val_loss did not improve from 0.13360
# 382/382 [==============================] - 559s 1s/step - loss: 0.1455 - accuracy: 0.9745 - val_loss: 0.1412 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 37/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9743
# Epoch 37: val_loss did not improve from 0.13360
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 382/382 [==============================] - 557s 1s/step - loss: 0.1442 - accuracy: 0.9743 - val_loss: 0.1385 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 38/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9738
# Epoch 38: val_loss improved from 0.13360 to 0.13270, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 559s 1s/step - loss: 0.1454 - accuracy: 0.9738 - val_loss: 0.1327 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 39/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9766
# Epoch 39: val_loss improved from 0.13270 to 0.13167, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1343 - accuracy: 0.9766 - val_loss: 0.1317 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 40/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9736
# Epoch 40: val_loss improved from 0.13167 to 0.13047, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1414 - accuracy: 0.9736 - val_loss: 0.1305 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 41/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9772
# Epoch 41: val_loss did not improve from 0.13047
# 382/382 [==============================] - 559s 1s/step - loss: 0.1313 - accuracy: 0.9772 - val_loss: 0.1319 - val_accuracy: 0.9771 - lr: 1.2500e-04
# Epoch 42/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9751
# Epoch 42: val_loss did not improve from 0.13047
# 382/382 [==============================] - 561s 1s/step - loss: 0.1329 - accuracy: 0.9751 - val_loss: 0.1324 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 43/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1232 - accuracy: 0.9803
# Epoch 43: val_loss did not improve from 0.13047
# 382/382 [==============================] - 559s 1s/step - loss: 0.1232 - accuracy: 0.9803 - val_loss: 0.1310 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 44/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9754
# Epoch 44: val_loss improved from 0.13047 to 0.12656, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1380 - accuracy: 0.9754 - val_loss: 0.1266 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 45/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9779
# Epoch 45: val_loss did not improve from 0.12656
# 382/382 [==============================] - 557s 1s/step - loss: 0.1293 - accuracy: 0.9779 - val_loss: 0.1296 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 46/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9792
# Epoch 46: val_loss did not improve from 0.12656
# 382/382 [==============================] - 560s 1s/step - loss: 0.1263 - accuracy: 0.9792 - val_loss: 0.1271 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 47/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1283 - accuracy: 0.9790
# Epoch 47: val_loss did not improve from 0.12656
# 382/382 [==============================] - 558s 1s/step - loss: 0.1283 - accuracy: 0.9790 - val_loss: 0.1288 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 48/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9759
# Epoch 48: val_loss improved from 0.12656 to 0.12557, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1294 - accuracy: 0.9759 - val_loss: 0.1256 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 49/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9753
# Epoch 49: val_loss did not improve from 0.12557
# 382/382 [==============================] - 558s 1s/step - loss: 0.1335 - accuracy: 0.9753 - val_loss: 0.1286 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 50/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1308 - accuracy: 0.9751
# Epoch 50: val_loss improved from 0.12557 to 0.12367, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1308 - accuracy: 0.9751 - val_loss: 0.1237 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 51/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9751
# Epoch 51: val_loss did not improve from 0.12367
# 382/382 [==============================] - 559s 1s/step - loss: 0.1281 - accuracy: 0.9751 - val_loss: 0.1243 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 52/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9777
# Epoch 52: val_loss improved from 0.12367 to 0.12315, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 562s 1s/step - loss: 0.1226 - accuracy: 0.9777 - val_loss: 0.1231 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 53/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9818
# Epoch 53: val_loss improved from 0.12315 to 0.11972, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 558s 1s/step - loss: 0.1192 - accuracy: 0.9818 - val_loss: 0.1197 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 54/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9799
# Epoch 54: val_loss did not improve from 0.11972
# 382/382 [==============================] - 561s 1s/step - loss: 0.1231 - accuracy: 0.9799 - val_loss: 0.1204 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 55/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9772
# Epoch 55: val_loss did not improve from 0.11972
# 382/382 [==============================] - 561s 1s/step - loss: 0.1244 - accuracy: 0.9772 - val_loss: 0.1214 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 56/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1184 - accuracy: 0.9803
# Epoch 56: val_loss improved from 0.11972 to 0.11809, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 564s 1s/step - loss: 0.1184 - accuracy: 0.9803 - val_loss: 0.1181 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 57/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9795
# Epoch 57: val_loss did not improve from 0.11809
# 382/382 [==============================] - 560s 1s/step - loss: 0.1198 - accuracy: 0.9795 - val_loss: 0.1199 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 58/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1246 - accuracy: 0.9769
# Epoch 58: val_loss did not improve from 0.11809
# 382/382 [==============================] - 558s 1s/step - loss: 0.1246 - accuracy: 0.9769 - val_loss: 0.1198 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 59/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1189 - accuracy: 0.9800
# Epoch 59: val_loss did not improve from 0.11809
# 382/382 [==============================] - 563s 1s/step - loss: 0.1189 - accuracy: 0.9800 - val_loss: 0.1192 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 60/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9790
# Epoch 60: val_loss did not improve from 0.11809
# 382/382 [==============================] - 560s 1s/step - loss: 0.1236 - accuracy: 0.9790 - val_loss: 0.1195 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 61/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.9787
# Epoch 61: val_loss improved from 0.11809 to 0.11777, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1204 - accuracy: 0.9787 - val_loss: 0.1178 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 62/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9797
# Epoch 62: val_loss improved from 0.11777 to 0.11683, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 562s 1s/step - loss: 0.1131 - accuracy: 0.9797 - val_loss: 0.1168 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 63/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9820
# Epoch 63: val_loss did not improve from 0.11683
# 382/382 [==============================] - 559s 1s/step - loss: 0.1128 - accuracy: 0.9820 - val_loss: 0.1170 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 64/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 0.9823
# Epoch 64: val_loss improved from 0.11683 to 0.11566, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 562s 1s/step - loss: 0.1168 - accuracy: 0.9823 - val_loss: 0.1157 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 65/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.9805
# Epoch 65: val_loss did not improve from 0.11566
# 382/382 [==============================] - 559s 1s/step - loss: 0.1199 - accuracy: 0.9805 - val_loss: 0.1215 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 66/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9799
# Epoch 66: val_loss improved from 0.11566 to 0.11528, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1163 - accuracy: 0.9799 - val_loss: 0.1153 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 67/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1158 - accuracy: 0.9795
# Epoch 67: val_loss improved from 0.11528 to 0.11217, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 559s 1s/step - loss: 0.1158 - accuracy: 0.9795 - val_loss: 0.1122 - val_accuracy: 0.9824 - lr: 1.2500e-04
# Epoch 68/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9823
# Epoch 68: val_loss did not improve from 0.11217
# 382/382 [==============================] - 560s 1s/step - loss: 0.1148 - accuracy: 0.9823 - val_loss: 0.1136 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 69/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9807
# Epoch 69: val_loss did not improve from 0.11217
# 382/382 [==============================] - 559s 1s/step - loss: 0.1128 - accuracy: 0.9807 - val_loss: 0.1131 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 70/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1234 - accuracy: 0.9748
# Epoch 70: val_loss did not improve from 0.11217
# 382/382 [==============================] - 561s 1s/step - loss: 0.1234 - accuracy: 0.9748 - val_loss: 0.1133 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 71/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9792
# Epoch 71: val_loss did not improve from 0.11217
# 382/382 [==============================] - 559s 1s/step - loss: 0.1198 - accuracy: 0.9792 - val_loss: 0.1142 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 72/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1002 - accuracy: 0.9864
# Epoch 72: val_loss did not improve from 0.11217
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 382/382 [==============================] - 562s 1s/step - loss: 0.1002 - accuracy: 0.9864 - val_loss: 0.1131 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 73/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1110 - accuracy: 0.9803
# Epoch 73: val_loss improved from 0.11217 to 0.11113, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1110 - accuracy: 0.9803 - val_loss: 0.1111 - val_accuracy: 0.9801 - lr: 6.2500e-05
# Epoch 74/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1138 - accuracy: 0.9805
# Epoch 74: val_loss did not improve from 0.11113
# 382/382 [==============================] - 559s 1s/step - loss: 0.1138 - accuracy: 0.9805 - val_loss: 0.1112 - val_accuracy: 0.9809 - lr: 6.2500e-05
# Epoch 75/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9795
# Epoch 75: val_loss improved from 0.11113 to 0.11084, saving model to efficientnetB3_con_ft_fase1_weights.h5
# 382/382 [==============================] - 564s 1s/step - loss: 0.1135 - accuracy: 0.9795 - val_loss: 0.1108 - val_accuracy: 0.9824 - lr: 6.2500e-05
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9824

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F2,          # = 10, igual en todos los modelos --> pasar a 15
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F2,          # = 5, igual en todos los modelos --> pasar a 8
    min_lr=1e-6,                      # = 1e-7, igual en todos los modelos --> pasar a 1e-6
    verbose=1 
) 

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 385
# Capas congeladas         : 355
# Capas descongeladas      : 30
# Epoch 1/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9815
# Epoch 1: val_loss improved from inf to 0.10985, saving model to efficientnetB3_con_ft_weights.h5
# 382/382 [==============================] - 559s 1s/step - loss: 0.1165 - accuracy: 0.9815 - val_loss: 0.1098 - val_accuracy: 0.9824 - lr: 1.0000e-05
# Epoch 2/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9808
# Epoch 2: val_loss improved from 0.10985 to 0.10955, saving model to efficientnetB3_con_ft_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1089 - accuracy: 0.9808 - val_loss: 0.1095 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 3/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1100 - accuracy: 0.9818
# Epoch 3: val_loss improved from 0.10955 to 0.10917, saving model to efficientnetB3_con_ft_weights.h5
# 382/382 [==============================] - 556s 1s/step - loss: 0.1100 - accuracy: 0.9818 - val_loss: 0.1092 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 4/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1048 - accuracy: 0.9833
# Epoch 4: val_loss improved from 0.10917 to 0.10878, saving model to efficientnetB3_con_ft_weights.h5
# 382/382 [==============================] - 555s 1s/step - loss: 0.1048 - accuracy: 0.9833 - val_loss: 0.1088 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 5/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1080 - accuracy: 0.9831
# Epoch 5: val_loss did not improve from 0.10878
# 382/382 [==============================] - 558s 1s/step - loss: 0.1080 - accuracy: 0.9831 - val_loss: 0.1088 - val_accuracy: 0.9839 - lr: 1.0000e-05
# Epoch 6/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9833
# Epoch 6: val_loss did not improve from 0.10878
# 382/382 [==============================] - 554s 1s/step - loss: 0.1053 - accuracy: 0.9833 - val_loss: 0.1090 - val_accuracy: 0.9839 - lr: 1.0000e-05
# Epoch 7/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9813
# Epoch 7: val_loss improved from 0.10878 to 0.10866, saving model to efficientnetB3_con_ft_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1094 - accuracy: 0.9813 - val_loss: 0.1087 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 8/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9846
# Epoch 8: val_loss did not improve from 0.10866
# 382/382 [==============================] - 555s 1s/step - loss: 0.1016 - accuracy: 0.9846 - val_loss: 0.1088 - val_accuracy: 0.9824 - lr: 1.0000e-05
# Epoch 9/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9794
# Epoch 9: val_loss did not improve from 0.10866
# 382/382 [==============================] - 552s 1s/step - loss: 0.1089 - accuracy: 0.9794 - val_loss: 0.1087 - val_accuracy: 0.9824 - lr: 1.0000e-05
# Epoch 10/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9869
# Epoch 10: val_loss did not improve from 0.10866
# 382/382 [==============================] - 555s 1s/step - loss: 0.1026 - accuracy: 0.9869 - val_loss: 0.1088 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 11/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9869
# Epoch 11: val_loss did not improve from 0.10866
# 382/382 [==============================] - 555s 1s/step - loss: 0.0988 - accuracy: 0.9869 - val_loss: 0.1089 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 12/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9841
# Epoch 12: val_loss did not improve from 0.10866
# 382/382 [==============================] - 555s 1s/step - loss: 0.1003 - accuracy: 0.9841 - val_loss: 0.1088 - val_accuracy: 0.9824 - lr: 1.0000e-05
# Epoch 13/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9843
# Epoch 13: val_loss did not improve from 0.10866
# 382/382 [==============================] - 555s 1s/step - loss: 0.1045 - accuracy: 0.9843 - val_loss: 0.1093 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 14/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9856
# Epoch 14: val_loss did not improve from 0.10866
# 382/382 [==============================] - 550s 1s/step - loss: 0.1033 - accuracy: 0.9856 - val_loss: 0.1091 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 15/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1086 - accuracy: 0.9826
# Epoch 15: val_loss improved from 0.10866 to 0.10827, saving model to efficientnetB3_con_ft_weights.h5
# 382/382 [==============================] - 557s 1s/step - loss: 0.1086 - accuracy: 0.9826 - val_loss: 0.1083 - val_accuracy: 0.9824 - lr: 1.0000e-05
# Epoch 16/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9820
# Epoch 16: val_loss improved from 0.10827 to 0.10797, saving model to efficientnetB3_con_ft_weights.h5
# 382/382 [==============================] - 555s 1s/step - loss: 0.1094 - accuracy: 0.9820 - val_loss: 0.1080 - val_accuracy: 0.9824 - lr: 1.0000e-05
# Epoch 17/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1058 - accuracy: 0.9830
# Epoch 17: val_loss improved from 0.10797 to 0.10765, saving model to efficientnetB3_con_ft_weights.h5
# 382/382 [==============================] - 560s 1s/step - loss: 0.1058 - accuracy: 0.9830 - val_loss: 0.1076 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 18/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 0.9844
# Epoch 18: val_loss did not improve from 0.10765
# 382/382 [==============================] - 555s 1s/step - loss: 0.1038 - accuracy: 0.9844 - val_loss: 0.1078 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 19/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9843
# Epoch 19: val_loss did not improve from 0.10765
# 382/382 [==============================] - 557s 1s/step - loss: 0.1010 - accuracy: 0.9843 - val_loss: 0.1082 - val_accuracy: 0.9839 - lr: 1.0000e-05
# Epoch 20/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9848
# Epoch 20: val_loss did not improve from 0.10765
# 382/382 [==============================] - 556s 1s/step - loss: 0.1011 - accuracy: 0.9848 - val_loss: 0.1081 - val_accuracy: 0.9839 - lr: 1.0000e-05
# Epoch 21/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9826
# Epoch 21: val_loss did not improve from 0.10765
# 382/382 [==============================] - 552s 1s/step - loss: 0.1027 - accuracy: 0.9826 - val_loss: 0.1080 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 22/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9830
# Epoch 22: val_loss did not improve from 0.10765
# 382/382 [==============================] - 553s 1s/step - loss: 0.1070 - accuracy: 0.9830 - val_loss: 0.1083 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 23/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9825
# Epoch 23: val_loss did not improve from 0.10765
# 382/382 [==============================] - 556s 1s/step - loss: 0.1076 - accuracy: 0.9825 - val_loss: 0.1078 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 24/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9849
# Epoch 24: val_loss improved from 0.10765 to 0.10755, saving model to efficientnetB3_con_ft_weights.h5
# 382/382 [==============================] - 557s 1s/step - loss: 0.1014 - accuracy: 0.9849 - val_loss: 0.1075 - val_accuracy: 0.9817 - lr: 1.0000e-05
# Epoch 25/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9836
# Epoch 25: val_loss did not improve from 0.10755
# 382/382 [==============================] - 554s 1s/step - loss: 0.1014 - accuracy: 0.9836 - val_loss: 0.1078 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 26/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9823
# Epoch 26: val_loss did not improve from 0.10755
# 382/382 [==============================] - 553s 1s/step - loss: 0.1065 - accuracy: 0.9823 - val_loss: 0.1079 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 27/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9838
# Epoch 27: val_loss did not improve from 0.10755
# 382/382 [==============================] - 555s 1s/step - loss: 0.1055 - accuracy: 0.9838 - val_loss: 0.1079 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 28/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9820
# Epoch 28: val_loss did not improve from 0.10755
# 382/382 [==============================] - 552s 1s/step - loss: 0.1060 - accuracy: 0.9820 - val_loss: 0.1077 - val_accuracy: 0.9824 - lr: 1.0000e-05
# Epoch 29/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9818
# Epoch 29: val_loss did not improve from 0.10755
# 382/382 [==============================] - 553s 1s/step - loss: 0.1045 - accuracy: 0.9818 - val_loss: 0.1082 - val_accuracy: 0.9824 - lr: 1.0000e-05
# Epoch 30/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9853
# Epoch 30: val_loss did not improve from 0.10755
# 382/382 [==============================] - 553s 1s/step - loss: 0.1018 - accuracy: 0.9853 - val_loss: 0.1081 - val_accuracy: 0.9817 - lr: 1.0000e-05
# Epoch 31/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9858
# Epoch 31: val_loss did not improve from 0.10755
# 382/382 [==============================] - 552s 1s/step - loss: 0.1032 - accuracy: 0.9858 - val_loss: 0.1082 - val_accuracy: 0.9817 - lr: 1.0000e-05
# Epoch 32/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9828
# Epoch 32: val_loss did not improve from 0.10755
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 382/382 [==============================] - 553s 1s/step - loss: 0.1062 - accuracy: 0.9828 - val_loss: 0.1080 - val_accuracy: 0.9817 - lr: 1.0000e-05
# Epoch 33/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1039 - accuracy: 0.9826
# Epoch 33: val_loss did not improve from 0.10755
# 382/382 [==============================] - 552s 1s/step - loss: 0.1039 - accuracy: 0.9826 - val_loss: 0.1081 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 34/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 0.9846
# Epoch 34: val_loss did not improve from 0.10755
# 382/382 [==============================] - 552s 1s/step - loss: 0.1007 - accuracy: 0.9846 - val_loss: 0.1080 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 35/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9823
# Epoch 35: val_loss did not improve from 0.10755
# 382/382 [==============================] - 557s 1s/step - loss: 0.1033 - accuracy: 0.9823 - val_loss: 0.1078 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 36/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9836
# Epoch 36: val_loss did not improve from 0.10755
# 382/382 [==============================] - 555s 1s/step - loss: 0.1044 - accuracy: 0.9836 - val_loss: 0.1079 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 37/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9841
# Epoch 37: val_loss did not improve from 0.10755
# 382/382 [==============================] - 557s 1s/step - loss: 0.1017 - accuracy: 0.9841 - val_loss: 0.1077 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 38/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0972 - accuracy: 0.9838
# Epoch 38: val_loss did not improve from 0.10755
# 382/382 [==============================] - 554s 1s/step - loss: 0.0972 - accuracy: 0.9838 - val_loss: 0.1079 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 39/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9843Restoring model weights from the end of the best epoch: 24.
#
# Epoch 39: val_loss did not improve from 0.10755
# 382/382 [==============================] - 553s 1s/step - loss: 0.1014 - accuracy: 0.9843 - val_loss: 0.1077 - val_accuracy: 0.9824 - lr: 5.0000e-06
# Epoch 39: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9839

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
# Unir historial de las dos fases para graficar continuamente
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])  # donde termina la Fase 1

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy
ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# Loss
ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9824
# Fase 2 — mejor val_accuracy: 0.9839

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys()
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys()
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 82/82 [==============================] - 90s 1s/step - loss: 0.1019 - accuracy: 0.9824
#
# Test Accuracy : 0.9824
# Test Loss     : 0.1019
# 82/82 [==============================] - 91s 1s/step
# F1 Score      : 0.9824
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon       1.00      1.00      1.00        75
#    hoja_amarilla       0.97      1.00      0.98       150
#    mancha_anillo       0.99      1.00      1.00       105
#     mancha_parda       0.97      0.97      0.97       150
#          mosaico       0.97      0.98      0.98       150
#      muermo_rojo       0.98      0.96      0.97       150
#             roya       0.99      0.96      0.97       150
#            sanas       0.97      0.98      0.98       150
#            secas       1.00      1.00      1.00        78
# tizon_bacteriano       1.00      0.99      1.00       150
#
#         accuracy                           0.98      1308
#        macro avg       0.98      0.98      0.98      1308
#     weighted avg       0.98      0.98      0.98      1308
#
#
# Resultados guardados en efficientnetB3_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Pares con 1 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 1 o más confusiones:
#   muermo_rojo → mancha_parda: 4 imágenes
#   mosaico → sanas: 3 imágenes
#   mancha_parda → hoja_amarilla: 2 imágenes
#   roya → mosaico: 2 imágenes
#   sanas → mosaico: 2 imágenes
#   mancha_parda → roya: 1 imágenes
#   mancha_parda → muermo_rojo: 1 imágenes
#   muermo_rojo → hoja_amarilla: 1 imágenes
#   muermo_rojo → roya: 1 imágenes
#   roya → sanas: 1 imágenes
#   roya → hoja_amarilla: 1 imágenes
#   roya → muermo_rojo: 1 imágenes
#   roya → mancha_anillo: 1 imágenes
#   sanas → hoja_amarilla: 1 imágenes
#   tizon_bacteriano → muermo_rojo: 1 imágenes
#
# Total de imágenes a mostrar: 23

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB3_con_ft_weights.h5
