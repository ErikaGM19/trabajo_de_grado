# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 240
BATCH_SIZE    = 32
EPOCHS        = 75
NUM_CLASSES   = 10
NOMBRE_MODELO = 'efficientnetB1_FT'

# Fase 1: Congelación de capas
PATIENCE_ES_F1  = 10
PATIENCE_LR_F1  = 5

# Fase 2: Descongelación de capas
PATIENCE_ES_F2  = 15
PATIENCE_LR_F2  = 8

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# DATA AUGMENTATION — IGUAL EN TODOS LOS MODELOS
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFICIENTNETB1

# %%
# CARGAR EFFICIENTNETB1 CON PESOS DE IMAGENET
base_model = EfficientNetB1(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False    # Congelamos para la Fase 1

# CAPAS FINALES PERSONALIZADAS
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "efficientnetB1_con_ft"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb1 (Functional)  (None, 8, 8, 1280)       6575239
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 6,740,497
# Trainable params: 165,258
# Non-trainable params: 6,575,239
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO — FASE 1 (backbone congelado)

# %%
# ============================================================
# FASE 1: Entrenar solo las capas nuevas (backbone congelado)
# El backbone actúa como extractor de características fijo.
# ============================================================
print('FASE 1: Entrenando cabeza (backbone congelado)')

early_stopping_fase1 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F1,
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase1 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_fase1_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

reduce_lr_fase1 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F1,
    min_lr=1e-6,
    verbose=1
)

history_fase1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase1, checkpoint_fase1, reduce_lr_fase1]
)

print(f'\nFase 1 completada.')
print(f'Mejor val_accuracy fase 1: {max(history_fase1.history["val_accuracy"]):.4f}')
# Out:
# FASE 1: Entrenando cabeza (backbone congelado)
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.9536 - accuracy: 0.6846
# Epoch 1: val_loss improved from inf to 0.45722, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 326s 2s/step - loss: 0.9536 - accuracy: 0.6846 - val_loss: 0.4572 - val_accuracy: 0.8731 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4849 - accuracy: 0.8541
# Epoch 2: val_loss improved from 0.45722 to 0.31392, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 305s 2s/step - loss: 0.4849 - accuracy: 0.8541 - val_loss: 0.3139 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3958 - accuracy: 0.8829
# Epoch 3: val_loss improved from 0.31392 to 0.25747, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 302s 2s/step - loss: 0.3958 - accuracy: 0.8829 - val_loss: 0.2575 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8970
# Epoch 4: val_loss improved from 0.25747 to 0.24024, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 308s 2s/step - loss: 0.3499 - accuracy: 0.8970 - val_loss: 0.2402 - val_accuracy: 0.9274 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3113 - accuracy: 0.9107
# Epoch 5: val_loss improved from 0.24024 to 0.23435, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 344s 2s/step - loss: 0.3113 - accuracy: 0.9107 - val_loss: 0.2344 - val_accuracy: 0.9365 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3103 - accuracy: 0.9112
# Epoch 6: val_loss improved from 0.23435 to 0.21785, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 299s 2s/step - loss: 0.3103 - accuracy: 0.9112 - val_loss: 0.2179 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2927 - accuracy: 0.9165
# Epoch 7: val_loss improved from 0.21785 to 0.21604, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 302s 2s/step - loss: 0.2927 - accuracy: 0.9165 - val_loss: 0.2160 - val_accuracy: 0.9404 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.9235
# Epoch 8: val_loss improved from 0.21604 to 0.21498, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 297s 2s/step - loss: 0.2760 - accuracy: 0.9235 - val_loss: 0.2150 - val_accuracy: 0.9404 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.9255
# Epoch 9: val_loss did not improve from 0.21498
# 191/191 [==============================] - 295s 2s/step - loss: 0.2676 - accuracy: 0.9255 - val_loss: 0.2184 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2603 - accuracy: 0.9296
# Epoch 10: val_loss improved from 0.21498 to 0.20404, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 297s 2s/step - loss: 0.2603 - accuracy: 0.9296 - val_loss: 0.2040 - val_accuracy: 0.9442 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2585 - accuracy: 0.9294
# Epoch 11: val_loss did not improve from 0.20404
# 191/191 [==============================] - 295s 2s/step - loss: 0.2585 - accuracy: 0.9294 - val_loss: 0.2069 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2497 - accuracy: 0.9335
# Epoch 12: val_loss improved from 0.20404 to 0.19421, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 297s 2s/step - loss: 0.2497 - accuracy: 0.9335 - val_loss: 0.1942 - val_accuracy: 0.9457 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2480 - accuracy: 0.9342
# Epoch 13: val_loss did not improve from 0.19421
# 191/191 [==============================] - 297s 2s/step - loss: 0.2480 - accuracy: 0.9342 - val_loss: 0.2183 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.9397
# Epoch 14: val_loss did not improve from 0.19421
# 191/191 [==============================] - 293s 2s/step - loss: 0.2346 - accuracy: 0.9397 - val_loss: 0.1976 - val_accuracy: 0.9503 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2317 - accuracy: 0.9384
# Epoch 15: val_loss did not improve from 0.19421
# 191/191 [==============================] - 295s 2s/step - loss: 0.2317 - accuracy: 0.9384 - val_loss: 0.2068 - val_accuracy: 0.9381 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2348 - accuracy: 0.9371
# Epoch 16: val_loss improved from 0.19421 to 0.19032, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 295s 2s/step - loss: 0.2348 - accuracy: 0.9371 - val_loss: 0.1903 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.9378
# Epoch 17: val_loss did not improve from 0.19032
# 191/191 [==============================] - 296s 2s/step - loss: 0.2394 - accuracy: 0.9378 - val_loss: 0.1966 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2553 - accuracy: 0.9333
# Epoch 18: val_loss did not improve from 0.19032
# 191/191 [==============================] - 296s 2s/step - loss: 0.2553 - accuracy: 0.9333 - val_loss: 0.2051 - val_accuracy: 0.9472 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2369 - accuracy: 0.9381
# Epoch 19: val_loss did not improve from 0.19032
# 191/191 [==============================] - 295s 2s/step - loss: 0.2369 - accuracy: 0.9381 - val_loss: 0.2067 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9404
# Epoch 20: val_loss did not improve from 0.19032
# 191/191 [==============================] - 296s 2s/step - loss: 0.2293 - accuracy: 0.9404 - val_loss: 0.2046 - val_accuracy: 0.9503 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9365
# Epoch 21: val_loss did not improve from 0.19032
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 296s 2s/step - loss: 0.2430 - accuracy: 0.9365 - val_loss: 0.2481 - val_accuracy: 0.9335 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.9492
# Epoch 22: val_loss improved from 0.19032 to 0.19029, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 295s 2s/step - loss: 0.2088 - accuracy: 0.9492 - val_loss: 0.1903 - val_accuracy: 0.9534 - lr: 5.0000e-04
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1922 - accuracy: 0.9535
# Epoch 23: val_loss improved from 0.19029 to 0.18314, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.1922 - accuracy: 0.9535 - val_loss: 0.1831 - val_accuracy: 0.9549 - lr: 5.0000e-04
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9533
# Epoch 24: val_loss improved from 0.18314 to 0.17835, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.1917 - accuracy: 0.9533 - val_loss: 0.1783 - val_accuracy: 0.9557 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1916 - accuracy: 0.9558
# Epoch 25: val_loss improved from 0.17835 to 0.17574, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 297s 2s/step - loss: 0.1916 - accuracy: 0.9558 - val_loss: 0.1757 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9514
# Epoch 26: val_loss improved from 0.17574 to 0.17292, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.1967 - accuracy: 0.9514 - val_loss: 0.1729 - val_accuracy: 0.9602 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 0.9556
# Epoch 27: val_loss improved from 0.17292 to 0.17097, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 294s 2s/step - loss: 0.1870 - accuracy: 0.9556 - val_loss: 0.1710 - val_accuracy: 0.9633 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9622
# Epoch 28: val_loss improved from 0.17097 to 0.17000, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 295s 2s/step - loss: 0.1789 - accuracy: 0.9622 - val_loss: 0.1700 - val_accuracy: 0.9625 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1869 - accuracy: 0.9569
# Epoch 29: val_loss improved from 0.17000 to 0.16721, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.1869 - accuracy: 0.9569 - val_loss: 0.1672 - val_accuracy: 0.9610 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1906 - accuracy: 0.9551
# Epoch 30: val_loss did not improve from 0.16721
# 191/191 [==============================] - 296s 2s/step - loss: 0.1906 - accuracy: 0.9551 - val_loss: 0.1716 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9636
# Epoch 31: val_loss did not improve from 0.16721
# 191/191 [==============================] - 296s 2s/step - loss: 0.1689 - accuracy: 0.9636 - val_loss: 0.1771 - val_accuracy: 0.9602 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9559
# Epoch 32: val_loss did not improve from 0.16721
# 191/191 [==============================] - 296s 2s/step - loss: 0.1853 - accuracy: 0.9559 - val_loss: 0.1715 - val_accuracy: 0.9610 - lr: 5.0000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1727 - accuracy: 0.9615
# Epoch 33: val_loss did not improve from 0.16721
# 191/191 [==============================] - 298s 2s/step - loss: 0.1727 - accuracy: 0.9615 - val_loss: 0.1679 - val_accuracy: 0.9633 - lr: 5.0000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.9628
# Epoch 34: val_loss did not improve from 0.16721
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 298s 2s/step - loss: 0.1674 - accuracy: 0.9628 - val_loss: 0.1691 - val_accuracy: 0.9587 - lr: 5.0000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1679 - accuracy: 0.9617
# Epoch 35: val_loss improved from 0.16721 to 0.16598, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.1679 - accuracy: 0.9617 - val_loss: 0.1660 - val_accuracy: 0.9625 - lr: 2.5000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9628
# Epoch 36: val_loss did not improve from 0.16598
# 191/191 [==============================] - 297s 2s/step - loss: 0.1643 - accuracy: 0.9628 - val_loss: 0.1660 - val_accuracy: 0.9572 - lr: 2.5000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1578 - accuracy: 0.9672
# Epoch 37: val_loss improved from 0.16598 to 0.16093, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 297s 2s/step - loss: 0.1578 - accuracy: 0.9672 - val_loss: 0.1609 - val_accuracy: 0.9671 - lr: 2.5000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9646
# Epoch 38: val_loss improved from 0.16093 to 0.15648, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.1545 - accuracy: 0.9646 - val_loss: 0.1565 - val_accuracy: 0.9664 - lr: 2.5000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9640
# Epoch 39: val_loss did not improve from 0.15648
# 191/191 [==============================] - 296s 2s/step - loss: 0.1623 - accuracy: 0.9640 - val_loss: 0.1571 - val_accuracy: 0.9694 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1549 - accuracy: 0.9661
# Epoch 40: val_loss did not improve from 0.15648
# 191/191 [==============================] - 294s 2s/step - loss: 0.1549 - accuracy: 0.9661 - val_loss: 0.1614 - val_accuracy: 0.9618 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1620 - accuracy: 0.9643
# Epoch 41: val_loss did not improve from 0.15648
# 191/191 [==============================] - 297s 2s/step - loss: 0.1620 - accuracy: 0.9643 - val_loss: 0.1575 - val_accuracy: 0.9648 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9687
# Epoch 42: val_loss improved from 0.15648 to 0.15266, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.1556 - accuracy: 0.9687 - val_loss: 0.1527 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9628
# Epoch 43: val_loss did not improve from 0.15266
# 191/191 [==============================] - 294s 2s/step - loss: 0.1658 - accuracy: 0.9628 - val_loss: 0.1550 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1514 - accuracy: 0.9692
# Epoch 44: val_loss improved from 0.15266 to 0.15099, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.1514 - accuracy: 0.9692 - val_loss: 0.1510 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1601 - accuracy: 0.9622
# Epoch 45: val_loss improved from 0.15099 to 0.14909, saving model to efficientnetB1_con_ft_fase1_weights.h5
# 191/191 [==============================] - 296s 2s/step - loss: 0.1601 - accuracy: 0.9622 - val_loss: 0.1491 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1670 - accuracy: 0.9620
# Epoch 46: val_loss did not improve from 0.14909
# 191/191 [==============================] - 294s 2s/step - loss: 0.1670 - accuracy: 0.9620 - val_loss: 0.1556 - val_accuracy: 0.9671 - lr: 2.5000e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.9702
# Epoch 47: val_loss did not improve from 0.14909
# 191/191 [==============================] - 295s 2s/step - loss: 0.1499 - accuracy: 0.9702 - val_loss: 0.1569 - val_accuracy: 0.9641 - lr: 2.5000e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.9664
# Epoch 48: val_loss did not improve from 0.14909
# 191/191 [==============================] - 296s 2s/step - loss: 0.1536 - accuracy: 0.9664 - val_loss: 0.1572 - val_accuracy: 0.9656 - lr: 2.5000e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1511 - accuracy: 0.9677
# Epoch 49: val_loss did not improve from 0.14909
# 191/191 [==============================] - 298s 2s/step - loss: 0.1511 - accuracy: 0.9677 - val_loss: 0.1542 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9705
# Epoch 50: val_loss did not improve from 0.14909
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 298s 2s/step - loss: 0.1439 - accuracy: 0.9705 - val_loss: 0.1520 - val_accuracy: 0.9671 - lr: 2.5000e-04
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.9672
# Epoch 51: val_loss did not improve from 0.14909
# 191/191 [==============================] - 294s 2s/step - loss: 0.1497 - accuracy: 0.9672 - val_loss: 0.1544 - val_accuracy: 0.9641 - lr: 1.2500e-04
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1436 - accuracy: 0.9686
# Epoch 52: val_loss did not improve from 0.14909
# 191/191 [==============================] - 297s 2s/step - loss: 0.1436 - accuracy: 0.9686 - val_loss: 0.1547 - val_accuracy: 0.9687 - lr: 1.2500e-04
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1474 - accuracy: 0.9690
# Epoch 53: val_loss did not improve from 0.14909
# 191/191 [==============================] - 298s 2s/step - loss: 0.1474 - accuracy: 0.9690 - val_loss: 0.1578 - val_accuracy: 0.9648 - lr: 1.2500e-04
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9705
# Epoch 54: val_loss did not improve from 0.14909
# 191/191 [==============================] - 295s 2s/step - loss: 0.1406 - accuracy: 0.9705 - val_loss: 0.1520 - val_accuracy: 0.9694 - lr: 1.2500e-04
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9710Restoring model weights from the end of the best epoch: 45.
#
# Epoch 55: val_loss did not improve from 0.14909
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 296s 2s/step - loss: 0.1372 - accuracy: 0.9710 - val_loss: 0.1525 - val_accuracy: 0.9671 - lr: 1.2500e-04
# Epoch 55: early stopping
#
# Fase 1 completada.
# Mejor val_accuracy fase 1: 0.9717

# %% [markdown]
# ### 7. ENTRENAMIENTO — FASE 2 (fine-tuning)

# %%
# FASE 2: Fine-tuning (descongelar últimas capas del backbone)
# Las primeras capas aprenden cosas generales - las dejamos congeladas.
# Las últimas capas aprenden patrones específicos.

import tensorflow.keras.backend as K

# Paso 1: descongelar todo el backbone
base_model.trainable = True

# Paso 2: volver a congelar las primeras capas, solo descongelamos las últimas 30 capas
CAPAS_A_CONGELAR = len(base_model.layers) - 30

for i, layer in enumerate(base_model.layers):
    if i < CAPAS_A_CONGELAR:
        layer.trainable = False   # primeras capas: congeladas
    else:
        layer.trainable = True    # últimas 30 capas: descongeladas

print('FASE 2: Fine-tuning (últimas 30 capas descongeladas)')
print(f'Total capas en backbone  : {len(base_model.layers)}')
print(f'Capas congeladas         : {CAPAS_A_CONGELAR}')
print(f'Capas descongeladas      : {len(base_model.layers) - CAPAS_A_CONGELAR}')

# Paso 3: solo cambiamos el lr, No recompilamos para preservar el momentum de Adam acumulado en la Fase 1
K.set_value(model.optimizer.learning_rate, 1e-5)

early_stopping_fase2 = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES_F2,          # = 10, igual en todos los modelos
    restore_best_weights=True,
    verbose=1
)

checkpoint_fase2 = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr_fase2 = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR_F2,
    min_lr=1e-6,
    verbose=1
)

history_fase2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping_fase2, checkpoint_fase2, reduce_lr_fase2]
)

print(f'\nFase 2 completada.')
print(f'Mejor val_accuracy fase 2: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# FASE 2: Fine-tuning (últimas 30 capas descongeladas)
# Total capas en backbone  : 340
# Capas congeladas         : 310
# Capas descongeladas      : 30
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9659
# Epoch 1: val_loss improved from inf to 0.14999, saving model to efficientnetB1_con_ft_weights.h5
# 191/191 [==============================] - 295s 2s/step - loss: 0.1544 - accuracy: 0.9659 - val_loss: 0.1500 - val_accuracy: 0.9694 - lr: 1.0000e-05
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9676
# Epoch 2: val_loss did not improve from 0.14999
# 191/191 [==============================] - 296s 2s/step - loss: 0.1518 - accuracy: 0.9676 - val_loss: 0.1505 - val_accuracy: 0.9687 - lr: 1.0000e-05
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9666
# Epoch 3: val_loss did not improve from 0.14999
# 191/191 [==============================] - 294s 2s/step - loss: 0.1500 - accuracy: 0.9666 - val_loss: 0.1504 - val_accuracy: 0.9717 - lr: 1.0000e-05
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1466 - accuracy: 0.9692
# Epoch 4: val_loss did not improve from 0.14999
# 191/191 [==============================] - 293s 2s/step - loss: 0.1466 - accuracy: 0.9692 - val_loss: 0.1512 - val_accuracy: 0.9702 - lr: 1.0000e-05
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1423 - accuracy: 0.9705
# Epoch 5: val_loss did not improve from 0.14999
# 191/191 [==============================] - 295s 2s/step - loss: 0.1423 - accuracy: 0.9705 - val_loss: 0.1511 - val_accuracy: 0.9694 - lr: 1.0000e-05
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9700
# Epoch 6: val_loss did not improve from 0.14999
# 191/191 [==============================] - 295s 2s/step - loss: 0.1462 - accuracy: 0.9700 - val_loss: 0.1519 - val_accuracy: 0.9671 - lr: 1.0000e-05
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9712
# Epoch 7: val_loss did not improve from 0.14999
# 191/191 [==============================] - 294s 2s/step - loss: 0.1420 - accuracy: 0.9712 - val_loss: 0.1517 - val_accuracy: 0.9687 - lr: 1.0000e-05
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1463 - accuracy: 0.9679
# Epoch 8: val_loss did not improve from 0.14999
# 191/191 [==============================] - 295s 2s/step - loss: 0.1463 - accuracy: 0.9679 - val_loss: 0.1517 - val_accuracy: 0.9702 - lr: 1.0000e-05
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9713
# Epoch 9: val_loss did not improve from 0.14999
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 294s 2s/step - loss: 0.1419 - accuracy: 0.9713 - val_loss: 0.1521 - val_accuracy: 0.9709 - lr: 1.0000e-05
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9699
# Epoch 10: val_loss did not improve from 0.14999
# 191/191 [==============================] - 296s 2s/step - loss: 0.1446 - accuracy: 0.9699 - val_loss: 0.1519 - val_accuracy: 0.9709 - lr: 5.0000e-06
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9708
# Epoch 11: val_loss did not improve from 0.14999
# 191/191 [==============================] - 294s 2s/step - loss: 0.1414 - accuracy: 0.9708 - val_loss: 0.1521 - val_accuracy: 0.9694 - lr: 5.0000e-06
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1436 - accuracy: 0.9679
# Epoch 12: val_loss did not improve from 0.14999
# 191/191 [==============================] - 296s 2s/step - loss: 0.1436 - accuracy: 0.9679 - val_loss: 0.1522 - val_accuracy: 0.9687 - lr: 5.0000e-06
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1395 - accuracy: 0.9745
# Epoch 13: val_loss did not improve from 0.14999
# 191/191 [==============================] - 295s 2s/step - loss: 0.1395 - accuracy: 0.9745 - val_loss: 0.1522 - val_accuracy: 0.9694 - lr: 5.0000e-06
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9697
# Epoch 14: val_loss did not improve from 0.14999
# 191/191 [==============================] - 294s 2s/step - loss: 0.1425 - accuracy: 0.9697 - val_loss: 0.1523 - val_accuracy: 0.9687 - lr: 5.0000e-06
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.9718
# Epoch 15: val_loss did not improve from 0.14999
# 191/191 [==============================] - 295s 2s/step - loss: 0.1427 - accuracy: 0.9718 - val_loss: 0.1523 - val_accuracy: 0.9687 - lr: 5.0000e-06
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9695Restoring model weights from the end of the best epoch: 1.
#
# Epoch 16: val_loss did not improve from 0.14999
# 191/191 [==============================] - 293s 2s/step - loss: 0.1446 - accuracy: 0.9695 - val_loss: 0.1523 - val_accuracy: 0.9687 - lr: 5.0000e-06
# Epoch 16: early stopping
#
# Fase 2 completada.
# Mejor val_accuracy fase 2: 0.9717

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO (Fase 1 + Fase 2)

# %%
acc      = history_fase1.history['accuracy']     + history_fase2.history['accuracy']
val_acc  = history_fase1.history['val_accuracy'] + history_fase2.history['val_accuracy']
loss     = history_fase1.history['loss']         + history_fase2.history['loss']
val_loss = history_fase1.history['val_loss']     + history_fase2.history['val_loss']

epochs_total = range(1, len(acc) + 1)
corte        = len(history_fase1.history['accuracy'])

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_total, acc,     label='Train')
ax1.plot(epochs_total, val_acc, label='Validación')
ax1.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs_total, loss,     label='Train')
ax2.plot(epochs_total, val_loss, label='Validación')
ax2.axvline(x=corte, color='red', linestyle='--', label='Inicio fine-tuning')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nFase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}')
print(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}')
# Out:
# Fase 1 — mejor val_accuracy: 0.9717
# Fase 2 — mejor val_accuracy: 0.9717

# %% [markdown]
# ### 9. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write(f'Fase 1 — mejor val_accuracy: {max(history_fase1.history["val_accuracy"]):.4f}\n')
    f.write(f'Fase 2 — mejor val_accuracy: {max(history_fase2.history["val_accuracy"]):.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 38s 924ms/step - loss: 0.1286 - accuracy: 0.9748
#
# Test Accuracy : 0.9748
# Test Loss     : 0.1286
# 41/41 [==============================] - 40s 921ms/step
# F1 Score      : 0.9748
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9671    0.9800    0.9735       150
#    mancha_anillo     1.0000    1.0000    1.0000       105
#     mancha_parda     0.9932    0.9800    0.9866       150
#          mosaico     0.9662    0.9533    0.9597       150
#      muermo_rojo     0.9477    0.9667    0.9571       150
#             roya     0.9660    0.9467    0.9562       150
#            sanas     0.9412    0.9600    0.9505       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     1.0000    0.9933    0.9967       150
#
#         accuracy                         0.9748      1308
#        macro avg     0.9781    0.9780    0.9780      1308
#     weighted avg     0.9749    0.9748    0.9748      1308
#
#
# Resultados guardados en efficientnetB1_con_ft_resultados.txt

# %% [markdown]
# ### 10. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]
class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL           = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 1 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]
print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]
    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()
    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9, color='red'
        )
        axes[j].axis('off')
    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')
    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14, fontweight='bold', y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 1 o más confusiones:
#   mosaico → sanas: 6 imágenes
#   roya → muermo_rojo: 5 imágenes
#   sanas → mosaico: 4 imágenes
#   hoja_amarilla → roya: 2 imágenes
#   mancha_parda → hoja_amarilla: 2 imágenes
#   muermo_rojo → roya: 2 imágenes
#   hoja_amarilla → sanas: 1 imágenes
#   mancha_parda → muermo_rojo: 1 imágenes
#   mosaico → muermo_rojo: 1 imágenes
#   muermo_rojo → hoja_amarilla: 1 imágenes
#   muermo_rojo → sanas: 1 imágenes
#   muermo_rojo → mancha_parda: 1 imágenes
#   roya → sanas: 1 imágenes
#   roya → hoja_amarilla: 1 imágenes
#   roya → mosaico: 1 imágenes
#   sanas → roya: 1 imágenes
#   sanas → hoja_amarilla: 1 imágenes
#   tizon_bacteriano → muermo_rojo: 1 imágenes
#
# Total de imágenes a mostrar: 33

# %% [markdown]
# ### 12. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB1_con_ft_weights.h5
