# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE          = 224
BATCH_SIZE        = 32
EPOCHS            = 75
PATIENCE_ES       = 10    # Early Stopping, para cuando el modelo deja de mejorar
PATIENCE_LR       = 5     # ReduceLROnPlateau, para bajar el learning rate
NUM_CLASSES       = 10
NOMBRE_MODELO     = "densenet201_TL"

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO DENSENET-201

# %%
# CARGAR DENSENET-201 CON PESOS DE IMAGENET

base_model = DenseNet201(
    weights='imagenet',                 
    include_top=False,                  
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Congelamos la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               245888
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 18,569,162
# Trainable params: 247,178
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{NOMBRE_MODELO}_weights.h5",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.9949 - accuracy: 0.6702
# Epoch 1: val_loss improved from inf to 0.31876, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 455s 2s/step - loss: 0.9949 - accuracy: 0.6702 - val_loss: 0.3188 - val_accuracy: 0.9060 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4498 - accuracy: 0.8587
# Epoch 2: val_loss improved from 0.31876 to 0.21006, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 434s 2s/step - loss: 0.4498 - accuracy: 0.8587 - val_loss: 0.2101 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3517 - accuracy: 0.8888
# Epoch 3: val_loss improved from 0.21006 to 0.18192, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 435s 2s/step - loss: 0.3517 - accuracy: 0.8888 - val_loss: 0.1819 - val_accuracy: 0.9434 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2990 - accuracy: 0.9062
# Epoch 4: val_loss improved from 0.18192 to 0.14658, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 434s 2s/step - loss: 0.2990 - accuracy: 0.9062 - val_loss: 0.1466 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2474 - accuracy: 0.9230
# Epoch 5: val_loss improved from 0.14658 to 0.13633, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 432s 2s/step - loss: 0.2474 - accuracy: 0.9230 - val_loss: 0.1363 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.9204
# Epoch 6: val_loss improved from 0.13633 to 0.13424, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 432s 2s/step - loss: 0.2434 - accuracy: 0.9204 - val_loss: 0.1342 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2200 - accuracy: 0.9311
# Epoch 7: val_loss improved from 0.13424 to 0.11411, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 432s 2s/step - loss: 0.2200 - accuracy: 0.9311 - val_loss: 0.1141 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2014 - accuracy: 0.9353
# Epoch 8: val_loss improved from 0.11411 to 0.11042, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 434s 2s/step - loss: 0.2014 - accuracy: 0.9353 - val_loss: 0.1104 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2020 - accuracy: 0.9350
# Epoch 9: val_loss did not improve from 0.11042
# 191/191 [==============================] - 431s 2s/step - loss: 0.2020 - accuracy: 0.9350 - val_loss: 0.1223 - val_accuracy: 0.9572 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1908 - accuracy: 0.9384
# Epoch 10: val_loss improved from 0.11042 to 0.10769, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 433s 2s/step - loss: 0.1908 - accuracy: 0.9384 - val_loss: 0.1077 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1814 - accuracy: 0.9407
# Epoch 11: val_loss did not improve from 0.10769
# 191/191 [==============================] - 433s 2s/step - loss: 0.1814 - accuracy: 0.9407 - val_loss: 0.1216 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1817 - accuracy: 0.9374
# Epoch 12: val_loss improved from 0.10769 to 0.09675, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 434s 2s/step - loss: 0.1817 - accuracy: 0.9374 - val_loss: 0.0968 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.9430
# Epoch 13: val_loss did not improve from 0.09675
# 191/191 [==============================] - 433s 2s/step - loss: 0.1714 - accuracy: 0.9430 - val_loss: 0.1055 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1758 - accuracy: 0.9455
# Epoch 14: val_loss did not improve from 0.09675
# 191/191 [==============================] - 433s 2s/step - loss: 0.1758 - accuracy: 0.9455 - val_loss: 0.1014 - val_accuracy: 0.9625 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.9519
# Epoch 15: val_loss improved from 0.09675 to 0.08951, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 432s 2s/step - loss: 0.1542 - accuracy: 0.9519 - val_loss: 0.0895 - val_accuracy: 0.9732 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1511 - accuracy: 0.9505
# Epoch 16: val_loss did not improve from 0.08951
# 191/191 [==============================] - 435s 2s/step - loss: 0.1511 - accuracy: 0.9505 - val_loss: 0.1119 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1562 - accuracy: 0.9474
# Epoch 17: val_loss did not improve from 0.08951
# 191/191 [==============================] - 432s 2s/step - loss: 0.1562 - accuracy: 0.9474 - val_loss: 0.1008 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9451
# Epoch 18: val_loss improved from 0.08951 to 0.08353, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 437s 2s/step - loss: 0.1567 - accuracy: 0.9451 - val_loss: 0.0835 - val_accuracy: 0.9763 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9520
# Epoch 19: val_loss did not improve from 0.08353
# 191/191 [==============================] - 432s 2s/step - loss: 0.1446 - accuracy: 0.9520 - val_loss: 0.0933 - val_accuracy: 0.9763 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1511 - accuracy: 0.9491
# Epoch 20: val_loss did not improve from 0.08353
# 191/191 [==============================] - 433s 2s/step - loss: 0.1511 - accuracy: 0.9491 - val_loss: 0.0953 - val_accuracy: 0.9709 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9519
# Epoch 21: val_loss did not improve from 0.08353
# 191/191 [==============================] - 468s 2s/step - loss: 0.1431 - accuracy: 0.9519 - val_loss: 0.1018 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9550
# Epoch 22: val_loss did not improve from 0.08353
# 191/191 [==============================] - 455s 2s/step - loss: 0.1343 - accuracy: 0.9550 - val_loss: 0.0900 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9479
# Epoch 23: val_loss did not improve from 0.08353
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 436s 2s/step - loss: 0.1517 - accuracy: 0.9479 - val_loss: 0.1105 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9663
# Epoch 24: val_loss did not improve from 0.08353
# 191/191 [==============================] - 428s 2s/step - loss: 0.1012 - accuracy: 0.9663 - val_loss: 0.0942 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9651
# Epoch 25: val_loss did not improve from 0.08353
# 191/191 [==============================] - 419s 2s/step - loss: 0.1043 - accuracy: 0.9651 - val_loss: 0.0888 - val_accuracy: 0.9732 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9650
# Epoch 26: val_loss did not improve from 0.08353
# 191/191 [==============================] - 444s 2s/step - loss: 0.1060 - accuracy: 0.9650 - val_loss: 0.0851 - val_accuracy: 0.9755 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1008 - accuracy: 0.9659
# Epoch 27: val_loss improved from 0.08353 to 0.08101, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 448s 2s/step - loss: 0.1008 - accuracy: 0.9659 - val_loss: 0.0810 - val_accuracy: 0.9740 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9640
# Epoch 28: val_loss improved from 0.08101 to 0.07859, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 437s 2s/step - loss: 0.1085 - accuracy: 0.9640 - val_loss: 0.0786 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 0.9668
# Epoch 29: val_loss did not improve from 0.07859
# 191/191 [==============================] - 434s 2s/step - loss: 0.1007 - accuracy: 0.9668 - val_loss: 0.0824 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9651
# Epoch 30: val_loss did not improve from 0.07859
# 191/191 [==============================] - 435s 2s/step - loss: 0.1018 - accuracy: 0.9651 - val_loss: 0.0831 - val_accuracy: 0.9755 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9650
# Epoch 31: val_loss did not improve from 0.07859
# 191/191 [==============================] - 434s 2s/step - loss: 0.1062 - accuracy: 0.9650 - val_loss: 0.0829 - val_accuracy: 0.9740 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0992 - accuracy: 0.9684
# Epoch 32: val_loss did not improve from 0.07859
# 191/191 [==============================] - 437s 2s/step - loss: 0.0992 - accuracy: 0.9684 - val_loss: 0.0853 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9648
# Epoch 33: val_loss improved from 0.07859 to 0.07528, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 436s 2s/step - loss: 0.1031 - accuracy: 0.9648 - val_loss: 0.0753 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0944 - accuracy: 0.9710
# Epoch 34: val_loss did not improve from 0.07528
# 191/191 [==============================] - 436s 2s/step - loss: 0.0944 - accuracy: 0.9710 - val_loss: 0.0874 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.9712
# Epoch 35: val_loss did not improve from 0.07528
# 191/191 [==============================] - 435s 2s/step - loss: 0.0869 - accuracy: 0.9712 - val_loss: 0.0826 - val_accuracy: 0.9732 - lr: 5.0000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0864 - accuracy: 0.9697
# Epoch 36: val_loss did not improve from 0.07528
# 191/191 [==============================] - 433s 2s/step - loss: 0.0864 - accuracy: 0.9697 - val_loss: 0.0803 - val_accuracy: 0.9771 - lr: 5.0000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9666
# Epoch 37: val_loss did not improve from 0.07528
# 191/191 [==============================] - 436s 2s/step - loss: 0.0931 - accuracy: 0.9666 - val_loss: 0.0923 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9674
# Epoch 38: val_loss improved from 0.07528 to 0.07071, saving model to densenet201_sin_ft_weights.h5
# 191/191 [==============================] - 436s 2s/step - loss: 0.0926 - accuracy: 0.9674 - val_loss: 0.0707 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9731
# Epoch 39: val_loss did not improve from 0.07071
# 191/191 [==============================] - 436s 2s/step - loss: 0.0858 - accuracy: 0.9731 - val_loss: 0.0781 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9689
# Epoch 40: val_loss did not improve from 0.07071
# 191/191 [==============================] - 433s 2s/step - loss: 0.0872 - accuracy: 0.9689 - val_loss: 0.0806 - val_accuracy: 0.9778 - lr: 5.0000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 0.9720
# Epoch 41: val_loss did not improve from 0.07071
# 191/191 [==============================] - 434s 2s/step - loss: 0.0857 - accuracy: 0.9720 - val_loss: 0.0760 - val_accuracy: 0.9740 - lr: 5.0000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9705
# Epoch 42: val_loss did not improve from 0.07071
# 191/191 [==============================] - 439s 2s/step - loss: 0.0892 - accuracy: 0.9705 - val_loss: 0.0834 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 0.9699
# Epoch 43: val_loss did not improve from 0.07071
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 437s 2s/step - loss: 0.0922 - accuracy: 0.9699 - val_loss: 0.0801 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9751
# Epoch 44: val_loss did not improve from 0.07071
# 191/191 [==============================] - 435s 2s/step - loss: 0.0723 - accuracy: 0.9751 - val_loss: 0.0732 - val_accuracy: 0.9786 - lr: 2.5000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9745
# Epoch 45: val_loss did not improve from 0.07071
# 191/191 [==============================] - 435s 2s/step - loss: 0.0770 - accuracy: 0.9745 - val_loss: 0.0789 - val_accuracy: 0.9786 - lr: 2.5000e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9754
# Epoch 46: val_loss did not improve from 0.07071
# 191/191 [==============================] - 434s 2s/step - loss: 0.0743 - accuracy: 0.9754 - val_loss: 0.0758 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9759
# Epoch 47: val_loss did not improve from 0.07071
# 191/191 [==============================] - 435s 2s/step - loss: 0.0776 - accuracy: 0.9759 - val_loss: 0.0765 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9790Restoring model weights from the end of the best epoch: 38.
#
# Epoch 48: val_loss did not improve from 0.07071
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 434s 2s/step - loss: 0.0652 - accuracy: 0.9790 - val_loss: 0.0712 - val_accuracy: 0.9809 - lr: 2.5000e-04
# Epoch 48: early stopping

# %% [markdown]
# ### 7. EVALUACIÓN DEL MODELO DENSENET-201

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

# Gráfica de Loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 73s 2s/step - loss: 0.0501 - accuracy: 0.9801
#
# Test Accuracy : 0.9801
# Test Loss     : 0.0501
# 41/41 [==============================] - 78s 2s/step
# F1 Score      : 0.9802
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9799    0.9733    0.9766       150
#    mancha_anillo     1.0000    1.0000    1.0000       105
#     mancha_parda     0.9932    0.9733    0.9832       150
#          mosaico     0.9796    0.9600    0.9697       150
#      muermo_rojo     0.9484    0.9800    0.9639       150
#             roya     0.9799    0.9733    0.9766       150
#            sanas     0.9610    0.9867    0.9737       150
#            secas     0.9873    1.0000    0.9936        78
# tizon_bacteriano     0.9932    0.9800    0.9866       150
#
#         accuracy                         0.9801      1308
#        macro avg     0.9823    0.9827    0.9824      1308
#     weighted avg     0.9803    0.9801    0.9802      1308
#
#
# Resultados guardados en densenet201_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Pares con 5 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#   mosaico → sanas: 5 imágenes
#
# Total de imágenes a mostrar: 5

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: densenet201_sin_ft_weights.h5
