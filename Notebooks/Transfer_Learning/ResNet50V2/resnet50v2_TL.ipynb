# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.applications.resnet_v2 import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = 'resnet50v2_TL'

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO RESNET50-V2

# %%
# CARGAR RESNET-50-V2

base_model = ResNet50V2(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False    # Congelamos toda la red base 

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 15s 0us/step

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 23,828,362
# Trainable params: 263,562
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 1.0514 - accuracy: 0.6405
# Epoch 1: val_loss improved from inf to 0.47246, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 396s 2s/step - loss: 1.0514 - accuracy: 0.6405 - val_loss: 0.4725 - val_accuracy: 0.8433 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.6132 - accuracy: 0.7943
# Epoch 2: val_loss improved from 0.47246 to 0.34606, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 399s 2s/step - loss: 0.6132 - accuracy: 0.7943 - val_loss: 0.3461 - val_accuracy: 0.8838 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.5114 - accuracy: 0.8241
# Epoch 3: val_loss improved from 0.34606 to 0.30527, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 406s 2s/step - loss: 0.5114 - accuracy: 0.8241 - val_loss: 0.3053 - val_accuracy: 0.8991 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4569 - accuracy: 0.8485
# Epoch 4: val_loss improved from 0.30527 to 0.26723, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 418s 2s/step - loss: 0.4569 - accuracy: 0.8485 - val_loss: 0.2672 - val_accuracy: 0.9205 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4299 - accuracy: 0.8552
# Epoch 5: val_loss improved from 0.26723 to 0.25009, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 383s 2s/step - loss: 0.4299 - accuracy: 0.8552 - val_loss: 0.2501 - val_accuracy: 0.9251 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3914 - accuracy: 0.8709
# Epoch 6: val_loss did not improve from 0.25009
# 191/191 [==============================] - 420s 2s/step - loss: 0.3914 - accuracy: 0.8709 - val_loss: 0.2510 - val_accuracy: 0.9128 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3641 - accuracy: 0.8768
# Epoch 7: val_loss improved from 0.25009 to 0.22619, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 532s 3s/step - loss: 0.3641 - accuracy: 0.8768 - val_loss: 0.2262 - val_accuracy: 0.9320 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3550 - accuracy: 0.8850
# Epoch 8: val_loss improved from 0.22619 to 0.22025, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 539s 3s/step - loss: 0.3550 - accuracy: 0.8850 - val_loss: 0.2203 - val_accuracy: 0.9304 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.8827
# Epoch 9: val_loss improved from 0.22025 to 0.18811, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 526s 3s/step - loss: 0.3451 - accuracy: 0.8827 - val_loss: 0.1881 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.8888
# Epoch 10: val_loss did not improve from 0.18811
# 191/191 [==============================] - 545s 3s/step - loss: 0.3265 - accuracy: 0.8888 - val_loss: 0.2043 - val_accuracy: 0.9343 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3205 - accuracy: 0.8942
# Epoch 11: val_loss did not improve from 0.18811
# 191/191 [==============================] - 471s 2s/step - loss: 0.3205 - accuracy: 0.8942 - val_loss: 0.2027 - val_accuracy: 0.9358 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.9001
# Epoch 12: val_loss did not improve from 0.18811
# 191/191 [==============================] - 487s 3s/step - loss: 0.3034 - accuracy: 0.9001 - val_loss: 0.2074 - val_accuracy: 0.9343 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2997 - accuracy: 0.8998
# Epoch 13: val_loss did not improve from 0.18811
# 191/191 [==============================] - 390s 2s/step - loss: 0.2997 - accuracy: 0.8998 - val_loss: 0.1909 - val_accuracy: 0.9358 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2913 - accuracy: 0.9026
# Epoch 14: val_loss did not improve from 0.18811
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 405s 2s/step - loss: 0.2913 - accuracy: 0.9026 - val_loss: 0.1950 - val_accuracy: 0.9404 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2566 - accuracy: 0.9158
# Epoch 15: val_loss did not improve from 0.18811
# 191/191 [==============================] - 378s 2s/step - loss: 0.2566 - accuracy: 0.9158 - val_loss: 0.1883 - val_accuracy: 0.9419 - lr: 5.0000e-04
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.9099
# Epoch 16: val_loss improved from 0.18811 to 0.17447, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 394s 2s/step - loss: 0.2544 - accuracy: 0.9099 - val_loss: 0.1745 - val_accuracy: 0.9419 - lr: 5.0000e-04
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2520 - accuracy: 0.9152
# Epoch 17: val_loss did not improve from 0.17447
# 191/191 [==============================] - 385s 2s/step - loss: 0.2520 - accuracy: 0.9152 - val_loss: 0.1812 - val_accuracy: 0.9442 - lr: 5.0000e-04
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9268
# Epoch 18: val_loss improved from 0.17447 to 0.16584, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 495s 3s/step - loss: 0.2241 - accuracy: 0.9268 - val_loss: 0.1658 - val_accuracy: 0.9503 - lr: 5.0000e-04
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2382 - accuracy: 0.9225
# Epoch 19: val_loss improved from 0.16584 to 0.15663, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 576s 3s/step - loss: 0.2382 - accuracy: 0.9225 - val_loss: 0.1566 - val_accuracy: 0.9564 - lr: 5.0000e-04
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2246 - accuracy: 0.9252
# Epoch 20: val_loss did not improve from 0.15663
# 191/191 [==============================] - 436s 2s/step - loss: 0.2246 - accuracy: 0.9252 - val_loss: 0.1803 - val_accuracy: 0.9465 - lr: 5.0000e-04
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2214 - accuracy: 0.9268
# Epoch 21: val_loss improved from 0.15663 to 0.15650, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 405s 2s/step - loss: 0.2214 - accuracy: 0.9268 - val_loss: 0.1565 - val_accuracy: 0.9480 - lr: 5.0000e-04
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2108 - accuracy: 0.9296
# Epoch 22: val_loss did not improve from 0.15650
# 191/191 [==============================] - 447s 2s/step - loss: 0.2108 - accuracy: 0.9296 - val_loss: 0.1763 - val_accuracy: 0.9472 - lr: 5.0000e-04
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9253
# Epoch 23: val_loss did not improve from 0.15650
# 191/191 [==============================] - 445s 2s/step - loss: 0.2224 - accuracy: 0.9253 - val_loss: 0.1593 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.9315
# Epoch 24: val_loss improved from 0.15650 to 0.15479, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 424s 2s/step - loss: 0.2138 - accuracy: 0.9315 - val_loss: 0.1548 - val_accuracy: 0.9495 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2143 - accuracy: 0.9302
# Epoch 25: val_loss improved from 0.15479 to 0.14485, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 420s 2s/step - loss: 0.2143 - accuracy: 0.9302 - val_loss: 0.1449 - val_accuracy: 0.9549 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9291
# Epoch 26: val_loss did not improve from 0.14485
# 191/191 [==============================] - 401s 2s/step - loss: 0.2086 - accuracy: 0.9291 - val_loss: 0.1475 - val_accuracy: 0.9534 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2096 - accuracy: 0.9306
# Epoch 27: val_loss did not improve from 0.14485
# 191/191 [==============================] - 395s 2s/step - loss: 0.2096 - accuracy: 0.9306 - val_loss: 0.1536 - val_accuracy: 0.9549 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2106 - accuracy: 0.9278
# Epoch 28: val_loss did not improve from 0.14485
# 191/191 [==============================] - 413s 2s/step - loss: 0.2106 - accuracy: 0.9278 - val_loss: 0.1489 - val_accuracy: 0.9541 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2134 - accuracy: 0.9317
# Epoch 29: val_loss did not improve from 0.14485
# 191/191 [==============================] - 446s 2s/step - loss: 0.2134 - accuracy: 0.9317 - val_loss: 0.1450 - val_accuracy: 0.9587 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2017 - accuracy: 0.9356
# Epoch 30: val_loss did not improve from 0.14485
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 444s 2s/step - loss: 0.2017 - accuracy: 0.9356 - val_loss: 0.1566 - val_accuracy: 0.9518 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9404
# Epoch 31: val_loss improved from 0.14485 to 0.14387, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 419s 2s/step - loss: 0.1820 - accuracy: 0.9404 - val_loss: 0.1439 - val_accuracy: 0.9557 - lr: 2.5000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9412
# Epoch 32: val_loss improved from 0.14387 to 0.13957, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 411s 2s/step - loss: 0.1778 - accuracy: 0.9412 - val_loss: 0.1396 - val_accuracy: 0.9580 - lr: 2.5000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9414
# Epoch 33: val_loss did not improve from 0.13957
# 191/191 [==============================] - 419s 2s/step - loss: 0.1742 - accuracy: 0.9414 - val_loss: 0.1436 - val_accuracy: 0.9526 - lr: 2.5000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1704 - accuracy: 0.9389
# Epoch 34: val_loss did not improve from 0.13957
# 191/191 [==============================] - 416s 2s/step - loss: 0.1704 - accuracy: 0.9389 - val_loss: 0.1483 - val_accuracy: 0.9526 - lr: 2.5000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1629 - accuracy: 0.9492
# Epoch 35: val_loss improved from 0.13957 to 0.13703, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 427s 2s/step - loss: 0.1629 - accuracy: 0.9492 - val_loss: 0.1370 - val_accuracy: 0.9580 - lr: 2.5000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.9443
# Epoch 36: val_loss did not improve from 0.13703
# 191/191 [==============================] - 436s 2s/step - loss: 0.1685 - accuracy: 0.9443 - val_loss: 0.1406 - val_accuracy: 0.9610 - lr: 2.5000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1737 - accuracy: 0.9424
# Epoch 37: val_loss did not improve from 0.13703
# 191/191 [==============================] - 443s 2s/step - loss: 0.1737 - accuracy: 0.9424 - val_loss: 0.1434 - val_accuracy: 0.9564 - lr: 2.5000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1765 - accuracy: 0.9445
# Epoch 38: val_loss did not improve from 0.13703
# 191/191 [==============================] - 452s 2s/step - loss: 0.1765 - accuracy: 0.9445 - val_loss: 0.1382 - val_accuracy: 0.9602 - lr: 2.5000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1684 - accuracy: 0.9446
# Epoch 39: val_loss did not improve from 0.13703
# 191/191 [==============================] - 427s 2s/step - loss: 0.1684 - accuracy: 0.9446 - val_loss: 0.1442 - val_accuracy: 0.9549 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.9433
# Epoch 40: val_loss did not improve from 0.13703
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 412s 2s/step - loss: 0.1597 - accuracy: 0.9433 - val_loss: 0.1416 - val_accuracy: 0.9572 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1579 - accuracy: 0.9478
# Epoch 41: val_loss did not improve from 0.13703
# 191/191 [==============================] - 410s 2s/step - loss: 0.1579 - accuracy: 0.9478 - val_loss: 0.1384 - val_accuracy: 0.9572 - lr: 1.2500e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1548 - accuracy: 0.9507
# Epoch 42: val_loss improved from 0.13703 to 0.13399, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 411s 2s/step - loss: 0.1548 - accuracy: 0.9507 - val_loss: 0.1340 - val_accuracy: 0.9587 - lr: 1.2500e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9484
# Epoch 43: val_loss did not improve from 0.13399
# 191/191 [==============================] - 414s 2s/step - loss: 0.1600 - accuracy: 0.9484 - val_loss: 0.1349 - val_accuracy: 0.9595 - lr: 1.2500e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1670 - accuracy: 0.9460
# Epoch 44: val_loss improved from 0.13399 to 0.13379, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 424s 2s/step - loss: 0.1670 - accuracy: 0.9460 - val_loss: 0.1338 - val_accuracy: 0.9572 - lr: 1.2500e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.9517
# Epoch 45: val_loss did not improve from 0.13379
# 191/191 [==============================] - 429s 2s/step - loss: 0.1477 - accuracy: 0.9517 - val_loss: 0.1343 - val_accuracy: 0.9549 - lr: 1.2500e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1574 - accuracy: 0.9486
# Epoch 46: val_loss did not improve from 0.13379
# 191/191 [==============================] - 441s 2s/step - loss: 0.1574 - accuracy: 0.9486 - val_loss: 0.1349 - val_accuracy: 0.9602 - lr: 1.2500e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1618 - accuracy: 0.9476
# Epoch 47: val_loss improved from 0.13379 to 0.13297, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 454s 2s/step - loss: 0.1618 - accuracy: 0.9476 - val_loss: 0.1330 - val_accuracy: 0.9618 - lr: 1.2500e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1508 - accuracy: 0.9504
# Epoch 48: val_loss improved from 0.13297 to 0.12710, saving model to resnet50v2_sin_ft_weights.h5
# 191/191 [==============================] - 438s 2s/step - loss: 0.1508 - accuracy: 0.9504 - val_loss: 0.1271 - val_accuracy: 0.9625 - lr: 1.2500e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9519
# Epoch 49: val_loss did not improve from 0.12710
# 191/191 [==============================] - 409s 2s/step - loss: 0.1495 - accuracy: 0.9519 - val_loss: 0.1294 - val_accuracy: 0.9618 - lr: 1.2500e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1471 - accuracy: 0.9512
# Epoch 50: val_loss did not improve from 0.12710
# 191/191 [==============================] - 409s 2s/step - loss: 0.1471 - accuracy: 0.9512 - val_loss: 0.1297 - val_accuracy: 0.9564 - lr: 1.2500e-04
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9463
# Epoch 51: val_loss did not improve from 0.12710
# 191/191 [==============================] - 407s 2s/step - loss: 0.1576 - accuracy: 0.9463 - val_loss: 0.1324 - val_accuracy: 0.9564 - lr: 1.2500e-04
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1448 - accuracy: 0.9533
# Epoch 52: val_loss did not improve from 0.12710
# 191/191 [==============================] - 413s 2s/step - loss: 0.1448 - accuracy: 0.9533 - val_loss: 0.1336 - val_accuracy: 0.9610 - lr: 1.2500e-04
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1311 - accuracy: 0.9556
# Epoch 53: val_loss did not improve from 0.12710
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 419s 2s/step - loss: 0.1311 - accuracy: 0.9556 - val_loss: 0.1292 - val_accuracy: 0.9618 - lr: 1.2500e-04
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.9522
# Epoch 54: val_loss did not improve from 0.12710
# 191/191 [==============================] - 456s 2s/step - loss: 0.1412 - accuracy: 0.9522 - val_loss: 0.1338 - val_accuracy: 0.9625 - lr: 6.2500e-05
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9520
# Epoch 55: val_loss did not improve from 0.12710
# 191/191 [==============================] - 448s 2s/step - loss: 0.1486 - accuracy: 0.9520 - val_loss: 0.1278 - val_accuracy: 0.9625 - lr: 6.2500e-05
# Epoch 56/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9530
# Epoch 56: val_loss did not improve from 0.12710
# 191/191 [==============================] - 452s 2s/step - loss: 0.1393 - accuracy: 0.9530 - val_loss: 0.1291 - val_accuracy: 0.9610 - lr: 6.2500e-05
# Epoch 57/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9551
# Epoch 57: val_loss did not improve from 0.12710
# 191/191 [==============================] - 417s 2s/step - loss: 0.1360 - accuracy: 0.9551 - val_loss: 0.1314 - val_accuracy: 0.9595 - lr: 6.2500e-05
# Epoch 58/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9546Restoring model weights from the end of the best epoch: 48.
#
# Epoch 58: val_loss did not improve from 0.12710
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 191/191 [==============================] - 408s 2s/step - loss: 0.1408 - accuracy: 0.9546 - val_loss: 0.1282 - val_accuracy: 0.9618 - lr: 6.2500e-05
# Epoch 58: early stopping

# %% [markdown]
# ### 7. CURVAS DE ENTRENAMIENTO

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 67s 2s/step - loss: 0.0898 - accuracy: 0.9732
#
# Test Accuracy : 0.9732
# Test Loss     : 0.0898
# 41/41 [==============================] - 67s 2s/step
# F1 Score      : 0.9733
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9669    0.9733    0.9701       150
#    mancha_anillo     1.0000    1.0000    1.0000       105
#     mancha_parda     0.9671    0.9800    0.9735       150
#          mosaico     0.9863    0.9600    0.9730       150
#      muermo_rojo     0.9286    0.9533    0.9408       150
#             roya     0.9728    0.9533    0.9630       150
#            sanas     0.9481    0.9733    0.9605       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     1.0000    0.9733    0.9865       150
#
#         accuracy                         0.9732      1308
#        macro avg     0.9770    0.9767    0.9767      1308
#     weighted avg     0.9736    0.9732    0.9733      1308
#
#
# Resultados guardados en resnet50v2_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL          = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 5 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#   mosaico → sanas: 5 imágenes
#
# Total de imágenes a mostrar: 5

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: resnet50v2_sin_ft_weights.h5
