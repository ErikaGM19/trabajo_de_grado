# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB2
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE      = 260
BATCH_SIZE    = 32
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = "efficientnetB2_TL"

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFIENTNETB2

# %%
# CARGAR EFFICIENTNET-B2 CON PESOS DE IMAGENET

base_model = EfficientNetB2(
    weights='imagenet',                 
    include_top=False,                  
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Congelamos la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb2 (Functional)  (None, 9, 9, 1408)       7768569
#
#  global_average_pooling2d (G  (None, 1408)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               180352
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 7,950,211
# Trainable params: 181,642
# Non-trainable params: 7,768,569
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{NOMBRE_MODELO}_weights.h5",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.8954 - accuracy: 0.7042
# Epoch 1: val_loss improved from inf to 0.38125, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 330s 2s/step - loss: 0.8954 - accuracy: 0.7042 - val_loss: 0.3813 - val_accuracy: 0.8800 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4419 - accuracy: 0.8565
# Epoch 2: val_loss improved from 0.38125 to 0.25369, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 315s 2s/step - loss: 0.4419 - accuracy: 0.8565 - val_loss: 0.2537 - val_accuracy: 0.9258 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3404 - accuracy: 0.8863
# Epoch 3: val_loss improved from 0.25369 to 0.20855, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 311s 2s/step - loss: 0.3404 - accuracy: 0.8863 - val_loss: 0.2086 - val_accuracy: 0.9335 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3058 - accuracy: 0.9027
# Epoch 4: val_loss improved from 0.20855 to 0.19997, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 304s 2s/step - loss: 0.3058 - accuracy: 0.9027 - val_loss: 0.2000 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.9044
# Epoch 5: val_loss improved from 0.19997 to 0.17464, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 306s 2s/step - loss: 0.2871 - accuracy: 0.9044 - val_loss: 0.1746 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2625 - accuracy: 0.9186
# Epoch 6: val_loss improved from 0.17464 to 0.16278, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 313s 2s/step - loss: 0.2625 - accuracy: 0.9186 - val_loss: 0.1628 - val_accuracy: 0.9442 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2391 - accuracy: 0.9204
# Epoch 7: val_loss improved from 0.16278 to 0.15722, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 309s 2s/step - loss: 0.2391 - accuracy: 0.9204 - val_loss: 0.1572 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2444 - accuracy: 0.9230
# Epoch 8: val_loss did not improve from 0.15722
# 191/191 [==============================] - 310s 2s/step - loss: 0.2444 - accuracy: 0.9230 - val_loss: 0.1741 - val_accuracy: 0.9388 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2319 - accuracy: 0.9255
# Epoch 9: val_loss did not improve from 0.15722
# 191/191 [==============================] - 318s 2s/step - loss: 0.2319 - accuracy: 0.9255 - val_loss: 0.1700 - val_accuracy: 0.9411 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2123 - accuracy: 0.9278
# Epoch 10: val_loss improved from 0.15722 to 0.13767, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 316s 2s/step - loss: 0.2123 - accuracy: 0.9278 - val_loss: 0.1377 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2068 - accuracy: 0.9312
# Epoch 11: val_loss improved from 0.13767 to 0.12217, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 310s 2s/step - loss: 0.2068 - accuracy: 0.9312 - val_loss: 0.1222 - val_accuracy: 0.9595 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1924 - accuracy: 0.9386
# Epoch 12: val_loss did not improve from 0.12217
# 191/191 [==============================] - 317s 2s/step - loss: 0.1924 - accuracy: 0.9386 - val_loss: 0.1490 - val_accuracy: 0.9518 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9350
# Epoch 13: val_loss did not improve from 0.12217
# 191/191 [==============================] - 309s 2s/step - loss: 0.1983 - accuracy: 0.9350 - val_loss: 0.1595 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9384
# Epoch 14: val_loss improved from 0.12217 to 0.12035, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 316s 2s/step - loss: 0.1842 - accuracy: 0.9384 - val_loss: 0.1204 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1767 - accuracy: 0.9415
# Epoch 15: val_loss improved from 0.12035 to 0.11942, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 316s 2s/step - loss: 0.1767 - accuracy: 0.9415 - val_loss: 0.1194 - val_accuracy: 0.9625 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1743 - accuracy: 0.9433
# Epoch 16: val_loss did not improve from 0.11942
# 191/191 [==============================] - 308s 2s/step - loss: 0.1743 - accuracy: 0.9433 - val_loss: 0.1224 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1809 - accuracy: 0.9401
# Epoch 17: val_loss did not improve from 0.11942
# 191/191 [==============================] - 312s 2s/step - loss: 0.1809 - accuracy: 0.9401 - val_loss: 0.1311 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9460
# Epoch 18: val_loss did not improve from 0.11942
# 191/191 [==============================] - 313s 2s/step - loss: 0.1608 - accuracy: 0.9460 - val_loss: 0.1234 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1750 - accuracy: 0.9384
# Epoch 19: val_loss improved from 0.11942 to 0.11885, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 315s 2s/step - loss: 0.1750 - accuracy: 0.9384 - val_loss: 0.1188 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9466
# Epoch 20: val_loss did not improve from 0.11885
# 191/191 [==============================] - 321s 2s/step - loss: 0.1565 - accuracy: 0.9466 - val_loss: 0.1229 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1605 - accuracy: 0.9461
# Epoch 21: val_loss did not improve from 0.11885
# 191/191 [==============================] - 314s 2s/step - loss: 0.1605 - accuracy: 0.9461 - val_loss: 0.1277 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 0.9496
# Epoch 22: val_loss did not improve from 0.11885
# 191/191 [==============================] - 315s 2s/step - loss: 0.1570 - accuracy: 0.9496 - val_loss: 0.1253 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1531 - accuracy: 0.9451
# Epoch 23: val_loss did not improve from 0.11885
# 191/191 [==============================] - 309s 2s/step - loss: 0.1531 - accuracy: 0.9451 - val_loss: 0.1255 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1473 - accuracy: 0.9509
# Epoch 24: val_loss improved from 0.11885 to 0.11694, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 309s 2s/step - loss: 0.1473 - accuracy: 0.9509 - val_loss: 0.1169 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1548 - accuracy: 0.9481
# Epoch 25: val_loss improved from 0.11694 to 0.10584, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 310s 2s/step - loss: 0.1548 - accuracy: 0.9481 - val_loss: 0.1058 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1503 - accuracy: 0.9479
# Epoch 26: val_loss did not improve from 0.10584
# 191/191 [==============================] - 317s 2s/step - loss: 0.1503 - accuracy: 0.9479 - val_loss: 0.1275 - val_accuracy: 0.9541 - lr: 0.0010
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1547 - accuracy: 0.9486
# Epoch 27: val_loss did not improve from 0.10584
# 191/191 [==============================] - 312s 2s/step - loss: 0.1547 - accuracy: 0.9486 - val_loss: 0.1132 - val_accuracy: 0.9633 - lr: 0.0010
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1446 - accuracy: 0.9510
# Epoch 28: val_loss improved from 0.10584 to 0.10002, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 312s 2s/step - loss: 0.1446 - accuracy: 0.9510 - val_loss: 0.1000 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.9533
# Epoch 29: val_loss did not improve from 0.10002
# 191/191 [==============================] - 309s 2s/step - loss: 0.1456 - accuracy: 0.9533 - val_loss: 0.1328 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9532
# Epoch 30: val_loss did not improve from 0.10002
# 191/191 [==============================] - 311s 2s/step - loss: 0.1389 - accuracy: 0.9532 - val_loss: 0.1200 - val_accuracy: 0.9595 - lr: 0.0010
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1404 - accuracy: 0.9514
# Epoch 31: val_loss did not improve from 0.10002
# 191/191 [==============================] - 308s 2s/step - loss: 0.1404 - accuracy: 0.9514 - val_loss: 0.1136 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9533
# Epoch 32: val_loss did not improve from 0.10002
# 191/191 [==============================] - 312s 2s/step - loss: 0.1361 - accuracy: 0.9533 - val_loss: 0.1235 - val_accuracy: 0.9572 - lr: 0.0010
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9548
# Epoch 33: val_loss did not improve from 0.10002
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 312s 2s/step - loss: 0.1380 - accuracy: 0.9548 - val_loss: 0.1154 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9602
# Epoch 34: val_loss did not improve from 0.10002
# 191/191 [==============================] - 311s 2s/step - loss: 0.1160 - accuracy: 0.9602 - val_loss: 0.1126 - val_accuracy: 0.9656 - lr: 5.0000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9613
# Epoch 35: val_loss improved from 0.10002 to 0.09991, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 311s 2s/step - loss: 0.1152 - accuracy: 0.9613 - val_loss: 0.0999 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1123 - accuracy: 0.9630
# Epoch 36: val_loss improved from 0.09991 to 0.09915, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 308s 2s/step - loss: 0.1123 - accuracy: 0.9630 - val_loss: 0.0992 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1067 - accuracy: 0.9663
# Epoch 37: val_loss improved from 0.09915 to 0.09855, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 310s 2s/step - loss: 0.1067 - accuracy: 0.9663 - val_loss: 0.0986 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9638
# Epoch 38: val_loss improved from 0.09855 to 0.09695, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 311s 2s/step - loss: 0.1011 - accuracy: 0.9638 - val_loss: 0.0970 - val_accuracy: 0.9633 - lr: 5.0000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 0.9646
# Epoch 39: val_loss improved from 0.09695 to 0.08725, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 308s 2s/step - loss: 0.1007 - accuracy: 0.9646 - val_loss: 0.0873 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1051 - accuracy: 0.9620
# Epoch 40: val_loss improved from 0.08725 to 0.08706, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 311s 2s/step - loss: 0.1051 - accuracy: 0.9620 - val_loss: 0.0871 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1091 - accuracy: 0.9620
# Epoch 41: val_loss improved from 0.08706 to 0.08590, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 307s 2s/step - loss: 0.1091 - accuracy: 0.9620 - val_loss: 0.0859 - val_accuracy: 0.9717 - lr: 5.0000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9672
# Epoch 42: val_loss did not improve from 0.08590
# 191/191 [==============================] - 312s 2s/step - loss: 0.1037 - accuracy: 0.9672 - val_loss: 0.0875 - val_accuracy: 0.9725 - lr: 5.0000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9648
# Epoch 43: val_loss improved from 0.08590 to 0.08508, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 310s 2s/step - loss: 0.0978 - accuracy: 0.9648 - val_loss: 0.0851 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9671
# Epoch 44: val_loss did not improve from 0.08508
# 191/191 [==============================] - 311s 2s/step - loss: 0.0997 - accuracy: 0.9671 - val_loss: 0.0948 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9663
# Epoch 45: val_loss did not improve from 0.08508
# 191/191 [==============================] - 312s 2s/step - loss: 0.1040 - accuracy: 0.9663 - val_loss: 0.0901 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9664
# Epoch 46: val_loss did not improve from 0.08508
# 191/191 [==============================] - 309s 2s/step - loss: 0.0914 - accuracy: 0.9664 - val_loss: 0.0885 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0895 - accuracy: 0.9692
# Epoch 47: val_loss did not improve from 0.08508
# 191/191 [==============================] - 311s 2s/step - loss: 0.0895 - accuracy: 0.9692 - val_loss: 0.0915 - val_accuracy: 0.9671 - lr: 5.0000e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9705
# Epoch 48: val_loss did not improve from 0.08508
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 313s 2s/step - loss: 0.0883 - accuracy: 0.9705 - val_loss: 0.0904 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0886 - accuracy: 0.9704
# Epoch 49: val_loss improved from 0.08508 to 0.08416, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 329s 2s/step - loss: 0.0886 - accuracy: 0.9704 - val_loss: 0.0842 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9720
# Epoch 50: val_loss did not improve from 0.08416
# 191/191 [==============================] - 311s 2s/step - loss: 0.0822 - accuracy: 0.9720 - val_loss: 0.0842 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9704
# Epoch 51: val_loss did not improve from 0.08416
# 191/191 [==============================] - 315s 2s/step - loss: 0.0881 - accuracy: 0.9704 - val_loss: 0.0843 - val_accuracy: 0.9687 - lr: 2.5000e-04
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9689
# Epoch 52: val_loss improved from 0.08416 to 0.08375, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 314s 2s/step - loss: 0.0906 - accuracy: 0.9689 - val_loss: 0.0838 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9700
# Epoch 53: val_loss improved from 0.08375 to 0.08359, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 308s 2s/step - loss: 0.0892 - accuracy: 0.9700 - val_loss: 0.0836 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9702
# Epoch 54: val_loss improved from 0.08359 to 0.08036, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 313s 2s/step - loss: 0.0879 - accuracy: 0.9702 - val_loss: 0.0804 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 55/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 0.9712
# Epoch 55: val_loss improved from 0.08036 to 0.07902, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 308s 2s/step - loss: 0.0857 - accuracy: 0.9712 - val_loss: 0.0790 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 56/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9728
# Epoch 56: val_loss did not improve from 0.07902
# 191/191 [==============================] - 312s 2s/step - loss: 0.0792 - accuracy: 0.9728 - val_loss: 0.0915 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 57/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0815 - accuracy: 0.9718
# Epoch 57: val_loss did not improve from 0.07902
# 191/191 [==============================] - 308s 2s/step - loss: 0.0815 - accuracy: 0.9718 - val_loss: 0.0922 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 58/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0894 - accuracy: 0.9700
# Epoch 58: val_loss did not improve from 0.07902
# 191/191 [==============================] - 312s 2s/step - loss: 0.0894 - accuracy: 0.9700 - val_loss: 0.0861 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 59/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9741
# Epoch 59: val_loss did not improve from 0.07902
# 191/191 [==============================] - 309s 2s/step - loss: 0.0822 - accuracy: 0.9741 - val_loss: 0.0818 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 60/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9743
# Epoch 60: val_loss improved from 0.07902 to 0.07814, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 310s 2s/step - loss: 0.0804 - accuracy: 0.9743 - val_loss: 0.0781 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 61/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9733
# Epoch 61: val_loss improved from 0.07814 to 0.07722, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 308s 2s/step - loss: 0.0803 - accuracy: 0.9733 - val_loss: 0.0772 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 62/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0757 - accuracy: 0.9746
# Epoch 62: val_loss improved from 0.07722 to 0.07642, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 308s 2s/step - loss: 0.0757 - accuracy: 0.9746 - val_loss: 0.0764 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 63/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9748
# Epoch 63: val_loss did not improve from 0.07642
# 191/191 [==============================] - 309s 2s/step - loss: 0.0756 - accuracy: 0.9748 - val_loss: 0.0781 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 64/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9731
# Epoch 64: val_loss improved from 0.07642 to 0.07463, saving model to efficientnetB2_sin_ft_weights.h5
# 191/191 [==============================] - 309s 2s/step - loss: 0.0829 - accuracy: 0.9731 - val_loss: 0.0746 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 65/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9756
# Epoch 65: val_loss did not improve from 0.07463
# 191/191 [==============================] - 310s 2s/step - loss: 0.0786 - accuracy: 0.9756 - val_loss: 0.0780 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 66/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9772
# Epoch 66: val_loss did not improve from 0.07463
# 191/191 [==============================] - 307s 2s/step - loss: 0.0741 - accuracy: 0.9772 - val_loss: 0.0789 - val_accuracy: 0.9740 - lr: 2.5000e-04
# Epoch 67/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9748
# Epoch 67: val_loss did not improve from 0.07463
# 191/191 [==============================] - 310s 2s/step - loss: 0.0776 - accuracy: 0.9748 - val_loss: 0.0801 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 68/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9743
# Epoch 68: val_loss did not improve from 0.07463
# 191/191 [==============================] - 309s 2s/step - loss: 0.0792 - accuracy: 0.9743 - val_loss: 0.0791 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 69/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0780 - accuracy: 0.9731
# Epoch 69: val_loss did not improve from 0.07463
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 311s 2s/step - loss: 0.0780 - accuracy: 0.9731 - val_loss: 0.0784 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 70/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9741
# Epoch 70: val_loss did not improve from 0.07463
# 191/191 [==============================] - 309s 2s/step - loss: 0.0785 - accuracy: 0.9741 - val_loss: 0.0748 - val_accuracy: 0.9717 - lr: 1.2500e-04
# Epoch 71/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9756
# Epoch 71: val_loss did not improve from 0.07463
# 191/191 [==============================] - 312s 2s/step - loss: 0.0696 - accuracy: 0.9756 - val_loss: 0.0769 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 72/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9761
# Epoch 72: val_loss did not improve from 0.07463
# 191/191 [==============================] - 309s 2s/step - loss: 0.0738 - accuracy: 0.9761 - val_loss: 0.0757 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 73/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9764
# Epoch 73: val_loss did not improve from 0.07463
# 191/191 [==============================] - 310s 2s/step - loss: 0.0703 - accuracy: 0.9764 - val_loss: 0.0785 - val_accuracy: 0.9740 - lr: 1.2500e-04
# Epoch 74/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9759Restoring model weights from the end of the best epoch: 64.
#
# Epoch 74: val_loss did not improve from 0.07463
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 307s 2s/step - loss: 0.0728 - accuracy: 0.9759 - val_loss: 0.0786 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 74: early stopping

# %% [markdown]
# ### 7. EVALUACIÓN DEL MODELO EFFICIENTNETB2

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

# Gráfica de Loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 39s 941ms/step - loss: 0.0575 - accuracy: 0.9824
#
# Test Accuracy : 0.9824
# Test Loss     : 0.0575
# 41/41 [==============================] - 41s 940ms/step
# F1 Score      : 0.9824
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon       1.00      1.00      1.00        75
#    hoja_amarilla       0.98      1.00      0.99       150
#    mancha_anillo       0.99      0.99      0.99       105
#     mancha_parda       0.97      0.98      0.98       150
#          mosaico       0.99      0.99      0.99       150
#      muermo_rojo       0.97      0.96      0.96       150
#             roya       0.97      0.97      0.97       150
#            sanas       0.98      0.97      0.98       150
#            secas       1.00      0.99      0.99        78
# tizon_bacteriano       0.99      0.99      0.99       150
#
#         accuracy                           0.98      1308
#        macro avg       0.98      0.98      0.98      1308
#     weighted avg       0.98      0.98      0.98      1308
#
#
# Resultados guardados en efficientnetB2_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Pares con 5 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#
# Total de imágenes a mostrar: 0

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB2_sin_ft_weights.h5
