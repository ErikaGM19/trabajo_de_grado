# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = "MobileNetV3Small_TL"

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO MOBILENETV3SMALL

# %%
# CARGAR MOBILENETV3SMALL CON PESOS DE IMAGENET

base_model = MobileNetV3Small(
    weights='imagenet',                 
    include_top=False,                  
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Congelamos la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3small (Functiona  (None, 7, 7, 576)        939120
#  l)
#
#  global_average_pooling2d (G  (None, 576)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               73856
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,014,266
# Trainable params: 75,146
# Non-trainable params: 939,120
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{NOMBRE_MODELO}_weights.h5",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 1.1059 - accuracy: 0.6323
# Epoch 1: val_loss improved from inf to 0.39845, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 181s 915ms/step - loss: 1.1059 - accuracy: 0.6323 - val_loss: 0.3985 - val_accuracy: 0.9083 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.5155 - accuracy: 0.8331
# Epoch 2: val_loss improved from 0.39845 to 0.27232, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 157s 825ms/step - loss: 0.5155 - accuracy: 0.8331 - val_loss: 0.2723 - val_accuracy: 0.9281 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3955 - accuracy: 0.8742
# Epoch 3: val_loss improved from 0.27232 to 0.22717, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 157s 822ms/step - loss: 0.3955 - accuracy: 0.8742 - val_loss: 0.2272 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8939
# Epoch 4: val_loss improved from 0.22717 to 0.19954, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 158s 826ms/step - loss: 0.3327 - accuracy: 0.8939 - val_loss: 0.1995 - val_accuracy: 0.9442 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3081 - accuracy: 0.9024
# Epoch 5: val_loss improved from 0.19954 to 0.19282, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 157s 821ms/step - loss: 0.3081 - accuracy: 0.9024 - val_loss: 0.1928 - val_accuracy: 0.9450 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2755 - accuracy: 0.9130
# Epoch 6: val_loss improved from 0.19282 to 0.18417, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 157s 824ms/step - loss: 0.2755 - accuracy: 0.9130 - val_loss: 0.1842 - val_accuracy: 0.9503 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2595 - accuracy: 0.9150
# Epoch 7: val_loss improved from 0.18417 to 0.16729, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 157s 821ms/step - loss: 0.2595 - accuracy: 0.9150 - val_loss: 0.1673 - val_accuracy: 0.9442 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2315 - accuracy: 0.9250
# Epoch 8: val_loss did not improve from 0.16729
# 191/191 [==============================] - 669s 4s/step - loss: 0.2315 - accuracy: 0.9250 - val_loss: 0.1706 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9299
# Epoch 9: val_loss improved from 0.16729 to 0.15453, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 164s 841ms/step - loss: 0.2238 - accuracy: 0.9299 - val_loss: 0.1545 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9288
# Epoch 10: val_loss did not improve from 0.15453
# 191/191 [==============================] - 157s 823ms/step - loss: 0.2224 - accuracy: 0.9288 - val_loss: 0.1615 - val_accuracy: 0.9503 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9329
# Epoch 11: val_loss improved from 0.15453 to 0.15389, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 158s 827ms/step - loss: 0.2079 - accuracy: 0.9329 - val_loss: 0.1539 - val_accuracy: 0.9518 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9306
# Epoch 12: val_loss improved from 0.15389 to 0.14243, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 160s 838ms/step - loss: 0.2112 - accuracy: 0.9306 - val_loss: 0.1424 - val_accuracy: 0.9549 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1858 - accuracy: 0.9428
# Epoch 13: val_loss improved from 0.14243 to 0.13110, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 158s 828ms/step - loss: 0.1858 - accuracy: 0.9428 - val_loss: 0.1311 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1869 - accuracy: 0.9399
# Epoch 14: val_loss did not improve from 0.13110
# 191/191 [==============================] - 158s 827ms/step - loss: 0.1869 - accuracy: 0.9399 - val_loss: 0.1365 - val_accuracy: 0.9595 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9442
# Epoch 15: val_loss did not improve from 0.13110
# 191/191 [==============================] - 158s 827ms/step - loss: 0.1749 - accuracy: 0.9442 - val_loss: 0.1410 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1851 - accuracy: 0.9383
# Epoch 16: val_loss did not improve from 0.13110
# 191/191 [==============================] - 159s 835ms/step - loss: 0.1851 - accuracy: 0.9383 - val_loss: 0.1339 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1834 - accuracy: 0.9420
# Epoch 17: val_loss did not improve from 0.13110
# 191/191 [==============================] - 161s 841ms/step - loss: 0.1834 - accuracy: 0.9420 - val_loss: 0.1355 - val_accuracy: 0.9625 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1666 - accuracy: 0.9471
# Epoch 18: val_loss improved from 0.13110 to 0.12297, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 162s 847ms/step - loss: 0.1666 - accuracy: 0.9471 - val_loss: 0.1230 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1604 - accuracy: 0.9473
# Epoch 19: val_loss did not improve from 0.12297
# 191/191 [==============================] - 163s 853ms/step - loss: 0.1604 - accuracy: 0.9473 - val_loss: 0.1257 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.9512
# Epoch 20: val_loss did not improve from 0.12297
# 191/191 [==============================] - 162s 851ms/step - loss: 0.1568 - accuracy: 0.9512 - val_loss: 0.1385 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9507
# Epoch 21: val_loss improved from 0.12297 to 0.12008, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 165s 862ms/step - loss: 0.1500 - accuracy: 0.9507 - val_loss: 0.1201 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1627 - accuracy: 0.9471
# Epoch 22: val_loss improved from 0.12008 to 0.11405, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 162s 847ms/step - loss: 0.1627 - accuracy: 0.9471 - val_loss: 0.1140 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1482 - accuracy: 0.9525
# Epoch 23: val_loss did not improve from 0.11405
# 191/191 [==============================] - 163s 853ms/step - loss: 0.1482 - accuracy: 0.9525 - val_loss: 0.1348 - val_accuracy: 0.9618 - lr: 0.0010
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.9443
# Epoch 24: val_loss did not improve from 0.11405
# 191/191 [==============================] - 162s 848ms/step - loss: 0.1661 - accuracy: 0.9443 - val_loss: 0.1158 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1602 - accuracy: 0.9466
# Epoch 25: val_loss did not improve from 0.11405
# 191/191 [==============================] - 163s 854ms/step - loss: 0.1602 - accuracy: 0.9466 - val_loss: 0.1155 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9510
# Epoch 26: val_loss improved from 0.11405 to 0.11013, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 164s 855ms/step - loss: 0.1400 - accuracy: 0.9510 - val_loss: 0.1101 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.9496
# Epoch 27: val_loss did not improve from 0.11013
# 191/191 [==============================] - 161s 846ms/step - loss: 0.1491 - accuracy: 0.9496 - val_loss: 0.1251 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9527
# Epoch 28: val_loss did not improve from 0.11013
# 191/191 [==============================] - 152s 796ms/step - loss: 0.1407 - accuracy: 0.9527 - val_loss: 0.1132 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9528
# Epoch 29: val_loss did not improve from 0.11013
# 191/191 [==============================] - 142s 744ms/step - loss: 0.1424 - accuracy: 0.9528 - val_loss: 0.1186 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9523
# Epoch 30: val_loss did not improve from 0.11013
# 191/191 [==============================] - 141s 738ms/step - loss: 0.1392 - accuracy: 0.9523 - val_loss: 0.1326 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1276 - accuracy: 0.9609
# Epoch 31: val_loss did not improve from 0.11013
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 139s 728ms/step - loss: 0.1276 - accuracy: 0.9609 - val_loss: 0.1124 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1183 - accuracy: 0.9610
# Epoch 32: val_loss did not improve from 0.11013
# 191/191 [==============================] - 140s 732ms/step - loss: 0.1183 - accuracy: 0.9610 - val_loss: 0.1117 - val_accuracy: 0.9725 - lr: 5.0000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9650
# Epoch 33: val_loss improved from 0.11013 to 0.10936, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 140s 732ms/step - loss: 0.1089 - accuracy: 0.9650 - val_loss: 0.1094 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9641
# Epoch 34: val_loss did not improve from 0.10936
# 191/191 [==============================] - 140s 733ms/step - loss: 0.1089 - accuracy: 0.9641 - val_loss: 0.1137 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9622
# Epoch 35: val_loss did not improve from 0.10936
# 191/191 [==============================] - 139s 730ms/step - loss: 0.1131 - accuracy: 0.9622 - val_loss: 0.1095 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1131 - accuracy: 0.9643
# Epoch 36: val_loss did not improve from 0.10936
# 191/191 [==============================] - 139s 729ms/step - loss: 0.1131 - accuracy: 0.9643 - val_loss: 0.1134 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9661
# Epoch 37: val_loss improved from 0.10936 to 0.10935, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 141s 736ms/step - loss: 0.1045 - accuracy: 0.9661 - val_loss: 0.1094 - val_accuracy: 0.9694 - lr: 5.0000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1109 - accuracy: 0.9661
# Epoch 38: val_loss improved from 0.10935 to 0.10264, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 140s 731ms/step - loss: 0.1109 - accuracy: 0.9661 - val_loss: 0.1026 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9636
# Epoch 39: val_loss did not improve from 0.10264
# 191/191 [==============================] - 139s 729ms/step - loss: 0.1102 - accuracy: 0.9636 - val_loss: 0.1126 - val_accuracy: 0.9679 - lr: 5.0000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9656
# Epoch 40: val_loss did not improve from 0.10264
# 191/191 [==============================] - 139s 727ms/step - loss: 0.1012 - accuracy: 0.9656 - val_loss: 0.1158 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1056 - accuracy: 0.9666
# Epoch 41: val_loss did not improve from 0.10264
# 191/191 [==============================] - 140s 733ms/step - loss: 0.1056 - accuracy: 0.9666 - val_loss: 0.1064 - val_accuracy: 0.9732 - lr: 5.0000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9658
# Epoch 42: val_loss did not improve from 0.10264
# 191/191 [==============================] - 139s 729ms/step - loss: 0.0997 - accuracy: 0.9658 - val_loss: 0.1134 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9640
# Epoch 43: val_loss did not improve from 0.10264
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 141s 736ms/step - loss: 0.1071 - accuracy: 0.9640 - val_loss: 0.1087 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9700
# Epoch 44: val_loss improved from 0.10264 to 0.10008, saving model to MobileNetV3Small_sin_ft_weights.h5
# 191/191 [==============================] - 139s 727ms/step - loss: 0.0898 - accuracy: 0.9700 - val_loss: 0.1001 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9697
# Epoch 45: val_loss did not improve from 0.10008
# 191/191 [==============================] - 140s 733ms/step - loss: 0.0910 - accuracy: 0.9697 - val_loss: 0.1034 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0913 - accuracy: 0.9694
# Epoch 46: val_loss did not improve from 0.10008
# 191/191 [==============================] - 140s 732ms/step - loss: 0.0913 - accuracy: 0.9694 - val_loss: 0.1068 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9704
# Epoch 47: val_loss did not improve from 0.10008
# 191/191 [==============================] - 139s 730ms/step - loss: 0.0890 - accuracy: 0.9704 - val_loss: 0.1091 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9723
# Epoch 48: val_loss did not improve from 0.10008
# 191/191 [==============================] - 139s 730ms/step - loss: 0.0793 - accuracy: 0.9723 - val_loss: 0.1064 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 49/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.9689
# Epoch 49: val_loss did not improve from 0.10008
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 141s 736ms/step - loss: 0.0896 - accuracy: 0.9689 - val_loss: 0.1038 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 50/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9715
# Epoch 50: val_loss did not improve from 0.10008
# 191/191 [==============================] - 140s 731ms/step - loss: 0.0887 - accuracy: 0.9715 - val_loss: 0.1063 - val_accuracy: 0.9717 - lr: 1.2500e-04
# Epoch 51/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9736
# Epoch 51: val_loss did not improve from 0.10008
# 191/191 [==============================] - 139s 728ms/step - loss: 0.0820 - accuracy: 0.9736 - val_loss: 0.1047 - val_accuracy: 0.9717 - lr: 1.2500e-04
# Epoch 52/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9735
# Epoch 52: val_loss did not improve from 0.10008
# 191/191 [==============================] - 153s 799ms/step - loss: 0.0776 - accuracy: 0.9735 - val_loss: 0.1033 - val_accuracy: 0.9725 - lr: 1.2500e-04
# Epoch 53/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9751
# Epoch 53: val_loss did not improve from 0.10008
# 191/191 [==============================] - 140s 732ms/step - loss: 0.0792 - accuracy: 0.9751 - val_loss: 0.1039 - val_accuracy: 0.9709 - lr: 1.2500e-04
# Epoch 54/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9759Restoring model weights from the end of the best epoch: 44.
#
# Epoch 54: val_loss did not improve from 0.10008
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 142s 741ms/step - loss: 0.0748 - accuracy: 0.9759 - val_loss: 0.1044 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 54: early stopping

# %% [markdown]
# ### 7. EVALUACIÓN DEL MODELO MOBILENETV3SMALL

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

# Gráfica de Loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 16s 383ms/step - loss: 0.0667 - accuracy: 0.9771
#
# Test Accuracy : 0.9771
# Test Loss     : 0.0667
# 41/41 [==============================] - 16s 373ms/step
# F1 Score      : 0.9770
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9551    0.9933    0.9739       150
#    mancha_anillo     0.9905    0.9905    0.9905       105
#     mancha_parda     0.9866    0.9800    0.9833       150
#          mosaico     0.9800    0.9800    0.9800       150
#      muermo_rojo     0.9530    0.9467    0.9498       150
#             roya     0.9726    0.9467    0.9595       150
#            sanas     0.9735    0.9800    0.9767       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     0.9866    0.9800    0.9833       150
#
#         accuracy                         0.9771      1308
#        macro avg     0.9798    0.9797    0.9797      1308
#     weighted avg     0.9772    0.9771    0.9770      1308
#
#
# Resultados guardados en MobileNetV3Small_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Pares con 5 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#
# Total de imágenes a mostrar: 0

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: MobileNetV3Small_sin_ft_weights.h5
