# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = "efficientnetB0_TL"

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFIENTNETB0

# %%
# CARGAR EFFICIENTNET-B0 CON PESOS DE IMAGENET

base_model = EfficientNetB0(
    weights='imagenet',                 
    include_top=False,                  
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Congelamos la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               163968
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 4,214,829
# Trainable params: 165,258
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{NOMBRE_MODELO}_weights.h5",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.8318 - accuracy: 0.7219
# Epoch 1: val_loss improved from inf to 0.29456, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 1113s 5s/step - loss: 0.8318 - accuracy: 0.7219 - val_loss: 0.2946 - val_accuracy: 0.9174 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4048 - accuracy: 0.8693
# Epoch 2: val_loss improved from 0.29456 to 0.20522, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 927s 5s/step - loss: 0.4048 - accuracy: 0.8693 - val_loss: 0.2052 - val_accuracy: 0.9434 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3058 - accuracy: 0.9021
# Epoch 3: val_loss improved from 0.20522 to 0.17604, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 632s 3s/step - loss: 0.3058 - accuracy: 0.9021 - val_loss: 0.1760 - val_accuracy: 0.9381 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.9135
# Epoch 4: val_loss improved from 0.17604 to 0.15832, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 573s 3s/step - loss: 0.2650 - accuracy: 0.9135 - val_loss: 0.1583 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.9247
# Epoch 5: val_loss improved from 0.15832 to 0.13878, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 588s 3s/step - loss: 0.2305 - accuracy: 0.9247 - val_loss: 0.1388 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9283
# Epoch 6: val_loss improved from 0.13878 to 0.12472, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 640s 3s/step - loss: 0.2241 - accuracy: 0.9283 - val_loss: 0.1247 - val_accuracy: 0.9595 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2126 - accuracy: 0.9292
# Epoch 7: val_loss improved from 0.12472 to 0.12399, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 648s 3s/step - loss: 0.2126 - accuracy: 0.9292 - val_loss: 0.1240 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2052 - accuracy: 0.9319
# Epoch 8: val_loss did not improve from 0.12399
# 191/191 [==============================] - 262s 1s/step - loss: 0.2052 - accuracy: 0.9319 - val_loss: 0.1247 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9401
# Epoch 9: val_loss improved from 0.12399 to 0.11207, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 227s 1s/step - loss: 0.1885 - accuracy: 0.9401 - val_loss: 0.1121 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1757 - accuracy: 0.9422
# Epoch 10: val_loss improved from 0.11207 to 0.11151, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 232s 1s/step - loss: 0.1757 - accuracy: 0.9422 - val_loss: 0.1115 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1752 - accuracy: 0.9440
# Epoch 11: val_loss did not improve from 0.11151
# 191/191 [==============================] - 236s 1s/step - loss: 0.1752 - accuracy: 0.9440 - val_loss: 0.1165 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1507 - accuracy: 0.9471
# Epoch 12: val_loss improved from 0.11151 to 0.10185, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 242s 1s/step - loss: 0.1507 - accuracy: 0.9471 - val_loss: 0.1018 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9466
# Epoch 13: val_loss improved from 0.10185 to 0.09733, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 256s 1s/step - loss: 0.1643 - accuracy: 0.9466 - val_loss: 0.0973 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9435
# Epoch 14: val_loss did not improve from 0.09733
# 191/191 [==============================] - 259s 1s/step - loss: 0.1613 - accuracy: 0.9435 - val_loss: 0.0996 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1520 - accuracy: 0.9515
# Epoch 15: val_loss improved from 0.09733 to 0.09703, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 288s 2s/step - loss: 0.1520 - accuracy: 0.9515 - val_loss: 0.0970 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1410 - accuracy: 0.9527
# Epoch 16: val_loss improved from 0.09703 to 0.07988, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 250s 1s/step - loss: 0.1410 - accuracy: 0.9527 - val_loss: 0.0799 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.9502
# Epoch 17: val_loss did not improve from 0.07988
# 191/191 [==============================] - 247s 1s/step - loss: 0.1467 - accuracy: 0.9502 - val_loss: 0.0894 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1458 - accuracy: 0.9527
# Epoch 18: val_loss did not improve from 0.07988
# 191/191 [==============================] - 262s 1s/step - loss: 0.1458 - accuracy: 0.9527 - val_loss: 0.0800 - val_accuracy: 0.9771 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9517
# Epoch 19: val_loss did not improve from 0.07988
# 191/191 [==============================] - 252s 1s/step - loss: 0.1425 - accuracy: 0.9517 - val_loss: 0.0965 - val_accuracy: 0.9694 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1339 - accuracy: 0.9563
# Epoch 20: val_loss did not improve from 0.07988
# 191/191 [==============================] - 248s 1s/step - loss: 0.1339 - accuracy: 0.9563 - val_loss: 0.0891 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9564
# Epoch 21: val_loss did not improve from 0.07988
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 244s 1s/step - loss: 0.1372 - accuracy: 0.9564 - val_loss: 0.1071 - val_accuracy: 0.9595 - lr: 0.0010
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9618
# Epoch 22: val_loss did not improve from 0.07988
# 191/191 [==============================] - 249s 1s/step - loss: 0.1135 - accuracy: 0.9618 - val_loss: 0.0820 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1001 - accuracy: 0.9668
# Epoch 23: val_loss improved from 0.07988 to 0.06929, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 254s 1s/step - loss: 0.1001 - accuracy: 0.9668 - val_loss: 0.0693 - val_accuracy: 0.9755 - lr: 5.0000e-04
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9658
# Epoch 24: val_loss improved from 0.06929 to 0.06870, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 255s 1s/step - loss: 0.1070 - accuracy: 0.9658 - val_loss: 0.0687 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1006 - accuracy: 0.9668
# Epoch 25: val_loss improved from 0.06870 to 0.06621, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 259s 1s/step - loss: 0.1006 - accuracy: 0.9668 - val_loss: 0.0662 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9690
# Epoch 26: val_loss improved from 0.06621 to 0.05999, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 258s 1s/step - loss: 0.0918 - accuracy: 0.9690 - val_loss: 0.0600 - val_accuracy: 0.9809 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9672
# Epoch 27: val_loss did not improve from 0.05999
# 191/191 [==============================] - 259s 1s/step - loss: 0.0969 - accuracy: 0.9672 - val_loss: 0.0663 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9699
# Epoch 28: val_loss did not improve from 0.05999
# 191/191 [==============================] - 262s 1s/step - loss: 0.0899 - accuracy: 0.9699 - val_loss: 0.0665 - val_accuracy: 0.9740 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9722
# Epoch 29: val_loss did not improve from 0.05999
# 191/191 [==============================] - 271s 1s/step - loss: 0.0892 - accuracy: 0.9722 - val_loss: 0.0743 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0974 - accuracy: 0.9664
# Epoch 30: val_loss did not improve from 0.05999
# 191/191 [==============================] - 271s 1s/step - loss: 0.0974 - accuracy: 0.9664 - val_loss: 0.0667 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0917 - accuracy: 0.9697
# Epoch 31: val_loss did not improve from 0.05999
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 274s 1s/step - loss: 0.0917 - accuracy: 0.9697 - val_loss: 0.0641 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9715
# Epoch 32: val_loss improved from 0.05999 to 0.05699, saving model to efficientnetB0_sin_ft_weights.h5
# 191/191 [==============================] - 282s 1s/step - loss: 0.0821 - accuracy: 0.9715 - val_loss: 0.0570 - val_accuracy: 0.9832 - lr: 2.5000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9708
# Epoch 33: val_loss did not improve from 0.05699
# 191/191 [==============================] - 285s 1s/step - loss: 0.0884 - accuracy: 0.9708 - val_loss: 0.0611 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0843 - accuracy: 0.9712
# Epoch 34: val_loss did not improve from 0.05699
# 191/191 [==============================] - 282s 1s/step - loss: 0.0843 - accuracy: 0.9712 - val_loss: 0.0619 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9736
# Epoch 35: val_loss did not improve from 0.05699
# 191/191 [==============================] - 291s 2s/step - loss: 0.0795 - accuracy: 0.9736 - val_loss: 0.0614 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9704
# Epoch 36: val_loss did not improve from 0.05699
# 191/191 [==============================] - 289s 2s/step - loss: 0.0824 - accuracy: 0.9704 - val_loss: 0.0616 - val_accuracy: 0.9794 - lr: 2.5000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.9735
# Epoch 37: val_loss did not improve from 0.05699
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 299s 2s/step - loss: 0.0799 - accuracy: 0.9735 - val_loss: 0.0577 - val_accuracy: 0.9809 - lr: 2.5000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0813 - accuracy: 0.9746
# Epoch 38: val_loss did not improve from 0.05699
# 191/191 [==============================] - 303s 2s/step - loss: 0.0813 - accuracy: 0.9746 - val_loss: 0.0573 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9748
# Epoch 39: val_loss did not improve from 0.05699
# 191/191 [==============================] - 271s 1s/step - loss: 0.0744 - accuracy: 0.9748 - val_loss: 0.0595 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9754
# Epoch 40: val_loss did not improve from 0.05699
# 191/191 [==============================] - 268s 1s/step - loss: 0.0695 - accuracy: 0.9754 - val_loss: 0.0591 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9749
# Epoch 41: val_loss did not improve from 0.05699
# 191/191 [==============================] - 266s 1s/step - loss: 0.0778 - accuracy: 0.9749 - val_loss: 0.0592 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9748Restoring model weights from the end of the best epoch: 32.
#
# Epoch 42: val_loss did not improve from 0.05699
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 270s 1s/step - loss: 0.0785 - accuracy: 0.9748 - val_loss: 0.0599 - val_accuracy: 0.9794 - lr: 1.2500e-04
# Epoch 42: early stopping

# %% [markdown]
# ### 7. EVALUACIÓN DEL MODELO EFFICIENTNETB0

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

# Gráfica de Loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 44s 1s/step - loss: 0.0619 - accuracy: 0.9794
#
# Test Accuracy : 0.9794
# Test Loss     : 0.0619
# 41/41 [==============================] - 43s 1s/step
# F1 Score      : 0.9793
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon       1.00      1.00      1.00        75
#    hoja_amarilla       0.98      0.99      0.98       150
#    mancha_anillo       1.00      1.00      1.00       105
#     mancha_parda       0.99      0.99      0.99       150
#          mosaico       0.97      0.98      0.97       150
#      muermo_rojo       0.97      0.97      0.97       150
#             roya       0.97      0.95      0.96       150
#            sanas       0.97      0.95      0.96       150
#            secas       1.00      1.00      1.00        78
# tizon_bacteriano       0.99      0.99      0.99       150
#
#         accuracy                           0.98      1308
#        macro avg       0.98      0.98      0.98      1308
#     weighted avg       0.98      0.98      0.98      1308
#
#
# Resultados guardados en efficientnetB0_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Pares con 5 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#
# Total de imágenes a mostrar: 0

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB0_sin_ft_weights.h5
