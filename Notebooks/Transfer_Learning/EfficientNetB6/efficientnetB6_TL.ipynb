# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB6
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE      = 528
BATCH_SIZE    = 8
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = "efficientnetB6_TL"

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFIENTNETB6

# %%
# CARGAR EFFICIENTNET-B6 CON PESOS DE IMAGENET

base_model = EfficientNetB6(
    weights='imagenet',                 
    include_top=False,                  
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Congelamos la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb6 (Functional)  (None, 17, 17, 2304)     40960143
#
#  global_average_pooling2d (G  (None, 2304)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               295040
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 41,256,473
# Trainable params: 296,330
# Non-trainable params: 40,960,143
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{NOMBRE_MODELO}_weights.h5",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 764/764 [==============================] - ETA: 0s - loss: 0.7306 - accuracy: 0.7561
# Epoch 1: val_loss improved from inf to 0.29243, saving model to efficientnetB6_sin_ft_weights.h5
# 764/764 [==============================] - 3923s 5s/step - loss: 0.7306 - accuracy: 0.7561 - val_loss: 0.2924 - val_accuracy: 0.9274 - lr: 0.0010
# Epoch 2/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3687 - accuracy: 0.8826
# Epoch 2: val_loss improved from 0.29243 to 0.21546, saving model to efficientnetB6_sin_ft_weights.h5
# 764/764 [==============================] - 3976s 5s/step - loss: 0.3687 - accuracy: 0.8826 - val_loss: 0.2155 - val_accuracy: 0.9358 - lr: 0.0010
# Epoch 3/75
# 764/764 [==============================] - ETA: 0s - loss: 0.3022 - accuracy: 0.9006
# Epoch 3: val_loss improved from 0.21546 to 0.20574, saving model to efficientnetB6_sin_ft_weights.h5
# 764/764 [==============================] - 3811s 5s/step - loss: 0.3022 - accuracy: 0.9006 - val_loss: 0.2057 - val_accuracy: 0.9396 - lr: 0.0010
# Epoch 4/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2713 - accuracy: 0.9124
# Epoch 4: val_loss did not improve from 0.20574
# 764/764 [==============================] - 3884s 5s/step - loss: 0.2713 - accuracy: 0.9124 - val_loss: 0.2076 - val_accuracy: 0.9304 - lr: 0.0010
# Epoch 5/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2437 - accuracy: 0.9216
# Epoch 5: val_loss improved from 0.20574 to 0.17408, saving model to efficientnetB6_sin_ft_weights.h5
# 764/764 [==============================] - 3962s 5s/step - loss: 0.2437 - accuracy: 0.9216 - val_loss: 0.1741 - val_accuracy: 0.9434 - lr: 0.0010
# Epoch 6/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2226 - accuracy: 0.9329
# Epoch 6: val_loss improved from 0.17408 to 0.17128, saving model to efficientnetB6_sin_ft_weights.h5
# 764/764 [==============================] - 3987s 5s/step - loss: 0.2226 - accuracy: 0.9329 - val_loss: 0.1713 - val_accuracy: 0.9472 - lr: 0.0010
# Epoch 7/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2256 - accuracy: 0.9266
# Epoch 7: val_loss did not improve from 0.17128
# 764/764 [==============================] - 3912s 5s/step - loss: 0.2256 - accuracy: 0.9266 - val_loss: 0.2046 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 8/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9270
# Epoch 8: val_loss improved from 0.17128 to 0.14331, saving model to efficientnetB6_sin_ft_weights.h5
# 764/764 [==============================] - 3968s 5s/step - loss: 0.2082 - accuracy: 0.9270 - val_loss: 0.1433 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 9/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9365
# Epoch 9: val_loss did not improve from 0.14331
# 764/764 [==============================] - 3956s 5s/step - loss: 0.1981 - accuracy: 0.9365 - val_loss: 0.1764 - val_accuracy: 0.9388 - lr: 0.0010
# Epoch 10/75
# 764/764 [==============================] - ETA: 0s - loss: 0.2053 - accuracy: 0.9315
# Epoch 10: val_loss improved from 0.14331 to 0.14299, saving model to efficientnetB6_sin_ft_weights.h5
# 764/764 [==============================] - 3684s 5s/step - loss: 0.2053 - accuracy: 0.9315 - val_loss: 0.1430 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 11/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1929 - accuracy: 0.9355
# Epoch 11: val_loss did not improve from 0.14299
# 764/764 [==============================] - 3671s 5s/step - loss: 0.1929 - accuracy: 0.9355 - val_loss: 0.1804 - val_accuracy: 0.9411 - lr: 0.0010
# Epoch 12/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1797 - accuracy: 0.9422
# Epoch 12: val_loss did not improve from 0.14299
# 764/764 [==============================] - 4016s 5s/step - loss: 0.1797 - accuracy: 0.9422 - val_loss: 0.1801 - val_accuracy: 0.9419 - lr: 0.0010
# Epoch 13/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9374
# Epoch 13: val_loss improved from 0.14299 to 0.13092, saving model to efficientnetB6_sin_ft_weights.h5
# 764/764 [==============================] - 4014s 5s/step - loss: 0.1837 - accuracy: 0.9374 - val_loss: 0.1309 - val_accuracy: 0.9549 - lr: 0.0010
# Epoch 14/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1860 - accuracy: 0.9376
# Epoch 14: val_loss did not improve from 0.13092
# 764/764 [==============================] - 4019s 5s/step - loss: 0.1860 - accuracy: 0.9376 - val_loss: 0.1774 - val_accuracy: 0.9488 - lr: 0.0010
# Epoch 15/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9479
# Epoch 15: val_loss did not improve from 0.13092
# 764/764 [==============================] - 4022s 5s/step - loss: 0.1693 - accuracy: 0.9479 - val_loss: 0.1912 - val_accuracy: 0.9404 - lr: 0.0010
# Epoch 16/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9507
# Epoch 16: val_loss improved from 0.13092 to 0.10613, saving model to efficientnetB6_sin_ft_weights.h5
# 764/764 [==============================] - 4022s 5s/step - loss: 0.1541 - accuracy: 0.9507 - val_loss: 0.1061 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 17/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9482
# Epoch 17: val_loss did not improve from 0.10613
# 764/764 [==============================] - 4019s 5s/step - loss: 0.1564 - accuracy: 0.9482 - val_loss: 0.1389 - val_accuracy: 0.9564 - lr: 0.0010
# Epoch 18/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9471
# Epoch 18: val_loss did not improve from 0.10613
# 764/764 [==============================] - 4022s 5s/step - loss: 0.1543 - accuracy: 0.9471 - val_loss: 0.1302 - val_accuracy: 0.9549 - lr: 0.0010
# Epoch 19/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1692 - accuracy: 0.9435
# Epoch 19: val_loss did not improve from 0.10613
# 764/764 [==============================] - 4007s 5s/step - loss: 0.1692 - accuracy: 0.9435 - val_loss: 0.1683 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 20/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9527
# Epoch 20: val_loss did not improve from 0.10613
# 764/764 [==============================] - 4012s 5s/step - loss: 0.1385 - accuracy: 0.9527 - val_loss: 0.1622 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 21/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9460
# Epoch 21: val_loss did not improve from 0.10613
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 764/764 [==============================] - 4012s 5s/step - loss: 0.1569 - accuracy: 0.9460 - val_loss: 0.1609 - val_accuracy: 0.9503 - lr: 0.0010
# Epoch 22/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1333 - accuracy: 0.9592
# Epoch 22: val_loss did not improve from 0.10613
# 764/764 [==============================] - 4019s 5s/step - loss: 0.1333 - accuracy: 0.9592 - val_loss: 0.1292 - val_accuracy: 0.9610 - lr: 5.0000e-04
# Epoch 23/75
# 764/764 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9632
# Epoch 23: val_loss did not improve from 0.10613
# 764/764 [==============================] - 4013s 5s/step - loss: 0.1134 - accuracy: 0.9632 - val_loss: 0.1341 - val_accuracy: 0.9587 - lr: 5.0000e-04
# Epoch 24/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9686
# Epoch 24: val_loss did not improve from 0.10613
# 764/764 [==============================] - 4012s 5s/step - loss: 0.0962 - accuracy: 0.9686 - val_loss: 0.1222 - val_accuracy: 0.9656 - lr: 5.0000e-04
# Epoch 25/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9658
# Epoch 25: val_loss did not improve from 0.10613
# 764/764 [==============================] - 4012s 5s/step - loss: 0.0998 - accuracy: 0.9658 - val_loss: 0.1251 - val_accuracy: 0.9610 - lr: 5.0000e-04
# Epoch 26/75
# 764/764 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9664Restoring model weights from the end of the best epoch: 16.
#
# Epoch 26: val_loss did not improve from 0.10613
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 764/764 [==============================] - 4002s 5s/step - loss: 0.0988 - accuracy: 0.9664 - val_loss: 0.1167 - val_accuracy: 0.9633 - lr: 5.0000e-04
# Epoch 26: early stopping

# %% [markdown]
# ### 7. EVALUACIÓN DEL MODELO EFFICIENTNETB6

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

# Gráfica de Loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 164/164 [==============================] - 694s 4s/step - loss: 0.0884 - accuracy: 0.9725
#
# Test Accuracy : 0.9725
# Test Loss     : 0.0884
# 164/164 [==============================] - 716s 4s/step
# F1 Score      : 0.9725
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9669    0.9733    0.9701       150
#    mancha_anillo     1.0000    0.9905    0.9952       105
#     mancha_parda     0.9542    0.9733    0.9637       150
#          mosaico     0.9610    0.9867    0.9737       150
#      muermo_rojo     0.9342    0.9467    0.9404       150
#             roya     0.9650    0.9200    0.9420       150
#            sanas     0.9800    0.9800    0.9800       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     1.0000    0.9867    0.9933       150
#
#         accuracy                         0.9725      1308
#        macro avg     0.9761    0.9757    0.9758      1308
#     weighted avg     0.9726    0.9725    0.9725      1308
#
#
# Resultados guardados en efficientnetB6_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Pares con 5 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#   muermo_rojo → mancha_parda: 6 imágenes
#
# Total de imágenes a mostrar: 6

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB6_sin_ft_weights.h5
