# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE      = 300
BATCH_SIZE    = 16
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = "efficientnetB3_TL"

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6112 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Imágenes de entrenamiento : 6112
# Imágenes de validación    : 1309
# Imágenes de test          : 1309

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFIENTNETB3

# %%
# CARGAR EFFICIENTNET-B3 CON PESOS DE IMAGENET

base_model = EfficientNetB3(
    weights='imagenet',                 
    include_top=False,                  
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Congelamos la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb3 (Functional)  (None, 10, 10, 1536)     10783535
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               196736
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 10,981,561
# Trainable params: 198,026
# Non-trainable params: 10,783,535
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{NOMBRE_MODELO}_weights.h5",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 382/382 [==============================] - ETA: 0s - loss: 0.7436 - accuracy: 0.7577
# Epoch 1: val_loss improved from inf to 0.30394, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 561s 1s/step - loss: 0.7436 - accuracy: 0.7577 - val_loss: 0.3039 - val_accuracy: 0.9068 - lr: 0.0010
# Epoch 2/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3765 - accuracy: 0.8806
# Epoch 2: val_loss improved from 0.30394 to 0.22203, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 549s 1s/step - loss: 0.3765 - accuracy: 0.8806 - val_loss: 0.2220 - val_accuracy: 0.9343 - lr: 0.0010
# Epoch 3/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.8977
# Epoch 3: val_loss improved from 0.22203 to 0.16497, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 552s 1s/step - loss: 0.3099 - accuracy: 0.8977 - val_loss: 0.1650 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 4/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2584 - accuracy: 0.9174
# Epoch 4: val_loss improved from 0.16497 to 0.13785, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 554s 1s/step - loss: 0.2584 - accuracy: 0.9174 - val_loss: 0.1379 - val_accuracy: 0.9565 - lr: 0.0010
# Epoch 5/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.9220
# Epoch 5: val_loss did not improve from 0.13785
# 382/382 [==============================] - 567s 1s/step - loss: 0.2360 - accuracy: 0.9220 - val_loss: 0.1471 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 6/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2190 - accuracy: 0.9280
# Epoch 6: val_loss improved from 0.13785 to 0.12801, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 611s 2s/step - loss: 0.2190 - accuracy: 0.9280 - val_loss: 0.1280 - val_accuracy: 0.9549 - lr: 0.0010
# Epoch 7/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9332
# Epoch 7: val_loss improved from 0.12801 to 0.12151, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 605s 2s/step - loss: 0.1984 - accuracy: 0.9332 - val_loss: 0.1215 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 8/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9342
# Epoch 8: val_loss did not improve from 0.12151
# 382/382 [==============================] - 599s 2s/step - loss: 0.1983 - accuracy: 0.9342 - val_loss: 0.1229 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 9/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1919 - accuracy: 0.9388
# Epoch 9: val_loss improved from 0.12151 to 0.11618, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 633s 2s/step - loss: 0.1919 - accuracy: 0.9388 - val_loss: 0.1162 - val_accuracy: 0.9603 - lr: 0.0010
# Epoch 10/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1924 - accuracy: 0.9367
# Epoch 10: val_loss improved from 0.11618 to 0.11291, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 597s 2s/step - loss: 0.1924 - accuracy: 0.9367 - val_loss: 0.1129 - val_accuracy: 0.9603 - lr: 0.0010
# Epoch 11/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9386
# Epoch 11: val_loss improved from 0.11291 to 0.10049, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 571s 1s/step - loss: 0.1802 - accuracy: 0.9386 - val_loss: 0.1005 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 12/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1671 - accuracy: 0.9422
# Epoch 12: val_loss did not improve from 0.10049
# 382/382 [==============================] - 595s 2s/step - loss: 0.1671 - accuracy: 0.9422 - val_loss: 0.1113 - val_accuracy: 0.9565 - lr: 0.0010
# Epoch 13/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.9432
# Epoch 13: val_loss did not improve from 0.10049
# 382/382 [==============================] - 616s 2s/step - loss: 0.1558 - accuracy: 0.9432 - val_loss: 0.1054 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 14/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9426
# Epoch 14: val_loss improved from 0.10049 to 0.09696, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 591s 2s/step - loss: 0.1658 - accuracy: 0.9426 - val_loss: 0.0970 - val_accuracy: 0.9610 - lr: 0.0010
# Epoch 15/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1582 - accuracy: 0.9454
# Epoch 15: val_loss improved from 0.09696 to 0.08884, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 550s 1s/step - loss: 0.1582 - accuracy: 0.9454 - val_loss: 0.0888 - val_accuracy: 0.9672 - lr: 0.0010
# Epoch 16/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1478 - accuracy: 0.9521
# Epoch 16: val_loss did not improve from 0.08884
# 382/382 [==============================] - 546s 1s/step - loss: 0.1478 - accuracy: 0.9521 - val_loss: 0.1055 - val_accuracy: 0.9649 - lr: 0.0010
# Epoch 17/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9508
# Epoch 17: val_loss did not improve from 0.08884
# 382/382 [==============================] - 553s 1s/step - loss: 0.1490 - accuracy: 0.9508 - val_loss: 0.1025 - val_accuracy: 0.9672 - lr: 0.0010
# Epoch 18/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9506
# Epoch 18: val_loss did not improve from 0.08884
# 382/382 [==============================] - 545s 1s/step - loss: 0.1524 - accuracy: 0.9506 - val_loss: 0.0943 - val_accuracy: 0.9649 - lr: 0.0010
# Epoch 19/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9553
# Epoch 19: val_loss did not improve from 0.08884
# 382/382 [==============================] - 597s 2s/step - loss: 0.1360 - accuracy: 0.9553 - val_loss: 0.0922 - val_accuracy: 0.9702 - lr: 0.0010
# Epoch 20/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1481 - accuracy: 0.9506
# Epoch 20: val_loss improved from 0.08884 to 0.08536, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 573s 1s/step - loss: 0.1481 - accuracy: 0.9506 - val_loss: 0.0854 - val_accuracy: 0.9710 - lr: 0.0010
# Epoch 21/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1387 - accuracy: 0.9514
# Epoch 21: val_loss improved from 0.08536 to 0.08480, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 548s 1s/step - loss: 0.1387 - accuracy: 0.9514 - val_loss: 0.0848 - val_accuracy: 0.9733 - lr: 0.0010
# Epoch 22/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1336 - accuracy: 0.9548
# Epoch 22: val_loss did not improve from 0.08480
# 382/382 [==============================] - 547s 1s/step - loss: 0.1336 - accuracy: 0.9548 - val_loss: 0.0906 - val_accuracy: 0.9733 - lr: 0.0010
# Epoch 23/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9527
# Epoch 23: val_loss did not improve from 0.08480
# 382/382 [==============================] - 548s 1s/step - loss: 0.1414 - accuracy: 0.9527 - val_loss: 0.0857 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 24/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9537
# Epoch 24: val_loss improved from 0.08480 to 0.08416, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 551s 1s/step - loss: 0.1429 - accuracy: 0.9537 - val_loss: 0.0842 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 25/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.9589
# Epoch 25: val_loss did not improve from 0.08416
# 382/382 [==============================] - 544s 1s/step - loss: 0.1215 - accuracy: 0.9589 - val_loss: 0.0977 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 26/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1256 - accuracy: 0.9570
# Epoch 26: val_loss did not improve from 0.08416
# 382/382 [==============================] - 553s 1s/step - loss: 0.1256 - accuracy: 0.9570 - val_loss: 0.0986 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 27/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9632
# Epoch 27: val_loss improved from 0.08416 to 0.08134, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 552s 1s/step - loss: 0.1141 - accuracy: 0.9632 - val_loss: 0.0813 - val_accuracy: 0.9733 - lr: 0.0010
# Epoch 28/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1200 - accuracy: 0.9611
# Epoch 28: val_loss did not improve from 0.08134
# 382/382 [==============================] - 547s 1s/step - loss: 0.1200 - accuracy: 0.9611 - val_loss: 0.0872 - val_accuracy: 0.9748 - lr: 0.0010
# Epoch 29/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9586
# Epoch 29: val_loss did not improve from 0.08134
# 382/382 [==============================] - 553s 1s/step - loss: 0.1162 - accuracy: 0.9586 - val_loss: 0.0853 - val_accuracy: 0.9733 - lr: 0.0010
# Epoch 30/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1136 - accuracy: 0.9596
# Epoch 30: val_loss did not improve from 0.08134
# 382/382 [==============================] - 550s 1s/step - loss: 0.1136 - accuracy: 0.9596 - val_loss: 0.0849 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 31/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9650
# Epoch 31: val_loss did not improve from 0.08134
# 382/382 [==============================] - 551s 1s/step - loss: 0.1046 - accuracy: 0.9650 - val_loss: 0.0819 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 32/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.9565
# Epoch 32: val_loss did not improve from 0.08134
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 382/382 [==============================] - 545s 1s/step - loss: 0.1248 - accuracy: 0.9565 - val_loss: 0.0905 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 33/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.9683
# Epoch 33: val_loss improved from 0.08134 to 0.07640, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 550s 1s/step - loss: 0.0915 - accuracy: 0.9683 - val_loss: 0.0764 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 34/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9674
# Epoch 34: val_loss did not improve from 0.07640
# 382/382 [==============================] - 554s 1s/step - loss: 0.0965 - accuracy: 0.9674 - val_loss: 0.0802 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 35/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0843 - accuracy: 0.9732
# Epoch 35: val_loss improved from 0.07640 to 0.07431, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 555s 1s/step - loss: 0.0843 - accuracy: 0.9732 - val_loss: 0.0743 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 36/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9720
# Epoch 36: val_loss improved from 0.07431 to 0.07195, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 550s 1s/step - loss: 0.0820 - accuracy: 0.9720 - val_loss: 0.0719 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 37/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9694
# Epoch 37: val_loss did not improve from 0.07195
# 382/382 [==============================] - 554s 1s/step - loss: 0.0865 - accuracy: 0.9694 - val_loss: 0.0745 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 38/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9743
# Epoch 38: val_loss improved from 0.07195 to 0.06571, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 552s 1s/step - loss: 0.0787 - accuracy: 0.9743 - val_loss: 0.0657 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 39/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9723
# Epoch 39: val_loss did not improve from 0.06571
# 382/382 [==============================] - 551s 1s/step - loss: 0.0786 - accuracy: 0.9723 - val_loss: 0.0733 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 40/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9727
# Epoch 40: val_loss did not improve from 0.06571
# 382/382 [==============================] - 550s 1s/step - loss: 0.0790 - accuracy: 0.9727 - val_loss: 0.0710 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 41/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9730
# Epoch 41: val_loss did not improve from 0.06571
# 382/382 [==============================] - 552s 1s/step - loss: 0.0845 - accuracy: 0.9730 - val_loss: 0.0719 - val_accuracy: 0.9778 - lr: 5.0000e-04
# Epoch 42/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0732 - accuracy: 0.9781
# Epoch 42: val_loss improved from 0.06571 to 0.06359, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 554s 1s/step - loss: 0.0732 - accuracy: 0.9781 - val_loss: 0.0636 - val_accuracy: 0.9817 - lr: 5.0000e-04
# Epoch 43/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9753
# Epoch 43: val_loss improved from 0.06359 to 0.06200, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 552s 1s/step - loss: 0.0743 - accuracy: 0.9753 - val_loss: 0.0620 - val_accuracy: 0.9809 - lr: 5.0000e-04
# Epoch 44/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9699
# Epoch 44: val_loss improved from 0.06200 to 0.06079, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 551s 1s/step - loss: 0.0848 - accuracy: 0.9699 - val_loss: 0.0608 - val_accuracy: 0.9809 - lr: 5.0000e-04
# Epoch 45/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0777 - accuracy: 0.9750
# Epoch 45: val_loss did not improve from 0.06079
# 382/382 [==============================] - 551s 1s/step - loss: 0.0777 - accuracy: 0.9750 - val_loss: 0.0671 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 46/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9733
# Epoch 46: val_loss did not improve from 0.06079
# 382/382 [==============================] - 551s 1s/step - loss: 0.0796 - accuracy: 0.9733 - val_loss: 0.0848 - val_accuracy: 0.9740 - lr: 5.0000e-04
# Epoch 47/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9761
# Epoch 47: val_loss did not improve from 0.06079
# 382/382 [==============================] - 550s 1s/step - loss: 0.0706 - accuracy: 0.9761 - val_loss: 0.0661 - val_accuracy: 0.9809 - lr: 5.0000e-04
# Epoch 48/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9730
# Epoch 48: val_loss did not improve from 0.06079
# 382/382 [==============================] - 552s 1s/step - loss: 0.0771 - accuracy: 0.9730 - val_loss: 0.0652 - val_accuracy: 0.9801 - lr: 5.0000e-04
# Epoch 49/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9723
# Epoch 49: val_loss did not improve from 0.06079
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 382/382 [==============================] - 551s 1s/step - loss: 0.0784 - accuracy: 0.9723 - val_loss: 0.0716 - val_accuracy: 0.9771 - lr: 5.0000e-04
# Epoch 50/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0653 - accuracy: 0.9781
# Epoch 50: val_loss did not improve from 0.06079
# 382/382 [==============================] - 550s 1s/step - loss: 0.0653 - accuracy: 0.9781 - val_loss: 0.0614 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 51/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9782
# Epoch 51: val_loss did not improve from 0.06079
# 382/382 [==============================] - 551s 1s/step - loss: 0.0612 - accuracy: 0.9782 - val_loss: 0.0668 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 52/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9779
# Epoch 52: val_loss improved from 0.06079 to 0.05838, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 548s 1s/step - loss: 0.0627 - accuracy: 0.9779 - val_loss: 0.0584 - val_accuracy: 0.9794 - lr: 2.5000e-04
# Epoch 53/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9774
# Epoch 53: val_loss did not improve from 0.05838
# 382/382 [==============================] - 549s 1s/step - loss: 0.0648 - accuracy: 0.9774 - val_loss: 0.0710 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 54/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9804
# Epoch 54: val_loss did not improve from 0.05838
# 382/382 [==============================] - 550s 1s/step - loss: 0.0565 - accuracy: 0.9804 - val_loss: 0.0613 - val_accuracy: 0.9794 - lr: 2.5000e-04
# Epoch 55/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9802
# Epoch 55: val_loss improved from 0.05838 to 0.05556, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 558s 1s/step - loss: 0.0652 - accuracy: 0.9802 - val_loss: 0.0556 - val_accuracy: 0.9824 - lr: 2.5000e-04
# Epoch 56/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0632 - accuracy: 0.9786
# Epoch 56: val_loss improved from 0.05556 to 0.05486, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 553s 1s/step - loss: 0.0632 - accuracy: 0.9786 - val_loss: 0.0549 - val_accuracy: 0.9817 - lr: 2.5000e-04
# Epoch 57/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9827
# Epoch 57: val_loss did not improve from 0.05486
# 382/382 [==============================] - 547s 1s/step - loss: 0.0534 - accuracy: 0.9827 - val_loss: 0.0584 - val_accuracy: 0.9794 - lr: 2.5000e-04
# Epoch 58/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9797
# Epoch 58: val_loss did not improve from 0.05486
# 382/382 [==============================] - 551s 1s/step - loss: 0.0635 - accuracy: 0.9797 - val_loss: 0.0559 - val_accuracy: 0.9824 - lr: 2.5000e-04
# Epoch 59/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9807
# Epoch 59: val_loss improved from 0.05486 to 0.05405, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 551s 1s/step - loss: 0.0508 - accuracy: 0.9807 - val_loss: 0.0540 - val_accuracy: 0.9809 - lr: 2.5000e-04
# Epoch 60/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0609 - accuracy: 0.9804
# Epoch 60: val_loss did not improve from 0.05405
# 382/382 [==============================] - 546s 1s/step - loss: 0.0609 - accuracy: 0.9804 - val_loss: 0.0594 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 61/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9815
# Epoch 61: val_loss did not improve from 0.05405
# 382/382 [==============================] - 550s 1s/step - loss: 0.0524 - accuracy: 0.9815 - val_loss: 0.0602 - val_accuracy: 0.9809 - lr: 2.5000e-04
# Epoch 62/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0556 - accuracy: 0.9802
# Epoch 62: val_loss did not improve from 0.05405
# 382/382 [==============================] - 548s 1s/step - loss: 0.0556 - accuracy: 0.9802 - val_loss: 0.0585 - val_accuracy: 0.9817 - lr: 2.5000e-04
# Epoch 63/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9786
# Epoch 63: val_loss did not improve from 0.05405
# 382/382 [==============================] - 550s 1s/step - loss: 0.0591 - accuracy: 0.9786 - val_loss: 0.0561 - val_accuracy: 0.9824 - lr: 2.5000e-04
# Epoch 64/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9815
# Epoch 64: val_loss did not improve from 0.05405
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 382/382 [==============================] - 550s 1s/step - loss: 0.0555 - accuracy: 0.9815 - val_loss: 0.0570 - val_accuracy: 0.9794 - lr: 2.5000e-04
# Epoch 65/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9823
# Epoch 65: val_loss did not improve from 0.05405
# 382/382 [==============================] - 547s 1s/step - loss: 0.0532 - accuracy: 0.9823 - val_loss: 0.0580 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 66/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9830
# Epoch 66: val_loss did not improve from 0.05405
# 382/382 [==============================] - 551s 1s/step - loss: 0.0545 - accuracy: 0.9830 - val_loss: 0.0558 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 67/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9854
# Epoch 67: val_loss improved from 0.05405 to 0.05387, saving model to efficientnetB3_TL_weights.h5
# 382/382 [==============================] - 551s 1s/step - loss: 0.0456 - accuracy: 0.9854 - val_loss: 0.0539 - val_accuracy: 0.9832 - lr: 1.2500e-04
# Epoch 68/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9830
# Epoch 68: val_loss did not improve from 0.05387
# 382/382 [==============================] - 549s 1s/step - loss: 0.0516 - accuracy: 0.9830 - val_loss: 0.0597 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 69/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9833
# Epoch 69: val_loss did not improve from 0.05387
# 382/382 [==============================] - 549s 1s/step - loss: 0.0500 - accuracy: 0.9833 - val_loss: 0.0566 - val_accuracy: 0.9824 - lr: 1.2500e-04
# Epoch 70/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9810
# Epoch 70: val_loss did not improve from 0.05387
# 382/382 [==============================] - 555s 1s/step - loss: 0.0511 - accuracy: 0.9810 - val_loss: 0.0582 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 71/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9845
# Epoch 71: val_loss did not improve from 0.05387
# 382/382 [==============================] - 551s 1s/step - loss: 0.0469 - accuracy: 0.9845 - val_loss: 0.0579 - val_accuracy: 0.9824 - lr: 1.2500e-04
# Epoch 72/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9853
# Epoch 72: val_loss did not improve from 0.05387
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 382/382 [==============================] - 546s 1s/step - loss: 0.0440 - accuracy: 0.9853 - val_loss: 0.0608 - val_accuracy: 0.9809 - lr: 1.2500e-04
# Epoch 73/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0515 - accuracy: 0.9833
# Epoch 73: val_loss did not improve from 0.05387
# 382/382 [==============================] - 551s 1s/step - loss: 0.0515 - accuracy: 0.9833 - val_loss: 0.0560 - val_accuracy: 0.9809 - lr: 6.2500e-05
# Epoch 74/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9836
# Epoch 74: val_loss did not improve from 0.05387
# 382/382 [==============================] - 550s 1s/step - loss: 0.0460 - accuracy: 0.9836 - val_loss: 0.0551 - val_accuracy: 0.9832 - lr: 6.2500e-05
# Epoch 75/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0452 - accuracy: 0.9858
# Epoch 75: val_loss did not improve from 0.05387
# 382/382 [==============================] - 550s 1s/step - loss: 0.0452 - accuracy: 0.9858 - val_loss: 0.0565 - val_accuracy: 0.9824 - lr: 6.2500e-05

# %% [markdown]
# ### 7. EVALUACIÓN DEL MODELO EFFICIENTNETB3

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

# Gráfica de Loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 82/82 [==============================] - 85s 1s/step - loss: 0.0507 - accuracy: 0.9832
#
# Test Accuracy : 0.9832
# Test Loss     : 0.0507
# 82/82 [==============================] - 88s 1s/step
# F1 Score      : 0.9832
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9554    1.0000    0.9772       150
#    mancha_anillo     1.0000    1.0000    1.0000       106
#     mancha_parda     0.9733    0.9733    0.9733       150
#          mosaico     0.9867    0.9867    0.9867       150
#      muermo_rojo     0.9728    0.9533    0.9630       150
#             roya     0.9865    0.9733    0.9799       150
#            sanas     0.9800    0.9800    0.9800       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     1.0000    0.9867    0.9933       150
#
#         accuracy                         0.9832      1309
#        macro avg     0.9855    0.9853    0.9853      1309
#     weighted avg     0.9833    0.9832    0.9832      1309
#
#
# Resultados guardados en efficientnetB3_TL_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Hojas con 1 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Hojas con 1 o más confusiones:
#   muermo_rojo → hoja_amarilla: 3 imágenes
#   muermo_rojo → mancha_parda: 3 imágenes
#   mancha_parda → hoja_amarilla: 2 imágenes
#   mosaico → sanas: 2 imágenes
#   roya → muermo_rojo: 2 imágenes
#   sanas → mosaico: 2 imágenes
#   mancha_parda → roya: 1 imágenes
#   mancha_parda → muermo_rojo: 1 imágenes
#   muermo_rojo → roya: 1 imágenes
#   roya → sanas: 1 imágenes
#   roya → hoja_amarilla: 1 imágenes
#   sanas → hoja_amarilla: 1 imágenes
#   tizon_bacteriano → muermo_rojo: 1 imágenes
#   tizon_bacteriano → mancha_parda: 1 imágenes
#
# Total de imágenes a mostrar: 22

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB3_TL_weights.h5
