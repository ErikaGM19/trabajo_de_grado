# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS DEL MODELO

# %%
IMG_SIZE      = 300
BATCH_SIZE    = 16
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = "efficientnetB3_TL"

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
# RUTAS DEL DATASET
base_dir  = "../../../Data/Cana_de_azucar"
train_dir = os.path.join(base_dir, "train")
val_dir   = os.path.join(base_dir, "val")
test_dir  = os.path.join(base_dir, "test")

# Generador para entrenamiento con augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

# Validación y test: SOLO normalización, sin augmentation
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

# Dataset de ENTRENAMIENTO
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

# Dataset de VALIDACIÓN
val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Dataset de TEST
test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Imágenes de entrenamiento : {train_generator.samples}")
print(f"Imágenes de validación    : {val_generator.samples}")
print(f"Imágenes de test          : {test_generator.samples}")
# Out:
# Found 6106 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Found 1308 images belonging to 10 classes.
# Imágenes de entrenamiento : 6106
# Imágenes de validación    : 1308
# Imágenes de test          : 1308

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO EFFIENTNETB3

# %%
# CARGAR EFFICIENTNET-B3 CON PESOS DE IMAGENET

base_model = EfficientNetB3(
    weights='imagenet',                 
    include_top=False,                  
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Congelamos la red base

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 2s 0us/step

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb3 (Functional)  (None, 10, 10, 1536)     10783535
#
#  global_average_pooling2d (G  (None, 1536)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               196736
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 10,981,561
# Trainable params: 198,026
# Non-trainable params: 10,783,535
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,          # = 10
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f"{NOMBRE_MODELO}_weights.h5",
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True, 
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 382/382 [==============================] - ETA: 0s - loss: 0.7551 - accuracy: 0.7522
# Epoch 1: val_loss improved from inf to 0.32518, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1702s 4s/step - loss: 0.7551 - accuracy: 0.7522 - val_loss: 0.3252 - val_accuracy: 0.8930 - lr: 0.0010
# Epoch 2/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3741 - accuracy: 0.8798
# Epoch 2: val_loss improved from 0.32518 to 0.20296, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1581s 4s/step - loss: 0.3741 - accuracy: 0.8798 - val_loss: 0.2030 - val_accuracy: 0.9373 - lr: 0.0010
# Epoch 3/75
# 382/382 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.9050
# Epoch 3: val_loss improved from 0.20296 to 0.16761, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1553s 4s/step - loss: 0.3019 - accuracy: 0.9050 - val_loss: 0.1676 - val_accuracy: 0.9472 - lr: 0.0010
# Epoch 4/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.9127
# Epoch 4: val_loss improved from 0.16761 to 0.16609, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1547s 4s/step - loss: 0.2657 - accuracy: 0.9127 - val_loss: 0.1661 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 5/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.9229
# Epoch 5: val_loss improved from 0.16609 to 0.15388, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1534s 4s/step - loss: 0.2423 - accuracy: 0.9229 - val_loss: 0.1539 - val_accuracy: 0.9480 - lr: 0.0010
# Epoch 6/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.9260
# Epoch 6: val_loss improved from 0.15388 to 0.13808, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1516s 4s/step - loss: 0.2228 - accuracy: 0.9260 - val_loss: 0.1381 - val_accuracy: 0.9595 - lr: 0.0010
# Epoch 7/75
# 382/382 [==============================] - ETA: 0s - loss: 0.2124 - accuracy: 0.9315
# Epoch 7: val_loss improved from 0.13808 to 0.11436, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1522s 4s/step - loss: 0.2124 - accuracy: 0.9315 - val_loss: 0.1144 - val_accuracy: 0.9648 - lr: 0.0010
# Epoch 8/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1975 - accuracy: 0.9343
# Epoch 8: val_loss did not improve from 0.11436
# 382/382 [==============================] - 1511s 4s/step - loss: 0.1975 - accuracy: 0.9343 - val_loss: 0.1184 - val_accuracy: 0.9564 - lr: 0.0010
# Epoch 9/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1924 - accuracy: 0.9391
# Epoch 9: val_loss did not improve from 0.11436
# 382/382 [==============================] - 1519s 4s/step - loss: 0.1924 - accuracy: 0.9391 - val_loss: 0.1196 - val_accuracy: 0.9625 - lr: 0.0010
# Epoch 10/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1706 - accuracy: 0.9427
# Epoch 10: val_loss did not improve from 0.11436
# 382/382 [==============================] - 1508s 4s/step - loss: 0.1706 - accuracy: 0.9427 - val_loss: 0.1196 - val_accuracy: 0.9602 - lr: 0.0010
# Epoch 11/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1752 - accuracy: 0.9428
# Epoch 11: val_loss did not improve from 0.11436
# 382/382 [==============================] - 1499s 4s/step - loss: 0.1752 - accuracy: 0.9428 - val_loss: 0.1360 - val_accuracy: 0.9518 - lr: 0.0010
# Epoch 12/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1630 - accuracy: 0.9432
# Epoch 12: val_loss did not improve from 0.11436
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 382/382 [==============================] - 1511s 4s/step - loss: 0.1630 - accuracy: 0.9432 - val_loss: 0.1179 - val_accuracy: 0.9549 - lr: 0.0010
# Epoch 13/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9566
# Epoch 13: val_loss improved from 0.11436 to 0.10840, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1506s 4s/step - loss: 0.1357 - accuracy: 0.9566 - val_loss: 0.1084 - val_accuracy: 0.9625 - lr: 5.0000e-04
# Epoch 14/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9568
# Epoch 14: val_loss improved from 0.10840 to 0.10402, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1512s 4s/step - loss: 0.1347 - accuracy: 0.9568 - val_loss: 0.1040 - val_accuracy: 0.9641 - lr: 5.0000e-04
# Epoch 15/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9586
# Epoch 15: val_loss improved from 0.10402 to 0.09065, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1503s 4s/step - loss: 0.1294 - accuracy: 0.9586 - val_loss: 0.0906 - val_accuracy: 0.9618 - lr: 5.0000e-04
# Epoch 16/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9591
# Epoch 16: val_loss did not improve from 0.09065
# 382/382 [==============================] - 1523s 4s/step - loss: 0.1212 - accuracy: 0.9591 - val_loss: 0.0925 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 17/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1162 - accuracy: 0.9627
# Epoch 17: val_loss did not improve from 0.09065
# 382/382 [==============================] - 1522s 4s/step - loss: 0.1162 - accuracy: 0.9627 - val_loss: 0.0909 - val_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 18/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9595
# Epoch 18: val_loss did not improve from 0.09065
# 382/382 [==============================] - 1518s 4s/step - loss: 0.1190 - accuracy: 0.9595 - val_loss: 0.0929 - val_accuracy: 0.9648 - lr: 5.0000e-04
# Epoch 19/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9605
# Epoch 19: val_loss did not improve from 0.09065
# 382/382 [==============================] - 1504s 4s/step - loss: 0.1174 - accuracy: 0.9605 - val_loss: 0.0923 - val_accuracy: 0.9702 - lr: 5.0000e-04
# Epoch 20/75
# 382/382 [==============================] - ETA: 0s - loss: 0.1074 - accuracy: 0.9659
# Epoch 20: val_loss did not improve from 0.09065
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 382/382 [==============================] - 1494s 4s/step - loss: 0.1074 - accuracy: 0.9659 - val_loss: 0.0939 - val_accuracy: 0.9664 - lr: 5.0000e-04
# Epoch 21/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9659
# Epoch 21: val_loss improved from 0.09065 to 0.08675, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1507s 4s/step - loss: 0.0900 - accuracy: 0.9659 - val_loss: 0.0868 - val_accuracy: 0.9687 - lr: 2.5000e-04
# Epoch 22/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9695
# Epoch 22: val_loss did not improve from 0.08675
# 382/382 [==============================] - 1504s 4s/step - loss: 0.0884 - accuracy: 0.9695 - val_loss: 0.0887 - val_accuracy: 0.9641 - lr: 2.5000e-04
# Epoch 23/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0905 - accuracy: 0.9712
# Epoch 23: val_loss improved from 0.08675 to 0.08481, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1522s 4s/step - loss: 0.0905 - accuracy: 0.9712 - val_loss: 0.0848 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 24/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0987 - accuracy: 0.9672
# Epoch 24: val_loss did not improve from 0.08481
# 382/382 [==============================] - 1561s 4s/step - loss: 0.0987 - accuracy: 0.9672 - val_loss: 0.0931 - val_accuracy: 0.9648 - lr: 2.5000e-04
# Epoch 25/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9708
# Epoch 25: val_loss improved from 0.08481 to 0.07663, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1528s 4s/step - loss: 0.0903 - accuracy: 0.9708 - val_loss: 0.0766 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 26/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9695
# Epoch 26: val_loss did not improve from 0.07663
# 382/382 [==============================] - 1504s 4s/step - loss: 0.0892 - accuracy: 0.9695 - val_loss: 0.0788 - val_accuracy: 0.9725 - lr: 2.5000e-04
# Epoch 27/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9722
# Epoch 27: val_loss did not improve from 0.07663
# 382/382 [==============================] - 1495s 4s/step - loss: 0.0859 - accuracy: 0.9722 - val_loss: 0.0834 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 28/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9700
# Epoch 28: val_loss did not improve from 0.07663
# 382/382 [==============================] - 1534s 4s/step - loss: 0.0899 - accuracy: 0.9700 - val_loss: 0.0821 - val_accuracy: 0.9694 - lr: 2.5000e-04
# Epoch 29/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9723
# Epoch 29: val_loss did not improve from 0.07663
# 382/382 [==============================] - 1512s 4s/step - loss: 0.0844 - accuracy: 0.9723 - val_loss: 0.0769 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 30/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9710
# Epoch 30: val_loss improved from 0.07663 to 0.07156, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1489s 4s/step - loss: 0.0851 - accuracy: 0.9710 - val_loss: 0.0716 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 31/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9725
# Epoch 31: val_loss did not improve from 0.07156
# 382/382 [==============================] - 1499s 4s/step - loss: 0.0811 - accuracy: 0.9725 - val_loss: 0.0811 - val_accuracy: 0.9732 - lr: 2.5000e-04
# Epoch 32/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0817 - accuracy: 0.9743
# Epoch 32: val_loss did not improve from 0.07156
# 382/382 [==============================] - 1494s 4s/step - loss: 0.0817 - accuracy: 0.9743 - val_loss: 0.0847 - val_accuracy: 0.9679 - lr: 2.5000e-04
# Epoch 33/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9743
# Epoch 33: val_loss did not improve from 0.07156
# 382/382 [==============================] - 1498s 4s/step - loss: 0.0754 - accuracy: 0.9743 - val_loss: 0.0804 - val_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 34/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9754
# Epoch 34: val_loss did not improve from 0.07156
# 382/382 [==============================] - 1499s 4s/step - loss: 0.0775 - accuracy: 0.9754 - val_loss: 0.0762 - val_accuracy: 0.9717 - lr: 2.5000e-04
# Epoch 35/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9745
# Epoch 35: val_loss did not improve from 0.07156
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 382/382 [==============================] - 1503s 4s/step - loss: 0.0756 - accuracy: 0.9745 - val_loss: 0.0821 - val_accuracy: 0.9702 - lr: 2.5000e-04
# Epoch 36/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9761
# Epoch 36: val_loss did not improve from 0.07156
# 382/382 [==============================] - 1521s 4s/step - loss: 0.0760 - accuracy: 0.9761 - val_loss: 0.0718 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 37/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9740
# Epoch 37: val_loss improved from 0.07156 to 0.07154, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1516s 4s/step - loss: 0.0711 - accuracy: 0.9740 - val_loss: 0.0715 - val_accuracy: 0.9732 - lr: 1.2500e-04
# Epoch 38/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0719 - accuracy: 0.9763
# Epoch 38: val_loss improved from 0.07154 to 0.06960, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1503s 4s/step - loss: 0.0719 - accuracy: 0.9763 - val_loss: 0.0696 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 39/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.9740
# Epoch 39: val_loss did not improve from 0.06960
# 382/382 [==============================] - 1494s 4s/step - loss: 0.0765 - accuracy: 0.9740 - val_loss: 0.0750 - val_accuracy: 0.9725 - lr: 1.2500e-04
# Epoch 40/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9797
# Epoch 40: val_loss did not improve from 0.06960
# 382/382 [==============================] - 1497s 4s/step - loss: 0.0634 - accuracy: 0.9797 - val_loss: 0.0752 - val_accuracy: 0.9748 - lr: 1.2500e-04
# Epoch 41/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9766
# Epoch 41: val_loss improved from 0.06960 to 0.06863, saving model to efficientnetB3_sin_ft_weights.h5
# 382/382 [==============================] - 1517s 4s/step - loss: 0.0730 - accuracy: 0.9766 - val_loss: 0.0686 - val_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 42/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0666 - accuracy: 0.9777
# Epoch 42: val_loss did not improve from 0.06863
# 382/382 [==============================] - 1520s 4s/step - loss: 0.0666 - accuracy: 0.9777 - val_loss: 0.0733 - val_accuracy: 0.9763 - lr: 1.2500e-04
# Epoch 43/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.9782
# Epoch 43: val_loss did not improve from 0.06863
# 382/382 [==============================] - 1522s 4s/step - loss: 0.0649 - accuracy: 0.9782 - val_loss: 0.0698 - val_accuracy: 0.9755 - lr: 1.2500e-04
# Epoch 44/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0710 - accuracy: 0.9754
# Epoch 44: val_loss did not improve from 0.06863
# 382/382 [==============================] - 1523s 4s/step - loss: 0.0710 - accuracy: 0.9754 - val_loss: 0.0761 - val_accuracy: 0.9709 - lr: 1.2500e-04
# Epoch 45/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9784
# Epoch 45: val_loss did not improve from 0.06863
# 382/382 [==============================] - 1537s 4s/step - loss: 0.0688 - accuracy: 0.9784 - val_loss: 0.0791 - val_accuracy: 0.9709 - lr: 1.2500e-04
# Epoch 46/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.9776
# Epoch 46: val_loss did not improve from 0.06863
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 382/382 [==============================] - 1517s 4s/step - loss: 0.0665 - accuracy: 0.9776 - val_loss: 0.0748 - val_accuracy: 0.9709 - lr: 1.2500e-04
# Epoch 47/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9776
# Epoch 47: val_loss did not improve from 0.06863
# 382/382 [==============================] - 1533s 4s/step - loss: 0.0686 - accuracy: 0.9776 - val_loss: 0.0725 - val_accuracy: 0.9732 - lr: 6.2500e-05
# Epoch 48/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9790
# Epoch 48: val_loss did not improve from 0.06863
# 382/382 [==============================] - 1580s 4s/step - loss: 0.0641 - accuracy: 0.9790 - val_loss: 0.0732 - val_accuracy: 0.9763 - lr: 6.2500e-05
# Epoch 49/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9790
# Epoch 49: val_loss did not improve from 0.06863
# 382/382 [==============================] - 1823s 5s/step - loss: 0.0620 - accuracy: 0.9790 - val_loss: 0.0718 - val_accuracy: 0.9778 - lr: 6.2500e-05
# Epoch 50/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9771
# Epoch 50: val_loss did not improve from 0.06863
# 382/382 [==============================] - 1525s 4s/step - loss: 0.0729 - accuracy: 0.9771 - val_loss: 0.0733 - val_accuracy: 0.9748 - lr: 6.2500e-05
# Epoch 51/75
# 382/382 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.9787Restoring model weights from the end of the best epoch: 41.
#
# Epoch 51: val_loss did not improve from 0.06863
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 382/382 [==============================] - 1447s 4s/step - loss: 0.0683 - accuracy: 0.9787 - val_loss: 0.0745 - val_accuracy: 0.9732 - lr: 6.2500e-05
# Epoch 51: early stopping

# %% [markdown]
# ### 7. EVALUACIÓN DEL MODELO EFFICIENTNETB3

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfica de Accuracy
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

# Gráfica de Loss
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 82/82 [==============================] - 249s 3s/step - loss: 0.0588 - accuracy: 0.9801
#
# Test Accuracy : 0.9801
# Test Loss     : 0.0588
# 82/82 [==============================] - 247s 3s/step
# F1 Score      : 0.9801
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9803    0.9933    0.9868       150
#    mancha_anillo     0.9906    1.0000    0.9953       105
#     mancha_parda     0.9799    0.9733    0.9766       150
#          mosaico     0.9737    0.9867    0.9801       150
#      muermo_rojo     0.9419    0.9733    0.9574       150
#             roya     0.9790    0.9333    0.9556       150
#            sanas     0.9800    0.9800    0.9800       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     1.0000    0.9867    0.9933       150
#
#         accuracy                         0.9801      1308
#        macro avg     0.9825    0.9827    0.9825      1308
#     weighted avg     0.9803    0.9801    0.9801      1308
#
#
# Resultados guardados en efficientnetB3_sin_ft_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL = 5
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print("Pares con 5 o más confusiones:")
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f"  {par[0]} → {par[1]}: {count} imágenes")

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f"\nTotal de imágenes a mostrar: {len(indices_filtrados)}")

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols = 5
    n_filas = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f"Real: {clase_real}\nPredicha: {clase_predicha}",
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f"{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)",
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#   roya → muermo_rojo: 5 imágenes
#
# Total de imágenes a mostrar: 5

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: efficientnetB3_sin_ft_weights.h5
