# %% [markdown]
# ### Ajuste de hiperparámetros - Batch size = 64

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from experimento_utils import ejecutar_experimento
from mejores_valores import MEJOR_DROPOUT, MEJOR_CAPAS

CARPETA_EXPERIMENTO = os.path.abspath('.')

# %%
resultado, history = ejecutar_experimento(
    nombre_experimento='resnet50_TL_batch64',
    carpeta_experimento=CARPETA_EXPERIMENTO,
    learning_rate=1e-5,
    optimizador='adam',
    batch_size=64,
    dropout=MEJOR_DROPOUT,
    capas_descongeladas=MEJOR_CAPAS,
    epochs=30, patience_es=5, patience_lr=3
)
resultado
# Out:
# ...
# EXPERIMENTO: resnet50_TL_batch64
# LR=1e-05 | optimizador=adam | batch=64 | dropout=0.3 | capas_descongeladas=50
# ...
#
# Found 6112 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Epoch 1/30
# 96/96 [==============================] - 394s 4s/step - loss: 1.9016 - accuracy: 0.3562 - val_loss: 1.0500 - val_accuracy: 0.7357 - lr: 1.0000e-05
# Epoch 2/30
# 96/96 [==============================] - 395s 4s/step - loss: 0.8612 - accuracy: 0.7695 - val_loss: 0.3078 - val_accuracy: 0.9305 - lr: 1.0000e-05
# Epoch 3/30
# 96/96 [==============================] - 394s 4s/step - loss: 0.4136 - accuracy: 0.9004 - val_loss: 0.1529 - val_accuracy: 0.9580 - lr: 1.0000e-05
# Epoch 4/30
# 96/96 [==============================] - 397s 4s/step - loss: 0.2503 - accuracy: 0.9400 - val_loss: 0.0988 - val_accuracy: 0.9702 - lr: 1.0000e-05
# Epoch 5/30
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy — resnet50_TL_batch64')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()
plt.show()
