# %% [markdown]
# ### Ajuste de hiperparámetros - Capas descongeladas = 10

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from experimento_utils import ejecutar_experimento
from mejores_valores import MEJOR_DROPOUT

CARPETA_EXPERIMENTO = os.path.abspath('.')

# %%
resultado, history = ejecutar_experimento(
    nombre_experimento='resnet50_TL_capas10',
    carpeta_experimento=CARPETA_EXPERIMENTO,
    learning_rate=1e-5,
    optimizador='adam',
    batch_size=32,
    dropout=MEJOR_DROPOUT,
    capas_descongeladas=10,
    epochs=30, patience_es=5, patience_lr=3
)
resultado
# Out:
# ============================================================
# EXPERIMENTO: resnet50_TL_capas10
# LR=1e-05 | optimizador=adam | batch=32 | dropout=0.3 | capas_descongeladas=10
# ============================================================
#
# Found 6112 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Epoch 1/30
# 191/191 [==============================] - 307s 2s/step - loss: 2.1302 - accuracy: 0.2947 - val_loss: 1.3273 - val_accuracy: 0.5974 - lr: 1.0000e-05
# Epoch 2/30
# 191/191 [==============================] - 325s 2s/step - loss: 1.2315 - accuracy: 0.6194 - val_loss: 0.7313 - val_accuracy: 0.8014 - lr: 1.0000e-05
# Epoch 3/30
# 191/191 [==============================] - 327s 2s/step - loss: 0.8230 - accuracy: 0.7580 - val_loss: 0.4462 - val_accuracy: 0.8755 - lr: 1.0000e-05
# Epoch 4/30
# 191/191 [==============================] - 329s 2s/step - loss: 0.5838 - accuracy: 0.8334 - val_loss: 0.2835 - val_accuracy: 0.9175 - lr: 1.0000e-05
# Epoch 5/30
# 191/191 [==============================] - 327s 2s/step - loss: 0.4233 - accuracy: 0.8869 - val_loss: 0.2092 - val_accuracy: 0.9427 - lr: 1.0000e-05
# Epoch 6/30
# 191/191 [==============================] - 323s 2s/step - loss: 0.3408 - accuracy: 0.9064 - val_loss: 0.1677 - val_accuracy: 0.9534 - lr: 1.0000e-05
# Epoch 7/30
# 191/191 [==============================] - 325s 2s/step - loss: 0.2781 - accuracy: 0.9274 - val_loss: 0.1423 - val_accuracy: 0.9587 - lr: 1.0000e-05
# Epoch 8/30
# 191/191 [==============================] - 334s 2s/step - loss: 0.2384 - accuracy: 0.9375 - val_loss: 0.1264 - val_accuracy: 0.9649 - lr: 1.0000e-05
# Epoch 9/30
# 191/191 [==============================] - 321s 2s/step - loss: 0.2014 - accuracy: 0.9416 - val_loss: 0.1057 - val_accuracy: 0.9694 - lr: 1.0000e-05
# Epoch 10/30
# 191/191 [==============================] - 322s 2s/step - loss: 0.1803 - accuracy: 0.9490 - val_loss: 0.0951 - val_accuracy: 0.9740 - lr: 1.0000e-05
# Epoch 11/30
# 191/191 [==============================] - 320s 2s/step - loss: 0.1599 - accuracy: 0.9576 - val_loss: 0.0899 - val_accuracy: 0.9725 - lr: 1.0000e-05
# Epoch 12/30
# 191/191 [==============================] - 322s 2s/step - loss: 0.1531 - accuracy: 0.9558 - val_loss: 0.0831 - val_accuracy: 0.9733 - lr: 1.0000e-05
# Epoch 13/30
# 191/191 [==============================] - 319s 2s/step - loss: 0.1297 - accuracy: 0.9634 - val_loss: 0.0734 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 14/30
# 191/191 [==============================] - 324s 2s/step - loss: 0.1218 - accuracy: 0.9655 - val_loss: 0.0735 - val_accuracy: 0.9763 - lr: 1.0000e-05
# Epoch 15/30
# 191/191 [==============================] - 321s 2s/step - loss: 0.1089 - accuracy: 0.9699 - val_loss: 0.0700 - val_accuracy: 0.9794 - lr: 1.0000e-05
# Epoch 16/30
# 191/191 [==============================] - 321s 2s/step - loss: 0.1040 - accuracy: 0.9701 - val_loss: 0.0715 - val_accuracy: 0.9778 - lr: 1.0000e-05
# Epoch 17/30
# 191/191 [==============================] - 321s 2s/step - loss: 0.0938 - accuracy: 0.9733 - val_loss: 0.0657 - val_accuracy: 0.9809 - lr: 1.0000e-05
# Epoch 18/30
# 191/191 [==============================] - 321s 2s/step - loss: 0.0864 - accuracy: 0.9763 - val_loss: 0.0607 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 19/30
# 191/191 [==============================] - 325s 2s/step - loss: 0.0765 - accuracy: 0.9782 - val_loss: 0.0561 - val_accuracy: 0.9840 - lr: 1.0000e-05
# Epoch 20/30
# 191/191 [==============================] - 322s 2s/step - loss: 0.0852 - accuracy: 0.9746 - val_loss: 0.0593 - val_accuracy: 0.9832 - lr: 1.0000e-05
# Epoch 21/30
# 191/191 [==============================] - 322s 2s/step - loss: 0.0827 - accuracy: 0.9758 - val_loss: 0.0583 - val_accuracy: 0.9855 - lr: 1.0000e-05
# Epoch 22/30
# 191/191 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9818
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 321s 2s/step - loss: 0.0627 - accuracy: 0.9818 - val_loss: 0.0600 - val_accuracy: 0.9840 - lr: 1.0000e-05
# Epoch 23/30
# 191/191 [==============================] - 322s 2s/step - loss: 0.0645 - accuracy: 0.9823 - val_loss: 0.0582 - val_accuracy: 0.9847 - lr: 5.0000e-06
# Epoch 24/30
# 191/191 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9818Restoring model weights from the end of the best epoch: 19.
# 191/191 [==============================] - 326s 2s/step - loss: 0.0660 - accuracy: 0.9818 - val_loss: 0.0573 - val_accuracy: 0.9855 - lr: 5.0000e-06
# Epoch 24: early stopping
# Resultados guardados en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\Capas_10\resnet50_TL_capas10_resultados.txt
# Resumen actualizado en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\resultados_todos_los_experimentos.csv
# {'timestamp': '20260730_232935',
#  'experimento': 'resnet50_TL_capas10',
#  'learning_rate': 1e-05,
#  'optimizador': 'adam',
#  'batch_size': 32,
#  'dropout': 0.3,
#  'capas_descongeladas': 10,
#  'epochs_max': 30,
#  'epochs_entrenadas': 24,
#  'test_accuracy': 0.9862,
#  'test_loss': 0.0457,
#  'f1_score': 0.9862,
#  'duracion_min': 129.2}

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy — resnet50_TL_capas10')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()
plt.show()
