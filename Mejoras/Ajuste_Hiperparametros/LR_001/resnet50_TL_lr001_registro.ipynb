# %% [markdown]
# ### Ajuste de hiperparámetros - Learning Rate = 0.001

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from experimento_utils import ejecutar_experimento

CARPETA_EXPERIMENTO = os.path.abspath('.')

# %%
resultado, history = ejecutar_experimento(
    nombre_experimento='resnet50_TL_lr001',
    carpeta_experimento=CARPETA_EXPERIMENTO,
    learning_rate=0.001,
    optimizador='adam',
    batch_size=32,
    dropout=0.5,
    capas_descongeladas=0,
    epochs=30, patience_es=5, patience_lr=3
)
resultado
# Out:
# ...
# EXPERIMENTO: resnet50_TL_lr001
# LR=0.001 | optimizador=adam | batch=32 | dropout=0.5 | capas_descongeladas=0
# ...
#
# Found 6112 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Epoch 1/30
# 191/191 [==============================] - 339s 2s/step - loss: 0.8830 - accuracy: 0.7027 - val_loss: 0.2565 - val_accuracy: 0.9259 - lr: 0.0010
# Epoch 2/30
# 191/191 [==============================] - 352s 2s/step - loss: 0.4174 - accuracy: 0.8622 - val_loss: 0.1894 - val_accuracy: 0.9427 - lr: 0.0010
# Epoch 3/30
# 191/191 [==============================] - 346s 2s/step - loss: 0.3443 - accuracy: 0.8865 - val_loss: 0.1974 - val_accuracy: 0.9335 - lr: 0.0010
# Epoch 4/30
# 191/191 [==============================] - 340s 2s/step - loss: 0.2926 - accuracy: 0.9066 - val_loss: 0.1498 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 5/30
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy — resnet50_TL_lr001 (búsqueda, 30 épocas)')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()
plt.show()

# %%
import sys, os
sys.path.append(os.path.abspath('.'))  # ajusta la ruta si lo corres desde otra carpeta
from experimento_utils import guardar_resultado_csv

datos_base = {
    'learning_rate': 0.001, 'optimizador': 'adam', 'batch_size': 32,
    'dropout': 0.5, 'capas_descongeladas': 0,
    'epochs_max': 30, 'epochs_entrenadas': 19,
    'test_accuracy': 0.9763, 'test_loss': 0.0786,
    'f1_score': 0.9763, 'duracion_min': 107.8
}

for nombre in ['resnet50_TL_dropout05', 'resnet50_TL_capas0', 'resnet50_TL_batch32']:
    fila = {'timestamp': '20260729_230237', 'experimento': nombre, **datos_base}
    guardar_resultado_csv(fila)
# Out:
# Resumen actualizado en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\resultados_todos_los_experimentos.csv
# Resumen actualizado en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\resultados_todos_los_experimentos.csv
# Resumen actualizado en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\resultados_todos_los_experimentos.csv
