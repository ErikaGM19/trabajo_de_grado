# %% [markdown]
# ### Ajuste de hiperparámetros - Batch size = 16

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from experimento_utils import ejecutar_experimento
from mejores_valores import MEJOR_DROPOUT, MEJOR_CAPAS

CARPETA_EXPERIMENTO = os.path.abspath('.')

# %%
resultado, history = ejecutar_experimento(
    nombre_experimento='resnet50_TL_batch16',
    carpeta_experimento=CARPETA_EXPERIMENTO,
    learning_rate=1e-5,
    optimizador='adam',
    batch_size=16,
    dropout=MEJOR_DROPOUT,
    capas_descongeladas=MEJOR_CAPAS,
    epochs=30, patience_es=5, patience_lr=3
)
resultado
# Out:
# ============================================================
# EXPERIMENTO: resnet50_TL_batch16
# LR=1e-05 | optimizador=adam | batch=16 | dropout=0.3 | capas_descongeladas=50
# ============================================================
#
# Found 6112 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Epoch 1/30
# 382/382 [==============================] - 442s 1s/step - loss: 1.3401 - accuracy: 0.5717 - val_loss: 0.3004 - val_accuracy: 0.9190 - lr: 1.0000e-05
# Epoch 2/30
# 382/382 [==============================] - 459s 1s/step - loss: 0.3981 - accuracy: 0.8950 - val_loss: 0.1002 - val_accuracy: 0.9702 - lr: 1.0000e-05
# Epoch 3/30
# 382/382 [==============================] - 446s 1s/step - loss: 0.2123 - accuracy: 0.9391 - val_loss: 0.0585 - val_accuracy: 0.9786 - lr: 1.0000e-05
# Epoch 4/30
# 382/382 [==============================] - 448s 1s/step - loss: 0.1526 - accuracy: 0.9542 - val_loss: 0.0467 - val_accuracy: 0.9847 - lr: 1.0000e-05
# Epoch 5/30
# 382/382 [==============================] - 448s 1s/step - loss: 0.1218 - accuracy: 0.9632 - val_loss: 0.0314 - val_accuracy: 0.9924 - lr: 1.0000e-05
# Epoch 6/30
# 382/382 [==============================] - 444s 1s/step - loss: 0.0992 - accuracy: 0.9696 - val_loss: 0.0405 - val_accuracy: 0.9862 - lr: 1.0000e-05
# Epoch 7/30
# 382/382 [==============================] - 461s 1s/step - loss: 0.0816 - accuracy: 0.9761 - val_loss: 0.0310 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 8/30
# 382/382 [==============================] - 442s 1s/step - loss: 0.0617 - accuracy: 0.9805 - val_loss: 0.0263 - val_accuracy: 0.9908 - lr: 1.0000e-05
# Epoch 9/30
# 382/382 [==============================] - 459s 1s/step - loss: 0.0568 - accuracy: 0.9840 - val_loss: 0.0198 - val_accuracy: 0.9947 - lr: 1.0000e-05
# Epoch 10/30
# 382/382 [==============================] - 458s 1s/step - loss: 0.0480 - accuracy: 0.9853 - val_loss: 0.0310 - val_accuracy: 0.9908 - lr: 1.0000e-05
# Epoch 11/30
# 382/382 [==============================] - 457s 1s/step - loss: 0.0483 - accuracy: 0.9854 - val_loss: 0.0287 - val_accuracy: 0.9924 - lr: 1.0000e-05
# Epoch 12/30
# 382/382 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9877
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 382/382 [==============================] - 455s 1s/step - loss: 0.0425 - accuracy: 0.9877 - val_loss: 0.0331 - val_accuracy: 0.9893 - lr: 1.0000e-05
# Epoch 13/30
# 382/382 [==============================] - 456s 1s/step - loss: 0.0333 - accuracy: 0.9913 - val_loss: 0.0213 - val_accuracy: 0.9916 - lr: 5.0000e-06
# Epoch 14/30
# 382/382 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9918Restoring model weights from the end of the best epoch: 9.
# 382/382 [==============================] - 445s 1s/step - loss: 0.0290 - accuracy: 0.9918 - val_loss: 0.0222 - val_accuracy: 0.9908 - lr: 5.0000e-06
# Epoch 14: early stopping
# Resultados guardados en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\Batch_16\resnet50_TL_batch16_resultados.txt
# Resumen actualizado en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\resultados_todos_los_experimentos.csv
# {'timestamp': '20260731_190330',
#  'experimento': 'resnet50_TL_batch16',
#  'learning_rate': 1e-05,
#  'optimizador': 'adam',
#  'batch_size': 16,
#  'dropout': 0.3,
#  'capas_descongeladas': 50,
#  'epochs_max': 30,
#  'epochs_entrenadas': 14,
#  'test_accuracy': 0.9977,
#  'test_loss': 0.0092,
#  'f1_score': 0.9977,
#  'duracion_min': 105.3}

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy — resnet50_TL_batch16')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()
plt.show()
