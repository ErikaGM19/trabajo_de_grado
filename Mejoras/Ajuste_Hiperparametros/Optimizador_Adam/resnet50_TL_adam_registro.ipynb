# %% [markdown]
# ### Experimento adicional - Optimizador = Adam

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from experimento_utils import guardar_resultado_csv

guardar_resultado_csv({
    'timestamp': '20260731_190330',
    'experimento': 'resnet50_TL_adam',
    'learning_rate': 1e-05,
    'optimizador': 'adam',
    'batch_size': 16,
    'dropout': 0.3,
    'capas_descongeladas': 50,
    'epochs_max': 30,
    'epochs_entrenadas': 14,
    'test_accuracy': 0.9977,
    'test_loss': 0.0092,
    'f1_score': 0.9977,
    'duracion_min': 105.3
})
# Out:
# Resumen actualizado en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\resultados_todos_los_experimentos.csv
