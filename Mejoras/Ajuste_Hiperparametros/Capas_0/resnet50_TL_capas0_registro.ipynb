# %% [markdown]
# ### Ajuste de hiperparámetros - Capas = 0

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from experimento_utils import guardar_resultado_csv

guardar_resultado_csv({
    'timestamp': '20260730_121200',
    'experimento': 'resnet50_TL_capas0',
    'learning_rate': 0.001,
    'optimizador': 'adam',
    'batch_size': 32,
    'dropout': 0.3,
    'capas_descongeladas': 0,
    'epochs_max': 30,
    'epochs_entrenadas': 27,
    'test_accuracy': 0.9855,
    'test_loss': 0.0597,
    'f1_score': 0.9855,
    'duracion_min': 150.9
})
# Out:
# Resumen actualizado en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\resultados_todos_los_experimentos.csv
