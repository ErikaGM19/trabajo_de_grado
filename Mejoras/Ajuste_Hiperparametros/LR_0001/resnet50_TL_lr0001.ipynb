# %% [markdown]
# ### Ajuste de hiperparámetros - Learning Rate = 0.0001

# %%
import sys, os
sys.path.append(os.path.abspath('..'))   # sube a la carpeta Ajuste_Hiperparametros
from experimento_utils import ejecutar_experimento

CARPETA_EXPERIMENTO = os.path.abspath('.')   # esta misma carpeta (LR_0001)

# %%
resultado, history = ejecutar_experimento(
    nombre_experimento='resnet50_TL_lr0001',
    carpeta_experimento=CARPETA_EXPERIMENTO,
    learning_rate=0.0001,
    optimizador='adam',
    batch_size=32,
    dropout=0.5,
    capas_descongeladas=0,
    epochs=30,          
    patience_es=5,
    patience_lr=3
)
resultado
# Out:
# ...
# EXPERIMENTO: resnet50_TL_lr0001
# LR=0.0001 | optimizador=adam | batch=32 | dropout=0.5 | capas_descongeladas=0
# ...
#
# Found 6112 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Epoch 1/30
# 191/191 [==============================] - 319s 2s/step - loss: 1.6261 - accuracy: 0.4547 - val_loss: 0.7733 - val_accuracy: 0.7930 - lr: 1.0000e-04
# Epoch 2/30
# 191/191 [==============================] - 338s 2s/step - loss: 0.8743 - accuracy: 0.7104 - val_loss: 0.4526 - val_accuracy: 0.8686 - lr: 1.0000e-04
# Epoch 3/30
# 191/191 [==============================] - 328s 2s/step - loss: 0.6557 - accuracy: 0.7870 - val_loss: 0.3569 - val_accuracy: 0.8984 - lr: 1.0000e-04
# Epoch 4/30
# 191/191 [==============================] - 328s 2s/step - loss: 0.5285 - accuracy: 0.8316 - val_loss: 0.2821 - val_accuracy: 0.9213 - lr: 1.0000e-04
# Epoch 5/30
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy — resnet50_TL_lr0001')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
