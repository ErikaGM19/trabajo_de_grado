# %% [markdown]
# ### Experimento adicional - Optimizador = RMSprop
# Parte de la combinación ganadora: dropout=0.3, capas_descongeladas=50, batch_size=16, LR=1e-5

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from experimento_utils import ejecutar_experimento
from mejores_valores import MEJOR_DROPOUT, MEJOR_CAPAS, MEJOR_BATCH

CARPETA_EXPERIMENTO = os.path.abspath('.')

# %%
resultado, history = ejecutar_experimento(
    nombre_experimento='resnet50_TL_rmsprop',
    carpeta_experimento=CARPETA_EXPERIMENTO,
    learning_rate=1e-5,
    optimizador='rmsprop',
    batch_size=MEJOR_BATCH,
    dropout=MEJOR_DROPOUT,
    capas_descongeladas=MEJOR_CAPAS,
    epochs=30, patience_es=5, patience_lr=3
)
resultado
# Out:
# ...
# EXPERIMENTO: resnet50_TL_rmsprop
# LR=1e-05 | optimizador=rmsprop | batch=16 | dropout=0.3 | capas_descongeladas=50
# ...
#
# Found 6112 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Epoch 1/30
# 382/382 [==============================] - 524s 1s/step - loss: 1.3045 - accuracy: 0.5905 - val_loss: 0.2697 - val_accuracy: 0.9305 - lr: 1.0000e-05
# Epoch 2/30
# 382/382 [==============================] - 527s 1s/step - loss: 0.3631 - accuracy: 0.9033 - val_loss: 0.1025 - val_accuracy: 0.9702 - lr: 1.0000e-05
# Epoch 3/30
# 382/382 [==============================] - 499s 1s/step - loss: 0.2014 - accuracy: 0.9395 - val_loss: 0.0585 - val_accuracy: 0.9801 - lr: 1.0000e-05
# Epoch 4/30
# 382/382 [==============================] - 495s 1s/step - loss: 0.1480 - accuracy: 0.9571 - val_loss: 0.0389 - val_accuracy: 0.9878 - lr: 1.0000e-05
# Epoch 5/30
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy — resnet50_TL_rmsprop')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()
plt.show()
