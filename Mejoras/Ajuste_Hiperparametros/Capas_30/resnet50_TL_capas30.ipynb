# %% [markdown]
# ### Ajuste de hiperparámetros - Capas descongeladas = 30

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from experimento_utils import ejecutar_experimento
from mejores_valores import MEJOR_DROPOUT

CARPETA_EXPERIMENTO = os.path.abspath('.')

# %%
resultado, history = ejecutar_experimento(
    nombre_experimento='resnet50_TL_capas30',
    carpeta_experimento=CARPETA_EXPERIMENTO,
    learning_rate=1e-5,
    optimizador='adam',
    batch_size=32,
    dropout=MEJOR_DROPOUT,
    capas_descongeladas=30,
    epochs=30, patience_es=5, patience_lr=3
)
resultado
# Out:
# ============================================================
# EXPERIMENTO: resnet50_TL_capas30
# LR=1e-05 | optimizador=adam | batch=32 | dropout=0.3 | capas_descongeladas=30
# ============================================================
#
# Found 6112 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Epoch 1/30
# 191/191 [==============================] - 360s 2s/step - loss: 1.6542 - accuracy: 0.4468 - val_loss: 0.6833 - val_accuracy: 0.8228 - lr: 1.0000e-05
# Epoch 2/30
# 191/191 [==============================] - 372s 2s/step - loss: 0.6653 - accuracy: 0.8233 - val_loss: 0.2084 - val_accuracy: 0.9412 - lr: 1.0000e-05
# Epoch 3/30
# 191/191 [==============================] - 371s 2s/step - loss: 0.3388 - accuracy: 0.9162 - val_loss: 0.1148 - val_accuracy: 0.9694 - lr: 1.0000e-05
# Epoch 4/30
# 191/191 [==============================] - 373s 2s/step - loss: 0.2160 - accuracy: 0.9486 - val_loss: 0.0769 - val_accuracy: 0.9733 - lr: 1.0000e-05
# Epoch 5/30
# 191/191 [==============================] - 369s 2s/step - loss: 0.1624 - accuracy: 0.9570 - val_loss: 0.0646 - val_accuracy: 0.9824 - lr: 1.0000e-05
# Epoch 6/30
# 191/191 [==============================] - 372s 2s/step - loss: 0.1225 - accuracy: 0.9676 - val_loss: 0.0521 - val_accuracy: 0.9847 - lr: 1.0000e-05
# Epoch 7/30
# 191/191 [==============================] - 369s 2s/step - loss: 0.1064 - accuracy: 0.9712 - val_loss: 0.0443 - val_accuracy: 0.9855 - lr: 1.0000e-05
# Epoch 8/30
# 191/191 [==============================] - 372s 2s/step - loss: 0.0859 - accuracy: 0.9751 - val_loss: 0.0414 - val_accuracy: 0.9878 - lr: 1.0000e-05
# Epoch 9/30
# 191/191 [==============================] - 369s 2s/step - loss: 0.0609 - accuracy: 0.9838 - val_loss: 0.0355 - val_accuracy: 0.9893 - lr: 1.0000e-05
# Epoch 10/30
# 191/191 [==============================] - 368s 2s/step - loss: 0.0620 - accuracy: 0.9830 - val_loss: 0.0346 - val_accuracy: 0.9862 - lr: 1.0000e-05
# Epoch 11/30
# 191/191 [==============================] - 379s 2s/step - loss: 0.0553 - accuracy: 0.9835 - val_loss: 0.0308 - val_accuracy: 0.9924 - lr: 1.0000e-05
# Epoch 12/30
# 191/191 [==============================] - 380s 2s/step - loss: 0.0540 - accuracy: 0.9864 - val_loss: 0.0420 - val_accuracy: 0.9870 - lr: 1.0000e-05
# Epoch 13/30
# 191/191 [==============================] - 377s 2s/step - loss: 0.0474 - accuracy: 0.9854 - val_loss: 0.0307 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 14/30
# 191/191 [==============================] - 378s 2s/step - loss: 0.0380 - accuracy: 0.9887 - val_loss: 0.0301 - val_accuracy: 0.9908 - lr: 1.0000e-05
# Epoch 15/30
# 191/191 [==============================] - 376s 2s/step - loss: 0.0364 - accuracy: 0.9900 - val_loss: 0.0311 - val_accuracy: 0.9893 - lr: 1.0000e-05
# Epoch 16/30
# 191/191 [==============================] - 375s 2s/step - loss: 0.0346 - accuracy: 0.9892 - val_loss: 0.0305 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 17/30
# 191/191 [==============================] - 380s 2s/step - loss: 0.0301 - accuracy: 0.9918 - val_loss: 0.0272 - val_accuracy: 0.9924 - lr: 1.0000e-05
# Epoch 18/30
# 191/191 [==============================] - 375s 2s/step - loss: 0.0277 - accuracy: 0.9920 - val_loss: 0.0317 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 19/30
# 191/191 [==============================] - 379s 2s/step - loss: 0.0281 - accuracy: 0.9913 - val_loss: 0.0296 - val_accuracy: 0.9908 - lr: 1.0000e-05
# Epoch 20/30
# 191/191 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9928
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 379s 2s/step - loss: 0.0265 - accuracy: 0.9928 - val_loss: 0.0326 - val_accuracy: 0.9908 - lr: 1.0000e-05
# Epoch 21/30
# 191/191 [==============================] - 377s 2s/step - loss: 0.0262 - accuracy: 0.9930 - val_loss: 0.0329 - val_accuracy: 0.9901 - lr: 5.0000e-06
# Epoch 22/30
# 191/191 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9931Restoring model weights from the end of the best epoch: 17.
# 191/191 [==============================] - 379s 2s/step - loss: 0.0232 - accuracy: 0.9931 - val_loss: 0.0299 - val_accuracy: 0.9908 - lr: 5.0000e-06
# Epoch 22: early stopping
# Resultados guardados en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\Capas_30\resnet50_TL_capas30_resultados.txt
# Resumen actualizado en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\resultados_todos_los_experimentos.csv
# {'timestamp': '20260731_120215',
#  'experimento': 'resnet50_TL_capas30',
#  'learning_rate': 1e-05,
#  'optimizador': 'adam',
#  'batch_size': 32,
#  'dropout': 0.3,
#  'capas_descongeladas': 30,
#  'epochs_max': 30,
#  'epochs_entrenadas': 22,
#  'test_accuracy': 0.9939,
#  'test_loss': 0.0126,
#  'f1_score': 0.9939,
#  'duracion_min': 137.1}

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy — resnet50_TL_capas30')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()
plt.show()
