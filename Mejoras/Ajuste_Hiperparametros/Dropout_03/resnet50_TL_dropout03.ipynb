# %% [markdown]
# ### Ajuste de hiperparámetros - Dropout = 0.3

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from experimento_utils import ejecutar_experimento
from mejores_valores import MEJOR_LR

CARPETA_EXPERIMENTO = os.path.abspath('.')

# %%
resultado, history = ejecutar_experimento(
    nombre_experimento='resnet50_TL_dropout03',
    carpeta_experimento=CARPETA_EXPERIMENTO,
    learning_rate=MEJOR_LR,
    optimizador='adam',
    batch_size=32,
    dropout=0.3,
    capas_descongeladas=0,
    epochs=30, patience_es=5, patience_lr=3
)
resultado
# Out:
# ============================================================
# EXPERIMENTO: resnet50_TL_dropout03
# LR=0.001 | optimizador=adam | batch=32 | dropout=0.3 | capas_descongeladas=0
# ============================================================
#
# Found 6112 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Epoch 1/30
# 191/191 [==============================] - 321s 2s/step - loss: 0.6681 - accuracy: 0.7759 - val_loss: 0.2266 - val_accuracy: 0.9259 - lr: 0.0010
# Epoch 2/30
# 191/191 [==============================] - 333s 2s/step - loss: 0.3108 - accuracy: 0.9013 - val_loss: 0.1915 - val_accuracy: 0.9358 - lr: 0.0010
# Epoch 3/30
# 191/191 [==============================] - 334s 2s/step - loss: 0.2212 - accuracy: 0.9288 - val_loss: 0.1572 - val_accuracy: 0.9526 - lr: 0.0010
# Epoch 4/30
# 191/191 [==============================] - 334s 2s/step - loss: 0.1970 - accuracy: 0.9383 - val_loss: 0.1497 - val_accuracy: 0.9519 - lr: 0.0010
# Epoch 5/30
# 191/191 [==============================] - 333s 2s/step - loss: 0.1881 - accuracy: 0.9375 - val_loss: 0.1405 - val_accuracy: 0.9565 - lr: 0.0010
# Epoch 6/30
# 191/191 [==============================] - 333s 2s/step - loss: 0.1667 - accuracy: 0.9454 - val_loss: 0.1323 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 7/30
# 191/191 [==============================] - 334s 2s/step - loss: 0.1406 - accuracy: 0.9532 - val_loss: 0.1378 - val_accuracy: 0.9572 - lr: 0.0010
# Epoch 8/30
# 191/191 [==============================] - 332s 2s/step - loss: 0.1492 - accuracy: 0.9516 - val_loss: 0.1268 - val_accuracy: 0.9580 - lr: 0.0010
# Epoch 9/30
# 191/191 [==============================] - 334s 2s/step - loss: 0.1400 - accuracy: 0.9530 - val_loss: 0.1278 - val_accuracy: 0.9572 - lr: 0.0010
# Epoch 10/30
# 191/191 [==============================] - 333s 2s/step - loss: 0.1253 - accuracy: 0.9571 - val_loss: 0.1115 - val_accuracy: 0.9656 - lr: 0.0010
# Epoch 11/30
# 191/191 [==============================] - 332s 2s/step - loss: 0.1255 - accuracy: 0.9547 - val_loss: 0.1086 - val_accuracy: 0.9626 - lr: 0.0010
# Epoch 12/30
# 191/191 [==============================] - 340s 2s/step - loss: 0.1201 - accuracy: 0.9609 - val_loss: 0.1171 - val_accuracy: 0.9603 - lr: 0.0010
# Epoch 13/30
# 191/191 [==============================] - 340s 2s/step - loss: 0.1031 - accuracy: 0.9642 - val_loss: 0.0861 - val_accuracy: 0.9748 - lr: 0.0010
# Epoch 14/30
# 191/191 [==============================] - 326s 2s/step - loss: 0.1101 - accuracy: 0.9607 - val_loss: 0.1012 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 15/30
# 191/191 [==============================] - 340s 2s/step - loss: 0.1043 - accuracy: 0.9670 - val_loss: 0.0787 - val_accuracy: 0.9771 - lr: 0.0010
# Epoch 16/30
# 191/191 [==============================] - 349s 2s/step - loss: 0.1091 - accuracy: 0.9611 - val_loss: 0.1111 - val_accuracy: 0.9672 - lr: 0.0010
# Epoch 17/30
# 191/191 [==============================] - 347s 2s/step - loss: 0.1054 - accuracy: 0.9650 - val_loss: 0.0773 - val_accuracy: 0.9756 - lr: 0.0010
# Epoch 18/30
# 191/191 [==============================] - 339s 2s/step - loss: 0.1050 - accuracy: 0.9647 - val_loss: 0.0908 - val_accuracy: 0.9733 - lr: 0.0010
# Epoch 19/30
# 191/191 [==============================] - 337s 2s/step - loss: 0.0986 - accuracy: 0.9686 - val_loss: 0.0849 - val_accuracy: 0.9740 - lr: 0.0010
# Epoch 20/30
# 191/191 [==============================] - ETA: 0s - loss: 0.0882 - accuracy: 0.9684
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 334s 2s/step - loss: 0.0882 - accuracy: 0.9684 - val_loss: 0.0790 - val_accuracy: 0.9778 - lr: 0.0010
# Epoch 21/30
# 191/191 [==============================] - 335s 2s/step - loss: 0.0752 - accuracy: 0.9750 - val_loss: 0.0691 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 22/30
# 191/191 [==============================] - 334s 2s/step - loss: 0.0629 - accuracy: 0.9792 - val_loss: 0.0662 - val_accuracy: 0.9809 - lr: 5.0000e-04
# Epoch 23/30
# 191/191 [==============================] - 337s 2s/step - loss: 0.0590 - accuracy: 0.9792 - val_loss: 0.0699 - val_accuracy: 0.9794 - lr: 5.0000e-04
# Epoch 24/30
# 191/191 [==============================] - 335s 2s/step - loss: 0.0664 - accuracy: 0.9800 - val_loss: 0.0879 - val_accuracy: 0.9717 - lr: 5.0000e-04
# Epoch 25/30
# 191/191 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9797
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 337s 2s/step - loss: 0.0572 - accuracy: 0.9797 - val_loss: 0.0765 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 26/30
# 191/191 [==============================] - 335s 2s/step - loss: 0.0514 - accuracy: 0.9815 - val_loss: 0.0803 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 27/30
# 191/191 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9830Restoring model weights from the end of the best epoch: 22.
# 191/191 [==============================] - 333s 2s/step - loss: 0.0499 - accuracy: 0.9830 - val_loss: 0.0719 - val_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 27: early stopping
# Resultados guardados en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\Dropout_03\resnet50_TL_dropout03_resultados.txt
# Resumen actualizado en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\resultados_todos_los_experimentos.csv
# {'timestamp': '20260730_121200',
#  'experimento': 'resnet50_TL_dropout03',
#  'learning_rate': 0.001,
#  'optimizador': 'adam',
#  'batch_size': 32,
#  'dropout': 0.3,
#  'capas_descongeladas': 0,
#  'epochs_max': 30,
#  'epochs_entrenadas': 27,
#  'test_accuracy': 0.9855,
#  'test_loss': 0.0597,
#  'f1_score': 0.9855,
#  'duracion_min': 150.9}

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy — resnet50_TL_dropout03')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()
plt.show()
