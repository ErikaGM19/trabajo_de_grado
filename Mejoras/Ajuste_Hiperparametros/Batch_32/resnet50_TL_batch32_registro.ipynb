# %% [markdown]
# ### Ajuste de hiperparámetros - Batch size = 32

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from experimento_utils import guardar_resultado_csv

guardar_resultado_csv({
    'timestamp': '20260731_141043',
    'experimento': 'resnet50_TL_batch32',
    'learning_rate': 1e-05,
    'optimizador': 'adam',
    'batch_size': 32,
    'dropout': 0.3,
    'capas_descongeladas': 50,
    'epochs_max': 30,
    'epochs_entrenadas': 16,
    'test_accuracy': 0.9954,
    'test_loss': 0.012,
    'f1_score': 0.9954,
    'duracion_min': 113.8
})
# Out:
# Resumen actualizado en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\resultados_todos_los_experimentos.csv
