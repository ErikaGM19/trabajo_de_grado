# %% [markdown]
# ### Ajuste de hiperparámetros - Capas descongeladas = 50

# %%
import sys, os
sys.path.append(os.path.abspath('..'))
from experimento_utils import ejecutar_experimento
from mejores_valores import MEJOR_DROPOUT

CARPETA_EXPERIMENTO = os.path.abspath('.')

# %%
resultado, history = ejecutar_experimento(
    nombre_experimento='resnet50_TL_capas50',
    carpeta_experimento=CARPETA_EXPERIMENTO,
    learning_rate=1e-5,
    optimizador='adam',
    batch_size=32,
    dropout=MEJOR_DROPOUT,
    capas_descongeladas=50,
    epochs=30, patience_es=5, patience_lr=3
)
resultado
# Out:
# ============================================================
# EXPERIMENTO: resnet50_TL_capas50
# LR=1e-05 | optimizador=adam | batch=32 | dropout=0.3 | capas_descongeladas=50
# ============================================================
#
# Found 6112 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Epoch 1/30
# 191/191 [==============================] - 417s 2s/step - loss: 1.6553 - accuracy: 0.4548 - val_loss: 0.6087 - val_accuracy: 0.8869 - lr: 1.0000e-05
# Epoch 2/30
# 191/191 [==============================] - 422s 2s/step - loss: 0.5919 - accuracy: 0.8573 - val_loss: 0.1612 - val_accuracy: 0.9542 - lr: 1.0000e-05
# Epoch 3/30
# 191/191 [==============================] - 421s 2s/step - loss: 0.2749 - accuracy: 0.9339 - val_loss: 0.0893 - val_accuracy: 0.9756 - lr: 1.0000e-05
# Epoch 4/30
# 191/191 [==============================] - 421s 2s/step - loss: 0.1674 - accuracy: 0.9563 - val_loss: 0.0582 - val_accuracy: 0.9817 - lr: 1.0000e-05
# Epoch 5/30
# 191/191 [==============================] - 414s 2s/step - loss: 0.1281 - accuracy: 0.9648 - val_loss: 0.0447 - val_accuracy: 0.9862 - lr: 1.0000e-05
# Epoch 6/30
# 191/191 [==============================] - 423s 2s/step - loss: 0.1023 - accuracy: 0.9720 - val_loss: 0.0413 - val_accuracy: 0.9885 - lr: 1.0000e-05
# Epoch 7/30
# 191/191 [==============================] - 431s 2s/step - loss: 0.0799 - accuracy: 0.9768 - val_loss: 0.0290 - val_accuracy: 0.9931 - lr: 1.0000e-05
# Epoch 8/30
# 191/191 [==============================] - 432s 2s/step - loss: 0.0692 - accuracy: 0.9802 - val_loss: 0.0263 - val_accuracy: 0.9931 - lr: 1.0000e-05
# Epoch 9/30
# 191/191 [==============================] - 432s 2s/step - loss: 0.0542 - accuracy: 0.9869 - val_loss: 0.0248 - val_accuracy: 0.9931 - lr: 1.0000e-05
# Epoch 10/30
# 191/191 [==============================] - 431s 2s/step - loss: 0.0547 - accuracy: 0.9848 - val_loss: 0.0272 - val_accuracy: 0.9916 - lr: 1.0000e-05
# Epoch 11/30
# 191/191 [==============================] - 431s 2s/step - loss: 0.0473 - accuracy: 0.9853 - val_loss: 0.0209 - val_accuracy: 0.9939 - lr: 1.0000e-05
# Epoch 12/30
# 191/191 [==============================] - 430s 2s/step - loss: 0.0448 - accuracy: 0.9879 - val_loss: 0.0271 - val_accuracy: 0.9931 - lr: 1.0000e-05
# Epoch 13/30
# 191/191 [==============================] - 431s 2s/step - loss: 0.0362 - accuracy: 0.9894 - val_loss: 0.0260 - val_accuracy: 0.9931 - lr: 1.0000e-05
# Epoch 14/30
# 191/191 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9917
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 191/191 [==============================] - 430s 2s/step - loss: 0.0326 - accuracy: 0.9917 - val_loss: 0.0296 - val_accuracy: 0.9908 - lr: 1.0000e-05
# Epoch 15/30
# 191/191 [==============================] - 431s 2s/step - loss: 0.0318 - accuracy: 0.9910 - val_loss: 0.0256 - val_accuracy: 0.9947 - lr: 5.0000e-06
# Epoch 16/30
# 191/191 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9930Restoring model weights from the end of the best epoch: 11.
# 191/191 [==============================] - 430s 2s/step - loss: 0.0255 - accuracy: 0.9930 - val_loss: 0.0250 - val_accuracy: 0.9947 - lr: 5.0000e-06
# Epoch 16: early stopping
# Resultados guardados en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\Capas_50\resnet50_TL_capas50_resultados.txt
# Resumen actualizado en c:\Users\USUARIO\Desktop\Proyecto de Grado\TESIS_CANA_AZUCAR\Mejoras\Ajuste_Hiperparametros\resultados_todos_los_experimentos.csv
# {'timestamp': '20260731_141043',
#  'experimento': 'resnet50_TL_capas50',
#  'learning_rate': 1e-05,
#  'optimizador': 'adam',
#  'batch_size': 32,
#  'dropout': 0.3,
#  'capas_descongeladas': 50,
#  'epochs_max': 30,
#  'epochs_entrenadas': 16,
#  'test_accuracy': 0.9954,
#  'test_loss': 0.012,
#  'f1_score': 0.9954,
#  'duracion_min': 113.8}

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy — resnet50_TL_capas50')
plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()
plt.show()
