# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter
import cv2

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS GLOBALES

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 75
PATIENCE_ES   = 10
PATIENCE_LR   = 5
NUM_CLASSES   = 10
NOMBRE_MODELO = 'resnet50_TL_hsv'

# %% [markdown]
# ### 3. PREPROCESAMIENTO
#
# #### 3.1 Transformación de Color (HSV)

# %%
# FUNCIÓN DE PREPROCESAMIENTO: CONVERSIÓN A HSV
def convertir_a_hsv(img):
    img_uint8 = img.astype('uint8')
    img_hsv = cv2.cvtColor(img_uint8, cv2.COLOR_RGB2HSV)
    img_hsv = img_hsv.astype('float32')
    return preprocess_input(img_hsv)

# %% [markdown]
# #### 3.2 Generador de Datos

# %%
base_dir  = '../../../Data/Cana_de_azucar'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

train_datagen = ImageDataGenerator(
    preprocessing_function=convertir_a_hsv,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=convertir_a_hsv
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 6112 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Found 1309 images belonging to 10 classes.
# Imágenes de entrenamiento : 6112
# Imágenes de validación    : 1309
# Imágenes de test          : 1309

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO RESNET50

# %%
# CARGAR RESNET50 CON PESOS DE IMAGENET
base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False    # Congelamos toda la red base 

# CREAR CAPA FINAL PERSONALIZADA
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
])

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 23,851,274
# Trainable params: 263,562
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
# 1. CALLBACKS 

# Callbacks para detener el entrenamiento si no mejora y guardar el mejor modelo
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,
    restore_best_weights=True,
    verbose=1
)

# Guardar solo el mejor modelo basado en la pérdida de validación
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{NOMBRE_MODELO}_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

# Reducir la tasa de aprendizaje si la pérdida de validación no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    verbose=1
)

# 2. ENTRENAMIENTO
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Epoch 1/75
# 191/191 [==============================] - ETA: 0s - loss: 0.8363 - accuracy: 0.7214
# Epoch 1: val_loss improved from inf to 0.29011, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 490s 3s/step - loss: 0.8363 - accuracy: 0.7214 - val_loss: 0.2901 - val_accuracy: 0.9106 - lr: 0.0010
# Epoch 2/75
# 191/191 [==============================] - ETA: 0s - loss: 0.4173 - accuracy: 0.8668
# Epoch 2: val_loss improved from 0.29011 to 0.19843, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 502s 3s/step - loss: 0.4173 - accuracy: 0.8668 - val_loss: 0.1984 - val_accuracy: 0.9396 - lr: 0.0010
# Epoch 3/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3171 - accuracy: 0.9013
# Epoch 3: val_loss improved from 0.19843 to 0.16466, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 2514s 2s/step - loss: 0.3171 - accuracy: 0.9013 - val_loss: 0.1647 - val_accuracy: 0.9481 - lr: 0.0010
# Epoch 4/75
# 191/191 [==============================] - ETA: 0s - loss: 0.3049 - accuracy: 0.9028
# Epoch 4: val_loss did not improve from 0.16466
# 191/191 [==============================] - 396s 2s/step - loss: 0.3049 - accuracy: 0.9028 - val_loss: 0.1677 - val_accuracy: 0.9481 - lr: 0.0010
# Epoch 5/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2534 - accuracy: 0.9156
# Epoch 5: val_loss improved from 0.16466 to 0.13909, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 395s 2s/step - loss: 0.2534 - accuracy: 0.9156 - val_loss: 0.1391 - val_accuracy: 0.9534 - lr: 0.0010
# Epoch 6/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2529 - accuracy: 0.9130
# Epoch 6: val_loss improved from 0.13909 to 0.13602, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 440s 2s/step - loss: 0.2529 - accuracy: 0.9130 - val_loss: 0.1360 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 7/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1978 - accuracy: 0.9380
# Epoch 7: val_loss did not improve from 0.13602
# 191/191 [==============================] - 427s 2s/step - loss: 0.1978 - accuracy: 0.9380 - val_loss: 0.1430 - val_accuracy: 0.9496 - lr: 0.0010
# Epoch 8/75
# 191/191 [==============================] - ETA: 0s - loss: 0.2142 - accuracy: 0.9280
# Epoch 8: val_loss did not improve from 0.13602
# 191/191 [==============================] - 414s 2s/step - loss: 0.2142 - accuracy: 0.9280 - val_loss: 0.1378 - val_accuracy: 0.9557 - lr: 0.0010
# Epoch 9/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1893 - accuracy: 0.9383
# Epoch 9: val_loss improved from 0.13602 to 0.11784, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 414s 2s/step - loss: 0.1893 - accuracy: 0.9383 - val_loss: 0.1178 - val_accuracy: 0.9641 - lr: 0.0010
# Epoch 10/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9360
# Epoch 10: val_loss did not improve from 0.11784
# 191/191 [==============================] - 382s 2s/step - loss: 0.1943 - accuracy: 0.9360 - val_loss: 0.1328 - val_accuracy: 0.9542 - lr: 0.0010
# Epoch 11/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.9398
# Epoch 11: val_loss improved from 0.11784 to 0.10224, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 427s 2s/step - loss: 0.1894 - accuracy: 0.9398 - val_loss: 0.1022 - val_accuracy: 0.9672 - lr: 0.0010
# Epoch 12/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1784 - accuracy: 0.9393
# Epoch 12: val_loss did not improve from 0.10224
# 191/191 [==============================] - 430s 2s/step - loss: 0.1784 - accuracy: 0.9393 - val_loss: 0.1063 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 13/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9421
# Epoch 13: val_loss improved from 0.10224 to 0.09105, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 406s 2s/step - loss: 0.1753 - accuracy: 0.9421 - val_loss: 0.0911 - val_accuracy: 0.9702 - lr: 0.0010
# Epoch 14/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1707 - accuracy: 0.9424
# Epoch 14: val_loss improved from 0.09105 to 0.08868, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 426s 2s/step - loss: 0.1707 - accuracy: 0.9424 - val_loss: 0.0887 - val_accuracy: 0.9710 - lr: 0.0010
# Epoch 15/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1709 - accuracy: 0.9458
# Epoch 15: val_loss improved from 0.08868 to 0.08692, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 403s 2s/step - loss: 0.1709 - accuracy: 0.9458 - val_loss: 0.0869 - val_accuracy: 0.9725 - lr: 0.0010
# Epoch 16/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1577 - accuracy: 0.9472
# Epoch 16: val_loss did not improve from 0.08692
# 191/191 [==============================] - 405s 2s/step - loss: 0.1577 - accuracy: 0.9472 - val_loss: 0.1064 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 17/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1722 - accuracy: 0.9393
# Epoch 17: val_loss did not improve from 0.08692
# 191/191 [==============================] - 393s 2s/step - loss: 0.1722 - accuracy: 0.9393 - val_loss: 0.0917 - val_accuracy: 0.9679 - lr: 0.0010
# Epoch 18/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1436 - accuracy: 0.9548
# Epoch 18: val_loss did not improve from 0.08692
# 191/191 [==============================] - 381s 2s/step - loss: 0.1436 - accuracy: 0.9548 - val_loss: 0.0885 - val_accuracy: 0.9717 - lr: 0.0010
# Epoch 19/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9535
# Epoch 19: val_loss did not improve from 0.08692
# 191/191 [==============================] - 377s 2s/step - loss: 0.1373 - accuracy: 0.9535 - val_loss: 0.1137 - val_accuracy: 0.9687 - lr: 0.0010
# Epoch 20/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1451 - accuracy: 0.9517
# Epoch 20: val_loss did not improve from 0.08692
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 191/191 [==============================] - 385s 2s/step - loss: 0.1451 - accuracy: 0.9517 - val_loss: 0.1086 - val_accuracy: 0.9702 - lr: 0.0010
# Epoch 21/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.9632
# Epoch 21: val_loss improved from 0.08692 to 0.08262, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 377s 2s/step - loss: 0.1028 - accuracy: 0.9632 - val_loss: 0.0826 - val_accuracy: 0.9748 - lr: 5.0000e-04
# Epoch 22/75
# 191/191 [==============================] - ETA: 0s - loss: 0.1020 - accuracy: 0.9630
# Epoch 22: val_loss improved from 0.08262 to 0.07160, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 382s 2s/step - loss: 0.1020 - accuracy: 0.9630 - val_loss: 0.0716 - val_accuracy: 0.9763 - lr: 5.0000e-04
# Epoch 23/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9717
# Epoch 23: val_loss did not improve from 0.07160
# 191/191 [==============================] - 384s 2s/step - loss: 0.0948 - accuracy: 0.9717 - val_loss: 0.0742 - val_accuracy: 0.9756 - lr: 5.0000e-04
# Epoch 24/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9673
# Epoch 24: val_loss did not improve from 0.07160
# 191/191 [==============================] - 379s 2s/step - loss: 0.0958 - accuracy: 0.9673 - val_loss: 0.0721 - val_accuracy: 0.9786 - lr: 5.0000e-04
# Epoch 25/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9699
# Epoch 25: val_loss did not improve from 0.07160
# 191/191 [==============================] - 383s 2s/step - loss: 0.0885 - accuracy: 0.9699 - val_loss: 0.0762 - val_accuracy: 0.9794 - lr: 5.0000e-04
# Epoch 26/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9722
# Epoch 26: val_loss improved from 0.07160 to 0.06535, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 378s 2s/step - loss: 0.0892 - accuracy: 0.9722 - val_loss: 0.0653 - val_accuracy: 0.9832 - lr: 5.0000e-04
# Epoch 27/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9681
# Epoch 27: val_loss did not improve from 0.06535
# 191/191 [==============================] - 384s 2s/step - loss: 0.0920 - accuracy: 0.9681 - val_loss: 0.0736 - val_accuracy: 0.9817 - lr: 5.0000e-04
# Epoch 28/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9694
# Epoch 28: val_loss did not improve from 0.06535
# 191/191 [==============================] - 376s 2s/step - loss: 0.0916 - accuracy: 0.9694 - val_loss: 0.0713 - val_accuracy: 0.9794 - lr: 5.0000e-04
# Epoch 29/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9696
# Epoch 29: val_loss did not improve from 0.06535
# 191/191 [==============================] - 381s 2s/step - loss: 0.0903 - accuracy: 0.9696 - val_loss: 0.0699 - val_accuracy: 0.9794 - lr: 5.0000e-04
# Epoch 30/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9719
# Epoch 30: val_loss did not improve from 0.06535
# 191/191 [==============================] - 376s 2s/step - loss: 0.0833 - accuracy: 0.9719 - val_loss: 0.0836 - val_accuracy: 0.9733 - lr: 5.0000e-04
# Epoch 31/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9683
# Epoch 31: val_loss did not improve from 0.06535
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 191/191 [==============================] - 383s 2s/step - loss: 0.0926 - accuracy: 0.9683 - val_loss: 0.0792 - val_accuracy: 0.9778 - lr: 5.0000e-04
# Epoch 32/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9756
# Epoch 32: val_loss did not improve from 0.06535
# 191/191 [==============================] - 383s 2s/step - loss: 0.0676 - accuracy: 0.9756 - val_loss: 0.0765 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 33/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9786
# Epoch 33: val_loss improved from 0.06535 to 0.05957, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 381s 2s/step - loss: 0.0613 - accuracy: 0.9786 - val_loss: 0.0596 - val_accuracy: 0.9809 - lr: 2.5000e-04
# Epoch 34/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9773
# Epoch 34: val_loss did not improve from 0.05957
# 191/191 [==============================] - 384s 2s/step - loss: 0.0676 - accuracy: 0.9773 - val_loss: 0.0602 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 35/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9773
# Epoch 35: val_loss did not improve from 0.05957
# 191/191 [==============================] - 380s 2s/step - loss: 0.0655 - accuracy: 0.9773 - val_loss: 0.0695 - val_accuracy: 0.9809 - lr: 2.5000e-04
# Epoch 36/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0693 - accuracy: 0.9750
# Epoch 36: val_loss did not improve from 0.05957
# 191/191 [==============================] - 380s 2s/step - loss: 0.0693 - accuracy: 0.9750 - val_loss: 0.0629 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 37/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9771
# Epoch 37: val_loss improved from 0.05957 to 0.05765, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 382s 2s/step - loss: 0.0655 - accuracy: 0.9771 - val_loss: 0.0576 - val_accuracy: 0.9817 - lr: 2.5000e-04
# Epoch 38/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0648 - accuracy: 0.9797
# Epoch 38: val_loss improved from 0.05765 to 0.05606, saving model to resnet50_TL_weights.h5
# 191/191 [==============================] - 385s 2s/step - loss: 0.0648 - accuracy: 0.9797 - val_loss: 0.0561 - val_accuracy: 0.9855 - lr: 2.5000e-04
# Epoch 39/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9812
# Epoch 39: val_loss did not improve from 0.05606
# 191/191 [==============================] - 383s 2s/step - loss: 0.0572 - accuracy: 0.9812 - val_loss: 0.0629 - val_accuracy: 0.9817 - lr: 2.5000e-04
# Epoch 40/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9786
# Epoch 40: val_loss did not improve from 0.05606
# 191/191 [==============================] - 382s 2s/step - loss: 0.0639 - accuracy: 0.9786 - val_loss: 0.0609 - val_accuracy: 0.9824 - lr: 2.5000e-04
# Epoch 41/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9758
# Epoch 41: val_loss did not improve from 0.05606
# 191/191 [==============================] - 384s 2s/step - loss: 0.0711 - accuracy: 0.9758 - val_loss: 0.0653 - val_accuracy: 0.9801 - lr: 2.5000e-04
# Epoch 42/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9815
# Epoch 42: val_loss did not improve from 0.05606
# 191/191 [==============================] - 377s 2s/step - loss: 0.0592 - accuracy: 0.9815 - val_loss: 0.0740 - val_accuracy: 0.9748 - lr: 2.5000e-04
# Epoch 43/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.9799
# Epoch 43: val_loss did not improve from 0.05606
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 191/191 [==============================] - 384s 2s/step - loss: 0.0585 - accuracy: 0.9799 - val_loss: 0.0700 - val_accuracy: 0.9771 - lr: 2.5000e-04
# Epoch 44/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9813
# Epoch 44: val_loss did not improve from 0.05606
# 191/191 [==============================] - 377s 2s/step - loss: 0.0560 - accuracy: 0.9813 - val_loss: 0.0606 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 45/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9805
# Epoch 45: val_loss did not improve from 0.05606
# 191/191 [==============================] - 384s 2s/step - loss: 0.0610 - accuracy: 0.9805 - val_loss: 0.0629 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 46/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9818
# Epoch 46: val_loss did not improve from 0.05606
# 191/191 [==============================] - 377s 2s/step - loss: 0.0575 - accuracy: 0.9818 - val_loss: 0.0582 - val_accuracy: 0.9817 - lr: 1.2500e-04
# Epoch 47/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9810
# Epoch 47: val_loss did not improve from 0.05606
# 191/191 [==============================] - 381s 2s/step - loss: 0.0540 - accuracy: 0.9810 - val_loss: 0.0594 - val_accuracy: 0.9801 - lr: 1.2500e-04
# Epoch 48/75
# 191/191 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 0.9836Restoring model weights from the end of the best epoch: 38.
#
# Epoch 48: val_loss did not improve from 0.05606
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 191/191 [==============================] - 379s 2s/step - loss: 0.0483 - accuracy: 0.9836 - val_loss: 0.0632 - val_accuracy: 0.9786 - lr: 1.2500e-04
# Epoch 48: early stopping

# %% [markdown]
# ### 7. CURVAS DE ENTRENAMIENTO

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'])

ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8. EVALUACIÓN FINAL EN TEST

# %%
# MÉTRICAS SOBRE EL CONJUNTO DE TEST (datos nunca vistos)
test_generator.reset()

# Accuracy y Loss en test
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')

# Predicciones
predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

# F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f'F1 Score      : {f1:.4f}')

# Reporte de clasificación (precision, recall, f1 por clase)
print('\n--- Reporte de clasificación ---')
print(classification_report(
    y_true,
    y_pred,
    target_names=test_generator.class_indices.keys(),
    digits=4
))

# Guardar resultados en .txt
with open(f'{NOMBRE_MODELO}_resultados.txt', 'w') as f:
    f.write(f'Modelo        : {NOMBRE_MODELO}\n')
    f.write(f'Test Accuracy : {test_accuracy:.4f}\n')
    f.write(f'Test Loss     : {test_loss:.4f}\n')
    f.write(f'F1 Score      : {f1:.4f}\n\n')
    f.write('--- Reporte de clasificación ---\n')
    f.write(classification_report(
        y_true,
        y_pred,
        target_names=test_generator.class_indices.keys(),
        digits=4        # ← 4 decimales
    ))

print(f'\nResultados guardados en {NOMBRE_MODELO}_resultados.txt')
# Out:
# 41/41 [==============================] - 58s 1s/step - loss: 0.0535 - accuracy: 0.9862
#
# Test Accuracy : 0.9862
# Test Loss     : 0.0535
# 41/41 [==============================] - 59s 1s/step
# F1 Score      : 0.9862
#
# --- Reporte de clasificación ---
#                   precision    recall  f1-score   support
#
#           carbon     1.0000    1.0000    1.0000        75
#    hoja_amarilla     0.9803    0.9933    0.9868       150
#    mancha_anillo     1.0000    1.0000    1.0000       106
#     mancha_parda     0.9735    0.9800    0.9767       150
#          mosaico     0.9933    0.9867    0.9900       150
#      muermo_rojo     0.9795    0.9533    0.9662       150
#             roya     0.9866    0.9800    0.9833       150
#            sanas     0.9739    0.9933    0.9835       150
#            secas     1.0000    1.0000    1.0000        78
# tizon_bacteriano     0.9933    0.9933    0.9933       150
#
#         accuracy                         0.9862      1309
#        macro avg     0.9880    0.9880    0.9880      1309
#     weighted avg     0.9863    0.9862    0.9862      1309
#
#
# Resultados guardados en resnet50_TL_resultados.txt

# %% [markdown]
# ### 9. MATRIZ DE CONFUSIÓN

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(11, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=test_generator.class_indices.keys(),
    yticklabels=test_generator.class_indices.keys()
)
plt.xlabel('Predicción')
plt.ylabel('Clase real')
plt.title(f'Matriz de Confusión — {NOMBRE_MODELO}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. IMÁGENES CLASIFICADAS INCORRECTAMENTE

# %%
test_generator.reset()
filenames = test_generator.filenames

incorrectas = np.where(y_pred != y_true)[0]

class_indices  = test_generator.class_indices
indice_a_clase = {v: k for k, v in class_indices.items()}

pares        = [(indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) for i in incorrectas]
conteo_pares = Counter(pares)

UMBRAL          = 1
pares_relevantes = {par for par, count in conteo_pares.items() if count >= UMBRAL}

print('Pares con 5 o más confusiones:')
for par, count in sorted(conteo_pares.items(), key=lambda x: -x[1]):
    if count >= UMBRAL:
        print(f'  {par[0]} → {par[1]}: {count} imágenes')

indices_filtrados = [
    i for i in incorrectas
    if (indice_a_clase[y_true[i]], indice_a_clase[y_pred[i]]) in pares_relevantes
]

print(f'\nTotal de imágenes a mostrar: {len(indices_filtrados)}')

base_dir = '../../../Data/Cana_de_azucar/test'

for par in sorted(pares_relevantes, key=lambda p: -conteo_pares[p]):
    clase_real, clase_predicha = par
    indices_par = [
        i for i in indices_filtrados
        if indice_a_clase[y_true[i]] == clase_real
        and indice_a_clase[y_pred[i]] == clase_predicha
    ]

    n_mostrar = len(indices_par)
    n_cols    = 5
    n_filas   = (n_mostrar + n_cols - 1) // n_cols

    fig, axes = plt.subplots(n_filas, n_cols, figsize=(20, n_filas * 4))
    axes = axes.flatten()

    for j, idx in enumerate(indices_par):
        ruta_imagen = os.path.join(base_dir, filenames[idx])
        img = Image.open(ruta_imagen)
        axes[j].imshow(img)
        axes[j].set_title(
            f'Real: {clase_real}\nPredicha: {clase_predicha}',
            fontsize=9,
            color='red'
        )
        axes[j].axis('off')

    for j in range(n_mostrar, len(axes)):
        axes[j].axis('off')

    plt.suptitle(
        f'{clase_real} → {clase_predicha}  ({n_mostrar} imágenes)',
        fontsize=14,
        fontweight='bold',
        y=1.02
    )
    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.show()
# Out:
# Pares con 5 o más confusiones:
#   muermo_rojo → mancha_parda: 4 imágenes
#   mancha_parda → hoja_amarilla: 2 imágenes
#   mosaico → sanas: 2 imágenes
#   roya → sanas: 2 imágenes
#   hoja_amarilla → roya: 1 imágenes
#   mancha_parda → muermo_rojo: 1 imágenes
#   muermo_rojo → hoja_amarilla: 1 imágenes
#   muermo_rojo → roya: 1 imágenes
#   muermo_rojo → tizon_bacteriano: 1 imágenes
#   roya → muermo_rojo: 1 imágenes
#   sanas → mosaico: 1 imágenes
#   tizon_bacteriano → muermo_rojo: 1 imágenes
#
# Total de imágenes a mostrar: 18

# %% [markdown]
# ### 11. GUARDAR PESOS DEL MODELO

# %%
model.save_weights(f'{NOMBRE_MODELO}_weights.h5')
print(f'Pesos guardados como: {NOMBRE_MODELO}_weights.h5')
# Out:
# Pesos guardados como: resnet50_TL_weights.h5
