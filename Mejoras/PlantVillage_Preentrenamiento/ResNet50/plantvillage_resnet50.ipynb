# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 15
NUM_CLASSES   = 38
NOMBRE_MODELO = 'plantvillage_resnet50'

PATIENCE_ES = 8
PATIENCE_LR = 4

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
base_dir = '../../../Data/PlantVillage'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
# Out:
# Found 43471 images belonging to 38 classes.
# Found 5417 images belonging to 38 classes.
# Found 5417 images belonging to 38 classes.
# Imágenes de entrenamiento : 43471
# Imágenes de validación    : 5417
# Imágenes de test          : 5417

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO

# %%
# weights=None → empieza desde cero, sin ImageNet
base_model = ResNet50(
    weights=None,
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = True

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

model.summary()
# Out:
# Model: "plantvillage_resnet50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 38)                4902
#
# =================================================================
# Total params: 23,854,886
# Trainable params: 23,801,766
# Non-trainable params: 53,120
# _________________________________________________________________

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
os.makedirs('../pesos_resnet50', exist_ok=True)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,
    restore_best_weights=True,
    verbose=1
)

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='../pesos_resnet50/resnet50_plantvillage_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    min_lr=1e-6,
    verbose=1
)

print("Iniciando entrenamiento en PlantVillage...")
print("Esto puede tardar muchas horas en CPU. No cierres Jupyter.\n")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Iniciando entrenamiento en PlantVillage...
# Esto puede tardar muchas horas en CPU. No cierres Jupyter.
#
# Epoch 1/15
# 1359/1359 [==============================] - ETA: 0s - loss: 2.8343 - accuracy: 0.2536
# Epoch 1: val_loss improved from inf to 2.36692, saving model to ../pesos_resnet50\resnet50_plantvillage_weights.h5
# 1359/1359 [==============================] - 6596s 5s/step - loss: 2.8343 - accuracy: 0.2536 - val_loss: 2.3669 - val_accuracy: 0.3485 - lr: 0.0010
# Epoch 2/15
# 1359/1359 [==============================] - ETA: 0s - loss: 2.4903 - accuracy: 0.3150
# Epoch 2: val_loss improved from 2.36692 to 2.21478, saving model to ../pesos_resnet50\resnet50_plantvillage_weights.h5
# 1359/1359 [==============================] - 6585s 5s/step - loss: 2.4903 - accuracy: 0.3150 - val_loss: 2.2148 - val_accuracy: 0.4019 - lr: 0.0010
# Epoch 3/15
# 1359/1359 [==============================] - ETA: 0s - loss: 2.2579 - accuracy: 0.3668
# Epoch 3: val_loss did not improve from 2.21478
# 1359/1359 [==============================] - 6590s 5s/step - loss: 2.2579 - accuracy: 0.3668 - val_loss: 27.1757 - val_accuracy: 0.1348 - lr: 0.0010
# Epoch 4/15
# 1359/1359 [==============================] - ETA: 0s - loss: 2.0067 - accuracy: 0.4277
# Epoch 4: val_loss improved from 2.21478 to 1.37203, saving model to ../pesos_resnet50\resnet50_plantvillage_weights.h5
# 1359/1359 [==============================] - 6614s 5s/step - loss: 2.0067 - accuracy: 0.4277 - val_loss: 1.3720 - val_accuracy: 0.5933 - lr: 0.0010
# Epoch 5/15
# 1359/1359 [==============================] - ETA: 0s - loss: 1.7723 - accuracy: 0.4813
# Epoch 5: val_loss improved from 1.37203 to 1.06107, saving model to ../pesos_resnet50\resnet50_plantvillage_weights.h5
# 1359/1359 [==============================] - 6696s 5s/step - loss: 1.7723 - accuracy: 0.4813 - val_loss: 1.0611 - val_accuracy: 0.6703 - lr: 0.0010
# Epoch 6/15
# 1359/1359 [==============================] - ETA: 0s - loss: 1.5552 - accuracy: 0.5355
# Epoch 6: val_loss improved from 1.06107 to 0.98509, saving model to ../pesos_resnet50\resnet50_plantvillage_weights.h5
# 1359/1359 [==============================] - 6563s 5s/step - loss: 1.5552 - accuracy: 0.5355 - val_loss: 0.9851 - val_accuracy: 0.7308 - lr: 0.0010
# Epoch 7/15
# 1359/1359 [==============================] - ETA: 0s - loss: 1.4073 - accuracy: 0.5702
# Epoch 7: val_loss did not improve from 0.98509
# 1359/1359 [==============================] - 6547s 5s/step - loss: 1.4073 - accuracy: 0.5702 - val_loss: 1.3320 - val_accuracy: 0.6478 - lr: 0.0010
# Epoch 8/15
# 1359/1359 [==============================] - ETA: 0s - loss: 1.2714 - accuracy: 0.6097
# Epoch 8: val_loss improved from 0.98509 to 0.78301, saving model to ../pesos_resnet50\resnet50_plantvillage_weights.h5
# 1359/1359 [==============================] - 6754s 5s/step - loss: 1.2714 - accuracy: 0.6097 - val_loss: 0.7830 - val_accuracy: 0.8010 - lr: 0.0010
# Epoch 9/15
# 1359/1359 [==============================] - ETA: 0s - loss: 1.1911 - accuracy: 0.6355
# Epoch 9: val_loss improved from 0.78301 to 0.72864, saving model to ../pesos_resnet50\resnet50_plantvillage_weights.h5
# 1359/1359 [==============================] - 6581s 5s/step - loss: 1.1911 - accuracy: 0.6355 - val_loss: 0.7286 - val_accuracy: 0.7920 - lr: 0.0010
# Epoch 10/15
# 1359/1359 [==============================] - ETA: 0s - loss: 1.1052 - accuracy: 0.6592
# Epoch 10: val_loss improved from 0.72864 to 0.57986, saving model to ../pesos_resnet50\resnet50_plantvillage_weights.h5
# 1359/1359 [==============================] - 6567s 5s/step - loss: 1.1052 - accuracy: 0.6592 - val_loss: 0.5799 - val_accuracy: 0.8590 - lr: 0.0010
# Epoch 11/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.9989 - accuracy: 0.6913
# Epoch 11: val_loss did not improve from 0.57986
# 1359/1359 [==============================] - 6541s 5s/step - loss: 0.9989 - accuracy: 0.6913 - val_loss: 0.7327 - val_accuracy: 0.8169 - lr: 0.0010
# Epoch 12/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.9572 - accuracy: 0.7051
# Epoch 12: val_loss did not improve from 0.57986
# 1359/1359 [==============================] - 6448s 5s/step - loss: 0.9572 - accuracy: 0.7051 - val_loss: 1.1559 - val_accuracy: 0.6686 - lr: 0.0010
# Epoch 13/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.8975 - accuracy: 0.7212
# Epoch 13: val_loss improved from 0.57986 to 0.37941, saving model to ../pesos_resnet50\resnet50_plantvillage_weights.h5
# 1359/1359 [==============================] - 6504s 5s/step - loss: 0.8975 - accuracy: 0.7212 - val_loss: 0.3794 - val_accuracy: 0.9092 - lr: 0.0010
# Epoch 14/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.8573 - accuracy: 0.7400
# Epoch 14: val_loss did not improve from 0.37941
# 1359/1359 [==============================] - 6668s 5s/step - loss: 0.8573 - accuracy: 0.7400 - val_loss: 0.4175 - val_accuracy: 0.8940 - lr: 0.0010
# Epoch 15/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.8092 - accuracy: 0.7516
# Epoch 15: val_loss did not improve from 0.37941
# 1359/1359 [==============================] - 6598s 5s/step - loss: 0.8092 - accuracy: 0.7516 - val_loss: 0.5667 - val_accuracy: 0.8675 - lr: 0.0010

# %% [markdown]
# ### 7. GUARDAR PESOS DEL BACKBONE

# %%
base_model.save_weights('../pesos_resnet50/resnet50_backbone_plantvillage.h5')
print("Pesos del backbone guardados en:")
print("../pesos_resnet50/resnet50_backbone_plantvillage.h5")
# Out:
# Pesos del backbone guardados en:
# ../pesos_resnet50/resnet50_backbone_plantvillage.h5

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'],     label='Train')
ax1.plot(history.history['val_accuracy'], label='Validación')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(history.history['loss'],     label='Train')
ax2.plot(history.history['val_loss'], label='Validación')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.savefig('../pesos_resnet50/curvas_resnet50_plantvillage.png', dpi=150)
plt.show()

print(f'Mejor val_accuracy: {max(history.history["val_accuracy"]):.4f}')
# Out:
# Mejor val_accuracy: 0.9092

# %% [markdown]
# ### 9. EVALUCACIÓN EN TEST

# %%
test_generator.reset()

test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)

predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

f1 = f1_score(y_true, y_pred, average='weighted')

print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')
print(f'F1 Score      : {f1:.4f}')

nombres_clases = list(test_generator.class_indices.keys())
print('\n--- Reporte de clasificación ---')
print(classification_report(y_true, y_pred, target_names=nombres_clases))
# Out:
# 170/170 [==============================] - 278s 2s/step - loss: 0.4730 - accuracy: 0.8652
# 170/170 [==============================] - 283s 2s/step
#
# Test Accuracy : 0.8652
# Test Loss     : 0.4730
# F1 Score      : 0.8568
#
# --- Reporte de clasificación ---
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.81      0.54      0.65        63
#                                  Apple___Black_rot       0.94      0.27      0.42        62
#                           Apple___Cedar_apple_rust       1.00      0.56      0.71        27
#                                    Apple___healthy       0.90      0.74      0.81       164
#                                Blueberry___healthy       0.72      0.99      0.83       150
#           Cherry_(including_sour)___Powdery_mildew       0.92      0.92      0.92       105
#                  Cherry_(including_sour)___healthy       0.90      0.44      0.59        85
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.00      0.00      0.00        51
#                        Corn_(maize)___Common_rust_       1.00      1.00      1.00       119
#                Corn_(maize)___Northern_Leaf_Blight       0.64      0.99      0.78        98
#                             Corn_(maize)___healthy       0.99      1.00      1.00       116
#                                  Grape___Black_rot       0.92      0.66      0.77       118
#                       Grape___Esca_(Black_Measles)       0.77      0.99      0.87       138
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.99      0.95      0.97       107
#                                    Grape___healthy       0.90      0.86      0.88        42
#           Orange___Haunglongbing_(Citrus_greening)       0.99      0.92      0.95       550
#                             Peach___Bacterial_spot       0.99      0.76      0.86       229
#                                    Peach___healthy       0.97      0.83      0.90        36
#                      Pepper,_bell___Bacterial_spot       0.62      0.77      0.69        99
#                             Pepper,_bell___healthy       0.91      0.51      0.66       147
#                              Potato___Early_blight       1.00      0.98      0.99       100
#                               Potato___Late_blight       0.80      0.90      0.85       100
#                                   Potato___healthy       0.00      0.00      0.00        15
#                                Raspberry___healthy       0.76      0.86      0.81        37
#                                  Soybean___healthy       0.73      1.00      0.84       509
#                            Squash___Powdery_mildew       0.97      0.99      0.98       183
#                           Strawberry___Leaf_scorch       0.99      0.99      0.99       110
#                               Strawberry___healthy       0.78      0.89      0.83        45
#                            Tomato___Bacterial_spot       0.86      0.91      0.88       212
#                              Tomato___Early_blight       0.93      0.68      0.79       100
#                               Tomato___Late_blight       0.84      0.88      0.86       190
#                                 Tomato___Leaf_Mold       0.89      0.96      0.92        95
#                        Tomato___Septoria_leaf_spot       0.72      0.91      0.81       177
#      Tomato___Spider_mites Two-spotted_spider_mite       0.74      0.86      0.80       167
#                               Tomato___Target_Spot       0.85      0.76      0.80       140
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.99      0.93      0.96       535
#                       Tomato___Tomato_mosaic_virus       0.92      0.65      0.76        37
#                                   Tomato___healthy       0.97      0.99      0.98       159
#
#                                           accuracy                           0.87      5417
#                                          macro avg       0.83      0.79      0.79      5417
#                                       weighted avg       0.87      0.87      0.86      5417
# c:\ProgramData\anaconda3\envs\tesis_cana\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\ProgramData\anaconda3\envs\tesis_cana\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\ProgramData\anaconda3\envs\tesis_cana\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
