# %% [markdown]
# ### 1. IMPORTAR LIBRERÍAS

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, models
from PIL import Image
from collections import Counter

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.0

# %% [markdown]
# ### 2. PARÁMETROS

# %%
IMG_SIZE      = 224
BATCH_SIZE    = 32
EPOCHS        = 15
NUM_CLASSES   = 38
NOMBRE_MODELO = 'plantvillage_efficientnetB4'

PATIENCE_ES = 8
PATIENCE_LR = 4

# %% [markdown]
# ### 3. PREPROCESAMIENTO

# %%
base_dir = '../../../Data/PlantVillage'
train_dir = os.path.join(base_dir, 'train')
val_dir   = os.path.join(base_dir, 'val')
test_dir  = os.path.join(base_dir, 'test')

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2]
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f'Imágenes de entrenamiento : {train_generator.samples}')
print(f'Imágenes de validación    : {val_generator.samples}')
print(f'Imágenes de test          : {test_generator.samples}')
print(f'Clases detectadas         : {len(train_generator.class_indices)}')
# Out:
# Found 43471 images belonging to 38 classes.
# Found 5417 images belonging to 38 classes.
# Found 5417 images belonging to 38 classes.
# Imágenes de entrenamiento : 43471
# Imágenes de validación    : 5417
# Imágenes de test          : 5417
# Clases detectadas         : 38

# %% [markdown]
# ### 4. CONSTRUCCIÓN DEL MODELO

# %%
# weights=None → empieza desde cero, sin ImageNet
base_model = EfficientNetB4(
    weights=None,
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = True

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4)
    ),
    layers.Dropout(0.5),
    layers.Dense(NUM_CLASSES, activation='softmax')
], name=NOMBRE_MODELO)

model.summary()
# Out:
# Model: "plantvillage_efficientnetB4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb4 (Functional)  (None, 7, 7, 1792)       17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)               229504
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 38)                4902
#
# =================================================================
# Total params: 17,908,229
# Trainable params: 17,783,022
# Non-trainable params: 125,207
# _________________________________________________________________

# %% [markdown]
# ### 5. COMPILAR EL MODELO

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### 6. ENTRENAMIENTO

# %%
os.makedirs('../pesos_efficientnetB4', exist_ok=True)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE_ES,
    restore_best_weights=True,
    verbose=1
)

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='../pesos_efficientnetB4/efficientnetB4_plantvillage_weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=PATIENCE_LR,
    min_lr=1e-6,
    verbose=1
)

print("Iniciando entrenamiento en PlantVillage...")
print("Esto puede tardar muchas horas en CPU. No cierres Jupyter.\n")

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint, reduce_lr]
)
# Out:
# Iniciando entrenamiento en PlantVillage...
# Esto puede tardar muchas horas en CPU. No cierres Jupyter.
#
# Epoch 1/15
# 1359/1359 [==============================] - ETA: 0s - loss: 2.6621 - accuracy: 0.3048
# Epoch 1: val_loss improved from inf to 2.31110, saving model to ../pesos_efficientnetB4\efficientnetB4_plantvillage_weights.h5
# 1359/1359 [==============================] - 10375s 8s/step - loss: 2.6621 - accuracy: 0.3048 - val_loss: 2.3111 - val_accuracy: 0.3932 - lr: 0.0010
# Epoch 2/15
# 1359/1359 [==============================] - ETA: 0s - loss: 1.7476 - accuracy: 0.5056
# Epoch 2: val_loss improved from 2.31110 to 1.66853, saving model to ../pesos_efficientnetB4\efficientnetB4_plantvillage_weights.h5
# 1359/1359 [==============================] - 10319s 8s/step - loss: 1.7476 - accuracy: 0.5056 - val_loss: 1.6685 - val_accuracy: 0.5163 - lr: 0.0010
# Epoch 3/15
# 1359/1359 [==============================] - ETA: 0s - loss: 1.4100 - accuracy: 0.5944
# Epoch 3: val_loss improved from 1.66853 to 1.27982, saving model to ../pesos_efficientnetB4\efficientnetB4_plantvillage_weights.h5
# 1359/1359 [==============================] - 10313s 8s/step - loss: 1.4100 - accuracy: 0.5944 - val_loss: 1.2798 - val_accuracy: 0.6529 - lr: 0.0010
# Epoch 4/15
# 1359/1359 [==============================] - ETA: 0s - loss: 1.0983 - accuracy: 0.6775
# Epoch 4: val_loss improved from 1.27982 to 0.70794, saving model to ../pesos_efficientnetB4\efficientnetB4_plantvillage_weights.h5
# 1359/1359 [==============================] - 10305s 8s/step - loss: 1.0983 - accuracy: 0.6775 - val_loss: 0.7079 - val_accuracy: 0.7753 - lr: 0.0010
# Epoch 5/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.9713 - accuracy: 0.7119
# Epoch 5: val_loss improved from 0.70794 to 0.70740, saving model to ../pesos_efficientnetB4\efficientnetB4_plantvillage_weights.h5
# 1359/1359 [==============================] - 10310s 8s/step - loss: 0.9713 - accuracy: 0.7119 - val_loss: 0.7074 - val_accuracy: 0.7884 - lr: 0.0010
# Epoch 6/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.8189 - accuracy: 0.7550
# Epoch 6: val_loss did not improve from 0.70740
# 1359/1359 [==============================] - 10327s 8s/step - loss: 0.8189 - accuracy: 0.7550 - val_loss: 1.3863 - val_accuracy: 0.7687 - lr: 0.0010
# Epoch 7/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.6943 - accuracy: 0.7933
# Epoch 7: val_loss improved from 0.70740 to 0.60726, saving model to ../pesos_efficientnetB4\efficientnetB4_plantvillage_weights.h5
# 1359/1359 [==============================] - 10374s 8s/step - loss: 0.6943 - accuracy: 0.7933 - val_loss: 0.6073 - val_accuracy: 0.8329 - lr: 0.0010
# Epoch 8/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.5992 - accuracy: 0.8215
# Epoch 8: val_loss improved from 0.60726 to 0.31877, saving model to ../pesos_efficientnetB4\efficientnetB4_plantvillage_weights.h5
# 1359/1359 [==============================] - 10433s 8s/step - loss: 0.5992 - accuracy: 0.8215 - val_loss: 0.3188 - val_accuracy: 0.9012 - lr: 0.0010
# Epoch 9/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.4709 - accuracy: 0.8624
# Epoch 9: val_loss did not improve from 0.31877
# 1359/1359 [==============================] - 10505s 8s/step - loss: 0.4709 - accuracy: 0.8624 - val_loss: 0.3488 - val_accuracy: 0.9110 - lr: 0.0010
# Epoch 10/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.3965 - accuracy: 0.8866
# Epoch 10: val_loss improved from 0.31877 to 0.30806, saving model to ../pesos_efficientnetB4\efficientnetB4_plantvillage_weights.h5
# 1359/1359 [==============================] - 10465s 8s/step - loss: 0.3965 - accuracy: 0.8866 - val_loss: 0.3081 - val_accuracy: 0.9114 - lr: 0.0010
# Epoch 11/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.3643 - accuracy: 0.8948
# Epoch 11: val_loss did not improve from 0.30806
# 1359/1359 [==============================] - 10455s 8s/step - loss: 0.3643 - accuracy: 0.8948 - val_loss: 0.4722 - val_accuracy: 0.8669 - lr: 0.0010
# Epoch 12/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.3246 - accuracy: 0.9080
# Epoch 12: val_loss improved from 0.30806 to 0.24603, saving model to ../pesos_efficientnetB4\efficientnetB4_plantvillage_weights.h5
# 1359/1359 [==============================] - 10481s 8s/step - loss: 0.3246 - accuracy: 0.9080 - val_loss: 0.2460 - val_accuracy: 0.9383 - lr: 0.0010
# Epoch 13/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.3240 - accuracy: 0.9084
# Epoch 13: val_loss did not improve from 0.24603
# 1359/1359 [==============================] - 10588s 8s/step - loss: 0.3240 - accuracy: 0.9084 - val_loss: 0.4089 - val_accuracy: 0.8811 - lr: 0.0010
# Epoch 14/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.2600 - accuracy: 0.9280
# Epoch 14: val_loss improved from 0.24603 to 0.14876, saving model to ../pesos_efficientnetB4\efficientnetB4_plantvillage_weights.h5
# 1359/1359 [==============================] - 10535s 8s/step - loss: 0.2600 - accuracy: 0.9280 - val_loss: 0.1488 - val_accuracy: 0.9599 - lr: 0.0010
# Epoch 15/15
# 1359/1359 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.9343
# Epoch 15: val_loss did not improve from 0.14876
# 1359/1359 [==============================] - 10584s 8s/step - loss: 0.2426 - accuracy: 0.9343 - val_loss: 0.2006 - val_accuracy: 0.9404 - lr: 0.0010

# %% [markdown]
# ### 7. GUARDAR PESOS DEL BACKBONE

# %%
base_model.save_weights('../pesos_efficientnetB4/efficientnetB4_backbone_plantvillage.h5')
print("Pesos del backbone guardados en:")
print("../pesos_efficientnetB4/efficientnetB4_backbone_plantvillage.h5")
# Out:
# Pesos del backbone guardados en:
# ../pesos_efficientnetB4/efficientnetB4_backbone_plantvillage.h5

# %% [markdown]
# ### 8. CURVAS DE ENTRENAMIENTO

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'],     label='Train')
ax1.plot(history.history['val_accuracy'], label='Validación')
ax1.set_title(f'Accuracy — {NOMBRE_MODELO}')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(history.history['loss'],     label='Train')
ax2.plot(history.history['val_loss'], label='Validación')
ax2.set_title(f'Loss — {NOMBRE_MODELO}')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.savefig('../pesos_efficientnetB4/curvas_efficientnetB4_plantvillage.png', dpi=150)
plt.show()

print(f'Mejor val_accuracy: {max(history.history["val_accuracy"]):.4f}')
# Out:
# Mejor val_accuracy: 0.9599

# %% [markdown]
# ### 9. EVALUCACIÓN EN TEST

# %%
test_generator.reset()

test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)

predicciones = model.predict(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1
)
y_pred = np.argmax(predicciones, axis=1)
y_true = test_generator.classes

f1 = f1_score(y_true, y_pred, average='weighted')

print(f'\nTest Accuracy : {test_accuracy:.4f}')
print(f'Test Loss     : {test_loss:.4f}')
print(f'F1 Score      : {f1:.4f}')

nombres_clases = list(test_generator.class_indices.keys())
print('\n--- Reporte de clasificación ---')
print(classification_report(y_true, y_pred, target_names=nombres_clases))
# Out:
# 170/170 [==============================] - 246s 1s/step - loss: 0.1768 - accuracy: 0.9466
# 170/170 [==============================] - 250s 1s/step
#
# Test Accuracy : 0.9466
# Test Loss     : 0.1768
# F1 Score      : 0.9437
#
# --- Reporte de clasificación ---
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.87      0.98      0.93        63
#                                  Apple___Black_rot       0.89      1.00      0.94        62
#                           Apple___Cedar_apple_rust       0.96      1.00      0.98        27
#                                    Apple___healthy       0.88      0.98      0.93       164
#                                Blueberry___healthy       0.96      0.96      0.96       150
#           Cherry_(including_sour)___Powdery_mildew       1.00      0.99      1.00       105
#                  Cherry_(including_sour)___healthy       0.97      0.99      0.98        85
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       1.00      0.18      0.30        51
#                        Corn_(maize)___Common_rust_       0.99      1.00      1.00       119
#                Corn_(maize)___Northern_Leaf_Blight       0.71      0.98      0.82        98
#                             Corn_(maize)___healthy       1.00      1.00      1.00       116
#                                  Grape___Black_rot       0.87      0.98      0.92       118
#                       Grape___Esca_(Black_Measles)       1.00      0.83      0.91       138
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.97      0.98      0.98       107
#                                    Grape___healthy       0.95      1.00      0.98        42
#           Orange___Haunglongbing_(Citrus_greening)       1.00      1.00      1.00       550
#                             Peach___Bacterial_spot       0.99      0.96      0.97       229
#                                    Peach___healthy       1.00      0.97      0.99        36
#                      Pepper,_bell___Bacterial_spot       0.97      0.97      0.97        99
#                             Pepper,_bell___healthy       0.99      0.93      0.96       147
#                              Potato___Early_blight       0.92      0.98      0.95       100
#                               Potato___Late_blight       0.76      0.97      0.85       100
#                                   Potato___healthy       1.00      0.20      0.33        15
#                                Raspberry___healthy       0.97      0.89      0.93        37
#                                  Soybean___healthy       0.98      0.97      0.97       509
#                            Squash___Powdery_mildew       1.00      0.99      1.00       183
#                           Strawberry___Leaf_scorch       0.99      0.95      0.97       110
#                               Strawberry___healthy       0.93      0.96      0.95        45
#                            Tomato___Bacterial_spot       0.90      0.92      0.91       212
#                              Tomato___Early_blight       0.93      0.68      0.79       100
#                               Tomato___Late_blight       0.97      0.79      0.87       190
#                                 Tomato___Leaf_Mold       0.99      0.99      0.99        95
#                        Tomato___Septoria_leaf_spot       0.86      0.93      0.89       177
#      Tomato___Spider_mites Two-spotted_spider_mite       0.95      0.89      0.92       167
#                               Tomato___Target_Spot       0.81      0.91      0.86       140
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.99      0.99      0.99       535
#                       Tomato___Tomato_mosaic_virus       0.97      1.00      0.99        37
#                                   Tomato___healthy       0.94      1.00      0.97       159
#
#                                           accuracy                           0.95      5417
#                                          macro avg       0.94      0.91      0.91      5417
#                                       weighted avg       0.95      0.95      0.94      5417
